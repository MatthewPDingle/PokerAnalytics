# %% [markdown]
# # Flop C-Bet Explorer
#
# Use this notebook to explore how different flop continuation-bet sizes correlate with the bettor's made hand or draw strength. Edit the configuration cell to experiment with custom sizing buckets or category groupings.
#
# Workflow:
# 1. Adjust `BUCKETS`, `PRIMARY_GROUPS`, or `DRAW_FLAGS` below.
# 2. Rerun the helper cell and the summary cell to see the updated breakdown.
# 3. Optional: enable caching or convert events to a pandas DataFrame for ad-hoc filtering.
#
# > Buckets use left-inclusive, right-exclusive ranges (e.g. a 0.25 bet falls into [0.25, 0.40)).

# %%
from pathlib import Path
import os

def _locate_project_root() -> Path:
    current = Path().resolve()
    for candidate in (current, *current.parents):
        if (candidate / "AGENTS.md").exists():
            return candidate
    raise FileNotFoundError("Repository root not found from notebook location.")

PROJECT_ROOT = _locate_project_root()
del _locate_project_root

DB_CANDIDATES = [
    Path(r"T:\Dev\ignition\drivehud\drivehud.db"),
    Path("/mnt/t/Dev/ignition/drivehud/drivehud.db"),
    PROJECT_ROOT / "drivehud" / "drivehud.db",
]

for candidate in DB_CANDIDATES:
    if candidate.exists():
        DB_PATH = candidate
        break
else:
    checked = os.linesep.join(str(p) for p in DB_CANDIDATES)
    message = "Database not found. Checked:" + os.linesep + checked
    raise FileNotFoundError(message)

CACHE_PATH = PROJECT_ROOT / "analysis" / "cache" / "cbet_events.json"

if not DB_PATH.exists():
    raise FileNotFoundError(f"Database not found at {DB_PATH}")

# %%
import sys
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from analysis.cbet_utils import (
    BASE_PRIMARY_CATEGORIES,
    DEFAULT_DRAW_FLAGS,
    available_primary_categories,
    events_to_dataframe,
    load_cbet_events,
    summarize_events,
    response_events,
)
from analysis.turn_utils import (
    TURN_BUCKETS as TURN_BUCKETS_TURN,
    load_turn_events as load_turn_events_turn,
    turn_response_events as turn_response_events_turn,
)

# %%
# --- Configuration ---
RAW_BUCKET_BOUNDS = [
    (0.00, 0.25),
    (0.25, 0.40),
    (0.40, 0.60),
    (0.60, 0.80),
    (0.80, 1.00),
    (1.00, 1.25),
    (1.25, float("inf")),
]

def _bucket_label(low: float, high: float) -> str:
    if high == float("inf"):
        return f">={low:.2f}"
    return f"[{low:.2f}, {high:.2f})"

BUCKETS = [(low, high, _bucket_label(low, high)) for (low, high) in RAW_BUCKET_BOUNDS]
del _bucket_label

PRIMARY_GROUPS = {cat: [cat] for cat in BASE_PRIMARY_CATEGORIES}
DRAW_FLAGS = DEFAULT_DRAW_FLAGS.copy()

# Set to True to rebuild the cache after changing parsing logic.
FORCE_RELOAD = True

TURN_CACHE_PATH = PROJECT_ROOT / "analysis/cache/turn_events.json"
TURN_FORCE_RELOAD = False

# %%
events = load_cbet_events(DB_PATH, cache_path=CACHE_PATH, force=FORCE_RELOAD)
print(f"Loaded {len(events)} c-bet events.")
available_categories = available_primary_categories(events)
print("Observed primary categories:", ", ".join(available_categories))

try:
    turn_events = load_turn_events_turn(DB_PATH, cache_path=TURN_CACHE_PATH, force=TURN_FORCE_RELOAD)
    turn_responses = turn_response_events_turn(turn_events)
except FileNotFoundError:
    turn_events = []
    turn_responses = []
# Out:
# Loaded 5847 c-bet events.
# Observed primary categories: Air, Bottom Pair, Flush, Full House, Middle Pair, Overpair, Quads, Straight, Top Pair, Trips/Set, Two Pair, Underpair

# %%
import pandas as pd
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

DEFAULT_DROP_COLUMNS = {"Range", "Made Flush", "Made Straight"}

GROUPED_PRIMARY_ORDER = [
    ("Events", None),
    ("Air", ["Air"]),
    ("Weak Pair", ["Underpair", "Bottom Pair", "Middle Pair"]),
    ("Top Pair", ["Top Pair"]),
    ("Overpair", ["Overpair"]),
    ("Two Pair", ["Two Pair"]),
    ("Trips/Set", ["Trips/Set"]),
    ("Monster", ["Straight", "Flush", "Full House", "Quads"]),
    ("Draw", ["Flush Draw", "OESD/DG"]),
]

RESPONSE_GROUP_ORDER = [
    ("Events", None),
    ("Fold", ["Fold"]),
    ("Call", ["Call"]),
    ("Raise", ["Raise"]),
    ("Continue", ["Call", "Raise"]),
]

def _gradient_cmap(base_color: str) -> LinearSegmentedColormap:
    name = f'gradient_{base_color.strip("#")}'
    return LinearSegmentedColormap.from_list(name, ['#ffffff', base_color])

def _summary_records_to_df(records, drop_columns=None):
    if not records:
        return pd.DataFrame()
    df = pd.DataFrame(records)
    drop_columns = drop_columns or set()
    for col in drop_columns:
        if col in df.columns:
            df = df.drop(columns=[col])
    df = df.set_index("Bucket").T
    df = df.apply(pd.to_numeric, errors="coerce")
    return df

def _style_heatmap(df, title, base_color="#1f77b4", fmt="{:.1f}", special_columns=None):
    if df.empty:
        return None
    data_index = df.index.difference(["Events"])
    styled = df.style.format(fmt)
    if not data_index.empty:
        styled = styled.background_gradient(
            cmap=_gradient_cmap(base_color),
            axis=None,
            subset=pd.IndexSlice[data_index, :]
        )
    if special_columns:
        first = special_columns[0]
        if first in df.columns:
            col_idx = df.columns.get_loc(first)
            styles = [
                {
                    'selector': f'th.col_heading.level0.col{col_idx}',
                    'props': [('border-left', '2px solid #64748b')]
                },
                {
                    'selector': f'td.col{col_idx}',
                    'props': [('border-left', '2px solid #64748b')]
                },
            ]
            styled = styled.set_table_styles(styles, overwrite=False)
    return styled.set_caption(title)

def _aggregate_grouped(df, group_order):
    rows = []
    for label, members in group_order:
        if members is None:
            if "Events" in df.index:
                rows.append((label, df.loc["Events"]))
            continue
        available = [member for member in members if member in df.index]
        if not available:
            continue
        rows.append((label, df.loc[available].sum()))
    if not rows:
        return pd.DataFrame()
    data = pd.DataFrame([series for _, series in rows], index=[label for label, _ in rows])
    return data

def display_heatmap_tables(summary_records, title, *, base_color="#1f77b4", group_color="#2ca25f", special_rows=None):
    records = list(summary_records)
    special_columns = []
    if special_rows:
        records.extend(special_rows)
        special_columns = [row['Bucket'] for row in special_rows if row.get('Bucket')]
    base_df = _summary_records_to_df(records, DEFAULT_DROP_COLUMNS)
    styled = _style_heatmap(base_df, title, base_color=base_color, special_columns=special_columns)
    if styled is not None:
        display(styled)
    grouped_df = _aggregate_grouped(base_df, GROUPED_PRIMARY_ORDER)
    styled_grouped = _style_heatmap(grouped_df, f"{title} (Grouped)", base_color=group_color, special_columns=special_columns)
    if styled_grouped is not None:
        display(styled_grouped)

def summarize_responses_df(responses_df, buckets):
    summary = []
    for low, high, label in buckets:
        subset = responses_df[(responses_df['ratio'] >= low) & (responses_df['ratio'] < high)]
        if subset.empty:
            summary.append({
                'Bucket': label,
                'Events': 0,
                'Fold': 0.0,
                'Call': 0.0,
                'Raise': 0.0,
                'Continue': 0.0,
            })
            continue
        events_count = len(subset)
        response_counts = subset['response'].value_counts()
        continue_count = int(response_counts.get('Call', 0) + response_counts.get('Raise', 0))
        summary.append({
            'Bucket': label,
            'Events': events_count,
            'Fold': response_counts.get('Fold', 0) / events_count * 100,
            'Call': response_counts.get('Call', 0) / events_count * 100,
            'Raise': response_counts.get('Raise', 0) / events_count * 100,
            'Continue': continue_count / events_count * 100,
        })
    return summary

# %%
if 'df' not in locals():
    df = events_to_dataframe(events)

df = df.copy()
bucket_edges = [bucket[0] for bucket in BUCKETS] + [BUCKETS[-1][1]]
bucket_labels = [bucket[2] for bucket in BUCKETS]
df['bucket'] = pd.cut(df['ratio'], bins=bucket_edges, labels=bucket_labels, right=False, include_lowest=True)

def _filtered_primary_groups(subset_records):
    available = {event['primary'] for event in subset_records}
    groups = {}
    for name, members in PRIMARY_GROUPS.items():
        members_in_subset = [cat for cat in members if cat in available]
        if members_in_subset:
            groups[name] = members_in_subset
    if not groups:
        for cat in sorted(available):
            groups[cat] = [cat]
    return groups

def _build_special_rows(subset_records):
    specials = []
    special_specs = [
        ("All-In", lambda event: event.get("is_all_in")),
        ("1 BB", lambda event: event.get("is_one_bb")),
    ]
    for label, predicate in special_specs:
        filtered = [event for event in subset_records if predicate(event)]
        if not filtered:
            continue
        groups = _filtered_primary_groups(filtered)
        specials.extend(
            summarize_events(
                filtered,
                [(0.0, float("inf"), label)],
                groups,
                DRAW_FLAGS,
            )
        )
    return specials

def display_heatmap_for_mask(mask, title, base_color='#1f77b4', group_color='#2ca25f'):
    subset = df.loc[mask]
    subset_records = subset.to_dict('records')
    if not subset_records:
        display(pd.DataFrame({'Bucket': bucket_labels, 'Message': 'No events'}))
        return
    groups = _filtered_primary_groups(subset_records)
    summary_subset = summarize_events(subset_records, BUCKETS, groups, DRAW_FLAGS)
    special_rows = _build_special_rows(subset_records)
    display_heatmap_tables(
        summary_subset,
        title,
        base_color=base_color,
        group_color=group_color,
        special_rows=special_rows,
    )

# %%
summary_records = summarize_events(events, BUCKETS, PRIMARY_GROUPS, DRAW_FLAGS)
special_rows = _build_special_rows(events)
display_heatmap_tables(summary_records, "All C-Bets", special_rows=special_rows)
# Out:
# <style type="text/css">
# #T_5cab0 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_5cab0 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_5cab0_row1_col0 {
#   background-color: #3283ba;
#   color: #f1f1f1;
# }
# #T_5cab0_row1_col1 {
#   background-color: #3383bb;
#   color: #f1f1f1;
# }
# #T_5cab0_row1_col2 {
#   background-color: #448dc0;
#   color: #f1f1f1;
# }
# #T_5cab0_row1_col3 {
#   background-color: #5e9dc9;
#   color: #f1f1f1;
# }
# #T_5cab0_row1_col4 {
#   background-color: #78add2;
#   color: #f1f1f1;
# }
# #T_5cab0_row1_col5 {
#   background-color: #3182ba;
#   color: #f1f1f1;
# }
# #T_5cab0_row1_col6 {
#   background-color: #5296c5;
#   color: #f1f1f1;
# }
# #T_5cab0_row1_col7 {
#   background-color: #6fa8cf;
#   color: #f1f1f1;
# }
# #T_5cab0_row1_col8 {
#   background-color: #1f77b4;
#   color: #f1f1f1;
# }
# #T_5cab0_row2_col0 {
#   background-color: #d2e4f0;
#   color: #000000;
# }
# #T_5cab0_row2_col1, #T_5cab0_row2_col8, #T_5cab0_row5_col8, #T_5cab0_row7_col7 {
#   background-color: #d5e5f1;
#   color: #000000;
# }
# #T_5cab0_row2_col2 {
#   background-color: #d3e4f0;
#   color: #000000;
# }
# #T_5cab0_row2_col3, #T_5cab0_row2_col4, #T_5cab0_row7_col0 {
#   background-color: #dfecf4;
#   color: #000000;
# }
# #T_5cab0_row2_col5, #T_5cab0_row4_col0, #T_5cab0_row7_col5, #T_5cab0_row13_col5, #T_5cab0_row14_col0, #T_5cab0_row14_col5 {
#   background-color: #e6f0f6;
#   color: #000000;
# }
# #T_5cab0_row2_col6, #T_5cab0_row4_col2, #T_5cab0_row4_col4, #T_5cab0_row7_col1 {
#   background-color: #e0ecf5;
#   color: #000000;
# }
# #T_5cab0_row2_col7 {
#   background-color: #d0e3ef;
#   color: #000000;
# }
# #T_5cab0_row3_col0, #T_5cab0_row4_col3 {
#   background-color: #f2f7fb;
#   color: #000000;
# }
# #T_5cab0_row3_col1 {
#   background-color: #f5f9fc;
#   color: #000000;
# }
# #T_5cab0_row3_col2, #T_5cab0_row3_col3 {
#   background-color: #f4f8fb;
#   color: #000000;
# }
# #T_5cab0_row3_col4, #T_5cab0_row8_col2 {
#   background-color: #f4f9fb;
#   color: #000000;
# }
# #T_5cab0_row3_col5, #T_5cab0_row3_col6, #T_5cab0_row4_col6, #T_5cab0_row8_col5 {
#   background-color: #f3f8fb;
#   color: #000000;
# }
# #T_5cab0_row3_col7, #T_5cab0_row11_col6 {
#   background-color: #f9fbfd;
#   color: #000000;
# }
# #T_5cab0_row3_col8, #T_5cab0_row4_col1, #T_5cab0_row8_col0, #T_5cab0_row13_col0 {
#   background-color: #e7f1f7;
#   color: #000000;
# }
# #T_5cab0_row4_col5, #T_5cab0_row4_col8, #T_5cab0_row5_col5 {
#   background-color: #d8e8f2;
#   color: #000000;
# }
# #T_5cab0_row4_col7, #T_5cab0_row13_col4, #T_5cab0_row14_col2 {
#   background-color: #e9f2f8;
#   color: #000000;
# }
# #T_5cab0_row5_col0 {
#   background-color: #c9deed;
#   color: #000000;
# }
# #T_5cab0_row5_col1, #T_5cab0_row5_col2 {
#   background-color: #bad5e8;
#   color: #000000;
# }
# #T_5cab0_row5_col3 {
#   background-color: #a6c9e1;
#   color: #000000;
# }
# #T_5cab0_row5_col4 {
#   background-color: #a5c9e1;
#   color: #000000;
# }
# #T_5cab0_row5_col6 {
#   background-color: #b1d0e5;
#   color: #000000;
# }
# #T_5cab0_row5_col7 {
#   background-color: #b5d2e6;
#   color: #000000;
# }
# #T_5cab0_row6_col0, #T_5cab0_row6_col1 {
#   background-color: #ebf3f8;
#   color: #000000;
# }
# #T_5cab0_row6_col2, #T_5cab0_row13_col1 {
#   background-color: #e3eef6;
#   color: #000000;
# }
# #T_5cab0_row6_col3, #T_5cab0_row6_col6 {
#   background-color: #c7ddec;
#   color: #000000;
# }
# #T_5cab0_row6_col4, #T_5cab0_row6_col7 {
#   background-color: #c1d9ea;
#   color: #000000;
# }
# #T_5cab0_row6_col5 {
#   background-color: #bfd8ea;
#   color: #000000;
# }
# #T_5cab0_row6_col8, #T_5cab0_row10_col8 {
#   background-color: #fafcfd;
#   color: #000000;
# }
# #T_5cab0_row7_col2 {
#   background-color: #dae9f3;
#   color: #000000;
# }
# #T_5cab0_row7_col3 {
#   background-color: #d7e7f2;
#   color: #000000;
# }
# #T_5cab0_row7_col4 {
#   background-color: #d4e5f1;
#   color: #000000;
# }
# #T_5cab0_row7_col6, #T_5cab0_row13_col6 {
#   background-color: #d7e6f1;
#   color: #000000;
# }
# #T_5cab0_row7_col8, #T_5cab0_row14_col3 {
#   background-color: #eaf2f8;
#   color: #000000;
# }
# #T_5cab0_row8_col1, #T_5cab0_row8_col7, #T_5cab0_row8_col8, #T_5cab0_row14_col7 {
#   background-color: #edf4f9;
#   color: #000000;
# }
# #T_5cab0_row8_col3, #T_5cab0_row14_col1 {
#   background-color: #eff5fa;
#   color: #000000;
# }
# #T_5cab0_row8_col4 {
#   background-color: #f1f6fa;
#   color: #000000;
# }
# #T_5cab0_row8_col6 {
#   background-color: #f6fafc;
#   color: #000000;
# }
# #T_5cab0_row9_col0, #T_5cab0_row9_col5, #T_5cab0_row10_col2, #T_5cab0_row10_col3, #T_5cab0_row10_col5, #T_5cab0_row10_col6, #T_5cab0_row11_col2, #T_5cab0_row11_col3, #T_5cab0_row11_col5, #T_5cab0_row12_col0, #T_5cab0_row12_col1, #T_5cab0_row12_col2, #T_5cab0_row12_col3, #T_5cab0_row12_col4, #T_5cab0_row12_col5, #T_5cab0_row12_col6 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_5cab0_row9_col1, #T_5cab0_row9_col7, #T_5cab0_row10_col0 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_5cab0_row9_col2, #T_5cab0_row9_col3 {
#   background-color: #fbfdfe;
#   color: #000000;
# }
# #T_5cab0_row9_col4, #T_5cab0_row10_col1, #T_5cab0_row11_col0, #T_5cab0_row11_col1, #T_5cab0_row11_col4 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_5cab0_row9_col6, #T_5cab0_row10_col4 {
#   background-color: #fcfdfe;
#   color: #000000;
# }
# #T_5cab0_row9_col8, #T_5cab0_row10_col7, #T_5cab0_row11_col8, #T_5cab0_row12_col7, #T_5cab0_row12_col8 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_5cab0_row11_col7 {
#   background-color: #fbfcfe;
#   color: #000000;
# }
# #T_5cab0_row13_col2 {
#   background-color: #e2edf5;
#   color: #000000;
# }
# #T_5cab0_row13_col3, #T_5cab0_row14_col4 {
#   background-color: #e5eff6;
#   color: #000000;
# }
# #T_5cab0_row13_col7 {
#   background-color: #dbe9f3;
#   color: #000000;
# }
# #T_5cab0_row13_col8, #T_5cab0_row14_col8 {
#   background-color: #e1edf5;
#   color: #000000;
# }
# #T_5cab0_row14_col6 {
#   background-color: #f0f6fa;
#   color: #000000;
# }
# </style>
# <table id="T_5cab0">
#   <caption>All C-Bets</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_5cab0_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_5cab0_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_5cab0_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_5cab0_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_5cab0_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_5cab0_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_5cab0_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_5cab0_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_5cab0_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cab0_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_5cab0_row0_col0" class="data row0 col0" >410.0</td>
#       <td id="T_5cab0_row0_col1" class="data row0 col1" >2367.0</td>
#       <td id="T_5cab0_row0_col2" class="data row0 col2" >1760.0</td>
#       <td id="T_5cab0_row0_col3" class="data row0 col3" >741.0</td>
#       <td id="T_5cab0_row0_col4" class="data row0 col4" >401.0</td>
#       <td id="T_5cab0_row0_col5" class="data row0 col5" >33.0</td>
#       <td id="T_5cab0_row0_col6" class="data row0 col6" >135.0</td>
#       <td id="T_5cab0_row0_col7" class="data row0 col7" >189.0</td>
#       <td id="T_5cab0_row0_col8" class="data row0 col8" >140.0</td>
#     </tr>
#     <tr>
#       <th id="T_5cab0_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_5cab0_row1_col0" class="data row1 col0" >48.3</td>
#       <td id="T_5cab0_row1_col1" class="data row1 col1" >48.0</td>
#       <td id="T_5cab0_row1_col2" class="data row1 col2" >44.0</td>
#       <td id="T_5cab0_row1_col3" class="data row1 col3" >37.8</td>
#       <td id="T_5cab0_row1_col4" class="data row1 col4" >31.9</td>
#       <td id="T_5cab0_row1_col5" class="data row1 col5" >48.5</td>
#       <td id="T_5cab0_row1_col6" class="data row1 col6" >40.7</td>
#       <td id="T_5cab0_row1_col7" class="data row1 col7" >33.9</td>
#       <td id="T_5cab0_row1_col8" class="data row1 col8" >52.9</td>
#     </tr>
#     <tr>
#       <th id="T_5cab0_level0_row2" class="row_h
# <style type="text/css">
# #T_61240 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_61240 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_61240_row1_col0 {
#   background-color: #3eaa6d;
#   color: #f1f1f1;
# }
# #T_61240_row1_col1 {
#   background-color: #3faa6d;
#   color: #f1f1f1;
# }
# #T_61240_row1_col2 {
#   background-color: #4fb179;
#   color: #f1f1f1;
# }
# #T_61240_row1_col3 {
#   background-color: #68bc8c;
#   color: #000000;
# }
# #T_61240_row1_col4 {
#   background-color: #80c79e;
#   color: #000000;
# }
# #T_61240_row1_col5 {
#   background-color: #3daa6c;
#   color: #f1f1f1;
# }
# #T_61240_row1_col6 {
#   background-color: #5cb783;
#   color: #f1f1f1;
# }
# #T_61240_row1_col7 {
#   background-color: #77c398;
#   color: #000000;
# }
# #T_61240_row1_col8 {
#   background-color: #2ca25f;
#   color: #f1f1f1;
# }
# #T_61240_row2_col0 {
#   background-color: #b0dcc3;
#   color: #000000;
# }
# #T_61240_row2_col1, #T_61240_row2_col7 {
#   background-color: #b7dfc8;
#   color: #000000;
# }
# #T_61240_row2_col2 {
#   background-color: #addbc1;
#   color: #000000;
# }
# #T_61240_row2_col3 {
#   background-color: #c8e7d6;
#   color: #000000;
# }
# #T_61240_row2_col4 {
#   background-color: #bae1cb;
#   color: #000000;
# }
# #T_61240_row2_col5 {
#   background-color: #b6dfc8;
#   color: #000000;
# }
# #T_61240_row2_col6, #T_61240_row4_col3, #T_61240_row4_col6, #T_61240_row8_col6 {
#   background-color: #cae8d7;
#   color: #000000;
# }
# #T_61240_row2_col8 {
#   background-color: #9bd3b3;
#   color: #000000;
# }
# #T_61240_row3_col0 {
#   background-color: #cce8d8;
#   color: #000000;
# }
# #T_61240_row3_col1 {
#   background-color: #bee2cd;
#   color: #000000;
# }
# #T_61240_row3_col2 {
#   background-color: #bee3ce;
#   color: #000000;
# }
# #T_61240_row3_col3 {
#   background-color: #abdac0;
#   color: #000000;
# }
# #T_61240_row3_col4 {
#   background-color: #abdabf;
#   color: #000000;
# }
# #T_61240_row3_col5 {
#   background-color: #dbefe3;
#   color: #000000;
# }
# #T_61240_row3_col6 {
#   background-color: #b5dfc7;
#   color: #000000;
# }
# #T_61240_row3_col7 {
#   background-color: #b9e0ca;
#   color: #000000;
# }
# #T_61240_row3_col8, #T_61240_row5_col7 {
#   background-color: #d7ede1;
#   color: #000000;
# }
# #T_61240_row4_col0, #T_61240_row4_col1 {
#   background-color: #ecf7f1;
#   color: #000000;
# }
# #T_61240_row4_col2 {
#   background-color: #e5f3eb;
#   color: #000000;
# }
# #T_61240_row4_col4, #T_61240_row4_col7 {
#   background-color: #c4e5d2;
#   color: #000000;
# }
# #T_61240_row4_col5 {
#   background-color: #c3e4d1;
#   color: #000000;
# }
# #T_61240_row4_col8, #T_61240_row7_col4, #T_61240_row7_col8 {
#   background-color: #fafdfb;
#   color: #000000;
# }
# #T_61240_row5_col0 {
#   background-color: #e1f2e8;
#   color: #000000;
# }
# #T_61240_row5_col1 {
#   background-color: #e2f2e9;
#   color: #000000;
# }
# #T_61240_row5_col2 {
#   background-color: #dcf0e5;
#   color: #000000;
# }
# #T_61240_row5_col3 {
#   background-color: #daefe3;
#   color: #000000;
# }
# #T_61240_row5_col4 {
#   background-color: #d6ede0;
#   color: #000000;
# }
# #T_61240_row5_col5 {
#   background-color: #e7f4ed;
#   color: #000000;
# }
# #T_61240_row5_col6 {
#   background-color: #d9eee2;
#   color: #000000;
# }
# #T_61240_row5_col8 {
#   background-color: #ebf6f0;
#   color: #000000;
# }
# #T_61240_row6_col0 {
#   background-color: #e9f5ee;
#   color: #000000;
# }
# #T_61240_row6_col1, #T_61240_row6_col7, #T_61240_row6_col8 {
#   background-color: #eef8f2;
#   color: #000000;
# }
# #T_61240_row6_col2 {
#   background-color: #f5fbf7;
#   color: #000000;
# }
# #T_61240_row6_col3 {
#   background-color: #f0f8f4;
#   color: #000000;
# }
# #T_61240_row6_col4 {
#   background-color: #f2f9f5;
#   color: #000000;
# }
# #T_61240_row6_col5 {
#   background-color: #f3faf6;
#   color: #000000;
# }
# #T_61240_row6_col6, #T_61240_row7_col6 {
#   background-color: #f7fbf9;
#   color: #000000;
# }
# #T_61240_row7_col0 {
#   background-color: #fdfefd;
#   color: #000000;
# }
# #T_61240_row7_col1, #T_61240_row7_col2, #T_61240_row7_col3 {
#   background-color: #fbfdfc;
#   color: #000000;
# }
# #T_61240_row7_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_61240_row7_col7 {
#   background-color: #f9fcfb;
#   color: #000000;
# }
# #T_61240_row8_col0, #T_61240_row8_col4 {
#   background-color: #d1ebdc;
#   color: #000000;
# }
# #T_61240_row8_col1 {
#   background-color: #d5ecdf;
#   color: #000000;
# }
# #T_61240_row8_col2 {
#   background-color: #cee9da;
#   color: #000000;
# }
# #T_61240_row8_col3 {
#   background-color: #d2ebdd;
#   color: #000000;
# }
# #T_61240_row8_col5 {
#   background-color: #cfeadb;
#   color: #000000;
# }
# #T_61240_row8_col7 {
#   background-color: #cde9d9;
#   color: #000000;
# }
# #T_61240_row8_col8 {
#   background-color: #c6e6d4;
#   color: #000000;
# }
# </style>
# <table id="T_61240">
#   <caption>All C-Bets (Grouped)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_61240_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_61240_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_61240_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_61240_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_61240_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_61240_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_61240_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_61240_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_61240_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61240_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_61240_row0_col0" class="data row0 col0" >410.0</td>
#       <td id="T_61240_row0_col1" class="data row0 col1" >2367.0</td>
#       <td id="T_61240_row0_col2" class="data row0 col2" >1760.0</td>
#       <td id="T_61240_row0_col3" class="data row0 col3" >741.0</td>
#       <td id="T_61240_row0_col4" class="data row0 col4" >401.0</td>
#       <td id="T_61240_row0_col5" class="data row0 col5" >33.0</td>
#       <td id="T_61240_row0_col6" class="data row0 col6" >135.0</td>
#       <td id="T_61240_row0_col7" class="data row0 col7" >189.0</td>
#       <td id="T_61240_row0_col8" class="data row0 col8" >140.0</td>
#     </tr>
#     <tr>
#       <th id="T_61240_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_61240_row1_col0" class="data row1 col0" >48.3</td>
#       <td id="T_61240_row1_col1" class="data row1 col1" >48.0</td>
#       <td id="T_61240_row1_col2" class="data row1 col2" >44.0</td>
#       <td id="T_61240_row1_col3" class="data row1 col3" >37.8</td>
#       <td id="T_61240_row1_col4" class="data row1 col4" >31.9</td>
#       <td id="T_61240_row1_col5" class="data row1 col5" >48.5</td>
#       <td id="T_61240_row1_col6" class="data row1 col6" >40.7</td>
#       <td id="T_61240_row1_col7" class="data row1 col7" >33.9</td>
#       <td id="T_61240_row1_col8" class="data row1 col8" >52.9</td>
#     </tr>
#     <tr>
#       <th id="T_61240_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_61240_row2_col0" class="data row2 col0" >20.0</td>
#       <td id="T_61240_row2_col1" class="data row2 col1" >18.1</td>
#       <td id="T_61240_row2_col2" class="data row2 col2" >20.5</td>
#       <td id="T_61240_row2_col3" class="data row2 col3" >13.6</td>
#       <td id="T_61240_row2_col4" class="data row2 col4" >17.2</td>
#       <td id="T_61240_row2_col5" class="data row2 col5" >18.2</td>
#       <td id="T_61240_row2_col6" class="data row2 col6" >13.3</td>
#       <td id="T_61240_row2_col7" class="data row2 col7" >18.0</td>
#       <td id="T_61240_row2_col8" class="data row2 col8" >25.0</td>
#     </tr>
#     <tr>
#       <th id="T_61240_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_61240_row3_col0" class="data row3 col0" >12.9</td>
#       <td id="T_61240_row3_col1" class="data row3 col1" >16.5</td>
#       <td id="T_61240_row3_col2" class="data row3 col2" >16.1</td>
#       <td id="T_61240_row3_col3" class="data row3 col3" >20.9</td>
#       <td id="T_61240_row3_col4" class="data row3 col4" >21.2</td>
#       <td id="T_61240_row3_col5" class="data row3 col5" >9.1</td>
#       <td id="T_61240_ro

# %%
display_heatmap_for_mask(df['in_position'], 'C-Bets In Position', base_color='#1f77b4', group_color='#2ca25f')
display_heatmap_for_mask(~df['in_position'], 'C-Bets Out of Position', base_color='#d95f02', group_color='#7570b3')
# Out:
# <style type="text/css">
# #T_ede03 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_ede03 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_ede03_row1_col0 {
#   background-color: #277cb7;
#   color: #f1f1f1;
# }
# #T_ede03_row1_col1 {
#   background-color: #2a7db8;
#   color: #f1f1f1;
# }
# #T_ede03_row1_col2 {
#   background-color: #3f8abf;
#   color: #f1f1f1;
# }
# #T_ede03_row1_col3 {
#   background-color: #5d9dc9;
#   color: #f1f1f1;
# }
# #T_ede03_row1_col4 {
#   background-color: #7fb1d4;
#   color: #f1f1f1;
# }
# #T_ede03_row1_col5 {
#   background-color: #297db7;
#   color: #f1f1f1;
# }
# #T_ede03_row1_col6 {
#   background-color: #478fc1;
#   color: #f1f1f1;
# }
# #T_ede03_row1_col7 {
#   background-color: #7aaed3;
#   color: #f1f1f1;
# }
# #T_ede03_row1_col8 {
#   background-color: #1f77b4;
#   color: #f1f1f1;
# }
# #T_ede03_row2_col0 {
#   background-color: #cde1ee;
#   color: #000000;
# }
# #T_ede03_row2_col1 {
#   background-color: #d1e3f0;
#   color: #000000;
# }
# #T_ede03_row2_col2, #T_ede03_row13_col6 {
#   background-color: #d0e2ef;
#   color: #000000;
# }
# #T_ede03_row2_col3, #T_ede03_row13_col7 {
#   background-color: #dbe9f3;
#   color: #000000;
# }
# #T_ede03_row2_col4 {
#   background-color: #dceaf3;
#   color: #000000;
# }
# #T_ede03_row2_col5, #T_ede03_row3_col5, #T_ede03_row5_col5, #T_ede03_row8_col5, #T_ede03_row14_col5 {
#   background-color: #ecf3f9;
#   color: #000000;
# }
# #T_ede03_row2_col6, #T_ede03_row7_col6 {
#   background-color: #dae9f3;
#   color: #000000;
# }
# #T_ede03_row2_col7 {
#   background-color: #bdd7e9;
#   color: #000000;
# }
# #T_ede03_row2_col8, #T_ede03_row5_col7, #T_ede03_row6_col3 {
#   background-color: #c9deed;
#   color: #000000;
# }
# #T_ede03_row3_col0 {
#   background-color: #f5f9fc;
#   color: #000000;
# }
# #T_ede03_row3_col1, #T_ede03_row3_col2, #T_ede03_row8_col2 {
#   background-color: #f4f8fb;
#   color: #000000;
# }
# #T_ede03_row3_col3, #T_ede03_row8_col3 {
#   background-color: #f3f8fb;
#   color: #000000;
# }
# #T_ede03_row3_col4 {
#   background-color: #f6fafc;
#   color: #000000;
# }
# #T_ede03_row3_col6 {
#   background-color: #f4f9fb;
#   color: #000000;
# }
# #T_ede03_row3_col7 {
#   background-color: #f8fbfd;
#   color: #000000;
# }
# #T_ede03_row3_col8, #T_ede03_row4_col0, #T_ede03_row4_col1 {
#   background-color: #e4eef6;
#   color: #000000;
# }
# #T_ede03_row4_col2, #T_ede03_row7_col0 {
#   background-color: #ddeaf4;
#   color: #000000;
# }
# #T_ede03_row4_col3, #T_ede03_row8_col6, #T_ede03_row14_col1 {
#   background-color: #eff5fa;
#   color: #000000;
# }
# #T_ede03_row4_col4 {
#   background-color: #d9e8f2;
#   color: #000000;
# }
# #T_ede03_row4_col5, #T_ede03_row7_col5 {
#   background-color: #d8e8f2;
#   color: #000000;
# }
# #T_ede03_row4_col6, #T_ede03_row9_col6, #T_ede03_row11_col6 {
#   background-color: #fafcfd;
#   color: #000000;
# }
# #T_ede03_row4_col7, #T_ede03_row13_col4 {
#   background-color: #e9f2f8;
#   color: #000000;
# }
# #T_ede03_row4_col8, #T_ede03_row5_col8 {
#   background-color: #d7e6f1;
#   color: #000000;
# }
# #T_ede03_row5_col0 {
#   background-color: #c3dbeb;
#   color: #000000;
# }
# #T_ede03_row5_col1 {
#   background-color: #b3d1e6;
#   color: #000000;
# }
# #T_ede03_row5_col2 {
#   background-color: #b7d3e7;
#   color: #000000;
# }
# #T_ede03_row5_col3 {
#   background-color: #95bedb;
#   color: #000000;
# }
# #T_ede03_row5_col4 {
#   background-color: #9dc4de;
#   color: #000000;
# }
# #T_ede03_row5_col6 {
#   background-color: #c0d9ea;
#   color: #000000;
# }
# #T_ede03_row6_col0, #T_ede03_row14_col6 {
#   background-color: #eaf2f8;
#   color: #000000;
# }
# #T_ede03_row6_col1, #T_ede03_row8_col1, #T_ede03_row8_col4, #T_ede03_row14_col7 {
#   background-color: #edf4f9;
#   color: #000000;
# }
# #T_ede03_row6_col2 {
#   background-color: #e0ecf5;
#   color: #000000;
# }
# #T_ede03_row6_col4 {
#   background-color: #c2daea;
#   color: #000000;
# }
# #T_ede03_row6_col5 {
#   background-color: #b1d0e5;
#   color: #000000;
# }
# #T_ede03_row6_col6, #T_ede03_row6_col7 {
#   background-color: #abcce3;
#   color: #000000;
# }
# #T_ede03_row6_col8, #T_ede03_row9_col8, #T_ede03_row10_col7, #T_ede03_row11_col8, #T_ede03_row12_col7, #T_ede03_row12_col8 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ede03_row7_col1, #T_ede03_row13_col2 {
#   background-color: #dfecf4;
#   color: #000000;
# }
# #T_ede03_row7_col2 {
#   background-color: #d7e7f2;
#   color: #000000;
# }
# #T_ede03_row7_col3 {
#   background-color: #d4e5f1;
#   color: #000000;
# }
# #T_ede03_row7_col4 {
#   background-color: #cadfed;
#   color: #000000;
# }
# #T_ede03_row7_col7 {
#   background-color: #d3e4f0;
#   color: #000000;
# }
# #T_ede03_row7_col8, #T_ede03_row13_col8, #T_ede03_row14_col8 {
#   background-color: #deebf4;
#   color: #000000;
# }
# #T_ede03_row8_col0, #T_ede03_row14_col2 {
#   background-color: #e6f0f7;
#   color: #000000;
# }
# #T_ede03_row8_col7, #T_ede03_row13_col0, #T_ede03_row14_col0 {
#   background-color: #e2edf5;
#   color: #000000;
# }
# #T_ede03_row8_col8, #T_ede03_row10_col8 {
#   background-color: #f2f7fb;
#   color: #000000;
# }
# #T_ede03_row9_col0, #T_ede03_row9_col5, #T_ede03_row10_col1, #T_ede03_row10_col2, #T_ede03_row10_col3, #T_ede03_row10_col5, #T_ede03_row10_col6, #T_ede03_row11_col0, #T_ede03_row11_col2, #T_ede03_row11_col3, #T_ede03_row11_col4, #T_ede03_row11_col5, #T_ede03_row12_col0, #T_ede03_row12_col1, #T_ede03_row12_col2, #T_ede03_row12_col3, #T_ede03_row12_col4, #T_ede03_row12_col5, #T_ede03_row12_col6, #T_ede03_row13_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_ede03_row9_col1, #T_ede03_row9_col4 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_ede03_row9_col2, #T_ede03_row9_col3, #T_ede03_row9_col7, #T_ede03_row10_col0, #T_ede03_row10_col4, #T_ede03_row11_col7 {
#   background-color: #fbfdfe;
#   color: #000000;
# }
# #T_ede03_row11_col1 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_ede03_row13_col1 {
#   background-color: #e1edf5;
#   color: #000000;
# }
# #T_ede03_row13_col3 {
#   background-color: #e3eef6;
#   color: #000000;
# }
# #T_ede03_row14_col3, #T_ede03_row14_col4 {
#   background-color: #e7f1f7;
#   color: #000000;
# }
# </style>
# <table id="T_ede03">
#   <caption>C-Bets In Position</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_ede03_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_ede03_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_ede03_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_ede03_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_ede03_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_ede03_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_ede03_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_ede03_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_ede03_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ede03_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_ede03_row0_col0" class="data row0 col0" >231.0</td>
#       <td id="T_ede03_row0_col1" class="data row0 col1" >1592.0</td>
#       <td id="T_ede03_row0_col2" class="data row0 col2" >1144.0</td>
#       <td id="T_ede03_row0_col3" class="data row0 col3" >490.0</td>
#       <td id="T_ede03_row0_col4" class="data row0 col4" >238.0</td>
#       <td id="T_ede03_row0_col5" class="data row0 col5" >23.0</td>
#       <td id="T_ede03_row0_col6" class="data row0 col6" >85.0</td>
#       <td id="T_ede03_row0_col7" class="data row0 col7" >122.0</td>
#       <td id="T_ede03_row0_col8" class="data row0 col8" >66.0</td>
#     </tr>
#     <tr>
#       <th id="T_ede03_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_ede03_row1_col0" class="data row1 col0" >48.1</td>
#       <td id="T_ede03_row1_col1" class="data row1 col1" >47.6</td>
#       <td id="T_ede03_row1_col2" class="data row1 col2" >42.9</td>
#       <td id="T_ede03_row1_col3" class="data row1 col3" >36.1</td>
#       <td id="T_ede03_row1_col4" class="data row1 col4" >28.6</td>
#       <td id="T_ede03_row1_col5" class="data row1 col5" >47.8</td>
#       <td id="T_ede03_row1_col6" class="data row1 col6" >41.2</td>
#       <td id="T_ede03_row1_col7" class="data
# <style type="text/css">
# #T_5c472 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_5c472 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_5c472_row1_col0 {
#   background-color: #33a565;
#   color: #f1f1f1;
# }
# #T_5c472_row1_col1 {
#   background-color: #36a667;
#   color: #f1f1f1;
# }
# #T_5c472_row1_col2 {
#   background-color: #4aaf76;
#   color: #f1f1f1;
# }
# #T_5c472_row1_col3 {
#   background-color: #67bc8c;
#   color: #f1f1f1;
# }
# #T_5c472_row1_col4 {
#   background-color: #86caa3;
#   color: #000000;
# }
# #T_5c472_row1_col5 {
#   background-color: #35a666;
#   color: #f1f1f1;
# }
# #T_5c472_row1_col6 {
#   background-color: #51b27b;
#   color: #f1f1f1;
# }
# #T_5c472_row1_col7 {
#   background-color: #82c8a0;
#   color: #000000;
# }
# #T_5c472_row1_col8 {
#   background-color: #2ca25f;
#   color: #f1f1f1;
# }
# #T_5c472_row2_col0 {
#   background-color: #addbc1;
#   color: #000000;
# }
# #T_5c472_row2_col1 {
#   background-color: #aedbc2;
#   color: #000000;
# }
# #T_5c472_row2_col2 {
#   background-color: #a6d8bc;
#   color: #000000;
# }
# #T_5c472_row2_col3 {
#   background-color: #c1e4d0;
#   color: #000000;
# }
# #T_5c472_row2_col4 {
#   background-color: #b1ddc4;
#   color: #000000;
# }
# #T_5c472_row2_col5, #T_5c472_row4_col5 {
#   background-color: #b5dfc7;
#   color: #000000;
# }
# #T_5c472_row2_col6, #T_5c472_row5_col4 {
#   background-color: #cde9d9;
#   color: #000000;
# }
# #T_5c472_row2_col7 {
#   background-color: #a5d7bb;
#   color: #000000;
# }
# #T_5c472_row2_col8 {
#   background-color: #8ccca8;
#   color: #000000;
# }
# #T_5c472_row3_col0 {
#   background-color: #c7e6d4;
#   color: #000000;
# }
# #T_5c472_row3_col1 {
#   background-color: #b8e0c9;
#   color: #000000;
# }
# #T_5c472_row3_col2 {
#   background-color: #bbe1cc;
#   color: #000000;
# }
# #T_5c472_row3_col3 {
#   background-color: #9bd3b3;
#   color: #000000;
# }
# #T_5c472_row3_col4 {
#   background-color: #a3d7b9;
#   color: #000000;
# }
# #T_5c472_row3_col5, #T_5c472_row6_col5, #T_5c472_row8_col5 {
#   background-color: #edf7f1;
#   color: #000000;
# }
# #T_5c472_row3_col6 {
#   background-color: #c3e5d2;
#   color: #000000;
# }
# #T_5c472_row3_col7, #T_5c472_row4_col3, #T_5c472_row8_col7 {
#   background-color: #cce8d8;
#   color: #000000;
# }
# #T_5c472_row3_col8 {
#   background-color: #d9eee2;
#   color: #000000;
# }
# #T_5c472_row4_col0 {
#   background-color: #ebf6f0;
#   color: #000000;
# }
# #T_5c472_row4_col1, #T_5c472_row6_col1 {
#   background-color: #eef8f2;
#   color: #000000;
# }
# #T_5c472_row4_col2 {
#   background-color: #e2f2e9;
#   color: #000000;
# }
# #T_5c472_row4_col4 {
#   background-color: #c5e5d3;
#   color: #000000;
# }
# #T_5c472_row4_col6, #T_5c472_row4_col7 {
#   background-color: #b0dcc3;
#   color: #000000;
# }
# #T_5c472_row4_col8, #T_5c472_row7_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_5c472_row5_col0 {
#   background-color: #dff1e7;
#   color: #000000;
# }
# #T_5c472_row5_col1 {
#   background-color: #e1f2e8;
#   color: #000000;
# }
# #T_5c472_row5_col2 {
#   background-color: #daefe3;
#   color: #000000;
# }
# #T_5c472_row5_col3, #T_5c472_row5_col7 {
#   background-color: #d6ede0;
#   color: #000000;
# }
# #T_5c472_row5_col5 {
#   background-color: #dbefe3;
#   color: #000000;
# }
# #T_5c472_row5_col6 {
#   background-color: #dcf0e5;
#   color: #000000;
# }
# #T_5c472_row5_col8 {
#   background-color: #e0f1e7;
#   color: #000000;
# }
# #T_5c472_row6_col0 {
#   background-color: #e8f5ed;
#   color: #000000;
# }
# #T_5c472_row6_col2 {
#   background-color: #f4faf7;
#   color: #000000;
# }
# #T_5c472_row6_col3, #T_5c472_row6_col8, #T_5c472_row7_col8 {
#   background-color: #f3faf6;
#   color: #000000;
# }
# #T_5c472_row6_col4 {
#   background-color: #eef7f2;
#   color: #000000;
# }
# #T_5c472_row6_col6 {
#   background-color: #f0f8f4;
#   color: #000000;
# }
# #T_5c472_row6_col7 {
#   background-color: #e4f3ea;
#   color: #000000;
# }
# #T_5c472_row7_col0, #T_5c472_row7_col3 {
#   background-color: #fcfefc;
#   color: #000000;
# }
# #T_5c472_row7_col1, #T_5c472_row7_col2, #T_5c472_row7_col4 {
#   background-color: #fafdfb;
#   color: #000000;
# }
# #T_5c472_row7_col6 {
#   background-color: #f5fbf7;
#   color: #000000;
# }
# #T_5c472_row7_col7 {
#   background-color: #f8fcfa;
#   color: #000000;
# }
# #T_5c472_row8_col0 {
#   background-color: #c8e7d6;
#   color: #000000;
# }
# #T_5c472_row8_col1, #T_5c472_row8_col4 {
#   background-color: #d3ecde;
#   color: #000000;
# }
# #T_5c472_row8_col2 {
#   background-color: #cae8d7;
#   color: #000000;
# }
# #T_5c472_row8_col3 {
#   background-color: #cee9da;
#   color: #000000;
# }
# #T_5c472_row8_col6 {
#   background-color: #bee3ce;
#   color: #000000;
# }
# #T_5c472_row8_col8 {
#   background-color: #bfe3cf;
#   color: #000000;
# }
# </style>
# <table id="T_5c472">
#   <caption>C-Bets In Position (Grouped)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_5c472_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_5c472_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_5c472_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_5c472_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_5c472_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_5c472_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_5c472_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_5c472_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_5c472_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c472_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_5c472_row0_col0" class="data row0 col0" >231.0</td>
#       <td id="T_5c472_row0_col1" class="data row0 col1" >1592.0</td>
#       <td id="T_5c472_row0_col2" class="data row0 col2" >1144.0</td>
#       <td id="T_5c472_row0_col3" class="data row0 col3" >490.0</td>
#       <td id="T_5c472_row0_col4" class="data row0 col4" >238.0</td>
#       <td id="T_5c472_row0_col5" class="data row0 col5" >23.0</td>
#       <td id="T_5c472_row0_col6" class="data row0 col6" >85.0</td>
#       <td id="T_5c472_row0_col7" class="data row0 col7" >122.0</td>
#       <td id="T_5c472_row0_col8" class="data row0 col8" >66.0</td>
#     </tr>
#     <tr>
#       <th id="T_5c472_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_5c472_row1_col0" class="data row1 col0" >48.1</td>
#       <td id="T_5c472_row1_col1" class="data row1 col1" >47.6</td>
#       <td id="T_5c472_row1_col2" class="data row1 col2" >42.9</td>
#       <td id="T_5c472_row1_col3" class="data row1 col3" >36.1</td>
#       <td id="T_5c472_row1_col4" class="data row1 col4" >28.6</td>
#       <td id="T_5c472_row1_col5" class="data row1 col5" >47.8</td>
#       <td id="T_5c472_row1_col6" class="data row1 col6" >41.2</td>
#       <td id="T_5c472_row1_col7" class="data row1 col7" >29.5</td>
#       <td id="T_5c472_row1_col8" class="data row1 col8" >50.0</td>
#     </tr>
#     <tr>
#       <th id="T_5c472_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_5c472_row2_col0" class="data row2 col0" >19.5</td>
#       <td id="T_5c472_row2_col1" class="data row2 col1" >19.2</td>
#       <td id="T_5c472_row2_col2" class="data row2 col2" >21.0</td>
#       <td id="T_5c472_row2_col3" class="data row2 col3" >14.7</td>
#       <td id="T_5c472_row2_col4" class="data row2 col4" >18.5</td>
#       <td id="T_5c472_row2_col5" class="data row2 col5" >17.4</td>
#       <td id="T_5c472_row2_col6" class="data row2 col6" >11.8</td>
#       <td id="T_5c472_row2_col7" class="data row2 col7" >21.3</td>
#       <td id="T_5c472_row2_col8" class="data row2 col8" >27.3</td>
#     </tr>
#     <tr>
#       <th id="T_5c472_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_5c472_row3_col0" class="data row3 col0" >13.4</td>
#       <td id="T_5c472_row3_col1" class="data row3 col1" >17.0</td>
#       <td id="T_5c472_row3_col2" class="data row3 col2" >16.2</td>
#       <td id="T_5c472_row3_col3" class="data row3 col3" >23.7</td>
#       <td id="T_5c472_row3_col4" class="data row3 col4" >21.8</td>
#       <td id="T_5c472_row3_col5" class="data row3 col5" >4.3</td>
#       <td id="T_5c472_row3_col6" class="data row3 col6" >14.1</td>
# <style type="text/css">
# #T_ffefa th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_ffefa td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_ffefa_row1_col0, #T_ffefa_row1_col1 {
#   background-color: #de7221;
#   color: #f1f1f1;
# }
# #T_ffefa_row1_col2 {
#   background-color: #df792c;
#   color: #f1f1f1;
# }
# #T_ffefa_row1_col3 {
#   background-color: #e38843;
#   color: #f1f1f1;
# }
# #T_ffefa_row1_col4 {
#   background-color: #e69456;
#   color: #f1f1f1;
# }
# #T_ffefa_row1_col5 {
#   background-color: #dd6e1a;
#   color: #f1f1f1;
# }
# #T_ffefa_row1_col6 {
#   background-color: #e48c48;
#   color: #f1f1f1;
# }
# #T_ffefa_row1_col7 {
#   background-color: #e28640;
#   color: #f1f1f1;
# }
# #T_ffefa_row1_col8 {
#   background-color: #d95f02;
#   color: #f1f1f1;
# }
# #T_ffefa_row2_col0, #T_ffefa_row2_col5, #T_ffefa_row4_col5, #T_ffefa_row6_col5, #T_ffefa_row13_col5 {
#   background-color: #f8e2d1;
#   color: #000000;
# }
# #T_ffefa_row2_col1 {
#   background-color: #f8e3d3;
#   color: #000000;
# }
# #T_ffefa_row2_col2 {
#   background-color: #f8e2d0;
#   color: #000000;
# }
# #T_ffefa_row2_col3, #T_ffefa_row6_col1, #T_ffefa_row6_col2, #T_ffefa_row12_col2 {
#   background-color: #fbede2;
#   color: #000000;
# }
# #T_ffefa_row2_col4, #T_ffefa_row12_col1, #T_ffefa_row12_col8, #T_ffefa_row13_col8 {
#   background-color: #faece0;
#   color: #000000;
# }
# #T_ffefa_row2_col6, #T_ffefa_row4_col6, #T_ffefa_row4_col7, #T_ffefa_row12_col3 {
#   background-color: #fbeee4;
#   color: #000000;
# }
# #T_ffefa_row2_col7, #T_ffefa_row3_col0, #T_ffefa_row12_col0, #T_ffefa_row13_col1, #T_ffefa_row13_col3, #T_ffefa_row13_col7 {
#   background-color: #fcf2eb;
#   color: #000000;
# }
# #T_ffefa_row2_col8 {
#   background-color: #f9e8da;
#   color: #000000;
# }
# #T_ffefa_row3_col1 {
#   background-color: #fefaf7;
#   color: #000000;
# }
# #T_ffefa_row3_col2, #T_ffefa_row3_col3, #T_ffefa_row6_col8, #T_ffefa_row7_col8, #T_ffefa_row8_col2 {
#   background-color: #fdf7f3;
#   color: #000000;
# }
# #T_ffefa_row3_col4 {
#   background-color: #fdf6f1;
#   color: #000000;
# }
# #T_ffefa_row3_col5, #T_ffefa_row7_col5, #T_ffefa_row8_col5, #T_ffefa_row8_col6, #T_ffefa_row9_col0, #T_ffefa_row9_col4, #T_ffefa_row9_col5, #T_ffefa_row9_col6, #T_ffefa_row10_col0, #T_ffefa_row10_col2, #T_ffefa_row10_col5, #T_ffefa_row10_col6, #T_ffefa_row11_col2, #T_ffefa_row11_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_ffefa_row3_col6, #T_ffefa_row6_col6 {
#   background-color: #fcf4ed;
#   color: #000000;
# }
# #T_ffefa_row3_col7, #T_ffefa_row11_col7 {
#   background-color: #fefbf9;
#   color: #000000;
# }
# #T_ffefa_row3_col8, #T_ffefa_row8_col8 {
#   background-color: #fbf0e7;
#   color: #000000;
# }
# #T_ffefa_row4_col0 {
#   background-color: #fbede3;
#   color: #000000;
# }
# #T_ffefa_row4_col1 {
#   background-color: #fcf3ec;
#   color: #000000;
# }
# #T_ffefa_row4_col2 {
#   background-color: #fbece1;
#   color: #000000;
# }
# #T_ffefa_row4_col3, #T_ffefa_row8_col4 {
#   background-color: #fdf8f4;
#   color: #000000;
# }
# #T_ffefa_row4_col4, #T_ffefa_row8_col0, #T_ffefa_row8_col3, #T_ffefa_row12_col4, #T_ffefa_row13_col0 {
#   background-color: #fbefe6;
#   color: #000000;
# }
# #T_ffefa_row4_col8 {
#   background-color: #f9e4d4;
#   color: #000000;
# }
# #T_ffefa_row5_col0 {
#   background-color: #f7dcc7;
#   color: #000000;
# }
# #T_ffefa_row5_col1, #T_ffefa_row5_col3 {
#   background-color: #f4d2b9;
#   color: #000000;
# }
# #T_ffefa_row5_col2 {
#   background-color: #f4d1b6;
#   color: #000000;
# }
# #T_ffefa_row5_col4 {
#   background-color: #f1c5a3;
#   color: #000000;
# }
# #T_ffefa_row5_col5, #T_ffefa_row12_col5 {
#   background-color: #f1c5a4;
#   color: #000000;
# }
# #T_ffefa_row5_col6 {
#   background-color: #edb488;
#   color: #000000;
# }
# #T_ffefa_row5_col7 {
#   background-color: #edb184;
#   color: #000000;
# }
# #T_ffefa_row5_col8 {
#   background-color: #f8e0ce;
#   color: #000000;
# }
# #T_ffefa_row6_col0, #T_ffefa_row13_col2 {
#   background-color: #fcf1e8;
#   color: #000000;
# }
# #T_ffefa_row6_col3 {
#   background-color: #f5d4bb;
#   color: #000000;
# }
# #T_ffefa_row6_col4 {
#   background-color: #f4d1b7;
#   color: #000000;
# }
# #T_ffefa_row6_col7, #T_ffefa_row13_col4 {
#   background-color: #faeadd;
#   color: #000000;
# }
# #T_ffefa_row7_col0 {
#   background-color: #faeade;
#   color: #000000;
# }
# #T_ffefa_row7_col1 {
#   background-color: #fae9dc;
#   color: #000000;
# }
# #T_ffefa_row7_col2 {
#   background-color: #f9e7d8;
#   color: #000000;
# }
# #T_ffefa_row7_col3 {
#   background-color: #f9e5d5;
#   color: #000000;
# }
# #T_ffefa_row7_col4, #T_ffefa_row12_col6 {
#   background-color: #fae8db;
#   color: #000000;
# }
# #T_ffefa_row7_col6 {
#   background-color: #f7dcc8;
#   color: #000000;
# }
# #T_ffefa_row7_col7 {
#   background-color: #f8e1cf;
#   color: #000000;
# }
# #T_ffefa_row8_col1 {
#   background-color: #fcf1e9;
#   color: #000000;
# }
# #T_ffefa_row8_col7, #T_ffefa_row9_col7, #T_ffefa_row9_col8, #T_ffefa_row10_col7, #T_ffefa_row10_col8, #T_ffefa_row11_col8 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ffefa_row9_col1, #T_ffefa_row10_col3, #T_ffefa_row11_col1, #T_ffefa_row11_col3 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_ffefa_row9_col2 {
#   background-color: #fffdfc;
#   color: #000000;
# }
# #T_ffefa_row9_col3 {
#   background-color: #fefcfa;
#   color: #000000;
# }
# #T_ffefa_row10_col1, #T_ffefa_row10_col4, #T_ffefa_row11_col0, #T_ffefa_row11_col4 {
#   background-color: #fffefd;
#   color: #000000;
# }
# #T_ffefa_row11_col6, #T_ffefa_row13_col6 {
#   background-color: #fef9f6;
#   color: #000000;
# }
# #T_ffefa_row12_col7 {
#   background-color: #f9e5d6;
#   color: #000000;
# }
# </style>
# <table id="T_ffefa">
#   <caption>C-Bets Out of Position</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_ffefa_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_ffefa_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_ffefa_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_ffefa_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_ffefa_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_ffefa_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_ffefa_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_ffefa_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_ffefa_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffefa_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_ffefa_row0_col0" class="data row0 col0" >179.0</td>
#       <td id="T_ffefa_row0_col1" class="data row0 col1" >775.0</td>
#       <td id="T_ffefa_row0_col2" class="data row0 col2" >616.0</td>
#       <td id="T_ffefa_row0_col3" class="data row0 col3" >251.0</td>
#       <td id="T_ffefa_row0_col4" class="data row0 col4" >163.0</td>
#       <td id="T_ffefa_row0_col5" class="data row0 col5" >10.0</td>
#       <td id="T_ffefa_row0_col6" class="data row0 col6" >50.0</td>
#       <td id="T_ffefa_row0_col7" class="data row0 col7" >67.0</td>
#       <td id="T_ffefa_row0_col8" class="data row0 col8" >74.0</td>
#     </tr>
#     <tr>
#       <th id="T_ffefa_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_ffefa_row1_col0" class="data row1 col0" >48.6</td>
#       <td id="T_ffefa_row1_col1" class="data row1 col1" >48.6</td>
#       <td id="T_ffefa_row1_col2" class="data row1 col2" >46.1</td>
#       <td id="T_ffefa_row1_col3" class="data row1 col3" >41.0</td>
#       <td id="T_ffefa_row1_col4" class="data row1 col4" >36.8</td>
#       <td id="T_ffefa_row1_col5" class="data row1 col5" >50.0</td>
#       <td id="T_ffefa_row1_col6" class="data row1 col6" >40.0</td>
#       <td id="T_ffefa_row1_col7" class="data row1 col7" >41.8</td>
#       <td id="T_ffefa_row1_col8" class="data row1 col8" >55.4</td>
#     </tr>
#     <tr>
#       <th id="T_ffefa_level0_row2" class="row_heading level0 row2" >Underpair</th>
#       <td id="T_ffefa_row2_col0" class="data row2 col0" >10.1</td>
#       <td id="T_ffefa_row2_col1" class="data row2 col1" >9.7</td>
#       <td id="T_ffefa_row2_col2" class="data row2 col2" >10.2</td>
#       <td id="T_ffefa_row2_col3" class="data r
# <style type="text/css">
# #T_3516d th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_3516d td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_3516d_row1_col0, #T_3516d_row1_col1 {
#   background-color: #8681bc;
#   color: #f1f1f1;
# }
# #T_3516d_row1_col2 {
#   background-color: #8c88c0;
#   color: #f1f1f1;
# }
# #T_3516d_row1_col3 {
#   background-color: #9995c7;
#   color: #f1f1f1;
# }
# #T_3516d_row1_col4 {
#   background-color: #a3a0cc;
#   color: #f1f1f1;
# }
# #T_3516d_row1_col5 {
#   background-color: #827dba;
#   color: #f1f1f1;
# }
# #T_3516d_row1_col6 {
#   background-color: #9b98c8;
#   color: #f1f1f1;
# }
# #T_3516d_row1_col7 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_3516d_row1_col8 {
#   background-color: #7570b3;
#   color: #f1f1f1;
# }
# #T_3516d_row2_col0 {
#   background-color: #cccae3;
#   color: #000000;
# }
# #T_3516d_row2_col1, #T_3516d_row2_col6, #T_3516d_row3_col2, #T_3516d_row4_col4 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_3516d_row2_col2 {
#   background-color: #cecde4;
#   color: #000000;
# }
# #T_3516d_row2_col3 {
#   background-color: #e2e1ef;
#   color: #000000;
# }
# #T_3516d_row2_col4 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_3516d_row2_col5, #T_3516d_row3_col5 {
#   background-color: #cdcbe4;
#   color: #000000;
# }
# #T_3516d_row2_col7, #T_3516d_row5_col6 {
#   background-color: #e1e0ef;
#   color: #000000;
# }
# #T_3516d_row2_col8 {
#   background-color: #c6c4df;
#   color: #000000;
# }
# #T_3516d_row3_col0 {
#   background-color: #e1e0ee;
#   color: #000000;
# }
# #T_3516d_row3_col1, #T_3516d_row3_col3 {
#   background-color: #d9d7ea;
#   color: #000000;
# }
# #T_3516d_row3_col4 {
#   background-color: #cdcbe3;
#   color: #000000;
# }
# #T_3516d_row3_col6 {
#   background-color: #bebcdb;
#   color: #000000;
# }
# #T_3516d_row3_col7 {
#   background-color: #bcb9da;
#   color: #000000;
# }
# #T_3516d_row3_col8 {
#   background-color: #e4e4f0;
#   color: #000000;
# }
# #T_3516d_row4_col0 {
#   background-color: #f3f2f8;
#   color: #000000;
# }
# #T_3516d_row4_col1, #T_3516d_row4_col2 {
#   background-color: #efeff6;
#   color: #000000;
# }
# #T_3516d_row4_col3 {
#   background-color: #dad8ea;
#   color: #000000;
# }
# #T_3516d_row4_col5, #T_3516d_row8_col0, #T_3516d_row8_col3, #T_3516d_row8_col6 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# #T_3516d_row4_col6 {
#   background-color: #f5f5fa;
#   color: #000000;
# }
# #T_3516d_row4_col7, #T_3516d_row5_col0 {
#   background-color: #edecf5;
#   color: #000000;
# }
# #T_3516d_row4_col8, #T_3516d_row5_col8, #T_3516d_row6_col2 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_3516d_row5_col1 {
#   background-color: #ecebf5;
#   color: #000000;
# }
# #T_3516d_row5_col2 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_3516d_row5_col3 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_3516d_row5_col4 {
#   background-color: #ecebf4;
#   color: #000000;
# }
# #T_3516d_row5_col5, #T_3516d_row6_col5, #T_3516d_row6_col6, #T_3516d_row6_col7, #T_3516d_row7_col5, #T_3516d_row7_col8 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_3516d_row5_col7 {
#   background-color: #e5e4f1;
#   color: #000000;
# }
# #T_3516d_row6_col0, #T_3516d_row6_col3 {
#   background-color: #f1f1f8;
#   color: #000000;
# }
# #T_3516d_row6_col1 {
#   background-color: #f3f3f8;
#   color: #000000;
# }
# #T_3516d_row6_col4 {
#   background-color: #f9f9fc;
#   color: #000000;
# }
# #T_3516d_row6_col8 {
#   background-color: #f2f2f8;
#   color: #000000;
# }
# #T_3516d_row7_col0 {
#   background-color: #fefefe;
#   color: #000000;
# }
# #T_3516d_row7_col1, #T_3516d_row7_col4 {
#   background-color: #fcfcfe;
#   color: #000000;
# }
# #T_3516d_row7_col2 {
#   background-color: #fdfdfe;
#   color: #000000;
# }
# #T_3516d_row7_col3, #T_3516d_row7_col6 {
#   background-color: #fafafc;
#   color: #000000;
# }
# #T_3516d_row7_col7 {
#   background-color: #fcfcfd;
#   color: #000000;
# }
# #T_3516d_row8_col1, #T_3516d_row8_col2 {
#   background-color: #e3e2f0;
#   color: #000000;
# }
# #T_3516d_row8_col4 {
#   background-color: #dfdeed;
#   color: #000000;
# }
# #T_3516d_row8_col5 {
#   background-color: #b4b2d6;
#   color: #000000;
# }
# #T_3516d_row8_col7, #T_3516d_row8_col8 {
#   background-color: #dddced;
#   color: #000000;
# }
# </style>
# <table id="T_3516d">
#   <caption>C-Bets Out of Position (Grouped)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_3516d_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_3516d_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_3516d_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_3516d_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_3516d_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_3516d_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_3516d_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_3516d_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_3516d_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3516d_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_3516d_row0_col0" class="data row0 col0" >179.0</td>
#       <td id="T_3516d_row0_col1" class="data row0 col1" >775.0</td>
#       <td id="T_3516d_row0_col2" class="data row0 col2" >616.0</td>
#       <td id="T_3516d_row0_col3" class="data row0 col3" >251.0</td>
#       <td id="T_3516d_row0_col4" class="data row0 col4" >163.0</td>
#       <td id="T_3516d_row0_col5" class="data row0 col5" >10.0</td>
#       <td id="T_3516d_row0_col6" class="data row0 col6" >50.0</td>
#       <td id="T_3516d_row0_col7" class="data row0 col7" >67.0</td>
#       <td id="T_3516d_row0_col8" class="data row0 col8" >74.0</td>
#     </tr>
#     <tr>
#       <th id="T_3516d_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_3516d_row1_col0" class="data row1 col0" >48.6</td>
#       <td id="T_3516d_row1_col1" class="data row1 col1" >48.6</td>
#       <td id="T_3516d_row1_col2" class="data row1 col2" >46.1</td>
#       <td id="T_3516d_row1_col3" class="data row1 col3" >41.0</td>
#       <td id="T_3516d_row1_col4" class="data row1 col4" >36.8</td>
#       <td id="T_3516d_row1_col5" class="data row1 col5" >50.0</td>
#       <td id="T_3516d_row1_col6" class="data row1 col6" >40.0</td>
#       <td id="T_3516d_row1_col7" class="data row1 col7" >41.8</td>
#       <td id="T_3516d_row1_col8" class="data row1 col8" >55.4</td>
#     </tr>
#     <tr>
#       <th id="T_3516d_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_3516d_row2_col0" class="data row2 col0" >20.7</td>
#       <td id="T_3516d_row2_col1" class="data row2 col1" >15.9</td>
#       <td id="T_3516d_row2_col2" class="data row2 col2" >19.5</td>
#       <td id="T_3516d_row2_col3" class="data row2 col3" >11.6</td>
#       <td id="T_3516d_row2_col4" class="data row2 col4" >15.3</td>
#       <td id="T_3516d_row2_col5" class="data row2 col5" >20.0</td>
#       <td id="T_3516d_row2_col6" class="data row2 col6" >16.0</td>
#       <td id="T_3516d_row2_col7" class="data row2 col7" >11.9</td>
#       <td id="T_3516d_row2_col8" class="data row2 col8" >23.0</td>
#     </tr>
#     <tr>
#       <th id="T_3516d_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_3516d_row3_col0" class="data row3 col0" >12.3</td>
#       <td id="T_3516d_row3_col1" class="data row3 col1" >15.5</td>
#       <td id="T_3516d_row3_col2" class="data row3 col2" >16.1</td>
#       <td id="T_3516d_row3_col3" class="data row3 col3" >15.5</td>
#       <td id="T_3516d_row3_col4" class="data row3 col4" >20.2</td>
#       <td id="T_3516d_row3_col5" class="data row3 col5" >20.0</td>
#       <td id="T_3516d_row3_col6" class="data row3 col6" >26.0</td>
#       <td id="T_3516d_row3_col7" class="data row3 col7" >26.9</td>
#       <td id="T_3516d_row3_col8" class="data row3 col8" >10.8</td>
#     </tr>
#     <tr>
#       <th id="T_3516d_level0_row4" class="row_heading level0 row4" >Overpair</th>
#       <td id="T_3516d_row4_col0" class="data row4 col0" >5.0</td>
#       <td id="T_3516d_row4_col1" class="data row4 col1" >6.3</td>
#       <td id="T_3516d_row4_col2"

# %%
def flop_group(count):
    if count <= 2:
        return '2 Players'
    if count == 3:
        return '3 Players'
    return '4+ Players'

df['flop_group'] = df['flop_players'].apply(flop_group)

cbet_group_titles = [
    ('2 Players', 'C-Bets (2 Players)'),
    ('3 Players', 'C-Bets (3 Players)'),
    ('4+ Players', 'C-Bets (4 Players)'),
]

for group_key, title in cbet_group_titles:
    mask = df['flop_group'] == group_key
    if mask.any():
        display_heatmap_for_mask(mask, title)
# Out:
# <style type="text/css">
# #T_81b62 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_81b62 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_81b62_row1_col0 {
#   background-color: #3886bc;
#   color: #f1f1f1;
# }
# #T_81b62_row1_col1 {
#   background-color: #3182ba;
#   color: #f1f1f1;
# }
# #T_81b62_row1_col2 {
#   background-color: #448dc0;
#   color: #f1f1f1;
# }
# #T_81b62_row1_col3 {
#   background-color: #5a9bc8;
#   color: #f1f1f1;
# }
# #T_81b62_row1_col4 {
#   background-color: #71a9cf;
#   color: #f1f1f1;
# }
# #T_81b62_row1_col5 {
#   background-color: #1f77b4;
#   color: #f1f1f1;
# }
# #T_81b62_row1_col6 {
#   background-color: #4a91c2;
#   color: #f1f1f1;
# }
# #T_81b62_row1_col7 {
#   background-color: #64a1cb;
#   color: #f1f1f1;
# }
# #T_81b62_row1_col8 {
#   background-color: #257bb6;
#   color: #f1f1f1;
# }
# #T_81b62_row2_col0, #T_81b62_row5_col0, #T_81b62_row6_col6, #T_81b62_row7_col6 {
#   background-color: #d0e2ef;
#   color: #000000;
# }
# #T_81b62_row2_col1, #T_81b62_row2_col2 {
#   background-color: #d5e5f1;
#   color: #000000;
# }
# #T_81b62_row2_col3, #T_81b62_row2_col4, #T_81b62_row5_col8 {
#   background-color: #deebf4;
#   color: #000000;
# }
# #T_81b62_row2_col5, #T_81b62_row4_col5, #T_81b62_row6_col5, #T_81b62_row7_col5, #T_81b62_row13_col5, #T_81b62_row13_col6 {
#   background-color: #ddeaf4;
#   color: #000000;
# }
# #T_81b62_row2_col6 {
#   background-color: #eaf2f8;
#   color: #000000;
# }
# #T_81b62_row2_col7, #T_81b62_row7_col7 {
#   background-color: #d4e5f1;
#   color: #000000;
# }
# #T_81b62_row2_col8, #T_81b62_row4_col8 {
#   background-color: #d7e6f1;
#   color: #000000;
# }
# #T_81b62_row3_col0 {
#   background-color: #f0f6fa;
#   color: #000000;
# }
# #T_81b62_row3_col1, #T_81b62_row3_col7, #T_81b62_row8_col2, #T_81b62_row8_col4 {
#   background-color: #f5f9fc;
#   color: #000000;
# }
# #T_81b62_row3_col2, #T_81b62_row8_col7, #T_81b62_row14_col7 {
#   background-color: #f2f7fb;
#   color: #000000;
# }
# #T_81b62_row3_col3 {
#   background-color: #f3f8fb;
#   color: #000000;
# }
# #T_81b62_row3_col4 {
#   background-color: #f6fafc;
#   color: #000000;
# }
# #T_81b62_row3_col5, #T_81b62_row8_col5, #T_81b62_row8_col6, #T_81b62_row9_col0, #T_81b62_row9_col5, #T_81b62_row10_col2, #T_81b62_row10_col3, #T_81b62_row10_col5, #T_81b62_row10_col6, #T_81b62_row11_col2, #T_81b62_row11_col3, #T_81b62_row11_col5, #T_81b62_row12_col0, #T_81b62_row12_col1, #T_81b62_row12_col2, #T_81b62_row12_col3, #T_81b62_row12_col4, #T_81b62_row12_col5, #T_81b62_row12_col6 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_81b62_row3_col6, #T_81b62_row4_col6, #T_81b62_row6_col1, #T_81b62_row14_col5, #T_81b62_row14_col6 {
#   background-color: #eef5f9;
#   color: #000000;
# }
# #T_81b62_row3_col8, #T_81b62_row6_col2, #T_81b62_row7_col0, #T_81b62_row8_col0, #T_81b62_row14_col8 {
#   background-color: #e6f0f6;
#   color: #000000;
# }
# #T_81b62_row4_col0, #T_81b62_row4_col4 {
#   background-color: #e6f0f7;
#   color: #000000;
# }
# #T_81b62_row4_col1, #T_81b62_row7_col8, #T_81b62_row8_col8, #T_81b62_row13_col4, #T_81b62_row14_col0 {
#   background-color: #e9f2f8;
#   color: #000000;
# }
# #T_81b62_row4_col2 {
#   background-color: #e1edf5;
#   color: #000000;
# }
# #T_81b62_row4_col3, #T_81b62_row8_col3 {
#   background-color: #f1f6fa;
#   color: #000000;
# }
# #T_81b62_row4_col7, #T_81b62_row14_col2 {
#   background-color: #ebf3f8;
#   color: #000000;
# }
# #T_81b62_row5_col1 {
#   background-color: #bfd8ea;
#   color: #000000;
# }
# #T_81b62_row5_col2 {
#   background-color: #c0d9ea;
#   color: #000000;
# }
# #T_81b62_row5_col3 {
#   background-color: #adcde4;
#   color: #000000;
# }
# #T_81b62_row5_col4 {
#   background-color: #a6c9e1;
#   color: #000000;
# }
# #T_81b62_row5_col5 {
#   background-color: #cbe0ee;
#   color: #000000;
# }
# #T_81b62_row5_col6 {
#   background-color: #b6d3e7;
#   color: #000000;
# }
# #T_81b62_row5_col7 {
#   background-color: #b9d4e7;
#   color: #000000;
# }
# #T_81b62_row6_col0, #T_81b62_row14_col3 {
#   background-color: #e8f1f7;
#   color: #000000;
# }
# #T_81b62_row6_col3, #T_81b62_row6_col7 {
#   background-color: #cde1ee;
#   color: #000000;
# }
# #T_81b62_row6_col4 {
#   background-color: #c3dbeb;
#   color: #000000;
# }
# #T_81b62_row6_col8 {
#   background-color: #f8fbfd;
#   color: #000000;
# }
# #T_81b62_row7_col1, #T_81b62_row14_col4 {
#   background-color: #e3eef6;
#   color: #000000;
# }
# #T_81b62_row7_col2, #T_81b62_row7_col3, #T_81b62_row13_col7 {
#   background-color: #dae9f3;
#   color: #000000;
# }
# #T_81b62_row7_col4 {
#   background-color: #d8e8f2;
#   color: #000000;
# }
# #T_81b62_row8_col1, #T_81b62_row13_col0 {
#   background-color: #edf4f9;
#   color: #000000;
# }
# #T_81b62_row9_col1 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_81b62_row9_col2, #T_81b62_row9_col3, #T_81b62_row9_col7, #T_81b62_row11_col7 {
#   background-color: #fcfdfe;
#   color: #000000;
# }
# #T_81b62_row9_col4, #T_81b62_row10_col0, #T_81b62_row10_col1, #T_81b62_row11_col0, #T_81b62_row11_col1, #T_81b62_row11_col4 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_81b62_row9_col6, #T_81b62_row10_col4, #T_81b62_row10_col8, #T_81b62_row11_col6 {
#   background-color: #fbfdfe;
#   color: #000000;
# }
# #T_81b62_row9_col8, #T_81b62_row10_col7, #T_81b62_row11_col8, #T_81b62_row12_col7, #T_81b62_row12_col8 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_81b62_row13_col1 {
#   background-color: #e5eff6;
#   color: #000000;
# }
# #T_81b62_row13_col2, #T_81b62_row13_col3 {
#   background-color: #e4eef6;
#   color: #000000;
# }
# #T_81b62_row13_col8 {
#   background-color: #e2edf5;
#   color: #000000;
# }
# #T_81b62_row14_col1 {
#   background-color: #eff5fa;
#   color: #000000;
# }
# </style>
# <table id="T_81b62">
#   <caption>C-Bets (2 Players)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_81b62_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_81b62_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_81b62_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_81b62_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_81b62_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_81b62_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_81b62_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_81b62_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_81b62_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81b62_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_81b62_row0_col0" class="data row0 col0" >318.0</td>
#       <td id="T_81b62_row0_col1" class="data row0 col1" >2049.0</td>
#       <td id="T_81b62_row0_col2" class="data row0 col2" >1442.0</td>
#       <td id="T_81b62_row0_col3" class="data row0 col3" >612.0</td>
#       <td id="T_81b62_row0_col4" class="data row0 col4" >317.0</td>
#       <td id="T_81b62_row0_col5" class="data row0 col5" >24.0</td>
#       <td id="T_81b62_row0_col6" class="data row0 col6" >96.0</td>
#       <td id="T_81b62_row0_col7" class="data row0 col7" >123.0</td>
#       <td id="T_81b62_row0_col8" class="data row0 col8" >112.0</td>
#     </tr>
#     <tr>
#       <th id="T_81b62_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_81b62_row1_col0" class="data row1 col0" >48.1</td>
#       <td id="T_81b62_row1_col1" class="data row1 col1" >49.6</td>
#       <td id="T_81b62_row1_col2" class="data row1 col2" >45.2</td>
#       <td id="T_81b62_row1_col3" class="data row1 col3" >39.9</td>
#       <td id="T_81b62_row1_col4" class="data row1 col4" >34.4</td>
#       <td id="T_81b62_row1_col5" class="data row1 col5" >54.2</td>
#       <td id="T_81b62_row1_col6" class="data row1 col6" >43.8</td>
#       <td id="T_81b62_row1_col7" class="data row1 col7" >37.4</td>
#       <td id="T_81b62_row1_col8" class="data row1 col8" >52.7</td>
#     </tr>
#     <tr>
#       <th id="T_81b62_level0_row2" class="row_heading level0 row2" >Underpair</th>
#       <td id="T_81b62_row2_col0" class="data row2 col0" >11.6</td>
#       <td id="T_81b62_row2_col1" class="data row2 col1" >10.3</td>
#       <td id="T_81b62_row2_col2" class="data row2 col2" >10.2</td>
# <style type="text/css">
# #T_c675d th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_c675d td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_c675d_row1_col0 {
#   background-color: #43ac71;
#   color: #f1f1f1;
# }
# #T_c675d_row1_col1 {
#   background-color: #3daa6c;
#   color: #f1f1f1;
# }
# #T_c675d_row1_col2 {
#   background-color: #4fb179;
#   color: #f1f1f1;
# }
# #T_c675d_row1_col3 {
#   background-color: #63ba89;
#   color: #f1f1f1;
# }
# #T_c675d_row1_col4 {
#   background-color: #79c499;
#   color: #000000;
# }
# #T_c675d_row1_col5 {
#   background-color: #2ca25f;
#   color: #f1f1f1;
# }
# #T_c675d_row1_col6 {
#   background-color: #55b47e;
#   color: #f1f1f1;
# }
# #T_c675d_row1_col7 {
#   background-color: #6dbf91;
#   color: #000000;
# }
# #T_c675d_row1_col8 {
#   background-color: #32a563;
#   color: #f1f1f1;
# }
# #T_c675d_row2_col0, #T_c675d_row3_col4 {
#   background-color: #abdac0;
#   color: #000000;
# }
# #T_c675d_row2_col1 {
#   background-color: #b8e0c9;
#   color: #000000;
# }
# #T_c675d_row2_col2 {
#   background-color: #afdcc2;
#   color: #000000;
# }
# #T_c675d_row2_col3 {
#   background-color: #c8e7d5;
#   color: #000000;
# }
# #T_c675d_row2_col4 {
#   background-color: #c0e3cf;
#   color: #000000;
# }
# #T_c675d_row2_col5 {
#   background-color: #bee3ce;
#   color: #000000;
# }
# #T_c675d_row2_col6 {
#   background-color: #cae8d7;
#   color: #000000;
# }
# #T_c675d_row2_col7 {
#   background-color: #b9e0ca;
#   color: #000000;
# }
# #T_c675d_row2_col8 {
#   background-color: #9ad3b2;
#   color: #000000;
# }
# #T_c675d_row3_col0, #T_c675d_row4_col6, #T_c675d_row5_col6 {
#   background-color: #d2ebdd;
#   color: #000000;
# }
# #T_c675d_row3_col1 {
#   background-color: #c3e4d1;
#   color: #000000;
# }
# #T_c675d_row3_col2 {
#   background-color: #c3e5d2;
#   color: #000000;
# }
# #T_c675d_row3_col3 {
#   background-color: #b2ddc5;
#   color: #000000;
# }
# #T_c675d_row3_col5, #T_c675d_row8_col5, #T_c675d_row8_col6 {
#   background-color: #cee9da;
#   color: #000000;
# }
# #T_c675d_row3_col6 {
#   background-color: #bae1cb;
#   color: #000000;
# }
# #T_c675d_row3_col7 {
#   background-color: #bde2cd;
#   color: #000000;
# }
# #T_c675d_row3_col8 {
#   background-color: #e0f2e8;
#   color: #000000;
# }
# #T_c675d_row4_col0 {
#   background-color: #e9f6ef;
#   color: #000000;
# }
# #T_c675d_row4_col1 {
#   background-color: #eff8f3;
#   color: #000000;
# }
# #T_c675d_row4_col2, #T_c675d_row5_col0, #T_c675d_row6_col0 {
#   background-color: #e7f4ed;
#   color: #000000;
# }
# #T_c675d_row4_col3, #T_c675d_row4_col7, #T_c675d_row8_col3, #T_c675d_row8_col7 {
#   background-color: #d0eadb;
#   color: #000000;
# }
# #T_c675d_row4_col4 {
#   background-color: #c7e6d4;
#   color: #000000;
# }
# #T_c675d_row4_col5, #T_c675d_row5_col5 {
#   background-color: #dff1e7;
#   color: #000000;
# }
# #T_c675d_row4_col8 {
#   background-color: #f8fcfa;
#   color: #000000;
# }
# #T_c675d_row5_col1 {
#   background-color: #e5f3eb;
#   color: #000000;
# }
# #T_c675d_row5_col2, #T_c675d_row5_col3 {
#   background-color: #dcf0e5;
#   color: #000000;
# }
# #T_c675d_row5_col4 {
#   background-color: #dbefe3;
#   color: #000000;
# }
# #T_c675d_row5_col7, #T_c675d_row8_col1 {
#   background-color: #d6ede0;
#   color: #000000;
# }
# #T_c675d_row5_col8, #T_c675d_row6_col8 {
#   background-color: #eaf6ef;
#   color: #000000;
# }
# #T_c675d_row6_col1 {
#   background-color: #eef8f2;
#   color: #000000;
# }
# #T_c675d_row6_col2, #T_c675d_row6_col4 {
#   background-color: #f6fbf8;
#   color: #000000;
# }
# #T_c675d_row6_col3 {
#   background-color: #f2f9f5;
#   color: #000000;
# }
# #T_c675d_row6_col5, #T_c675d_row6_col6, #T_c675d_row7_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_c675d_row6_col7 {
#   background-color: #f3faf6;
#   color: #000000;
# }
# #T_c675d_row7_col0 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_c675d_row7_col1 {
#   background-color: #fafdfb;
#   color: #000000;
# }
# #T_c675d_row7_col2, #T_c675d_row7_col3 {
#   background-color: #fbfdfc;
#   color: #000000;
# }
# #T_c675d_row7_col4, #T_c675d_row7_col7 {
#   background-color: #f9fcfb;
#   color: #000000;
# }
# #T_c675d_row7_col6 {
#   background-color: #f8fcf9;
#   color: #000000;
# }
# #T_c675d_row7_col8 {
#   background-color: #fcfefc;
#   color: #000000;
# }
# #T_c675d_row8_col0 {
#   background-color: #d9eee2;
#   color: #000000;
# }
# #T_c675d_row8_col2 {
#   background-color: #d1ebdc;
#   color: #000000;
# }
# #T_c675d_row8_col4 {
#   background-color: #cfeadb;
#   color: #000000;
# }
# #T_c675d_row8_col8 {
#   background-color: #cbe8d7;
#   color: #000000;
# }
# </style>
# <table id="T_c675d">
#   <caption>C-Bets (2 Players) (Grouped)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_c675d_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_c675d_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_c675d_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_c675d_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_c675d_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_c675d_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_c675d_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_c675d_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_c675d_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c675d_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_c675d_row0_col0" class="data row0 col0" >318.0</td>
#       <td id="T_c675d_row0_col1" class="data row0 col1" >2049.0</td>
#       <td id="T_c675d_row0_col2" class="data row0 col2" >1442.0</td>
#       <td id="T_c675d_row0_col3" class="data row0 col3" >612.0</td>
#       <td id="T_c675d_row0_col4" class="data row0 col4" >317.0</td>
#       <td id="T_c675d_row0_col5" class="data row0 col5" >24.0</td>
#       <td id="T_c675d_row0_col6" class="data row0 col6" >96.0</td>
#       <td id="T_c675d_row0_col7" class="data row0 col7" >123.0</td>
#       <td id="T_c675d_row0_col8" class="data row0 col8" >112.0</td>
#     </tr>
#     <tr>
#       <th id="T_c675d_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_c675d_row1_col0" class="data row1 col0" >48.1</td>
#       <td id="T_c675d_row1_col1" class="data row1 col1" >49.6</td>
#       <td id="T_c675d_row1_col2" class="data row1 col2" >45.2</td>
#       <td id="T_c675d_row1_col3" class="data row1 col3" >39.9</td>
#       <td id="T_c675d_row1_col4" class="data row1 col4" >34.4</td>
#       <td id="T_c675d_row1_col5" class="data row1 col5" >54.2</td>
#       <td id="T_c675d_row1_col6" class="data row1 col6" >43.8</td>
#       <td id="T_c675d_row1_col7" class="data row1 col7" >37.4</td>
#       <td id="T_c675d_row1_col8" class="data row1 col8" >52.7</td>
#     </tr>
#     <tr>
#       <th id="T_c675d_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_c675d_row2_col0" class="data row2 col0" >21.4</td>
#       <td id="T_c675d_row2_col1" class="data row2 col1" >18.3</td>
#       <td id="T_c675d_row2_col2" class="data row2 col2" >20.7</td>
#       <td id="T_c675d_row2_col3" class="data row2 col3" >14.4</td>
#       <td id="T_c675d_row2_col4" class="data row2 col4" >16.1</td>
#       <td id="T_c675d_row2_col5" class="data row2 col5" >16.7</td>
#       <td id="T_c675d_row2_col6" class="data row2 col6" >13.5</td>
#       <td id="T_c675d_row2_col7" class="data row2 col7" >17.9</td>
#       <td id="T_c675d_row2_col8" class="data row2 col8" >25.9</td>
#     </tr>
#     <tr>
#       <th id="T_c675d_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_c675d_row3_col0" class="data row3 col0" >11.6</td>
#       <td id="T_c675d_row3_col1" class="data row3 col1" >15.5</td>
#       <td id="T_c675d_row3_col2" class="data row3 col2" >15.4</td>
#       <td id="T_c675d_row3_col3" class="data row3 col3" >19.8</td>
#       <td id="T_c675d_row3_col4" class="data row3 col4" >21.5</td>
#       <td id="T_c675d_row3_col5" class="data row3 col5" >12.5</td>
#       <td id="T_c675d_row3_col6" class="data row3 col6" >17.7</td>
#       <td id="T_c675d_row3_col7" class="data row3 col7" >17.1</td>
#       <td id="T_c675d_row3_col8" class="data row3 col8" >8.0</td>
#     </tr>
#     <t
# <style type="text/css">
# #T_2d517 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_2d517 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_2d517_row1_col0 {
#   background-color: #3182ba;
#   color: #f1f1f1;
# }
# #T_2d517_row1_col1 {
#   background-color: #5f9ec9;
#   color: #f1f1f1;
# }
# #T_2d517_row1_col2 {
#   background-color: #609eca;
#   color: #f1f1f1;
# }
# #T_2d517_row1_col3 {
#   background-color: #8bb9d8;
#   color: #000000;
# }
# #T_2d517_row1_col4 {
#   background-color: #a7cae2;
#   color: #000000;
# }
# #T_2d517_row1_col5, #T_2d517_row1_col6, #T_2d517_row6_col5 {
#   background-color: #76acd1;
#   color: #f1f1f1;
# }
# #T_2d517_row1_col7 {
#   background-color: #89b8d8;
#   color: #000000;
# }
# #T_2d517_row1_col8 {
#   background-color: #1f77b4;
#   color: #f1f1f1;
# }
# #T_2d517_row2_col0 {
#   background-color: #ddeaf4;
#   color: #000000;
# }
# #T_2d517_row2_col1, #T_2d517_row4_col7, #T_2d517_row7_col2, #T_2d517_row8_col4, #T_2d517_row8_col7, #T_2d517_row13_col1, #T_2d517_row14_col7 {
#   background-color: #deebf4;
#   color: #000000;
# }
# #T_2d517_row2_col2 {
#   background-color: #d0e2ef;
#   color: #000000;
# }
# #T_2d517_row2_col3 {
#   background-color: #e2edf5;
#   color: #000000;
# }
# #T_2d517_row2_col4 {
#   background-color: #e4eef6;
#   color: #000000;
# }
# #T_2d517_row2_col5, #T_2d517_row3_col6, #T_2d517_row4_col6, #T_2d517_row5_col5, #T_2d517_row7_col5, #T_2d517_row9_col0, #T_2d517_row9_col4, #T_2d517_row9_col5, #T_2d517_row9_col6, #T_2d517_row10_col1, #T_2d517_row10_col3, #T_2d517_row10_col4, #T_2d517_row10_col5, #T_2d517_row10_col6, #T_2d517_row11_col0, #T_2d517_row11_col1, #T_2d517_row11_col3, #T_2d517_row11_col4, #T_2d517_row11_col5, #T_2d517_row12_col0, #T_2d517_row12_col2, #T_2d517_row12_col3, #T_2d517_row12_col4, #T_2d517_row12_col5, #T_2d517_row12_col6, #T_2d517_row13_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_2d517_row2_col6, #T_2d517_row6_col6 {
#   background-color: #c2daeb;
#   color: #000000;
# }
# #T_2d517_row2_col7 {
#   background-color: #c4dbeb;
#   color: #000000;
# }
# #T_2d517_row2_col8, #T_2d517_row6_col1 {
#   background-color: #dae9f3;
#   color: #000000;
# }
# #T_2d517_row3_col0, #T_2d517_row10_col0 {
#   background-color: #fafcfd;
#   color: #000000;
# }
# #T_2d517_row3_col1, #T_2d517_row11_col7 {
#   background-color: #f7fafc;
#   color: #000000;
# }
# #T_2d517_row3_col2 {
#   background-color: #fcfdfe;
#   color: #000000;
# }
# #T_2d517_row3_col3 {
#   background-color: #fbfdfe;
#   color: #000000;
# }
# #T_2d517_row3_col4, #T_2d517_row4_col3, #T_2d517_row13_col4, #T_2d517_row14_col3 {
#   background-color: #f4f9fb;
#   color: #000000;
# }
# #T_2d517_row3_col5, #T_2d517_row4_col5, #T_2d517_row8_col5, #T_2d517_row8_col6, #T_2d517_row13_col6, #T_2d517_row14_col5 {
#   background-color: #d1e3f0;
#   color: #000000;
# }
# #T_2d517_row3_col7, #T_2d517_row6_col8, #T_2d517_row8_col8, #T_2d517_row9_col7, #T_2d517_row9_col8, #T_2d517_row10_col7, #T_2d517_row11_col8, #T_2d517_row12_col7, #T_2d517_row12_col8 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_2d517_row3_col8, #T_2d517_row4_col8, #T_2d517_row7_col8, #T_2d517_row10_col8, #T_2d517_row13_col3, #T_2d517_row13_col8 {
#   background-color: #edf4f9;
#   color: #000000;
# }
# #T_2d517_row4_col0, #T_2d517_row6_col0, #T_2d517_row8_col0, #T_2d517_row8_col2 {
#   background-color: #f4f8fb;
#   color: #000000;
# }
# #T_2d517_row4_col1 {
#   background-color: #e6f0f6;
#   color: #000000;
# }
# #T_2d517_row4_col2 {
#   background-color: #e5eff6;
#   color: #000000;
# }
# #T_2d517_row4_col4 {
#   background-color: #c9deed;
#   color: #000000;
# }
# #T_2d517_row5_col0 {
#   background-color: #aacbe2;
#   color: #000000;
# }
# #T_2d517_row5_col1 {
#   background-color: #a5c8e1;
#   color: #000000;
# }
# #T_2d517_row5_col2 {
#   background-color: #afcee4;
#   color: #000000;
# }
# #T_2d517_row5_col3 {
#   background-color: #8fbbd9;
#   color: #000000;
# }
# #T_2d517_row5_col4 {
#   background-color: #b3d1e5;
#   color: #000000;
# }
# #T_2d517_row5_col6 {
#   background-color: #b3d1e6;
#   color: #000000;
# }
# #T_2d517_row5_col7, #T_2d517_row6_col7 {
#   background-color: #bcd6e9;
#   color: #000000;
# }
# #T_2d517_row5_col8 {
#   background-color: #b4d2e6;
#   color: #000000;
# }
# #T_2d517_row6_col2 {
#   background-color: #d6e6f1;
#   color: #000000;
# }
# #T_2d517_row6_col3 {
#   background-color: #bed8e9;
#   color: #000000;
# }
# #T_2d517_row6_col4, #T_2d517_row7_col4 {
#   background-color: #c3dbeb;
#   color: #000000;
# }
# #T_2d517_row7_col0, #T_2d517_row13_col0, #T_2d517_row14_col0 {
#   background-color: #d7e7f2;
#   color: #000000;
# }
# #T_2d517_row7_col1 {
#   background-color: #dbe9f3;
#   color: #000000;
# }
# #T_2d517_row7_col3 {
#   background-color: #cce0ee;
#   color: #000000;
# }
# #T_2d517_row7_col6, #T_2d517_row11_col6, #T_2d517_row14_col6 {
#   background-color: #f0f6fa;
#   color: #000000;
# }
# #T_2d517_row7_col7, #T_2d517_row13_col7, #T_2d517_row14_col2 {
#   background-color: #e6f0f7;
#   color: #000000;
# }
# #T_2d517_row8_col1 {
#   background-color: #eef5f9;
#   color: #000000;
# }
# #T_2d517_row8_col3, #T_2d517_row14_col1 {
#   background-color: #f1f6fa;
#   color: #000000;
# }
# #T_2d517_row9_col1, #T_2d517_row10_col2, #T_2d517_row11_col2, #T_2d517_row12_col1 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_2d517_row9_col2 {
#   background-color: #fbfcfe;
#   color: #000000;
# }
# #T_2d517_row9_col3 {
#   background-color: #f8fbfd;
#   color: #000000;
# }
# #T_2d517_row13_col2 {
#   background-color: #e0ecf5;
#   color: #000000;
# }
# #T_2d517_row14_col4 {
#   background-color: #eff5fa;
#   color: #000000;
# }
# #T_2d517_row14_col8 {
#   background-color: #c7ddec;
#   color: #000000;
# }
# </style>
# <table id="T_2d517">
#   <caption>C-Bets (3 Players)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_2d517_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_2d517_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_2d517_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_2d517_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_2d517_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_2d517_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_2d517_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_2d517_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_2d517_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d517_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_2d517_row0_col0" class="data row0 col0" >72.0</td>
#       <td id="T_2d517_row0_col1" class="data row0 col1" >286.0</td>
#       <td id="T_2d517_row0_col2" class="data row0 col2" >277.0</td>
#       <td id="T_2d517_row0_col3" class="data row0 col3" >113.0</td>
#       <td id="T_2d517_row0_col4" class="data row0 col4" >75.0</td>
#       <td id="T_2d517_row0_col5" class="data row0 col5" >9.0</td>
#       <td id="T_2d517_row0_col6" class="data row0 col6" >27.0</td>
#       <td id="T_2d517_row0_col7" class="data row0 col7" >49.0</td>
#       <td id="T_2d517_row0_col8" class="data row0 col8" >22.0</td>
#     </tr>
#     <tr>
#       <th id="T_2d517_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_2d517_row1_col0" class="data row1 col0" >50.0</td>
#       <td id="T_2d517_row1_col1" class="data row1 col1" >38.8</td>
#       <td id="T_2d517_row1_col2" class="data row1 col2" >38.6</td>
#       <td id="T_2d517_row1_col3" class="data row1 col3" >28.3</td>
#       <td id="T_2d517_row1_col4" class="data row1 col4" >21.3</td>
#       <td id="T_2d517_row1_col5" class="data row1 col5" >33.3</td>
#       <td id="T_2d517_row1_col6" class="data row1 col6" >33.3</td>
#       <td id="T_2d517_row1_col7" class="data row1 col7" >28.6</td>
#       <td id="T_2d517_row1_col8" class="data row1 col8" >54.5</td>
#     </tr>
#     <tr>
#       <th id="T_2d517_level0_row2" class="row_heading level0 row2" >Underpair</th>
#       <td id="T_2d517_row2_col0" class="data row2 col0" >8.3</td>
#       <td id="T_2d517_row2_col1" class="data row2 col1" >8.0</td>
#       <td id="T_2d517_row2_col2" class="data row2 col2" >11.6</td>
#       <td id="T
# <style type="text/css">
# #T_c14c4 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_c14c4 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_c14c4_row1_col0 {
#   background-color: #3daa6c;
#   color: #f1f1f1;
# }
# #T_c14c4_row1_col1 {
#   background-color: #68bd8d;
#   color: #000000;
# }
# #T_c14c4_row1_col2 {
#   background-color: #69bd8d;
#   color: #000000;
# }
# #T_c14c4_row1_col3 {
#   background-color: #92cfac;
#   color: #000000;
# }
# #T_c14c4_row1_col4 {
#   background-color: #acdbc0;
#   color: #000000;
# }
# #T_c14c4_row1_col5, #T_c14c4_row1_col6, #T_c14c4_row4_col5 {
#   background-color: #7ec69d;
#   color: #000000;
# }
# #T_c14c4_row1_col7 {
#   background-color: #90ceab;
#   color: #000000;
# }
# #T_c14c4_row1_col8 {
#   background-color: #2ca25f;
#   color: #f1f1f1;
# }
# #T_c14c4_row2_col0, #T_c14c4_row5_col3 {
#   background-color: #cfeadb;
#   color: #000000;
# }
# #T_c14c4_row2_col1 {
#   background-color: #bfe3cf;
#   color: #000000;
# }
# #T_c14c4_row2_col2 {
#   background-color: #b6dfc8;
#   color: #000000;
# }
# #T_c14c4_row2_col3 {
#   background-color: #d6ede0;
#   color: #000000;
# }
# #T_c14c4_row2_col4 {
#   background-color: #a7d8bc;
#   color: #000000;
# }
# #T_c14c4_row2_col5 {
#   background-color: #a9d9be;
#   color: #000000;
# }
# #T_c14c4_row2_col6, #T_c14c4_row4_col6, #T_c14c4_row8_col6 {
#   background-color: #c6e6d4;
#   color: #000000;
# }
# #T_c14c4_row2_col7 {
#   background-color: #a8d9bd;
#   color: #000000;
# }
# #T_c14c4_row2_col8, #T_c14c4_row3_col8, #T_c14c4_row8_col8 {
#   background-color: #b9e0ca;
#   color: #000000;
# }
# #T_c14c4_row3_col0 {
#   background-color: #afdcc2;
#   color: #000000;
# }
# #T_c14c4_row3_col1 {
#   background-color: #aad9be;
#   color: #000000;
# }
# #T_c14c4_row3_col2, #T_c14c4_row8_col0 {
#   background-color: #b4dec6;
#   color: #000000;
# }
# #T_c14c4_row3_col3 {
#   background-color: #95d0af;
#   color: #000000;
# }
# #T_c14c4_row3_col4 {
#   background-color: #b7dfc8;
#   color: #000000;
# }
# #T_c14c4_row3_col5, #T_c14c4_row4_col8, #T_c14c4_row5_col5, #T_c14c4_row6_col8, #T_c14c4_row7_col4, #T_c14c4_row7_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_c14c4_row3_col6 {
#   background-color: #b8e0c9;
#   color: #000000;
# }
# #T_c14c4_row3_col7, #T_c14c4_row4_col7 {
#   background-color: #c0e3cf;
#   color: #000000;
# }
# #T_c14c4_row4_col0, #T_c14c4_row6_col0, #T_c14c4_row6_col2 {
#   background-color: #f4faf7;
#   color: #000000;
# }
# #T_c14c4_row4_col1 {
#   background-color: #dcf0e5;
#   color: #000000;
# }
# #T_c14c4_row4_col2 {
#   background-color: #d8eee2;
#   color: #000000;
# }
# #T_c14c4_row4_col3 {
#   background-color: #c2e4d1;
#   color: #000000;
# }
# #T_c14c4_row4_col4, #T_c14c4_row5_col4 {
#   background-color: #c7e6d4;
#   color: #000000;
# }
# #T_c14c4_row5_col0 {
#   background-color: #daefe3;
#   color: #000000;
# }
# #T_c14c4_row5_col1 {
#   background-color: #ddf0e5;
#   color: #000000;
# }
# #T_c14c4_row5_col2, #T_c14c4_row6_col7 {
#   background-color: #e0f1e7;
#   color: #000000;
# }
# #T_c14c4_row5_col6, #T_c14c4_row7_col6 {
#   background-color: #f1f9f4;
#   color: #000000;
# }
# #T_c14c4_row5_col7 {
#   background-color: #e8f5ed;
#   color: #000000;
# }
# #T_c14c4_row5_col8, #T_c14c4_row7_col8 {
#   background-color: #eef7f2;
#   color: #000000;
# }
# #T_c14c4_row6_col1 {
#   background-color: #eff8f3;
#   color: #000000;
# }
# #T_c14c4_row6_col3 {
#   background-color: #f2f9f5;
#   color: #000000;
# }
# #T_c14c4_row6_col4 {
#   background-color: #e0f2e8;
#   color: #000000;
# }
# #T_c14c4_row6_col5, #T_c14c4_row6_col6, #T_c14c4_row8_col5 {
#   background-color: #d4ecde;
#   color: #000000;
# }
# #T_c14c4_row7_col0 {
#   background-color: #fafdfb;
#   color: #000000;
# }
# #T_c14c4_row7_col1 {
#   background-color: #fdfefd;
#   color: #000000;
# }
# #T_c14c4_row7_col2, #T_c14c4_row7_col3 {
#   background-color: #f8fcfa;
#   color: #000000;
# }
# #T_c14c4_row7_col7 {
#   background-color: #f8fcf9;
#   color: #000000;
# }
# #T_c14c4_row8_col1 {
#   background-color: #d2ebdd;
#   color: #000000;
# }
# #T_c14c4_row8_col2 {
#   background-color: #cae8d7;
#   color: #000000;
# }
# #T_c14c4_row8_col3 {
#   background-color: #e4f3ea;
#   color: #000000;
# }
# #T_c14c4_row8_col4 {
#   background-color: #e5f4ec;
#   color: #000000;
# }
# #T_c14c4_row8_col7 {
#   background-color: #c8e7d5;
#   color: #000000;
# }
# </style>
# <table id="T_c14c4">
#   <caption>C-Bets (3 Players) (Grouped)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_c14c4_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_c14c4_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_c14c4_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_c14c4_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_c14c4_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_c14c4_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_c14c4_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_c14c4_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_c14c4_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c14c4_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_c14c4_row0_col0" class="data row0 col0" >72.0</td>
#       <td id="T_c14c4_row0_col1" class="data row0 col1" >286.0</td>
#       <td id="T_c14c4_row0_col2" class="data row0 col2" >277.0</td>
#       <td id="T_c14c4_row0_col3" class="data row0 col3" >113.0</td>
#       <td id="T_c14c4_row0_col4" class="data row0 col4" >75.0</td>
#       <td id="T_c14c4_row0_col5" class="data row0 col5" >9.0</td>
#       <td id="T_c14c4_row0_col6" class="data row0 col6" >27.0</td>
#       <td id="T_c14c4_row0_col7" class="data row0 col7" >49.0</td>
#       <td id="T_c14c4_row0_col8" class="data row0 col8" >22.0</td>
#     </tr>
#     <tr>
#       <th id="T_c14c4_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_c14c4_row1_col0" class="data row1 col0" >50.0</td>
#       <td id="T_c14c4_row1_col1" class="data row1 col1" >38.8</td>
#       <td id="T_c14c4_row1_col2" class="data row1 col2" >38.6</td>
#       <td id="T_c14c4_row1_col3" class="data row1 col3" >28.3</td>
#       <td id="T_c14c4_row1_col4" class="data row1 col4" >21.3</td>
#       <td id="T_c14c4_row1_col5" class="data row1 col5" >33.3</td>
#       <td id="T_c14c4_row1_col6" class="data row1 col6" >33.3</td>
#       <td id="T_c14c4_row1_col7" class="data row1 col7" >28.6</td>
#       <td id="T_c14c4_row1_col8" class="data row1 col8" >54.5</td>
#     </tr>
#     <tr>
#       <th id="T_c14c4_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_c14c4_row2_col0" class="data row2 col0" >12.5</td>
#       <td id="T_c14c4_row2_col1" class="data row2 col1" >16.4</td>
#       <td id="T_c14c4_row2_col2" class="data row2 col2" >18.8</td>
#       <td id="T_c14c4_row2_col3" class="data row2 col3" >10.6</td>
#       <td id="T_c14c4_row2_col4" class="data row2 col4" >22.7</td>
#       <td id="T_c14c4_row2_col5" class="data row2 col5" >22.2</td>
#       <td id="T_c14c4_row2_col6" class="data row2 col6" >14.8</td>
#       <td id="T_c14c4_row2_col7" class="data row2 col7" >22.4</td>
#       <td id="T_c14c4_row2_col8" class="data row2 col8" >18.2</td>
#     </tr>
#     <tr>
#       <th id="T_c14c4_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_c14c4_row3_col0" class="data row3 col0" >20.8</td>
#       <td id="T_c14c4_row3_col1" class="data row3 col1" >22.0</td>
#       <td id="T_c14c4_row3_col2" class="data row3 col2" >19.5</td>
#       <td id="T_c14c4_row3_col3" class="data row3 col3" >27.4</td>
#       <td id="T_c14c4_row3_col4" class="data row3 col4" >18.7</td>
#       <td id="T_c14c4_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_c14c4_row3_col6" class="data row3 col6" >18.5</td>
#       <td id="T_c14c4_row3_col7" class="data row3 col7" >16.3</td>
#       <td id="T_c14c4_row3_col8" class="data row3 col8" >18.2</td>
#     </tr>
#     <tr>
#       <th id="T_c14c4_level0_row4" class="row_heading level0 row4" >Overpair</th>
#       <td id="T_c14c4_row4_col0" class="data row4 col0" >2.8</td>
#       <td id="T_c14c4_row4_col1" class="data row4 col1"
# <style type="text/css">
# #T_d20b8 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_d20b8 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_d20b8_row1_col0 {
#   background-color: #3584bb;
#   color: #f1f1f1;
# }
# #T_d20b8_row1_col1, #T_d20b8_row1_col3, #T_d20b8_row5_col6, #T_d20b8_row6_col6 {
#   background-color: #8fbbd9;
#   color: #000000;
# }
# #T_d20b8_row1_col2 {
#   background-color: #5095c4;
#   color: #f1f1f1;
# }
# #T_d20b8_row1_col4, #T_d20b8_row1_col6, #T_d20b8_row5_col4 {
#   background-color: #6aa4cd;
#   color: #f1f1f1;
# }
# #T_d20b8_row1_col5, #T_d20b8_row2_col3, #T_d20b8_row2_col4, #T_d20b8_row2_col5, #T_d20b8_row3_col0, #T_d20b8_row3_col1, #T_d20b8_row3_col2, #T_d20b8_row3_col5, #T_d20b8_row3_col6, #T_d20b8_row4_col3, #T_d20b8_row4_col4, #T_d20b8_row4_col5, #T_d20b8_row4_col6, #T_d20b8_row5_col5, #T_d20b8_row6_col0, #T_d20b8_row6_col5, #T_d20b8_row7_col4, #T_d20b8_row7_col5, #T_d20b8_row8_col4, #T_d20b8_row8_col5, #T_d20b8_row8_col6, #T_d20b8_row9_col3, #T_d20b8_row9_col5, #T_d20b8_row10_col1, #T_d20b8_row10_col3, #T_d20b8_row10_col4, #T_d20b8_row10_col5, #T_d20b8_row10_col6, #T_d20b8_row10_col7, #T_d20b8_row10_col8 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_d20b8_row1_col7, #T_d20b8_row5_col7 {
#   background-color: #96bfdc;
#   color: #000000;
# }
# #T_d20b8_row1_col8 {
#   background-color: #1f77b4;
#   color: #f1f1f1;
# }
# #T_d20b8_row2_col0, #T_d20b8_row5_col0, #T_d20b8_row8_col0, #T_d20b8_row10_col0 {
#   background-color: #e9f2f8;
#   color: #000000;
# }
# #T_d20b8_row2_col1, #T_d20b8_row4_col1, #T_d20b8_row9_col1 {
#   background-color: #d5e5f1;
#   color: #000000;
# }
# #T_d20b8_row2_col2, #T_d20b8_row4_col2, #T_d20b8_row9_col2 {
#   background-color: #c9deed;
#   color: #000000;
# }
# #T_d20b8_row2_col6, #T_d20b8_row7_col6 {
#   background-color: #dae9f3;
#   color: #000000;
# }
# #T_d20b8_row2_col7 {
#   background-color: #e5eff6;
#   color: #000000;
# }
# #T_d20b8_row2_col8, #T_d20b8_row4_col8, #T_d20b8_row5_col8, #T_d20b8_row9_col6, #T_d20b8_row9_col8 {
#   background-color: #b4d2e6;
#   color: #000000;
# }
# #T_d20b8_row3_col3, #T_d20b8_row7_col3 {
#   background-color: #e3eef6;
#   color: #000000;
# }
# #T_d20b8_row3_col4 {
#   background-color: #cee1ef;
#   color: #000000;
# }
# #T_d20b8_row3_col7, #T_d20b8_row3_col8, #T_d20b8_row4_col7, #T_d20b8_row6_col8, #T_d20b8_row7_col8, #T_d20b8_row8_col7, #T_d20b8_row8_col8 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d20b8_row4_col0, #T_d20b8_row7_col0 {
#   background-color: #a5c9e1;
#   color: #000000;
# }
# #T_d20b8_row5_col1, #T_d20b8_row6_col3 {
#   background-color: #72aad0;
#   color: #f1f1f1;
# }
# #T_d20b8_row5_col2 {
#   background-color: #a8cae2;
#   color: #000000;
# }
# #T_d20b8_row5_col3, #T_d20b8_row7_col1 {
#   background-color: #abcce3;
#   color: #000000;
# }
# #T_d20b8_row6_col1, #T_d20b8_row8_col1 {
#   background-color: #f1f6fa;
#   color: #000000;
# }
# #T_d20b8_row6_col2 {
#   background-color: #f4f9fb;
#   color: #000000;
# }
# #T_d20b8_row6_col4, #T_d20b8_row9_col4 {
#   background-color: #9cc3de;
#   color: #000000;
# }
# #T_d20b8_row6_col7 {
#   background-color: #7bafd3;
#   color: #f1f1f1;
# }
# #T_d20b8_row7_col2 {
#   background-color: #eaf2f8;
#   color: #000000;
# }
# #T_d20b8_row7_col7 {
#   background-color: #b0cfe5;
#   color: #000000;
# }
# #T_d20b8_row8_col2, #T_d20b8_row10_col2 {
#   background-color: #d4e5f1;
#   color: #000000;
# }
# #T_d20b8_row8_col3 {
#   background-color: #c7ddec;
#   color: #000000;
# }
# #T_d20b8_row9_col0 {
#   background-color: #d2e4f0;
#   color: #000000;
# }
# #T_d20b8_row9_col7 {
#   background-color: #cadfed;
#   color: #000000;
# }
# </style>
# <table id="T_d20b8">
#   <caption>C-Bets (4 Players)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_d20b8_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_d20b8_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_d20b8_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_d20b8_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_d20b8_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_d20b8_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_d20b8_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_d20b8_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_d20b8_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d20b8_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_d20b8_row0_col0" class="data row0 col0" >20.0</td>
#       <td id="T_d20b8_row0_col1" class="data row0 col1" >32.0</td>
#       <td id="T_d20b8_row0_col2" class="data row0 col2" >41.0</td>
#       <td id="T_d20b8_row0_col3" class="data row0 col3" >16.0</td>
#       <td id="T_d20b8_row0_col4" class="data row0 col4" >9.0</td>
#       <td id="T_d20b8_row0_col5" class="data row0 col5" >0.0</td>
#       <td id="T_d20b8_row0_col6" class="data row0 col6" >12.0</td>
#       <td id="T_d20b8_row0_col7" class="data row0 col7" >17.0</td>
#       <td id="T_d20b8_row0_col8" class="data row0 col8" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_d20b8_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_d20b8_row1_col0" class="data row1 col0" >45.0</td>
#       <td id="T_d20b8_row1_col1" class="data row1 col1" >25.0</td>
#       <td id="T_d20b8_row1_col2" class="data row1 col2" >39.0</td>
#       <td id="T_d20b8_row1_col3" class="data row1 col3" >25.0</td>
#       <td id="T_d20b8_row1_col4" class="data row1 col4" >33.3</td>
#       <td id="T_d20b8_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_d20b8_row1_col6" class="data row1 col6" >33.3</td>
#       <td id="T_d20b8_row1_col7" class="data row1 col7" >23.5</td>
#       <td id="T_d20b8_row1_col8" class="data row1 col8" >50.0</td>
#     </tr>
#     <tr>
#       <th id="T_d20b8_level0_row2" class="row_heading level0 row2" >Underpair</th>
#       <td id="T_d20b8_row2_col0" class="data row2 col0" >5.0</td>
#       <td id="T_d20b8_row2_col1" class="data row2 col1" >9.4</td>
#       <td id="T_d20b8_row2_col2" class="data row2 col2" >12.2</td>
#       <td id="T_d20b8_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_d20b8_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_d20b8_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_d20b8_row2_col6" class="data row2 col6" >8.3</td>
#       <td id="T_d20b8_row2_col7" class="data row2 col7" >5.9</td>
#       <td id="T_d20b8_row2_col8" class="data row2 col8" >16.7</td>
#     </tr>
#     <tr>
#       <th id="T_d20b8_level0_row3" class="row_heading level0 row3" >Bottom Pair</th>
#       <td id="T_d20b8_row3_col0" class="data row3 col0" >0.0</td>
#       <td id="T_d20b8_row3_col1" class="data row3 col1" >0.0</td>
#       <td id="T_d20b8_row3_col2" class="data row3 col2" >0.0</td>
#       <td id="T_d20b8_row3_col3" class="data row3 col3" >6.2</td>
#       <td id="T_d20b8_row3_col4" class="data row3 col4" >11.1</td>
#       <td id="T_d20b8_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_d20b8_row3_col6" class="data row3 col6" >0.0</td>
#       <td id="T_d20b8_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_d20b8_row3_col8" class="data row3 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d20b8_level0_row4" class="row_heading level0 row4" >Middle Pair</th>
#       <td id="T_d20b8_row4_col0" class="data row4 col0" >20.0</td>
#       <td id="T_d20b8_row4_col1" class="data row4 col1" >9.4</td>
#       <td id="T_d20b8_row4_col2" class="data row4 col2" >12.2</td>
#       <td id="T_d20b8_row4_col3" class="data row4 col3" >0.0</td>
#       <td id="T_d20b8_row4_col4" class="data row4 col4" >0.0</td>
#       <td id="T_d20b8_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_d20b8_row4_col6" class="data row4 col6" >0.0</td>
#       <td id="T_d20b8_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_d20b8_row4_col8" class="data row4 col8" >16.7</td>
#     </tr>
#     <tr>
#       <th id="T_d20b8_level0_row5" class="row_heading level0 row5" >Top Pair</th>
#       <td id="T_d20b8_row5_co
# <style type="text/css">
# #T_b9e33 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_b9e33 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_b9e33_row1_col0 {
#   background-color: #41ab6f;
#   color: #f1f1f1;
# }
# #T_b9e33_row1_col1, #T_b9e33_row1_col3, #T_b9e33_row2_col0, #T_b9e33_row3_col6, #T_b9e33_row4_col6 {
#   background-color: #95d0af;
#   color: #000000;
# }
# #T_b9e33_row1_col2 {
#   background-color: #5ab682;
#   color: #f1f1f1;
# }
# #T_b9e33_row1_col4, #T_b9e33_row1_col6, #T_b9e33_row2_col8, #T_b9e33_row3_col4 {
#   background-color: #72c194;
#   color: #000000;
# }
# #T_b9e33_row1_col5, #T_b9e33_row2_col5, #T_b9e33_row3_col5, #T_b9e33_row4_col0, #T_b9e33_row4_col5, #T_b9e33_row4_col8, #T_b9e33_row5_col4, #T_b9e33_row5_col5, #T_b9e33_row5_col8, #T_b9e33_row6_col4, #T_b9e33_row6_col5, #T_b9e33_row6_col6, #T_b9e33_row6_col7, #T_b9e33_row6_col8, #T_b9e33_row7_col3, #T_b9e33_row7_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_b9e33_row1_col7, #T_b9e33_row3_col7 {
#   background-color: #9cd3b4;
#   color: #000000;
# }
# #T_b9e33_row1_col8 {
#   background-color: #2ca25f;
#   color: #f1f1f1;
# }
# #T_b9e33_row2_col1, #T_b9e33_row3_col3, #T_b9e33_row5_col1 {
#   background-color: #b0dcc3;
#   color: #000000;
# }
# #T_b9e33_row2_col2 {
#   background-color: #98d2b1;
#   color: #000000;
# }
# #T_b9e33_row2_col3, #T_b9e33_row5_col3 {
#   background-color: #e5f3eb;
#   color: #000000;
# }
# #T_b9e33_row2_col4 {
#   background-color: #d1ebdc;
#   color: #000000;
# }
# #T_b9e33_row2_col6, #T_b9e33_row5_col6 {
#   background-color: #dcf0e5;
#   color: #000000;
# }
# #T_b9e33_row2_col7 {
#   background-color: #e6f4ec;
#   color: #000000;
# }
# #T_b9e33_row3_col0, #T_b9e33_row6_col0 {
#   background-color: #eaf6ef;
#   color: #000000;
# }
# #T_b9e33_row3_col1, #T_b9e33_row4_col3 {
#   background-color: #7bc59b;
#   color: #000000;
# }
# #T_b9e33_row3_col2 {
#   background-color: #addbc1;
#   color: #000000;
# }
# #T_b9e33_row3_col8, #T_b9e33_row7_col6, #T_b9e33_row7_col8 {
#   background-color: #b9e0ca;
#   color: #000000;
# }
# #T_b9e33_row4_col1, #T_b9e33_row6_col1 {
#   background-color: #f2f9f5;
#   color: #000000;
# }
# #T_b9e33_row4_col2 {
#   background-color: #f5fbf7;
#   color: #000000;
# }
# #T_b9e33_row4_col4, #T_b9e33_row7_col4 {
#   background-color: #a1d6b8;
#   color: #000000;
# }
# #T_b9e33_row4_col7 {
#   background-color: #83c8a1;
#   color: #000000;
# }
# #T_b9e33_row5_col0 {
#   background-color: #abdabf;
#   color: #000000;
# }
# #T_b9e33_row5_col2 {
#   background-color: #ebf6f0;
#   color: #000000;
# }
# #T_b9e33_row5_col7 {
#   background-color: #b5dec7;
#   color: #000000;
# }
# #T_b9e33_row6_col2 {
#   background-color: #d6ede0;
#   color: #000000;
# }
# #T_b9e33_row6_col3 {
#   background-color: #cae8d7;
#   color: #000000;
# }
# #T_b9e33_row7_col0 {
#   background-color: #c0e3cf;
#   color: #000000;
# }
# #T_b9e33_row7_col1 {
#   background-color: #d7ede1;
#   color: #000000;
# }
# #T_b9e33_row7_col2 {
#   background-color: #a2d6b9;
#   color: #000000;
# }
# #T_b9e33_row7_col7 {
#   background-color: #cde9d9;
#   color: #000000;
# }
# </style>
# <table id="T_b9e33">
#   <caption>C-Bets (4 Players) (Grouped)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_b9e33_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_b9e33_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_b9e33_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_b9e33_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_b9e33_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_b9e33_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_b9e33_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_b9e33_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_b9e33_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9e33_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_b9e33_row0_col0" class="data row0 col0" >20.0</td>
#       <td id="T_b9e33_row0_col1" class="data row0 col1" >32.0</td>
#       <td id="T_b9e33_row0_col2" class="data row0 col2" >41.0</td>
#       <td id="T_b9e33_row0_col3" class="data row0 col3" >16.0</td>
#       <td id="T_b9e33_row0_col4" class="data row0 col4" >9.0</td>
#       <td id="T_b9e33_row0_col5" class="data row0 col5" >0.0</td>
#       <td id="T_b9e33_row0_col6" class="data row0 col6" >12.0</td>
#       <td id="T_b9e33_row0_col7" class="data row0 col7" >17.0</td>
#       <td id="T_b9e33_row0_col8" class="data row0 col8" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_b9e33_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_b9e33_row1_col0" class="data row1 col0" >45.0</td>
#       <td id="T_b9e33_row1_col1" class="data row1 col1" >25.0</td>
#       <td id="T_b9e33_row1_col2" class="data row1 col2" >39.0</td>
#       <td id="T_b9e33_row1_col3" class="data row1 col3" >25.0</td>
#       <td id="T_b9e33_row1_col4" class="data row1 col4" >33.3</td>
#       <td id="T_b9e33_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_b9e33_row1_col6" class="data row1 col6" >33.3</td>
#       <td id="T_b9e33_row1_col7" class="data row1 col7" >23.5</td>
#       <td id="T_b9e33_row1_col8" class="data row1 col8" >50.0</td>
#     </tr>
#     <tr>
#       <th id="T_b9e33_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_b9e33_row2_col0" class="data row2 col0" >25.0</td>
#       <td id="T_b9e33_row2_col1" class="data row2 col1" >18.8</td>
#       <td id="T_b9e33_row2_col2" class="data row2 col2" >24.4</td>
#       <td id="T_b9e33_row2_col3" class="data row2 col3" >6.2</td>
#       <td id="T_b9e33_row2_col4" class="data row2 col4" >11.1</td>
#       <td id="T_b9e33_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_b9e33_row2_col6" class="data row2 col6" >8.3</td>
#       <td id="T_b9e33_row2_col7" class="data row2 col7" >5.9</td>
#       <td id="T_b9e33_row2_col8" class="data row2 col8" >33.3</td>
#     </tr>
#     <tr>
#       <th id="T_b9e33_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_b9e33_row3_col0" class="data row3 col0" >5.0</td>
#       <td id="T_b9e33_row3_col1" class="data row3 col1" >31.2</td>
#       <td id="T_b9e33_row3_col2" class="data row3 col2" >19.5</td>
#       <td id="T_b9e33_row3_col3" class="data row3 col3" >18.8</td>
#       <td id="T_b9e33_row3_col4" class="data row3 col4" >33.3</td>
#       <td id="T_b9e33_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_b9e33_row3_col6" class="data row3 col6" >25.0</td>
#       <td id="T_b9e33_row3_col7" class="data row3 col7" >23.5</td>
#       <td id="T_b9e33_row3_col8" class="data row3 col8" >16.7</td>
#     </tr>
#     <tr>
#       <th id="T_b9e33_level0_row4" class="row_heading level0 row4" >Overpair</th>
#       <td id="T_b9e33_row4_col0" class="data row4 col0" >0.0</td>
#       <td id="T_b9e33_row4_col1" class="data row4 col1" >3.1</td>
#       <td id="T_b9e33_row4_col2" class="data row4 col2" >2.4</td>
#       <td id="T_b9e33_row4_col3" class="data row4 col3" >31.2</td>
#       <td id="T_b9e33_row4_col4" class="data row4 col4" >22.2</td>
#       <td id="T_b9e33_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_b9e33_row4_col6" class="data row4 col6" >25.0</td>
#       <td id="T_b9e33_row4_col7" class="data row4 col7" >29.4</td>
#       <td id="T_b9e33_row4_col8" class="data row4 col8" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_b9e33_level0_row5" class="row_heading level0 row5" >Two Pair</th>
#       <td id="T_b9e33_row5_col0" class="data row5 col0" >20.0</td>
#       <td id="T_b9e33_row5_col1" class="data row5 col1" >18.8</td>
#       <td id="T_b9e33_row5_col2" class="data row5 col2" >4.9</td>
#       <td id="T_b9e33_row5_col3" class="data row5 col3" >6.2</td>
#       <td id="T_b9e33_row5_col4" class="data row5 col4" >0.0</td>
#       <td id="T_b9e33_row5_col5" class="data row5 col5" >0.0</td>
#       <td id="T_b9e33_row5_col6" class="data row5 col6" >8.3</td>
#       <td id="T_b9e33_row5_col7" class="data row5 col7" >17.6</td>
#       <td id="T_b9e33_row5_col8"

# %%
response_rows = response_events(events)
responses_df = pd.DataFrame(response_rows)

def _prepare_response_table(records):
    if not records:
        return pd.DataFrame()
    df = pd.DataFrame(records)
    if 'Bucket' not in df.columns:
        return pd.DataFrame()
    df = df.set_index('Bucket').T.apply(pd.to_numeric, errors='coerce')
    row_order = ['Events', 'Fold', 'Call', 'Raise', 'Continue']
    ordered = [row for row in row_order if row in df.index]
    extras = [row for row in df.index if row not in row_order]
    if ordered or extras:
        df = df.loc[ordered + extras]
    return df

def _response_summary(subset_df):
    if subset_df is None or subset_df.empty:
        return {'Events': 0, 'Fold': 0.0, 'Call': 0.0, 'Raise': 0.0, 'Continue': 0.0}
    events_count = len(subset_df)
    response_counts = subset_df['response'].value_counts()
    continue_count = int(response_counts.get('Call', 0) + response_counts.get('Raise', 0))
    return {
        'Events': events_count,
        'Fold': response_counts.get('Fold', 0) / events_count * 100,
        'Call': response_counts.get('Call', 0) / events_count * 100,
        'Raise': response_counts.get('Raise', 0) / events_count * 100,
        'Continue': continue_count / events_count * 100,
    }

def _compute_special_columns(source_df):
    specials = {}
    if source_df is None:
        return specials
    if 'is_all_in_cbet' in source_df.columns:
        specials['All-In'] = _response_summary(source_df[source_df['is_all_in_cbet']])
    if 'is_one_bb_cbet' in source_df.columns:
        specials['1 BB'] = _response_summary(source_df[source_df['is_one_bb_cbet']])
    return specials

def _style_response_table(df, title, base_color: str = '#6baed6'):
    if df.empty:
        return None
    percent_rows = [row for row in ['Fold', 'Call', 'Raise', 'Continue'] if row in df.index]
    styled = df.style
    if 'Events' in df.index:
        styled = styled.format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
    if percent_rows:
        styled = styled.format('{:.1f}%', subset=pd.IndexSlice[percent_rows, :])
        styled = styled.background_gradient(
            cmap=_gradient_cmap(base_color),
            axis=None,
            subset=pd.IndexSlice[percent_rows, :]
        )
    special_cols = [col for col in ['All-In', '1 BB'] if col in df.columns]
    if special_cols:
        first = special_cols[0]
        idx = df.columns.get_loc(first)
        styled = styled.set_table_styles([
            {'selector': f'th.col_heading.level0.col{idx}', 'props': [('border-left', '2px solid #64748b')]},
            {'selector': f'td.col{idx}', 'props': [('border-left', '2px solid #64748b')]},
        ], overwrite=False)
    return styled.set_caption(title)

def display_response_tables(summary_records, title, base_color='#6baed6', source_df=None):
    df = _prepare_response_table(summary_records)
    if df.empty:
        display(pd.DataFrame({'Bucket': bucket_labels, 'Message': 'No events'}))
        return
    specials = _compute_special_columns(source_df)
    if specials:
        for col_name, values in specials.items():
            for row in df.index:
                df.loc[row, col_name] = values.get(row, 0.0)
    styled = _style_response_table(df, title, base_color=base_color)
    if styled is not None:
        display(styled)

def display_response_for_mask(mask, title, base_color='#6baed6'):
    if responses_df.empty:
        display(pd.DataFrame({'Bucket': bucket_labels, 'Message': 'No events'}))
        return
    subset = responses_df.loc[mask]
    if subset.empty:
        display(pd.DataFrame({'Bucket': bucket_labels, 'Message': 'No events'}))
        return
    summary_subset = summarize_responses_df(subset, BUCKETS)
    display_response_tables(summary_subset, title, base_color=base_color, source_df=subset)

def _prepare_turn_response_records(turn_events, turn_responses, line_type, response_type):
    records = []
    for response in turn_responses:
        if response.get('line_type') != line_type:
            continue
        if response.get('response') != response_type:
            continue
        primary = response.get('responder_primary')
        if not primary:
            continue
        records.append({
            'ratio': float(response.get('ratio', 0.0)),
            'primary': primary,
            'has_flush_draw': bool(response.get('responder_has_flush_draw')),
            'has_oesd_dg': bool(response.get('responder_has_oesd_dg')),
            'made_flush': bool(response.get('responder_made_flush')),
            'made_straight': bool(response.get('responder_made_straight')),
        })
    return records

def _summarize_response_records(records, buckets):
    summary = []
    for low, high, label in buckets:
        bucket_records = [rec for rec in records if low <= rec['ratio'] < high]
        if not bucket_records:
            row = {'Bucket': label, 'Events': 0}
            for group_name in PRIMARY_GROUPS:
                row[group_name] = 0.0
            for draw_name in DRAW_FLAGS:
                row[draw_name] = 0.0
            summary.append(row)
            continue
        total = len(bucket_records)
        row = {'Bucket': label, 'Events': total}
        for group_name, members in PRIMARY_GROUPS.items():
            row[group_name] = sum(rec['primary'] in members for rec in bucket_records) / total * 100
        for draw_name, field in DRAW_FLAGS.items():
            row[draw_name] = sum(bool(rec.get(field)) for rec in bucket_records) / total * 100
        summary.append(row)
    return summary

def display_turn_response_holdings(turn_events, turn_responses, line_type, response_type, title, *, base_color='#1f77b4', group_color='#2ca25f'):
    records = _prepare_turn_response_records(turn_events, turn_responses, line_type, response_type)
    if not records:
        print(f"No {response_type.lower()} responses recorded for {line_type.lower()} line.")
        return
    summary = _summarize_response_records(records, TURN_BUCKETS_TURN)
    display_heatmap_tables(summary, title, base_color=base_color, group_color=group_color)

def _villain_response_metrics(subset_df):
    events = len(subset_df)
    if events == 0:
        return {
            'Events': 0,
            'Fold%': 0.0,
            'Call%': 0.0,
            'Raise%': 0.0,
            'Continue%': 0.0,
            'Avg Call Amount': 0.0,
            'Avg Raise Amount': 0.0,
            'Expected Continue Amount': 0.0,
        }
    fold_pct = subset_df['response'].eq('Fold').mean() * 100
    call_mask = subset_df['response'].eq('Call')
    raise_mask = subset_df['response'].eq('Raise')
    call_pct = call_mask.mean() * 100
    raise_pct = raise_mask.mean() * 100
    continue_pct = call_pct + raise_pct
    avg_call_amt = subset_df.loc[call_mask, 'response_amount'].mean() if call_mask.any() else 0.0
    avg_raise_amt = subset_df.loc[raise_mask, 'response_amount'].mean() if raise_mask.any() else 0.0
    expected_continue = (call_pct / 100) * (avg_call_amt or 0.0) + (raise_pct / 100) * (avg_raise_amt or 0.0)
    return {
        'Events': float(events),
        'Fold%': fold_pct,
        'Call%': call_pct,
        'Raise%': raise_pct,
        'Continue%': continue_pct,
        'Avg Call Amount': avg_call_amt or 0.0,
        'Avg Raise Amount': avg_raise_amt or 0.0,
        'Expected Continue Amount': expected_continue,
    }

def summarize_response_ev(responses_df, buckets):
    summary = []
    for low, high, label in buckets:
        subset = responses_df[(responses_df['ratio'] >= low) & (responses_df['ratio'] < high)]
        metrics = _villain_response_metrics(subset)
        metrics['Bucket'] = label
        summary.append(metrics)
    return summary

def display_response_ev_table(responses_df, title, base_color='#6baed6'):
    records = summarize_response_ev(responses_df, TURN_BUCKETS)
    df = pd.DataFrame(records)
    if df.empty:
        display(pd.DataFrame({'Bucket': [bucket[2] for bucket in TURN_BUCKETS], 'Message': 'No events'}))
        return
    df = df.set_index('Bucket').T.apply(pd.to_numeric, errors='coerce')
    styled = (
        df.style
        .format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
        .format('{:.1f}%', subset=pd.IndexSlice[['Fold%', 'Call%', 'Raise%', 'Continue%'], :])
        .format('{:.2f}', subset=pd.IndexSlice[['Avg Call Amount', 'Avg Raise Amount', 'Expected Continue Amount'], :])
        .background_gradient(cmap=_gradient_cmap(base_color), axis=None, subset=pd.IndexSlice[['Fold%', 'Call%', 'Raise%', 'Continue%'], :])
        .set_caption(title)
    )
    display(styled)

if responses_df.empty:
    print("No c-bet response events available.")
else:
    responses_df['bucket'] = pd.cut(
        responses_df['ratio'],
        bins=bucket_edges,
        labels=bucket_labels,
        right=False,
        include_lowest=True,
    )

# %%
def _filter_standard_cbet_events(events_df):
    if events_df is None or events_df.empty:
        return events_df.iloc[0:0].copy()
    mask = pd.Series(True, index=events_df.index)
    if 'is_all_in' in events_df.columns:
        mask &= ~events_df['is_all_in']
    if 'is_one_bb' in events_df.columns:
        mask &= ~events_df['is_one_bb']
    return events_df.loc[mask].copy()


def _filter_standard_cbet_responses(responses_df):
    if responses_df is None or responses_df.empty:
        return responses_df.iloc[0:0].copy()
    mask = pd.Series(True, index=responses_df.index)
    if 'is_all_in_cbet' in responses_df.columns:
        mask &= ~responses_df['is_all_in_cbet']
    if 'is_one_bb_cbet' in responses_df.columns:
        mask &= ~responses_df['is_one_bb_cbet']
    return responses_df.loc[mask].copy()


def _safe_mean(series):
    if series is None or len(series) == 0:
        return 0.0
    cleaned = series.dropna()
    if cleaned.empty:
        return 0.0
    value = cleaned.mean()
    return float(value) if pd.notna(value) else 0.0


def _prepare_cbet_event_metrics(events_subset, responses_subset, *, exclude_special=True):
    if events_subset is None or events_subset.empty:
        return pd.DataFrame()
    events_work = events_subset.copy()
    responses_work = responses_subset.copy()
    if exclude_special:
        events_work = _filter_standard_cbet_events(events_work)
        responses_work = _filter_standard_cbet_responses(responses_work)
    if events_work.empty:
        return pd.DataFrame()
    events_work = events_work.rename(columns={'player': 'bettor'})
    base_cols = [
        'hand_number',
        'bettor',
        'ratio',
        'bucket',
        'bet_amount',
        'bet_amount_bb',
        'big_blind',
    ]
    missing = [col for col in base_cols if col not in events_work.columns]
    if missing:
        raise KeyError(f"Missing columns in events dataframe: {', '.join(missing)}")
    events_work = events_work[base_cols].copy()
    if not responses_work.empty:
        allowed = set(zip(events_work['hand_number'], events_work['bettor']))
        responses_work = responses_work[
            responses_work.apply(lambda row: (row['hand_number'], row['bettor']) in allowed, axis=1)
        ]
    if responses_work.empty:
        grouped = pd.DataFrame(
            columns=[
                'hand_number',
                'bettor',
                'continue_amount',
                'call_amount',
                'raise_amount',
                'call_flag',
                'raise_flag',
            ]
        )
    else:
        prepped = responses_work.copy()
        prepped['continue_amount'] = np.where(
            prepped['response'].isin(['Call', 'Raise']),
            prepped['response_amount'],
            0.0,
        )
        prepped['call_amount'] = np.where(
            prepped['response'] == 'Call',
            prepped['response_amount'],
            0.0,
        )
        prepped['raise_amount'] = np.where(
            prepped['response'] == 'Raise',
            prepped['response_amount'],
            0.0,
        )
        prepped['call_flag'] = (prepped['response'] == 'Call').astype(int)
        prepped['raise_flag'] = (prepped['response'] == 'Raise').astype(int)
        grouped = (
            prepped.groupby(['hand_number', 'bettor'], as_index=False)
            .agg({
                'continue_amount': 'sum',
                'call_amount': 'sum',
                'raise_amount': 'sum',
                'call_flag': 'max',
                'raise_flag': 'max',
            })
        )
    metrics = events_work.merge(grouped, on=['hand_number', 'bettor'], how='left')
    for col in ['continue_amount', 'call_amount', 'raise_amount']:
        metrics[col] = metrics[col].fillna(0.0)
    for col in ['call_flag', 'raise_flag']:
        metrics[col] = metrics[col].fillna(0).astype(int)
    metrics['continue_flag'] = metrics['continue_amount'] > 0
    metrics['call_only_flag'] = (metrics['call_flag'] > 0) & (metrics['raise_flag'] == 0)
    with np.errstate(divide='ignore', invalid='ignore'):
        metrics['pot_before'] = np.where(
            metrics['ratio'] > 0,
            metrics['bet_amount'] / metrics['ratio'],
            np.nan,
        )
        metrics['bet_ratio_pct'] = metrics['ratio'].astype(float) * 100.0
        metrics['raise_ratio_pct'] = np.where(
            (metrics['raise_flag'] > 0) & (metrics['pot_before'] > 0),
            (metrics['raise_amount'] / metrics['pot_before']) * 100.0,
            np.nan,
        )
        metrics['breakeven_fold_pct'] = np.where(
            (metrics['bet_amount'] + metrics['pot_before']) > 0,
            metrics['bet_amount'] / (metrics['bet_amount'] + metrics['pot_before']) * 100,
            np.nan,
        )
    return metrics


def _compute_cbet_bucket_metrics(metrics_df, buckets=BUCKETS):
    results = []
    if metrics_df is None or metrics_df.empty:
        for _, _, label in buckets:
            results.append({'Bucket': label, 'Events': 0.0})
        return results
    for low, high, label in buckets:
        bucket_mask = (metrics_df['ratio'] >= low) & (metrics_df['ratio'] < high)
        bucket_events = metrics_df.loc[bucket_mask]
        total = len(bucket_events)
        if total == 0:
            results.append({'Bucket': label, 'Events': 0.0})
            continue
        continue_events = int(bucket_events['continue_flag'].sum())
        raise_events = int(bucket_events['raise_flag'].sum())
        call_only_events = int(bucket_events['call_only_flag'].sum())
        continue_pct = continue_events / total * 100
        raise_pct = raise_events / total * 100
        call_only_pct = call_only_events / total * 100
        fold_pct = 100.0 - continue_pct
        avg_ratio_pct = _safe_mean(bucket_events['bet_ratio_pct'])
        raise_mask = bucket_events['raise_flag'] > 0
        avg_raise_ratio_pct = _safe_mean(bucket_events.loc[raise_mask, 'raise_ratio_pct'])
        avg_breakeven = _safe_mean(bucket_events['breakeven_fold_pct'])
        expected_call_contrib_pct = (call_only_pct * avg_ratio_pct) / 100.0 if not np.isnan(avg_ratio_pct) else 0.0
        expected_raise_contrib_pct = (raise_pct * avg_raise_ratio_pct) / 100.0 if not np.isnan(avg_raise_ratio_pct) else 0.0
        total_contrib_pct = expected_call_contrib_pct + expected_raise_contrib_pct
        row = {
            'Bucket': label,
            'Events': float(total),
            'Fold%': fold_pct,
            'Continue%': continue_pct,
            'Call-Only%': call_only_pct,
            'Raise%': raise_pct,
            'Avg Size (Pot%)': avg_ratio_pct,
            'Avg Raise Size (Pot%)': avg_raise_ratio_pct,
            'Expected Call Contribution (Pot%)': expected_call_contrib_pct,
            'Expected Raise Contribution (Pot%)': expected_raise_contrib_pct,
            'Raise Contribution Total (Pot%)': total_contrib_pct,
            'Breakeven Fold%': avg_breakeven,
        }
        row['Fold Surplus'] = row['Fold%'] - row['Breakeven Fold%']
        results.append(row)
    return results


VALUE_COLUMNS_CBET = [
    'Bucket',
    'Events',
    'Continue%',
    'Call-Only%',
    'Raise%',
    'Avg Size (Pot%)',
    'Avg Raise Size (Pot%)',
    'Expected Call Contribution (Pot%)',
    'Expected Raise Contribution (Pot%)',
    'Raise Contribution Total (Pot%)',
]


PRESSURE_COLUMNS_CBET = [
    'Bucket',
    'Events',
    'Fold%',
    'Avg Size (Pot%)',
    'Breakeven Fold%',
    'Fold Surplus',
]


_FOLD_SURPLUS_CMAP = LinearSegmentedColormap.from_list(
    'fold_surplus_cmp_flop', ['#b91c1c', '#ffffff', '#15803d']
)


def _style_cbet_value_table(table_df, title):
    if table_df.empty:
        return None
    df = table_df.set_index('Bucket').T
    percent_rows = [row for row in df.index if row != 'Events']
    styled = df.style
    if 'Events' in df.index:
        styled = styled.format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
    if percent_rows:
        styled = styled.format('{:.1f}%', subset=pd.IndexSlice[percent_rows, :])
        contribution_rows = [row for row in percent_rows if 'Contribution' in row]
        size_rows = [row for row in percent_rows if 'Size' in row]
        pct_rows_other = [row for row in percent_rows if row not in contribution_rows + size_rows]
        if pct_rows_other:
            styled = styled.background_gradient(
                cmap='YlOrRd',
                axis=None,
                subset=pd.IndexSlice[pct_rows_other, :],
            )
        if size_rows:
            styled = styled.background_gradient(
                cmap='BuGn',
                axis=None,
                subset=pd.IndexSlice[size_rows, :],
            )
        if contribution_rows:
            styled = styled.background_gradient(
                cmap='PuBu',
                axis=None,
                subset=pd.IndexSlice[contribution_rows, :],
            )
    return styled.set_caption(title)


def _style_cbet_pressure_table(table_df, title):
    if table_df.empty:
        return None
    df = table_df.set_index('Bucket').T
    desired_order = ['Events', 'Fold%', 'Avg Size (Pot%)', 'Breakeven Fold%', 'Fold Surplus']
    existing_order = [row for row in desired_order if row in df.index]
    df = df.loc[existing_order]
    styled = df.style
    if 'Events' in df.index:
        styled = styled.format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
    percent_rows = [row for row in df.index if row != 'Events']
    if percent_rows:
        styled = styled.format('{:.1f}%', subset=pd.IndexSlice[percent_rows, :])
    if 'Fold%' in df.index:
        styled = styled.background_gradient(
            cmap='YlOrRd',
            axis=None,
            subset=pd.IndexSlice[['Fold%'], :],
        )
    if 'Avg Size (Pot%)' in df.index:
        styled = styled.background_gradient(
            cmap='BuGn',
            axis=None,
            subset=pd.IndexSlice[['Avg Size (Pot%)'], :],
        )
    if 'Fold Surplus' in df.index:
        fold_values = df.loc['Fold Surplus'].dropna().astype(float)
        if not fold_values.empty:
            max_abs = max(abs(fold_values.min()), abs(fold_values.max()))
            if max_abs == 0:
                max_abs = 1.0
            styled = styled.background_gradient(
                cmap=_FOLD_SURPLUS_CMAP,
                axis=None,
                subset=pd.IndexSlice[['Fold Surplus'], :],
                vmin=-max_abs,
                vmax=max_abs,
            )
    return styled.set_caption(title)


def _display_cbet_event_tables(metrics_df, title_prefix):
    if metrics_df is None or metrics_df.empty:
        print(f'No events available for {title_prefix}.')
        return
    records = _compute_cbet_bucket_metrics(metrics_df)
    if not records:
        print(f'No bucketed metrics available for {title_prefix}.')
        return
    metrics_table = pd.DataFrame(records)
    value_columns = [col for col in VALUE_COLUMNS_CBET if col in metrics_table.columns]
    pressure_columns = [col for col in PRESSURE_COLUMNS_CBET if col in metrics_table.columns]
    value_table = metrics_table[value_columns]
    pressure_table = metrics_table[pressure_columns]
    value_styled = _style_cbet_value_table(value_table, f"{title_prefix} - Value Profile")
    if value_styled is not None:
        display(value_styled)
    pressure_styled = _style_cbet_pressure_table(pressure_table, f"{title_prefix} - Fold Pressure")
    if pressure_styled is not None:
        display(pressure_styled)


def display_cbet_event_ev_tables(title_prefix='Flop C-Bet Event Outcomes', *, exclude_special=True):
    if df.empty or responses_df.empty:
        print('No c-bet events or responses available for event-level contribution tables.')
        return
    base_metrics = _prepare_cbet_event_metrics(df, responses_df, exclude_special=exclude_special)
    if base_metrics.empty:
        print('No c-bet events remain after filtering special cases.')
        return
    subsets = [
        (base_metrics, f"{title_prefix} (Overall)"),
        (
            _prepare_cbet_event_metrics(
                df[df['in_position']],
                responses_df[responses_df['bettor_in_position']],
                exclude_special=exclude_special,
            ),
            f"{title_prefix} (In Position)",
        ),
        (
            _prepare_cbet_event_metrics(
                df[~df['in_position']],
                responses_df[~responses_df['bettor_in_position']],
                exclude_special=exclude_special,
            ),
            f"{title_prefix} (Out of Position)",
        ),
    ]
    for metrics_slice, label in subsets:
        if metrics_slice is None or metrics_slice.empty:
            continue
        _display_cbet_event_tables(metrics_slice, label)

# %% [markdown]
# ### Flop Event-Level Outcomes
#
# These tables mirror the turn explorer value/fold summaries.
# They exclude one big blind probes and all-in bets, summarising villain
# contributions in pot-percent terms for easier sizing comparisons.

# %%
if df.empty or responses_df.empty:
    print('No flop events or responses available for event-level analysis.')
else:
    display_cbet_event_ev_tables()
# Out:
# <style type="text/css">
# #T_23213_row1_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_23213_row1_col1 {
#   background-color: #c90823;
#   color: #f1f1f1;
# }
# #T_23213_row1_col2 {
#   background-color: #e0181d;
#   color: #f1f1f1;
# }
# #T_23213_row1_col3 {
#   background-color: #f43e26;
#   color: #f1f1f1;
# }
# #T_23213_row1_col4 {
#   background-color: #fd7234;
#   color: #f1f1f1;
# }
# #T_23213_row1_col5 {
#   background-color: #fd913e;
#   color: #000000;
# }
# #T_23213_row1_col6 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_23213_row2_col0 {
#   background-color: #e1191d;
#   color: #f1f1f1;
# }
# #T_23213_row2_col1 {
#   background-color: #ed2e21;
#   color: #f1f1f1;
# }
# #T_23213_row2_col2 {
#   background-color: #fc4f2a;
#   color: #f1f1f1;
# }
# #T_23213_row2_col3 {
#   background-color: #fd7a37;
#   color: #f1f1f1;
# }
# #T_23213_row2_col4 {
#   background-color: #feb34d;
#   color: #000000;
# }
# #T_23213_row2_col5 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_23213_row2_col6 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_23213_row3_col0 {
#   background-color: #ffe590;
#   color: #000000;
# }
# #T_23213_row3_col1, #T_23213_row3_col2 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_23213_row3_col3 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_23213_row3_col4 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_23213_row3_col5 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_23213_row3_col6 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_23213_row4_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_23213_row4_col1 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_23213_row4_col2 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_23213_row4_col3 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_23213_row4_col4 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_23213_row4_col5 {
#   background-color: #def2f4;
#   color: #000000;
# }
# #T_23213_row4_col6, #T_23213_row5_col5 {
#   background-color: #acdfd4;
#   color: #000000;
# }
# #T_23213_row5_col0 {
#   background-color: #e2f4f7;
#   color: #000000;
# }
# #T_23213_row5_col1 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_23213_row5_col2 {
#   background-color: #b4e2d8;
#   color: #000000;
# }
# #T_23213_row5_col3 {
#   background-color: #afe1d5;
#   color: #000000;
# }
# #T_23213_row5_col4 {
#   background-color: #6cc4a8;
#   color: #000000;
# }
# #T_23213_row5_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_23213_row6_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_23213_row6_col1, #T_23213_row7_col3 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_23213_row6_col2 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_23213_row6_col3 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_23213_row6_col4 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_23213_row6_col5 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_23213_row6_col6 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_23213_row7_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_23213_row7_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_23213_row7_col2 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_23213_row7_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_23213_row7_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_23213_row7_col6 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_23213_row8_col0 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_23213_row8_col1 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_23213_row8_col2 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_23213_row8_col3 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_23213_row8_col4 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_23213_row8_col5 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_23213_row8_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_23213">
#   <caption>Flop C-Bet Event Outcomes (Overall) - Value Profile</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_23213_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_23213_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_23213_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_23213_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_23213_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_23213_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_23213_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23213_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_23213_row0_col0" class="data row0 col0" >256</td>
#       <td id="T_23213_row0_col1" class="data row0 col1" >2361</td>
#       <td id="T_23213_row0_col2" class="data row0 col2" >1744</td>
#       <td id="T_23213_row0_col3" class="data row0 col3" >728</td>
#       <td id="T_23213_row0_col4" class="data row0 col4" >387</td>
#       <td id="T_23213_row0_col5" class="data row0 col5" >19</td>
#       <td id="T_23213_row0_col6" class="data row0 col6" >23</td>
#     </tr>
#     <tr>
#       <th id="T_23213_level0_row1" class="row_heading level0 row1" >Continue%</th>
#       <td id="T_23213_row1_col0" class="data row1 col0" >80.9%</td>
#       <td id="T_23213_row1_col1" class="data row1 col1" >68.4%</td>
#       <td id="T_23213_row1_col2" class="data row1 col2" >62.6%</td>
#       <td id="T_23213_row1_col3" class="data row1 col3" >55.2%</td>
#       <td id="T_23213_row1_col4" class="data row1 col4" >47.0%</td>
#       <td id="T_23213_row1_col5" class="data row1 col5" >42.1%</td>
#       <td id="T_23213_row1_col6" class="data row1 col6" >21.7%</td>
#     </tr>
#     <tr>
#       <th id="T_23213_level0_row2" class="row_heading level0 row2" >Call-Only%</th>
#       <td id="T_23213_row2_col0" class="data row2 col0" >62.5%</td>
#       <td id="T_23213_row2_col1" class="data row2 col1" >58.2%</td>
#       <td id="T_23213_row2_col2" class="data row2 col2" >52.5%</td>
#       <td id="T_23213_row2_col3" class="data row2 col3" >45.7%</td>
#       <td id="T_23213_row2_col4" class="data row2 col4" >33.6%</td>
#       <td id="T_23213_row2_col5" class="data row2 col5" >36.8%</td>
#       <td id="T_23213_row2_col6" class="data row2 col6" >13.0%</td>
#     </tr>
#     <tr>
#       <th id="T_23213_level0_row3" class="row_heading level0 row3" >Raise%</th>
#       <td id="T_23213_row3_col0" class="data row3 col0" >18.4%</td>
#       <td id="T_23213_row3_col1" class="data row3 col1" >10.2%</td>
#       <td id="T_23213_row3_col2" class="data row3 col2" >10.1%</td>
#       <td id="T_23213_row3_col3" class="data row3 col3" >9.5%</td>
#       <td id="T_23213_row3_col4" class="data row3 col4" >13.4%</td>
#       <td id="T_23213_row3_col5" class="data row3 col5" >5.3%</td>
#       <td id="T_23213_row3_col6" class="data row3 col6" >8.7%</td>
#     </tr>
#     <tr>
#       <th id="T_23213_level0_row4" class="row_heading level0 row4" >Avg Size (Pot%)</th>
#       <td id="T_23213_row4_col0" class="data row4 col0" >21.5%</td>
#       <td id="T_23213_row4_col1" class="data row4 col1" >31.5%</td>
#       <td id="T_23213_row4_col2" class="data row4 col2" >47.2%</td>
#       <td id="T_23213_row4_col3" class="data row4 col3" >68.5%</td>
#       <td id="T_23213_row4_col4" class="data row4 col4" >91.7%</td>
#       <td id="T_23213_row4_col5" class="data row4 col5" >109.7%</td>
#       <td id="T_23213_row4_col6" class="data row4 col6" >200.4%</td>
#     </tr>
#     <tr>
#       <th id="T_23213_level0_row5" class="row_heading level0 row5" >Avg Raise Size (Pot%)</th>
#       <td id="T_23213_row5_col0" class="data row5 col0" >98.3%</td>
#       <td id="T_23213_row5_col1" class="data row5 col1" >118.0%</td>
#       <td id="T_23213_row5_col2" class="data row5 col2" >190.5%</td>
#       <td id="T_23213_row5_col3" class="data row5 col3" >195.7%</td>
#       <td id="T_23213_row5_col4" class="data row5 col4" >285.4%</td>
#       <td id="T_23213_row5_col5" class="data row5 col5" >200.0%</td>
#       <td id="T
# <style type="text/css">
# #T_c8717_row1_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_c8717_row1_col1 {
#   background-color: #fee084;
#   color: #000000;
# }
# #T_c8717_row1_col2 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_c8717_row1_col3 {
#   background-color: #fea044;
#   color: #000000;
# }
# #T_c8717_row1_col4 {
#   background-color: #fc6832;
#   color: #f1f1f1;
# }
# #T_c8717_row1_col5 {
#   background-color: #f64227;
#   color: #f1f1f1;
# }
# #T_c8717_row1_col6 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_c8717_row2_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_c8717_row2_col1 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_c8717_row2_col2 {
#   background-color: #e2f4f7;
#   color: #000000;
# }
# #T_c8717_row2_col3 {
#   background-color: #c7eae3;
#   color: #000000;
# }
# #T_c8717_row2_col4 {
#   background-color: #92d5c4;
#   color: #000000;
# }
# #T_c8717_row2_col5 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# #T_c8717_row2_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c8717_row4_col0 {
#   background-color: #e4f1e9;
#   color: #000000;
# }
# #T_c8717_row4_col1 {
#   background-color: #7ab791;
#   color: #f1f1f1;
# }
# #T_c8717_row4_col2 {
#   background-color: #a0ccb1;
#   color: #000000;
# }
# #T_c8717_row4_col3 {
#   background-color: #b7d8c3;
#   color: #000000;
# }
# #T_c8717_row4_col4 {
#   background-color: #a4ceb4;
#   color: #000000;
# }
# #T_c8717_row4_col5 {
#   background-color: #9dcaae;
#   color: #000000;
# }
# #T_c8717_row4_col6 {
#   background-color: #15803d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c8717">
#   <caption>Flop C-Bet Event Outcomes (Overall) - Fold Pressure</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_c8717_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_c8717_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_c8717_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_c8717_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_c8717_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_c8717_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_c8717_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8717_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_c8717_row0_col0" class="data row0 col0" >256</td>
#       <td id="T_c8717_row0_col1" class="data row0 col1" >2361</td>
#       <td id="T_c8717_row0_col2" class="data row0 col2" >1744</td>
#       <td id="T_c8717_row0_col3" class="data row0 col3" >728</td>
#       <td id="T_c8717_row0_col4" class="data row0 col4" >387</td>
#       <td id="T_c8717_row0_col5" class="data row0 col5" >19</td>
#       <td id="T_c8717_row0_col6" class="data row0 col6" >23</td>
#     </tr>
#     <tr>
#       <th id="T_c8717_level0_row1" class="row_heading level0 row1" >Fold%</th>
#       <td id="T_c8717_row1_col0" class="data row1 col0" >19.1%</td>
#       <td id="T_c8717_row1_col1" class="data row1 col1" >31.6%</td>
#       <td id="T_c8717_row1_col2" class="data row1 col2" >37.4%</td>
#       <td id="T_c8717_row1_col3" class="data row1 col3" >44.8%</td>
#       <td id="T_c8717_row1_col4" class="data row1 col4" >53.0%</td>
#       <td id="T_c8717_row1_col5" class="data row1 col5" >57.9%</td>
#       <td id="T_c8717_row1_col6" class="data row1 col6" >78.3%</td>
#     </tr>
#     <tr>
#       <th id="T_c8717_level0_row2" class="row_heading level0 row2" >Avg Size (Pot%)</th>
#       <td id="T_c8717_row2_col0" class="data row2 col0" >21.5%</td>
#       <td id="T_c8717_row2_col1" class="data row2 col1" >31.5%</td>
#       <td id="T_c8717_row2_col2" class="data row2 col2" >47.2%</td>
#       <td id="T_c8717_row2_col3" class="data row2 col3" >68.5%</td>
#       <td id="T_c8717_row2_col4" class="data row2 col4" >91.7%</td>
#       <td id="T_c8717_row2_col5" class="data row2 col5" >109.7%</td>
#       <td id="T_c8717_row2_col6" class="data row2 col6" >200.4%</td>
#     </tr>
#     <tr>
#       <th id="T_c8717_level0_row3" class="row_heading level0 row3" >Breakeven Fold%</th>
#       <td id="T_c8717_row3_col0" class="data row3 col0" >17.6%</td>
#       <td id="T_c8717_row3_col1" class="data row3 col1" >23.9%</td>
#       <td id="T_c8717_row3_col2" class="data row3 col2" >32.0%</td>
#       <td id="T_c8717_row3_col3" class="data row3 col3" >40.6%</td>
#       <td id="T_c8717_row3_col4" class="data row3 col4" >47.8%</td>
#       <td id="T_c8717_row3_col5" class="data row3 col5" >52.3%</td>
#       <td id="T_c8717_row3_col6" class="data row3 col6" >64.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c8717_level0_row4" class="row_heading level0 row4" >Fold Surplus</th>
#       <td id="T_c8717_row4_col0" class="data row4 col0" >1.5%</td>
#       <td id="T_c8717_row4_col1" class="data row4 col1" >7.7%</td>
#       <td id="T_c8717_row4_col2" class="data row4 col2" >5.4%</td>
#       <td id="T_c8717_row4_col3" class="data row4 col3" >4.2%</td>
#       <td id="T_c8717_row4_col4" class="data row4 col4" >5.2%</td>
#       <td id="T_c8717_row4_col5" class="data row4 col5" >5.6%</td>
#       <td id="T_c8717_row4_col6" class="data row4 col6" >13.5%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_54446_row1_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_54446_row1_col1 {
#   background-color: #cf0c21;
#   color: #f1f1f1;
# }
# #T_54446_row1_col2 {
#   background-color: #e41c1d;
#   color: #f1f1f1;
# }
# #T_54446_row1_col3 {
#   background-color: #fc592d;
#   color: #f1f1f1;
# }
# #T_54446_row1_col4 {
#   background-color: #fd8a3b;
#   color: #f1f1f1;
# }
# #T_54446_row1_col5 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_54446_row1_col6 {
#   background-color: #feda78;
#   color: #000000;
# }
# #T_54446_row2_col0 {
#   background-color: #db141e;
#   color: #f1f1f1;
# }
# #T_54446_row2_col1 {
#   background-color: #ed2e21;
#   color: #f1f1f1;
# }
# #T_54446_row2_col2 {
#   background-color: #fc552c;
#   color: #f1f1f1;
# }
# #T_54446_row2_col3 {
#   background-color: #fd883b;
#   color: #f1f1f1;
# }
# #T_54446_row2_col4 {
#   background-color: #feb44e;
#   color: #000000;
# }
# #T_54446_row2_col5 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_54446_row2_col6 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_54446_row3_col0 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_54446_row3_col1 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_54446_row3_col2 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_54446_row3_col3, #T_54446_row3_col5 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_54446_row3_col4, #T_54446_row3_col6 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_54446_row4_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_54446_row4_col1 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_54446_row4_col2 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_54446_row4_col3 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_54446_row4_col4 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_54446_row4_col5, #T_54446_row5_col0 {
#   background-color: #def2f4;
#   color: #000000;
# }
# #T_54446_row4_col6 {
#   background-color: #b8e4db;
#   color: #000000;
# }
# #T_54446_row5_col1 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_54446_row5_col2 {
#   background-color: #a5ddd0;
#   color: #000000;
# }
# #T_54446_row5_col3 {
#   background-color: #b2e2d7;
#   color: #000000;
# }
# #T_54446_row5_col4 {
#   background-color: #45b07b;
#   color: #f1f1f1;
# }
# #T_54446_row5_col5 {
#   background-color: #acdfd4;
#   color: #000000;
# }
# #T_54446_row5_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_54446_row6_col0, #T_54446_row7_col5 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_54446_row6_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_54446_row6_col2 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_54446_row6_col3 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_54446_row6_col4 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_54446_row6_col5 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_54446_row6_col6 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_54446_row7_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_54446_row7_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_54446_row7_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_54446_row7_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_54446_row7_col4 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_54446_row7_col6 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_54446_row8_col0 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_54446_row8_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_54446_row8_col2 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_54446_row8_col3 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_54446_row8_col4 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_54446_row8_col5 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_54446_row8_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_54446">
#   <caption>Flop C-Bet Event Outcomes (In Position) - Value Profile</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_54446_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_54446_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_54446_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_54446_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_54446_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_54446_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_54446_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54446_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_54446_row0_col0" class="data row0 col0" >152</td>
#       <td id="T_54446_row0_col1" class="data row0 col1" >1587</td>
#       <td id="T_54446_row0_col2" class="data row0 col2" >1133</td>
#       <td id="T_54446_row0_col3" class="data row0 col3" >481</td>
#       <td id="T_54446_row0_col4" class="data row0 col4" >228</td>
#       <td id="T_54446_row0_col5" class="data row0 col5" >14</td>
#       <td id="T_54446_row0_col6" class="data row0 col6" >20</td>
#     </tr>
#     <tr>
#       <th id="T_54446_level0_row1" class="row_heading level0 row1" >Continue%</th>
#       <td id="T_54446_row1_col0" class="data row1 col0" >80.9%</td>
#       <td id="T_54446_row1_col1" class="data row1 col1" >67.2%</td>
#       <td id="T_54446_row1_col2" class="data row1 col2" >62.0%</td>
#       <td id="T_54446_row1_col3" class="data row1 col3" >51.8%</td>
#       <td id="T_54446_row1_col4" class="data row1 col4" >44.3%</td>
#       <td id="T_54446_row1_col5" class="data row1 col5" >21.4%</td>
#       <td id="T_54446_row1_col6" class="data row1 col6" >25.0%</td>
#     </tr>
#     <tr>
#       <th id="T_54446_level0_row2" class="row_heading level0 row2" >Call-Only%</th>
#       <td id="T_54446_row2_col0" class="data row2 col0" >64.5%</td>
#       <td id="T_54446_row2_col1" class="data row2 col1" >58.7%</td>
#       <td id="T_54446_row2_col2" class="data row2 col2" >52.1%</td>
#       <td id="T_54446_row2_col3" class="data row2 col3" >44.7%</td>
#       <td id="T_54446_row2_col4" class="data row2 col4" >34.2%</td>
#       <td id="T_54446_row2_col5" class="data row2 col5" >14.3%</td>
#       <td id="T_54446_row2_col6" class="data row2 col6" >15.0%</td>
#     </tr>
#     <tr>
#       <th id="T_54446_level0_row3" class="row_heading level0 row3" >Raise%</th>
#       <td id="T_54446_row3_col0" class="data row3 col0" >16.4%</td>
#       <td id="T_54446_row3_col1" class="data row3 col1" >8.4%</td>
#       <td id="T_54446_row3_col2" class="data row3 col2" >9.9%</td>
#       <td id="T_54446_row3_col3" class="data row3 col3" >7.1%</td>
#       <td id="T_54446_row3_col4" class="data row3 col4" >10.1%</td>
#       <td id="T_54446_row3_col5" class="data row3 col5" >7.1%</td>
#       <td id="T_54446_row3_col6" class="data row3 col6" >10.0%</td>
#     </tr>
#     <tr>
#       <th id="T_54446_level0_row4" class="row_heading level0 row4" >Avg Size (Pot%)</th>
#       <td id="T_54446_row4_col0" class="data row4 col0" >22.1%</td>
#       <td id="T_54446_row4_col1" class="data row4 col1" >31.8%</td>
#       <td id="T_54446_row4_col2" class="data row4 col2" >47.6%</td>
#       <td id="T_54446_row4_col3" class="data row4 col3" >69.3%</td>
#       <td id="T_54446_row4_col4" class="data row4 col4" >92.8%</td>
#       <td id="T_54446_row4_col5" class="data row4 col5" >110.2%</td>
#       <td id="T_54446_row4_col6" class="data row4 col6" >184.1%</td>
#     </tr>
#     <tr>
#       <th id="T_54446_level0_row5" class="row_heading level0 row5" >Avg Raise Size (Pot%)</th>
#       <td id="T_54446_row5_col0" class="data row5 col0" >110.4%</td>
#       <td id="T_54446_row5_col1" class="data row5 col1" >117.2%</td>
#       <td id="T_54446_row5_col2" class="data row5 col2" >210.1%</td>
#       <td id="T_54446_row5_col3" class="data row5 col3" >191.9%</td>
#       <td id="T_54446_row5_col4" class="data row5 col4" >353.0%</td>
#       <td id="T_54446_row5_col5" class="data row5 col5" >200.0%</td>
#       <td id="T_54446_row5_col6" class="data row5 col6" >563.
# <style type="text/css">
# #T_c6a10_row1_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_c6a10_row1_col1 {
#   background-color: #fedc7c;
#   color: #000000;
# }
# #T_c6a10_row1_col2 {
#   background-color: #fec45f;
#   color: #000000;
# }
# #T_c6a10_row1_col3 {
#   background-color: #fd903d;
#   color: #000000;
# }
# #T_c6a10_row1_col4 {
#   background-color: #fc532b;
#   color: #f1f1f1;
# }
# #T_c6a10_row1_col5 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_c6a10_row1_col6 {
#   background-color: #9d0026;
#   color: #f1f1f1;
# }
# #T_c6a10_row2_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_c6a10_row2_col1 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_c6a10_row2_col2 {
#   background-color: #dff3f4;
#   color: #000000;
# }
# #T_c6a10_row2_col3 {
#   background-color: #bce6dd;
#   color: #000000;
# }
# #T_c6a10_row2_col4 {
#   background-color: #80cdb7;
#   color: #000000;
# }
# #T_c6a10_row2_col5 {
#   background-color: #59bb93;
#   color: #f1f1f1;
# }
# #T_c6a10_row2_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c6a10_row4_col0 {
#   background-color: #f5faf7;
#   color: #000000;
# }
# #T_c6a10_row4_col1 {
#   background-color: #b1d5be;
#   color: #000000;
# }
# #T_c6a10_row4_col2 {
#   background-color: #cbe3d4;
#   color: #000000;
# }
# #T_c6a10_row4_col3 {
#   background-color: #bedcc9;
#   color: #000000;
# }
# #T_c6a10_row4_col4 {
#   background-color: #badac6;
#   color: #000000;
# }
# #T_c6a10_row4_col5 {
#   background-color: #15803d;
#   color: #f1f1f1;
# }
# #T_c6a10_row4_col6 {
#   background-color: #97c7a9;
#   color: #000000;
# }
# </style>
# <table id="T_c6a10">
#   <caption>Flop C-Bet Event Outcomes (In Position) - Fold Pressure</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_c6a10_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_c6a10_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_c6a10_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_c6a10_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_c6a10_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_c6a10_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_c6a10_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6a10_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_c6a10_row0_col0" class="data row0 col0" >152</td>
#       <td id="T_c6a10_row0_col1" class="data row0 col1" >1587</td>
#       <td id="T_c6a10_row0_col2" class="data row0 col2" >1133</td>
#       <td id="T_c6a10_row0_col3" class="data row0 col3" >481</td>
#       <td id="T_c6a10_row0_col4" class="data row0 col4" >228</td>
#       <td id="T_c6a10_row0_col5" class="data row0 col5" >14</td>
#       <td id="T_c6a10_row0_col6" class="data row0 col6" >20</td>
#     </tr>
#     <tr>
#       <th id="T_c6a10_level0_row1" class="row_heading level0 row1" >Fold%</th>
#       <td id="T_c6a10_row1_col0" class="data row1 col0" >19.1%</td>
#       <td id="T_c6a10_row1_col1" class="data row1 col1" >32.8%</td>
#       <td id="T_c6a10_row1_col2" class="data row1 col2" >38.0%</td>
#       <td id="T_c6a10_row1_col3" class="data row1 col3" >48.2%</td>
#       <td id="T_c6a10_row1_col4" class="data row1 col4" >55.7%</td>
#       <td id="T_c6a10_row1_col5" class="data row1 col5" >78.6%</td>
#       <td id="T_c6a10_row1_col6" class="data row1 col6" >75.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c6a10_level0_row2" class="row_heading level0 row2" >Avg Size (Pot%)</th>
#       <td id="T_c6a10_row2_col0" class="data row2 col0" >22.1%</td>
#       <td id="T_c6a10_row2_col1" class="data row2 col1" >31.8%</td>
#       <td id="T_c6a10_row2_col2" class="data row2 col2" >47.6%</td>
#       <td id="T_c6a10_row2_col3" class="data row2 col3" >69.3%</td>
#       <td id="T_c6a10_row2_col4" class="data row2 col4" >92.8%</td>
#       <td id="T_c6a10_row2_col5" class="data row2 col5" >110.2%</td>
#       <td id="T_c6a10_row2_col6" class="data row2 col6" >184.1%</td>
#     </tr>
#     <tr>
#       <th id="T_c6a10_level0_row3" class="row_heading level0 row3" >Breakeven Fold%</th>
#       <td id="T_c6a10_row3_col0" class="data row3 col0" >18.1%</td>
#       <td id="T_c6a10_row3_col1" class="data row3 col1" >24.1%</td>
#       <td id="T_c6a10_row3_col2" class="data row3 col2" >32.2%</td>
#       <td id="T_c6a10_row3_col3" class="data row3 col3" >40.9%</td>
#       <td id="T_c6a10_row3_col4" class="data row3 col4" >48.1%</td>
#       <td id="T_c6a10_row3_col5" class="data row3 col5" >52.4%</td>
#       <td id="T_c6a10_row3_col6" class="data row3 col6" >63.4%</td>
#     </tr>
#     <tr>
#       <th id="T_c6a10_level0_row4" class="row_heading level0 row4" >Fold Surplus</th>
#       <td id="T_c6a10_row4_col0" class="data row4 col0" >1.0%</td>
#       <td id="T_c6a10_row4_col1" class="data row4 col1" >8.7%</td>
#       <td id="T_c6a10_row4_col2" class="data row4 col2" >5.8%</td>
#       <td id="T_c6a10_row4_col3" class="data row4 col3" >7.4%</td>
#       <td id="T_c6a10_row4_col4" class="data row4 col4" >7.6%</td>
#       <td id="T_c6a10_row4_col5" class="data row4 col5" >26.2%</td>
#       <td id="T_c6a10_row4_col6" class="data row4 col6" >11.6%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b975b_row1_col0 {
#   background-color: #d10e21;
#   color: #f1f1f1;
# }
# #T_b975b_row1_col1 {
#   background-color: #eb2b21;
#   color: #f1f1f1;
# }
# #T_b975b_row1_col2 {
#   background-color: #f94828;
#   color: #f1f1f1;
# }
# #T_b975b_row1_col3 {
#   background-color: #fc512b;
#   color: #f1f1f1;
# }
# #T_b975b_row1_col4 {
#   background-color: #fd883b;
#   color: #f1f1f1;
# }
# #T_b975b_row1_col5, #T_b975b_row2_col5 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_b975b_row1_col6, #T_b975b_row2_col6, #T_b975b_row3_col5, #T_b975b_row3_col6 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_b975b_row2_col0 {
#   background-color: #fc5d2e;
#   color: #f1f1f1;
# }
# #T_b975b_row2_col1 {
#   background-color: #fc6832;
#   color: #f1f1f1;
# }
# #T_b975b_row2_col2 {
#   background-color: #fd7c37;
#   color: #f1f1f1;
# }
# #T_b975b_row2_col3 {
#   background-color: #fd933f;
#   color: #000000;
# }
# #T_b975b_row2_col4 {
#   background-color: #fec15d;
#   color: #000000;
# }
# #T_b975b_row3_col0 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_b975b_row3_col1 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_b975b_row3_col2 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_b975b_row3_col3 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_b975b_row3_col4 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_b975b_row4_col0 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_b975b_row4_col1 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_b975b_row4_col2 {
#   background-color: #e0f3f5;
#   color: #000000;
# }
# #T_b975b_row4_col3 {
#   background-color: #d3eeeb;
#   color: #000000;
# }
# #T_b975b_row4_col4 {
#   background-color: #bce6dd;
#   color: #000000;
# }
# #T_b975b_row4_col5 {
#   background-color: #a4dccf;
#   color: #000000;
# }
# #T_b975b_row4_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_b975b_row5_col0 {
#   background-color: #c2e8e0;
#   color: #000000;
# }
# #T_b975b_row5_col1 {
#   background-color: #95d6c6;
#   color: #000000;
# }
# #T_b975b_row5_col2 {
#   background-color: #64c1a2;
#   color: #000000;
# }
# #T_b975b_row5_col3 {
#   background-color: #3ca86d;
#   color: #f1f1f1;
# }
# #T_b975b_row5_col4 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_b975b_row5_col5, #T_b975b_row5_col6 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_b975b_row6_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_b975b_row6_col1 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_b975b_row6_col2 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_b975b_row6_col3 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_b975b_row6_col4 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_b975b_row6_col5, #T_b975b_row8_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b975b_row6_col6, #T_b975b_row7_col5, #T_b975b_row7_col6, #T_b975b_row8_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b975b_row7_col0 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_b975b_row7_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_b975b_row7_col2 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_b975b_row7_col3 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_b975b_row7_col4 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_b975b_row8_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_b975b_row8_col1 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_b975b_row8_col2 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_b975b_row8_col3 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_b975b_row8_col4 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b975b">
#   <caption>Flop C-Bet Event Outcomes (Out of Position) - Value Profile</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_b975b_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_b975b_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_b975b_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_b975b_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_b975b_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_b975b_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_b975b_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b975b_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_b975b_row0_col0" class="data row0 col0" >104</td>
#       <td id="T_b975b_row0_col1" class="data row0 col1" >774</td>
#       <td id="T_b975b_row0_col2" class="data row0 col2" >611</td>
#       <td id="T_b975b_row0_col3" class="data row0 col3" >247</td>
#       <td id="T_b975b_row0_col4" class="data row0 col4" >159</td>
#       <td id="T_b975b_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_b975b_row0_col6" class="data row0 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b975b_level0_row1" class="row_heading level0 row1" >Continue%</th>
#       <td id="T_b975b_row1_col0" class="data row1 col0" >80.8%</td>
#       <td id="T_b975b_row1_col1" class="data row1 col1" >70.9%</td>
#       <td id="T_b975b_row1_col2" class="data row1 col2" >63.8%</td>
#       <td id="T_b975b_row1_col3" class="data row1 col3" >61.9%</td>
#       <td id="T_b975b_row1_col4" class="data row1 col4" >50.9%</td>
#       <td id="T_b975b_row1_col5" class="data row1 col5" >100.0%</td>
#       <td id="T_b975b_row1_col6" class="data row1 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b975b_level0_row2" class="row_heading level0 row2" >Call-Only%</th>
#       <td id="T_b975b_row2_col0" class="data row2 col0" >59.6%</td>
#       <td id="T_b975b_row2_col1" class="data row2 col1" >57.2%</td>
#       <td id="T_b975b_row2_col2" class="data row2 col2" >53.2%</td>
#       <td id="T_b975b_row2_col3" class="data row2 col3" >47.8%</td>
#       <td id="T_b975b_row2_col4" class="data row2 col4" >32.7%</td>
#       <td id="T_b975b_row2_col5" class="data row2 col5" >100.0%</td>
#       <td id="T_b975b_row2_col6" class="data row2 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b975b_level0_row3" class="row_heading level0 row3" >Raise%</th>
#       <td id="T_b975b_row3_col0" class="data row3 col0" >21.2%</td>
#       <td id="T_b975b_row3_col1" class="data row3 col1" >13.7%</td>
#       <td id="T_b975b_row3_col2" class="data row3 col2" >10.6%</td>
#       <td id="T_b975b_row3_col3" class="data row3 col3" >14.2%</td>
#       <td id="T_b975b_row3_col4" class="data row3 col4" >18.2%</td>
#       <td id="T_b975b_row3_col5" class="data row3 col5" >0.0%</td>
#       <td id="T_b975b_row3_col6" class="data row3 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b975b_level0_row4" class="row_heading level0 row4" >Avg Size (Pot%)</th>
#       <td id="T_b975b_row4_col0" class="data row4 col0" >20.7%</td>
#       <td id="T_b975b_row4_col1" class="data row4 col1" >30.8%</td>
#       <td id="T_b975b_row4_col2" class="data row4 col2" >46.3%</td>
#       <td id="T_b975b_row4_col3" class="data row4 col3" >66.9%</td>
#       <td id="T_b975b_row4_col4" class="data row4 col4" >90.1%</td>
#       <td id="T_b975b_row4_col5" class="data row4 col5" >108.1%</td>
#       <td id="T_b975b_row4_col6" class="data row4 col6" >309.2%</td>
#     </tr>
#     <tr>
#       <th id="T_b975b_level0_row5" class="row_heading level0 row5" >Avg Raise Size (Pot%)</th>
#       <td id="T_b975b_row5_col0" class="data row5 col0" >84.6%</td>
#       <td id="T_b975b_row5_col1" class="data row5 col1" >119.0%</td>
#       <td id="T_b975b_row5_col2" class="data row5 col2" >156.7%</td>
#       <td id="T_b975b_row5_col3" class="data row5 col3" >199.4%</td>
#       <td id="T_b975b_row5_col4" class="data row5 col4" >231.8%</td>
#       <td id="T_b975b_row5_col5" class="data row5 col5" >0.0%</td>
#       <td id="T_b975b_row5_col6" class="data row5 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b975b_level0_row6" class="row_heading level0 row6" >Expected Call Contribution (Pot%)</th>
#       <td id="T_b975b_row6_col0" class="data row6 col0" >12.3%</td>
#       <td id="T_b975b_row6_col1" class="data row6 c
# <style type="text/css">
# #T_703f2_row1_col0 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_703f2_row1_col1 {
#   background-color: #fecc68;
#   color: #000000;
# }
# #T_703f2_row1_col2 {
#   background-color: #feb651;
#   color: #000000;
# }
# #T_703f2_row1_col3 {
#   background-color: #feb04b;
#   color: #000000;
# }
# #T_703f2_row1_col4 {
#   background-color: #fd903d;
#   color: #000000;
# }
# #T_703f2_row1_col5 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_703f2_row1_col6 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_703f2_row2_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_703f2_row2_col1 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_703f2_row2_col2 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_703f2_row2_col3 {
#   background-color: #def2f4;
#   color: #000000;
# }
# #T_703f2_row2_col4 {
#   background-color: #ceede8;
#   color: #000000;
# }
# #T_703f2_row2_col5 {
#   background-color: #b7e4da;
#   color: #000000;
# }
# #T_703f2_row2_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_703f2_row4_col0 {
#   background-color: #f5faf7;
#   color: #000000;
# }
# #T_703f2_row4_col1 {
#   background-color: #e6f2ea;
#   color: #000000;
# }
# #T_703f2_row4_col2 {
#   background-color: #eaf4ee;
#   color: #000000;
# }
# #T_703f2_row4_col3 {
#   background-color: #fdf7f7;
#   color: #000000;
# }
# #T_703f2_row4_col4 {
#   background-color: #f7fbf8;
#   color: #000000;
# }
# #T_703f2_row4_col5 {
#   background-color: #b91c1c;
#   color: #f1f1f1;
# }
# #T_703f2_row4_col6 {
#   background-color: #8ac09e;
#   color: #000000;
# }
# </style>
# <table id="T_703f2">
#   <caption>Flop C-Bet Event Outcomes (Out of Position) - Fold Pressure</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_703f2_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_703f2_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_703f2_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_703f2_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_703f2_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_703f2_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_703f2_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_703f2_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_703f2_row0_col0" class="data row0 col0" >104</td>
#       <td id="T_703f2_row0_col1" class="data row0 col1" >774</td>
#       <td id="T_703f2_row0_col2" class="data row0 col2" >611</td>
#       <td id="T_703f2_row0_col3" class="data row0 col3" >247</td>
#       <td id="T_703f2_row0_col4" class="data row0 col4" >159</td>
#       <td id="T_703f2_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_703f2_row0_col6" class="data row0 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_703f2_level0_row1" class="row_heading level0 row1" >Fold%</th>
#       <td id="T_703f2_row1_col0" class="data row1 col0" >19.2%</td>
#       <td id="T_703f2_row1_col1" class="data row1 col1" >29.1%</td>
#       <td id="T_703f2_row1_col2" class="data row1 col2" >36.2%</td>
#       <td id="T_703f2_row1_col3" class="data row1 col3" >38.1%</td>
#       <td id="T_703f2_row1_col4" class="data row1 col4" >49.1%</td>
#       <td id="T_703f2_row1_col5" class="data row1 col5" >0.0%</td>
#       <td id="T_703f2_row1_col6" class="data row1 col6" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_703f2_level0_row2" class="row_heading level0 row2" >Avg Size (Pot%)</th>
#       <td id="T_703f2_row2_col0" class="data row2 col0" >20.7%</td>
#       <td id="T_703f2_row2_col1" class="data row2 col1" >30.8%</td>
#       <td id="T_703f2_row2_col2" class="data row2 col2" >46.3%</td>
#       <td id="T_703f2_row2_col3" class="data row2 col3" >66.9%</td>
#       <td id="T_703f2_row2_col4" class="data row2 col4" >90.1%</td>
#       <td id="T_703f2_row2_col5" class="data row2 col5" >108.1%</td>
#       <td id="T_703f2_row2_col6" class="data row2 col6" >309.2%</td>
#     </tr>
#     <tr>
#       <th id="T_703f2_level0_row3" class="row_heading level0 row3" >Breakeven Fold%</th>
#       <td id="T_703f2_row3_col0" class="data row3 col0" >17.0%</td>
#       <td id="T_703f2_row3_col1" class="data row3 col1" >23.5%</td>
#       <td id="T_703f2_row3_col2" class="data row3 col2" >31.6%</td>
#       <td id="T_703f2_row3_col3" class="data row3 col3" >40.0%</td>
#       <td id="T_703f2_row3_col4" class="data row3 col4" >47.4%</td>
#       <td id="T_703f2_row3_col5" class="data row3 col5" >51.9%</td>
#       <td id="T_703f2_row3_col6" class="data row3 col6" >74.2%</td>
#     </tr>
#     <tr>
#       <th id="T_703f2_level0_row4" class="row_heading level0 row4" >Fold Surplus</th>
#       <td id="T_703f2_row4_col0" class="data row4 col0" >2.2%</td>
#       <td id="T_703f2_row4_col1" class="data row4 col1" >5.5%</td>
#       <td id="T_703f2_row4_col2" class="data row4 col2" >4.5%</td>
#       <td id="T_703f2_row4_col3" class="data row4 col3" >-2.0%</td>
#       <td id="T_703f2_row4_col4" class="data row4 col4" >1.7%</td>
#       <td id="T_703f2_row4_col5" class="data row4 col5" >-51.9%</td>
#       <td id="T_703f2_row4_col6" class="data row4 col6" >25.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
if not responses_df.empty:
    summary_responses = summarize_responses_df(responses_df, BUCKETS)
    display_response_tables(summary_responses, "Responses to C-Bets", source_df=responses_df)
# Out:
# <style type="text/css">
# #T_f2800 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_f2800 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_f2800_row1_col0 {
#   background-color: #d5e8f3;
#   color: #000000;
# }
# #T_f2800_row1_col1 {
#   background-color: #bfdced;
#   color: #000000;
# }
# #T_f2800_row1_col2 {
#   background-color: #b0d4e9;
#   color: #000000;
# }
# #T_f2800_row1_col3 {
#   background-color: #a2cce5;
#   color: #000000;
# }
# #T_f2800_row1_col4 {
#   background-color: #91c3e1;
#   color: #000000;
# }
# #T_f2800_row1_col5 {
#   background-color: #97c6e2;
#   color: #000000;
# }
# #T_f2800_row1_col6 {
#   background-color: #92c4e1;
#   color: #000000;
# }
# #T_f2800_row1_col7 {
#   background-color: #a0cbe5;
#   color: #000000;
# }
# #T_f2800_row1_col8, #T_f2800_row3_col6 {
#   background-color: #dfeef6;
#   color: #000000;
# }
# #T_f2800_row2_col0 {
#   background-color: #93c4e1;
#   color: #000000;
# }
# #T_f2800_row2_col1 {
#   background-color: #9dc9e4;
#   color: #000000;
# }
# #T_f2800_row2_col2 {
#   background-color: #abd1e8;
#   color: #000000;
# }
# #T_f2800_row2_col3 {
#   background-color: #b9d9ec;
#   color: #000000;
# }
# #T_f2800_row2_col4 {
#   background-color: #d1e6f2;
#   color: #000000;
# }
# #T_f2800_row2_col5 {
#   background-color: #c3deee;
#   color: #000000;
# }
# #T_f2800_row2_col6 {
#   background-color: #e8f2f9;
#   color: #000000;
# }
# #T_f2800_row2_col7 {
#   background-color: #d6e9f4;
#   color: #000000;
# }
# #T_f2800_row2_col8 {
#   background-color: #8cc0df;
#   color: #000000;
# }
# #T_f2800_row3_col0 {
#   background-color: #f0f7fb;
#   color: #000000;
# }
# #T_f2800_row3_col1 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_f2800_row3_col2 {
#   background-color: #fdfeff;
#   color: #000000;
# }
# #T_f2800_row3_col3 {
#   background-color: #feffff;
#   color: #000000;
# }
# #T_f2800_row3_col4 {
#   background-color: #f6fafd;
#   color: #000000;
# }
# #T_f2800_row3_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_f2800_row3_col7 {
#   background-color: #e3eff7;
#   color: #000000;
# }
# #T_f2800_row3_col8 {
#   background-color: #eff6fa;
#   color: #000000;
# }
# #T_f2800_row4_col0 {
#   background-color: #74b3d9;
#   color: #000000;
# }
# #T_f2800_row4_col1 {
#   background-color: #8abfdf;
#   color: #000000;
# }
# #T_f2800_row4_col2 {
#   background-color: #99c7e3;
#   color: #000000;
# }
# #T_f2800_row4_col3 {
#   background-color: #a7cfe7;
#   color: #000000;
# }
# #T_f2800_row4_col4 {
#   background-color: #b8d8eb;
#   color: #000000;
# }
# #T_f2800_row4_col5 {
#   background-color: #b2d5ea;
#   color: #000000;
# }
# #T_f2800_row4_col6 {
#   background-color: #b7d8eb;
#   color: #000000;
# }
# #T_f2800_row4_col7 {
#   background-color: #a9d0e7;
#   color: #000000;
# }
# #T_f2800_row4_col8 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f2800">
#   <caption>Responses to C-Bets</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_f2800_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_f2800_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_f2800_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_f2800_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_f2800_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_f2800_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_f2800_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_f2800_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_f2800_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2800_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_f2800_row0_col0" class="data row0 col0" >509</td>
#       <td id="T_f2800_row0_col1" class="data row0 col1" >2714</td>
#       <td id="T_f2800_row0_col2" class="data row0 col2" >2118</td>
#       <td id="T_f2800_row0_col3" class="data row0 col3" >885</td>
#       <td id="T_f2800_row0_col4" class="data row0 col4" >493</td>
#       <td id="T_f2800_row0_col5" class="data row0 col5" >39</td>
#       <td id="T_f2800_row0_col6" class="data row0 col6" >181</td>
#       <td id="T_f2800_row0_col7" class="data row0 col7" >236</td>
#       <td id="T_f2800_row0_col8" class="data row0 col8" >175</td>
#     </tr>
#     <tr>
#       <th id="T_f2800_level0_row1" class="row_heading level0 row1" >Fold</th>
#       <td id="T_f2800_row1_col0" class="data row1 col0" >27.3%</td>
#       <td id="T_f2800_row1_col1" class="data row1 col1" >37.5%</td>
#       <td id="T_f2800_row1_col2" class="data row1 col2" >44.6%</td>
#       <td id="T_f2800_row1_col3" class="data row1 col3" >51.3%</td>
#       <td id="T_f2800_row1_col4" class="data row1 col4" >59.0%</td>
#       <td id="T_f2800_row1_col5" class="data row1 col5" >56.4%</td>
#       <td id="T_f2800_row1_col6" class="data row1 col6" >58.6%</td>
#       <td id="T_f2800_row1_col7" class="data row1 col7" >52.1%</td>
#       <td id="T_f2800_row1_col8" class="data row1 col8" >22.9%</td>
#     </tr>
#     <tr>
#       <th id="T_f2800_level0_row2" class="row_heading level0 row2" >Call</th>
#       <td id="T_f2800_row2_col0" class="data row2 col0" >58.2%</td>
#       <td id="T_f2800_row2_col1" class="data row2 col1" >53.6%</td>
#       <td id="T_f2800_row2_col2" class="data row2 col2" >46.8%</td>
#       <td id="T_f2800_row2_col3" class="data row2 col3" >40.7%</td>
#       <td id="T_f2800_row2_col4" class="data row2 col4" >29.2%</td>
#       <td id="T_f2800_row2_col5" class="data row2 col5" >35.9%</td>
#       <td id="T_f2800_row2_col6" class="data row2 col6" >18.8%</td>
#       <td id="T_f2800_row2_col7" class="data row2 col7" >26.7%</td>
#       <td id="T_f2800_row2_col8" class="data row2 col8" >61.7%</td>
#     </tr>
#     <tr>
#       <th id="T_f2800_level0_row3" class="row_heading level0 row3" >Raise</th>
#       <td id="T_f2800_row3_col0" class="data row3 col0" >14.5%</td>
#       <td id="T_f2800_row3_col1" class="data row3 col1" >8.9%</td>
#       <td id="T_f2800_row3_col2" class="data row3 col2" >8.5%</td>
#       <td id="T_f2800_row3_col3" class="data row3 col3" >8.0%</td>
#       <td id="T_f2800_row3_col4" class="data row3 col4" >11.8%</td>
#       <td id="T_f2800_row3_col5" class="data row3 col5" >7.7%</td>
#       <td id="T_f2800_row3_col6" class="data row3 col6" >22.7%</td>
#       <td id="T_f2800_row3_col7" class="data row3 col7" >21.2%</td>
#       <td id="T_f2800_row3_col8" class="data row3 col8" >15.4%</td>
#     </tr>
#     <tr>
#       <th id="T_f2800_level0_row4" class="row_heading level0 row4" >Continue</th>
#       <td id="T_f2800_row4_col0" class="data row4 col0" >72.7%</td>
#       <td id="T_f2800_row4_col1" class="data row4 col1" >62.5%</td>
#       <td id="T_f2800_row4_col2" class="data row4 col2" >55.4%</td>
#       <td id="T_f2800_row4_col3" class="data row4 col3" >48.7%</td>
#       <td id="T_f2800_row4_col4" class="data row4 col4" >41.0%</td>
#       <td id="T_f2800_row4_col5" class="data row4 col5" >43.6%</td>
#       <td id="T_f2800_row4_col6" class="data row4 col6" >41.4%</td>
#       <td id="T_f2800_row4_col7" class="data row4 col7" >47.9%</td>
#       <td id="T_f2800_row4_col8" class="data row4 col8" >77.1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
if not responses_df.empty:
    display_response_for_mask(responses_df['bettor_in_position'], 'Responses vs In-Position C-Bets')
    display_response_for_mask(~responses_df['bettor_in_position'], 'Responses vs Out-of-Position C-Bets')
# Out:
# <style type="text/css">
# #T_2cc65 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_2cc65 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_2cc65_row1_col0, #T_2cc65_row2_col4 {
#   background-color: #cce3f1;
#   color: #000000;
# }
# #T_2cc65_row1_col1 {
#   background-color: #b4d6ea;
#   color: #000000;
# }
# #T_2cc65_row1_col2 {
#   background-color: #a5cee6;
#   color: #000000;
# }
# #T_2cc65_row1_col3 {
#   background-color: #91c3e1;
#   color: #000000;
# }
# #T_2cc65_row1_col4 {
#   background-color: #85bcdd;
#   color: #000000;
# }
# #T_2cc65_row1_col5 {
#   background-color: #74b3d9;
#   color: #000000;
# }
# #T_2cc65_row1_col6 {
#   background-color: #89bfde;
#   color: #000000;
# }
# #T_2cc65_row1_col7 {
#   background-color: #99c7e3;
#   color: #000000;
# }
# #T_2cc65_row1_col8 {
#   background-color: #d1e6f2;
#   color: #000000;
# }
# #T_2cc65_row2_col0, #T_2cc65_row4_col1 {
#   background-color: #89bede;
#   color: #000000;
# }
# #T_2cc65_row2_col1 {
#   background-color: #98c7e3;
#   color: #000000;
# }
# #T_2cc65_row2_col2 {
#   background-color: #a9d0e7;
#   color: #000000;
# }
# #T_2cc65_row2_col3, #T_2cc65_row4_col4 {
#   background-color: #b8d8eb;
#   color: #000000;
# }
# #T_2cc65_row2_col5 {
#   background-color: #d7e9f4;
#   color: #000000;
# }
# #T_2cc65_row2_col6 {
#   background-color: #dcecf5;
#   color: #000000;
# }
# #T_2cc65_row2_col7 {
#   background-color: #cde4f1;
#   color: #000000;
# }
# #T_2cc65_row2_col8 {
#   background-color: #7fb9dc;
#   color: #000000;
# }
# #T_2cc65_row3_col0 {
#   background-color: #f3f9fc;
#   color: #000000;
# }
# #T_2cc65_row3_col1 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_2cc65_row3_col2 {
#   background-color: #fbfdfe;
#   color: #000000;
# }
# #T_2cc65_row3_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_2cc65_row3_col4, #T_2cc65_row3_col8 {
#   background-color: #f8fbfd;
#   color: #000000;
# }
# #T_2cc65_row3_col5 {
#   background-color: #fdfeff;
#   color: #000000;
# }
# #T_2cc65_row3_col6 {
#   background-color: #e3f0f7;
#   color: #000000;
# }
# #T_2cc65_row3_col7 {
#   background-color: #e2eff7;
#   color: #000000;
# }
# #T_2cc65_row4_col0 {
#   background-color: #70b1d7;
#   color: #f1f1f1;
# }
# #T_2cc65_row4_col2 {
#   background-color: #97c6e2;
#   color: #000000;
# }
# #T_2cc65_row4_col3 {
#   background-color: #abd1e8;
#   color: #000000;
# }
# #T_2cc65_row4_col5 {
#   background-color: #c8e1f0;
#   color: #000000;
# }
# #T_2cc65_row4_col6 {
#   background-color: #b2d5ea;
#   color: #000000;
# }
# #T_2cc65_row4_col7 {
#   background-color: #a3cce5;
#   color: #000000;
# }
# #T_2cc65_row4_col8 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2cc65">
#   <caption>Responses vs In-Position C-Bets</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_2cc65_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_2cc65_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_2cc65_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_2cc65_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_2cc65_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_2cc65_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_2cc65_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_2cc65_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_2cc65_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cc65_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_2cc65_row0_col0" class="data row0 col0" >295</td>
#       <td id="T_2cc65_row0_col1" class="data row0 col1" >1890</td>
#       <td id="T_2cc65_row0_col2" class="data row0 col2" >1448</td>
#       <td id="T_2cc65_row0_col3" class="data row0 col3" >609</td>
#       <td id="T_2cc65_row0_col4" class="data row0 col4" >302</td>
#       <td id="T_2cc65_row0_col5" class="data row0 col5" >29</td>
#       <td id="T_2cc65_row0_col6" class="data row0 col6" >123</td>
#       <td id="T_2cc65_row0_col7" class="data row0 col7" >157</td>
#       <td id="T_2cc65_row0_col8" class="data row0 col8" >86</td>
#     </tr>
#     <tr>
#       <th id="T_2cc65_level0_row1" class="row_heading level0 row1" >Fold</th>
#       <td id="T_2cc65_row1_col0" class="data row1 col0" >29.2%</td>
#       <td id="T_2cc65_row1_col1" class="data row1 col1" >40.3%</td>
#       <td id="T_2cc65_row1_col2" class="data row1 col2" >46.8%</td>
#       <td id="T_2cc65_row1_col3" class="data row1 col3" >55.8%</td>
#       <td id="T_2cc65_row1_col4" class="data row1 col4" >61.6%</td>
#       <td id="T_2cc65_row1_col5" class="data row1 col5" >69.0%</td>
#       <td id="T_2cc65_row1_col6" class="data row1 col6" >59.3%</td>
#       <td id="T_2cc65_row1_col7" class="data row1 col7" >52.2%</td>
#       <td id="T_2cc65_row1_col8" class="data row1 col8" >26.7%</td>
#     </tr>
#     <tr>
#       <th id="T_2cc65_level0_row2" class="row_heading level0 row2" >Call</th>
#       <td id="T_2cc65_row2_col0" class="data row2 col0" >59.7%</td>
#       <td id="T_2cc65_row2_col1" class="data row2 col1" >52.6%</td>
#       <td id="T_2cc65_row2_col2" class="data row2 col2" >45.2%</td>
#       <td id="T_2cc65_row2_col3" class="data row2 col3" >38.3%</td>
#       <td id="T_2cc65_row2_col4" class="data row2 col4" >29.1%</td>
#       <td id="T_2cc65_row2_col5" class="data row2 col5" >24.1%</td>
#       <td id="T_2cc65_row2_col6" class="data row2 col6" >22.0%</td>
#       <td id="T_2cc65_row2_col7" class="data row2 col7" >28.7%</td>
#       <td id="T_2cc65_row2_col8" class="data row2 col8" >64.0%</td>
#     </tr>
#     <tr>
#       <th id="T_2cc65_level0_row3" class="row_heading level0 row3" >Raise</th>
#       <td id="T_2cc65_row3_col0" class="data row3 col0" >11.2%</td>
#       <td id="T_2cc65_row3_col1" class="data row3 col1" >7.1%</td>
#       <td id="T_2cc65_row3_col2" class="data row3 col2" >7.9%</td>
#       <td id="T_2cc65_row3_col3" class="data row3 col3" >5.9%</td>
#       <td id="T_2cc65_row3_col4" class="data row3 col4" >9.3%</td>
#       <td id="T_2cc65_row3_col5" class="data row3 col5" >6.9%</td>
#       <td id="T_2cc65_row3_col6" class="data row3 col6" >18.7%</td>
#       <td id="T_2cc65_row3_col7" class="data row3 col7" >19.1%</td>
#       <td id="T_2cc65_row3_col8" class="data row3 col8" >9.3%</td>
#     </tr>
#     <tr>
#       <th id="T_2cc65_level0_row4" class="row_heading level0 row4" >Continue</th>
#       <td id="T_2cc65_row4_col0" class="data row4 col0" >70.8%</td>
#       <td id="T_2cc65_row4_col1" class="data row4 col1" >59.7%</td>
#       <td id="T_2cc65_row4_col2" class="data row4 col2" >53.2%</td>
#       <td id="T_2cc65_row4_col3" class="data row4 col3" >44.2%</td>
#       <td id="T_2cc65_row4_col4" class="data row4 col4" >38.4%</td>
#       <td id="T_2cc65_row4_col5" class="data row4 col5" >31.0%</td>
#       <td id="T_2cc65_row4_col6" class="data row4 col6" >40.7%</td>
#       <td id="T_2cc65_row4_col7" class="data row4 col7" >47.8%</td>
#       <td id="T_2cc65_row4_col8" class="data row4 col8" >73.3%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ebd07 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_ebd07 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_ebd07_row1_col0 {
#   background-color: #e0eef6;
#   color: #000000;
# }
# #T_ebd07_row1_col1 {
#   background-color: #d2e7f3;
#   color: #000000;
# }
# #T_ebd07_row1_col2 {
#   background-color: #c0ddee;
#   color: #000000;
# }
# #T_ebd07_row1_col3 {
#   background-color: #bddbed;
#   color: #000000;
# }
# #T_ebd07_row1_col4 {
#   background-color: #a1cce5;
#   color: #000000;
# }
# #T_ebd07_row1_col5 {
#   background-color: #eaf4f9;
#   color: #000000;
# }
# #T_ebd07_row1_col6 {
#   background-color: #9dc9e4;
#   color: #000000;
# }
# #T_ebd07_row1_col7 {
#   background-color: #a7cfe7;
#   color: #000000;
# }
# #T_ebd07_row1_col8, #T_ebd07_row3_col0 {
#   background-color: #ecf5fa;
#   color: #000000;
# }
# #T_ebd07_row2_col0 {
#   background-color: #9fcae4;
#   color: #000000;
# }
# #T_ebd07_row2_col1 {
#   background-color: #9fcbe4;
#   color: #000000;
# }
# #T_ebd07_row2_col2 {
#   background-color: #abd1e8;
#   color: #000000;
# }
# #T_ebd07_row2_col3 {
#   background-color: #b4d6ea;
#   color: #000000;
# }
# #T_ebd07_row2_col4 {
#   background-color: #d6e9f4;
#   color: #000000;
# }
# #T_ebd07_row2_col5 {
#   background-color: #82badc;
#   color: #000000;
# }
# #T_ebd07_row2_col6 {
#   background-color: #fbfdfe;
#   color: #000000;
# }
# #T_ebd07_row2_col7 {
#   background-color: #e4f0f8;
#   color: #000000;
# }
# #T_ebd07_row2_col8 {
#   background-color: #97c6e2;
#   color: #000000;
# }
# #T_ebd07_row3_col1, #T_ebd07_row3_col3 {
#   background-color: #f9fcfd;
#   color: #000000;
# }
# #T_ebd07_row3_col2, #T_ebd07_row3_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_ebd07_row3_col4 {
#   background-color: #f3f8fc;
#   color: #000000;
# }
# #T_ebd07_row3_col6 {
#   background-color: #d3e7f3;
#   color: #000000;
# }
# #T_ebd07_row3_col7 {
#   background-color: #dfeef6;
#   color: #000000;
# }
# #T_ebd07_row3_col8 {
#   background-color: #e7f2f8;
#   color: #000000;
# }
# #T_ebd07_row4_col0 {
#   background-color: #77b4d9;
#   color: #000000;
# }
# #T_ebd07_row4_col1 {
#   background-color: #84bcdd;
#   color: #000000;
# }
# #T_ebd07_row4_col2 {
#   background-color: #96c6e2;
#   color: #000000;
# }
# #T_ebd07_row4_col3 {
#   background-color: #99c7e3;
#   color: #000000;
# }
# #T_ebd07_row4_col4 {
#   background-color: #b6d7eb;
#   color: #000000;
# }
# #T_ebd07_row4_col5 {
#   background-color: #6dafd6;
#   color: #f1f1f1;
# }
# #T_ebd07_row4_col6 {
#   background-color: #bad9ec;
#   color: #000000;
# }
# #T_ebd07_row4_col7 {
#   background-color: #afd3e9;
#   color: #000000;
# }
# #T_ebd07_row4_col8 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ebd07">
#   <caption>Responses vs Out-of-Position C-Bets</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_ebd07_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_ebd07_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_ebd07_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_ebd07_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_ebd07_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_ebd07_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_ebd07_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_ebd07_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_ebd07_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebd07_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_ebd07_row0_col0" class="data row0 col0" >214</td>
#       <td id="T_ebd07_row0_col1" class="data row0 col1" >824</td>
#       <td id="T_ebd07_row0_col2" class="data row0 col2" >670</td>
#       <td id="T_ebd07_row0_col3" class="data row0 col3" >276</td>
#       <td id="T_ebd07_row0_col4" class="data row0 col4" >191</td>
#       <td id="T_ebd07_row0_col5" class="data row0 col5" >10</td>
#       <td id="T_ebd07_row0_col6" class="data row0 col6" >58</td>
#       <td id="T_ebd07_row0_col7" class="data row0 col7" >79</td>
#       <td id="T_ebd07_row0_col8" class="data row0 col8" >89</td>
#     </tr>
#     <tr>
#       <th id="T_ebd07_level0_row1" class="row_heading level0 row1" >Fold</th>
#       <td id="T_ebd07_row1_col0" class="data row1 col0" >24.8%</td>
#       <td id="T_ebd07_row1_col1" class="data row1 col1" >31.3%</td>
#       <td id="T_ebd07_row1_col2" class="data row1 col2" >39.9%</td>
#       <td id="T_ebd07_row1_col3" class="data row1 col3" >41.3%</td>
#       <td id="T_ebd07_row1_col4" class="data row1 col4" >55.0%</td>
#       <td id="T_ebd07_row1_col5" class="data row1 col5" >20.0%</td>
#       <td id="T_ebd07_row1_col6" class="data row1 col6" >56.9%</td>
#       <td id="T_ebd07_row1_col7" class="data row1 col7" >51.9%</td>
#       <td id="T_ebd07_row1_col8" class="data row1 col8" >19.1%</td>
#     </tr>
#     <tr>
#       <th id="T_ebd07_level0_row2" class="row_heading level0 row2" >Call</th>
#       <td id="T_ebd07_row2_col0" class="data row2 col0" >56.1%</td>
#       <td id="T_ebd07_row2_col1" class="data row2 col1" >55.8%</td>
#       <td id="T_ebd07_row2_col2" class="data row2 col2" >50.3%</td>
#       <td id="T_ebd07_row2_col3" class="data row2 col3" >46.0%</td>
#       <td id="T_ebd07_row2_col4" class="data row2 col4" >29.3%</td>
#       <td id="T_ebd07_row2_col5" class="data row2 col5" >70.0%</td>
#       <td id="T_ebd07_row2_col6" class="data row2 col6" >12.1%</td>
#       <td id="T_ebd07_row2_col7" class="data row2 col7" >22.8%</td>
#       <td id="T_ebd07_row2_col8" class="data row2 col8" >59.6%</td>
#     </tr>
#     <tr>
#       <th id="T_ebd07_level0_row3" class="row_heading level0 row3" >Raise</th>
#       <td id="T_ebd07_row3_col0" class="data row3 col0" >19.2%</td>
#       <td id="T_ebd07_row3_col1" class="data row3 col1" >12.9%</td>
#       <td id="T_ebd07_row3_col2" class="data row3 col2" >9.9%</td>
#       <td id="T_ebd07_row3_col3" class="data row3 col3" >12.7%</td>
#       <td id="T_ebd07_row3_col4" class="data row3 col4" >15.7%</td>
#       <td id="T_ebd07_row3_col5" class="data row3 col5" >10.0%</td>
#       <td id="T_ebd07_row3_col6" class="data row3 col6" >31.0%</td>
#       <td id="T_ebd07_row3_col7" class="data row3 col7" >25.3%</td>
#       <td id="T_ebd07_row3_col8" class="data row3 col8" >21.3%</td>
#     </tr>
#     <tr>
#       <th id="T_ebd07_level0_row4" class="row_heading level0 row4" >Continue</th>
#       <td id="T_ebd07_row4_col0" class="data row4 col0" >75.2%</td>
#       <td id="T_ebd07_row4_col1" class="data row4 col1" >68.7%</td>
#       <td id="T_ebd07_row4_col2" class="data row4 col2" >60.1%</td>
#       <td id="T_ebd07_row4_col3" class="data row4 col3" >58.7%</td>
#       <td id="T_ebd07_row4_col4" class="data row4 col4" >45.0%</td>
#       <td id="T_ebd07_row4_col5" class="data row4 col5" >80.0%</td>
#       <td id="T_ebd07_row4_col6" class="data row4 col6" >43.1%</td>
#       <td id="T_ebd07_row4_col7" class="data row4 col7" >48.1%</td>
#       <td id="T_ebd07_row4_col8" class="data row4 col8" >80.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
if not responses_df.empty:
    def response_flop_group(count):
        if count <= 2:
            return '2 Players'
        if count == 3:
            return '3 Players'
        return '4+ Players'

    responses_df['flop_group'] = responses_df['flop_players'].apply(response_flop_group)

    response_group_titles = [
        ('2 Players', 'Responses (2 Players)'),
        ('3 Players', 'Responses (3 Players)'),
        ('4+ Players', 'Responses (4 Players)'),
    ]

    for group_key, title in response_group_titles:
        mask = responses_df['flop_group'] == group_key
        if mask.any():
            display_response_for_mask(mask, title)
# Out:
# <style type="text/css">
# #T_2f39a th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_2f39a td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_2f39a_row1_col0 {
#   background-color: #e1eff7;
#   color: #000000;
# }
# #T_2f39a_row1_col1 {
#   background-color: #cae2f0;
#   color: #000000;
# }
# #T_2f39a_row1_col2 {
#   background-color: #bddbed;
#   color: #000000;
# }
# #T_2f39a_row1_col3, #T_2f39a_row2_col3 {
#   background-color: #b1d4e9;
#   color: #000000;
# }
# #T_2f39a_row1_col4 {
#   background-color: #9bc8e3;
#   color: #000000;
# }
# #T_2f39a_row1_col5, #T_2f39a_row4_col5 {
#   background-color: #a7cfe7;
#   color: #000000;
# }
# #T_2f39a_row1_col6 {
#   background-color: #a0cbe5;
#   color: #000000;
# }
# #T_2f39a_row1_col7 {
#   background-color: #b8d8eb;
#   color: #000000;
# }
# #T_2f39a_row1_col8 {
#   background-color: #e4f0f7;
#   color: #000000;
# }
# #T_2f39a_row2_col0 {
#   background-color: #8fc2e0;
#   color: #000000;
# }
# #T_2f39a_row2_col1 {
#   background-color: #98c7e3;
#   color: #000000;
# }
# #T_2f39a_row2_col2 {
#   background-color: #a5cee6;
#   color: #000000;
# }
# #T_2f39a_row2_col4 {
#   background-color: #cfe5f2;
#   color: #000000;
# }
# #T_2f39a_row2_col5 {
#   background-color: #b9d9ec;
#   color: #000000;
# }
# #T_2f39a_row2_col6 {
#   background-color: #e3eff7;
#   color: #000000;
# }
# #T_2f39a_row2_col7 {
#   background-color: #c8e1f0;
#   color: #000000;
# }
# #T_2f39a_row2_col8 {
#   background-color: #8bbfdf;
#   color: #000000;
# }
# #T_2f39a_row3_col0 {
#   background-color: #eff6fa;
#   color: #000000;
# }
# #T_2f39a_row3_col1 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_2f39a_row3_col2, #T_2f39a_row3_col3 {
#   background-color: #fdfeff;
#   color: #000000;
# }
# #T_2f39a_row3_col4 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# #T_2f39a_row3_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_2f39a_row3_col6 {
#   background-color: #dcecf5;
#   color: #000000;
# }
# #T_2f39a_row3_col7 {
#   background-color: #e0eef6;
#   color: #000000;
# }
# #T_2f39a_row3_col8 {
#   background-color: #f1f7fb;
#   color: #000000;
# }
# #T_2f39a_row4_col0 {
#   background-color: #6dafd6;
#   color: #f1f1f1;
# }
# #T_2f39a_row4_col1 {
#   background-color: #84bcdd;
#   color: #000000;
# }
# #T_2f39a_row4_col2 {
#   background-color: #91c3e1;
#   color: #000000;
# }
# #T_2f39a_row4_col3 {
#   background-color: #9dcae4;
#   color: #000000;
# }
# #T_2f39a_row4_col4 {
#   background-color: #b4d6ea;
#   color: #000000;
# }
# #T_2f39a_row4_col6 {
#   background-color: #aed3e8;
#   color: #000000;
# }
# #T_2f39a_row4_col7 {
#   background-color: #97c6e2;
#   color: #000000;
# }
# #T_2f39a_row4_col8 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2f39a">
#   <caption>Responses (2 Players)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_2f39a_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_2f39a_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_2f39a_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_2f39a_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_2f39a_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_2f39a_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_2f39a_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_2f39a_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_2f39a_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f39a_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_2f39a_row0_col0" class="data row0 col0" >309</td>
#       <td id="T_2f39a_row0_col1" class="data row0 col1" >2048</td>
#       <td id="T_2f39a_row0_col2" class="data row0 col2" >1441</td>
#       <td id="T_2f39a_row0_col3" class="data row0 col3" >611</td>
#       <td id="T_2f39a_row0_col4" class="data row0 col4" >317</td>
#       <td id="T_2f39a_row0_col5" class="data row0 col5" >24</td>
#       <td id="T_2f39a_row0_col6" class="data row0 col6" >96</td>
#       <td id="T_2f39a_row0_col7" class="data row0 col7" >111</td>
#       <td id="T_2f39a_row0_col8" class="data row0 col8" >112</td>
#     </tr>
#     <tr>
#       <th id="T_2f39a_level0_row1" class="row_heading level0 row1" >Fold</th>
#       <td id="T_2f39a_row1_col0" class="data row1 col0" >22.3%</td>
#       <td id="T_2f39a_row1_col1" class="data row1 col1" >33.3%</td>
#       <td id="T_2f39a_row1_col2" class="data row1 col2" >39.7%</td>
#       <td id="T_2f39a_row1_col3" class="data row1 col3" >45.3%</td>
#       <td id="T_2f39a_row1_col4" class="data row1 col4" >55.8%</td>
#       <td id="T_2f39a_row1_col5" class="data row1 col5" >50.0%</td>
#       <td id="T_2f39a_row1_col6" class="data row1 col6" >53.1%</td>
#       <td id="T_2f39a_row1_col7" class="data row1 col7" >42.3%</td>
#       <td id="T_2f39a_row1_col8" class="data row1 col8" >21.4%</td>
#     </tr>
#     <tr>
#       <th id="T_2f39a_level0_row2" class="row_heading level0 row2" >Call</th>
#       <td id="T_2f39a_row2_col0" class="data row2 col0" >61.5%</td>
#       <td id="T_2f39a_row2_col1" class="data row2 col1" >57.1%</td>
#       <td id="T_2f39a_row2_col2" class="data row2 col2" >51.0%</td>
#       <td id="T_2f39a_row2_col3" class="data row2 col3" >45.3%</td>
#       <td id="T_2f39a_row2_col4" class="data row2 col4" >30.9%</td>
#       <td id="T_2f39a_row2_col5" class="data row2 col5" >41.7%</td>
#       <td id="T_2f39a_row2_col6" class="data row2 col6" >21.9%</td>
#       <td id="T_2f39a_row2_col7" class="data row2 col7" >34.2%</td>
#       <td id="T_2f39a_row2_col8" class="data row2 col8" >63.4%</td>
#     </tr>
#     <tr>
#       <th id="T_2f39a_level0_row3" class="row_heading level0 row3" >Raise</th>
#       <td id="T_2f39a_row3_col0" class="data row3 col0" >16.2%</td>
#       <td id="T_2f39a_row3_col1" class="data row3 col1" >9.6%</td>
#       <td id="T_2f39a_row3_col2" class="data row3 col2" >9.3%</td>
#       <td id="T_2f39a_row3_col3" class="data row3 col3" >9.3%</td>
#       <td id="T_2f39a_row3_col4" class="data row3 col4" >13.2%</td>
#       <td id="T_2f39a_row3_col5" class="data row3 col5" >8.3%</td>
#       <td id="T_2f39a_row3_col6" class="data row3 col6" >25.0%</td>
#       <td id="T_2f39a_row3_col7" class="data row3 col7" >23.4%</td>
#       <td id="T_2f39a_row3_col8" class="data row3 col8" >15.2%</td>
#     </tr>
#     <tr>
#       <th id="T_2f39a_level0_row4" class="row_heading level0 row4" >Continue</th>
#       <td id="T_2f39a_row4_col0" class="data row4 col0" >77.7%</td>
#       <td id="T_2f39a_row4_col1" class="data row4 col1" >66.7%</td>
#       <td id="T_2f39a_row4_col2" class="data row4 col2" >60.3%</td>
#       <td id="T_2f39a_row4_col3" class="data row4 col3" >54.7%</td>
#       <td id="T_2f39a_row4_col4" class="data row4 col4" >44.2%</td>
#       <td id="T_2f39a_row4_col5" class="data row4 col5" >50.0%</td>
#       <td id="T_2f39a_row4_col6" class="data row4 col6" >46.9%</td>
#       <td id="T_2f39a_row4_col7" class="data row4 col7" >57.7%</td>
#       <td id="T_2f39a_row4_col8" class="data row4 col8" >78.6%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2e504 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_2e504 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_2e504_row1_col0 {
#   background-color: #b6d7eb;
#   color: #000000;
# }
# #T_2e504_row1_col1 {
#   background-color: #95c5e2;
#   color: #000000;
# }
# #T_2e504_row1_col2 {
#   background-color: #8cc0df;
#   color: #000000;
# }
# #T_2e504_row1_col3 {
#   background-color: #71b1d8;
#   color: #f1f1f1;
# }
# #T_2e504_row1_col4, #T_2e504_row4_col8 {
#   background-color: #6dafd6;
#   color: #f1f1f1;
# }
# #T_2e504_row1_col5 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# #T_2e504_row1_col6 {
#   background-color: #78b5da;
#   color: #000000;
# }
# #T_2e504_row1_col7 {
#   background-color: #85bcdd;
#   color: #000000;
# }
# #T_2e504_row1_col8 {
#   background-color: #bad9ec;
#   color: #000000;
# }
# #T_2e504_row2_col0 {
#   background-color: #8dc1df;
#   color: #000000;
# }
# #T_2e504_row2_col1, #T_2e504_row4_col7 {
#   background-color: #a2cce5;
#   color: #000000;
# }
# #T_2e504_row2_col2 {
#   background-color: #acd2e8;
#   color: #000000;
# }
# #T_2e504_row2_col3 {
#   background-color: #c1ddee;
#   color: #000000;
# }
# #T_2e504_row2_col4 {
#   background-color: #cee4f1;
#   color: #000000;
# }
# #T_2e504_row2_col5, #T_2e504_row3_col6 {
#   background-color: #cce3f1;
#   color: #000000;
# }
# #T_2e504_row2_col6 {
#   background-color: #eff6fa;
#   color: #000000;
# }
# #T_2e504_row2_col7, #T_2e504_row3_col7 {
#   background-color: #d7e9f4;
#   color: #000000;
# }
# #T_2e504_row2_col8 {
#   background-color: #99c7e3;
#   color: #000000;
# }
# #T_2e504_row3_col0 {
#   background-color: #eff6fb;
#   color: #000000;
# }
# #T_2e504_row3_col1, #T_2e504_row3_col5 {
#   background-color: #fcfdfe;
#   color: #000000;
# }
# #T_2e504_row3_col2 {
#   background-color: #fafcfe;
#   color: #000000;
# }
# #T_2e504_row3_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_2e504_row3_col4 {
#   background-color: #f7fbfd;
#   color: #000000;
# }
# #T_2e504_row3_col8 {
#   background-color: #e0eef6;
#   color: #000000;
# }
# #T_2e504_row4_col0 {
#   background-color: #70b1d7;
#   color: #f1f1f1;
# }
# #T_2e504_row4_col1 {
#   background-color: #91c3e1;
#   color: #000000;
# }
# #T_2e504_row4_col2 {
#   background-color: #9ac8e3;
#   color: #000000;
# }
# #T_2e504_row4_col3 {
#   background-color: #b5d6ea;
#   color: #000000;
# }
# #T_2e504_row4_col4 {
#   background-color: #b9d9ec;
#   color: #000000;
# }
# #T_2e504_row4_col5 {
#   background-color: #bcdaec;
#   color: #000000;
# }
# #T_2e504_row4_col6 {
#   background-color: #aed3e9;
#   color: #000000;
# }
# </style>
# <table id="T_2e504">
#   <caption>Responses (3 Players)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_2e504_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_2e504_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_2e504_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_2e504_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_2e504_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_2e504_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_2e504_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_2e504_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_2e504_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e504_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_2e504_row0_col0" class="data row0 col0" >141</td>
#       <td id="T_2e504_row0_col1" class="data row0 col1" >570</td>
#       <td id="T_2e504_row0_col2" class="data row0 col2" >554</td>
#       <td id="T_2e504_row0_col3" class="data row0 col3" >224</td>
#       <td id="T_2e504_row0_col4" class="data row0 col4" >149</td>
#       <td id="T_2e504_row0_col5" class="data row0 col5" >15</td>
#       <td id="T_2e504_row0_col6" class="data row0 col6" >49</td>
#       <td id="T_2e504_row0_col7" class="data row0 col7" >82</td>
#       <td id="T_2e504_row0_col8" class="data row0 col8" >44</td>
#     </tr>
#     <tr>
#       <th id="T_2e504_level0_row1" class="row_heading level0 row1" >Fold</th>
#       <td id="T_2e504_row1_col0" class="data row1 col0" >35.5%</td>
#       <td id="T_2e504_row1_col1" class="data row1 col1" >49.3%</td>
#       <td id="T_2e504_row1_col2" class="data row1 col2" >52.9%</td>
#       <td id="T_2e504_row1_col3" class="data row1 col3" >63.8%</td>
#       <td id="T_2e504_row1_col4" class="data row1 col4" >65.8%</td>
#       <td id="T_2e504_row1_col5" class="data row1 col5" >66.7%</td>
#       <td id="T_2e504_row1_col6" class="data row1 col6" >61.2%</td>
#       <td id="T_2e504_row1_col7" class="data row1 col7" >56.1%</td>
#       <td id="T_2e504_row1_col8" class="data row1 col8" >34.1%</td>
#     </tr>
#     <tr>
#       <th id="T_2e504_level0_row2" class="row_heading level0 row2" >Call</th>
#       <td id="T_2e504_row2_col0" class="data row2 col0" >52.5%</td>
#       <td id="T_2e504_row2_col1" class="data row2 col1" >43.7%</td>
#       <td id="T_2e504_row2_col2" class="data row2 col2" >39.7%</td>
#       <td id="T_2e504_row2_col3" class="data row2 col3" >30.8%</td>
#       <td id="T_2e504_row2_col4" class="data row2 col4" >25.5%</td>
#       <td id="T_2e504_row2_col5" class="data row2 col5" >26.7%</td>
#       <td id="T_2e504_row2_col6" class="data row2 col6" >12.2%</td>
#       <td id="T_2e504_row2_col7" class="data row2 col7" >22.0%</td>
#       <td id="T_2e504_row2_col8" class="data row2 col8" >47.7%</td>
#     </tr>
#     <tr>
#       <th id="T_2e504_level0_row3" class="row_heading level0 row3" >Raise</th>
#       <td id="T_2e504_row3_col0" class="data row3 col0" >12.1%</td>
#       <td id="T_2e504_row3_col1" class="data row3 col1" >7.0%</td>
#       <td id="T_2e504_row3_col2" class="data row3 col2" >7.4%</td>
#       <td id="T_2e504_row3_col3" class="data row3 col3" >5.4%</td>
#       <td id="T_2e504_row3_col4" class="data row3 col4" >8.7%</td>
#       <td id="T_2e504_row3_col5" class="data row3 col5" >6.7%</td>
#       <td id="T_2e504_row3_col6" class="data row3 col6" >26.5%</td>
#       <td id="T_2e504_row3_col7" class="data row3 col7" >22.0%</td>
#       <td id="T_2e504_row3_col8" class="data row3 col8" >18.2%</td>
#     </tr>
#     <tr>
#       <th id="T_2e504_level0_row4" class="row_heading level0 row4" >Continue</th>
#       <td id="T_2e504_row4_col0" class="data row4 col0" >64.5%</td>
#       <td id="T_2e504_row4_col1" class="data row4 col1" >50.7%</td>
#       <td id="T_2e504_row4_col2" class="data row4 col2" >47.1%</td>
#       <td id="T_2e504_row4_col3" class="data row4 col3" >36.2%</td>
#       <td id="T_2e504_row4_col4" class="data row4 col4" >34.2%</td>
#       <td id="T_2e504_row4_col5" class="data row4 col5" >33.3%</td>
#       <td id="T_2e504_row4_col6" class="data row4 col6" >38.8%</td>
#       <td id="T_2e504_row4_col7" class="data row4 col7" >43.9%</td>
#       <td id="T_2e504_row4_col8" class="data row4 col8" >65.9%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_efbe2 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_efbe2 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_efbe2_row1_col0 {
#   background-color: #cae2f0;
#   color: #000000;
# }
# #T_efbe2_row1_col1 {
#   background-color: #a4cde6;
#   color: #000000;
# }
# #T_efbe2_row1_col2 {
#   background-color: #99c7e3;
#   color: #000000;
# }
# #T_efbe2_row1_col3 {
#   background-color: #95c5e2;
#   color: #000000;
# }
# #T_efbe2_row1_col4 {
#   background-color: #a2cce5;
#   color: #000000;
# }
# #T_efbe2_row1_col5, #T_efbe2_row2_col5, #T_efbe2_row3_col5, #T_efbe2_row4_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_efbe2_row1_col6 {
#   background-color: #92c4e1;
#   color: #000000;
# }
# #T_efbe2_row1_col7 {
#   background-color: #92c3e1;
#   color: #000000;
# }
# #T_efbe2_row1_col8, #T_efbe2_row3_col2 {
#   background-color: #f7fbfd;
#   color: #000000;
# }
# #T_efbe2_row2_col0 {
#   background-color: #aad1e8;
#   color: #000000;
# }
# #T_efbe2_row2_col1 {
#   background-color: #c4dfef;
#   color: #000000;
# }
# #T_efbe2_row2_col2, #T_efbe2_row4_col7 {
#   background-color: #d0e5f2;
#   color: #000000;
# }
# #T_efbe2_row2_col3 {
#   background-color: #d3e7f3;
#   color: #000000;
# }
# #T_efbe2_row2_col4 {
#   background-color: #d1e6f2;
#   color: #000000;
# }
# #T_efbe2_row2_col6 {
#   background-color: #e1eef7;
#   color: #000000;
# }
# #T_efbe2_row2_col7 {
#   background-color: #e6f1f8;
#   color: #000000;
# }
# #T_efbe2_row2_col8 {
#   background-color: #7bb7db;
#   color: #000000;
# }
# #T_efbe2_row3_col0 {
#   background-color: #ecf5fa;
#   color: #000000;
# }
# #T_efbe2_row3_col1, #T_efbe2_row3_col3 {
#   background-color: #f9fcfd;
#   color: #000000;
# }
# #T_efbe2_row3_col4, #T_efbe2_row3_col6 {
#   background-color: #eef5fa;
#   color: #000000;
# }
# #T_efbe2_row3_col7 {
#   background-color: #eaf3f9;
#   color: #000000;
# }
# #T_efbe2_row3_col8 {
#   background-color: #eff6fa;
#   color: #000000;
# }
# #T_efbe2_row4_col0 {
#   background-color: #98c6e2;
#   color: #000000;
# }
# #T_efbe2_row4_col1 {
#   background-color: #bedbed;
#   color: #000000;
# }
# #T_efbe2_row4_col2 {
#   background-color: #c8e1f0;
#   color: #000000;
# }
# #T_efbe2_row4_col3 {
#   background-color: #cde4f1;
#   color: #000000;
# }
# #T_efbe2_row4_col4 {
#   background-color: #bfdced;
#   color: #000000;
# }
# #T_efbe2_row4_col6 {
#   background-color: #cfe5f2;
#   color: #000000;
# }
# #T_efbe2_row4_col8 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_efbe2">
#   <caption>Responses (4 Players)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_efbe2_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_efbe2_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_efbe2_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_efbe2_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_efbe2_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_efbe2_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_efbe2_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_efbe2_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_efbe2_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efbe2_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_efbe2_row0_col0" class="data row0 col0" >59</td>
#       <td id="T_efbe2_row0_col1" class="data row0 col1" >96</td>
#       <td id="T_efbe2_row0_col2" class="data row0 col2" >123</td>
#       <td id="T_efbe2_row0_col3" class="data row0 col3" >50</td>
#       <td id="T_efbe2_row0_col4" class="data row0 col4" >27</td>
#       <td id="T_efbe2_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_efbe2_row0_col6" class="data row0 col6" >36</td>
#       <td id="T_efbe2_row0_col7" class="data row0 col7" >43</td>
#       <td id="T_efbe2_row0_col8" class="data row0 col8" >19</td>
#     </tr>
#     <tr>
#       <th id="T_efbe2_level0_row1" class="row_heading level0 row1" >Fold</th>
#       <td id="T_efbe2_row1_col0" class="data row1 col0" >33.9%</td>
#       <td id="T_efbe2_row1_col1" class="data row1 col1" >58.3%</td>
#       <td id="T_efbe2_row1_col2" class="data row1 col2" >65.0%</td>
#       <td id="T_efbe2_row1_col3" class="data row1 col3" >68.0%</td>
#       <td id="T_efbe2_row1_col4" class="data row1 col4" >59.3%</td>
#       <td id="T_efbe2_row1_col5" class="data row1 col5" >0.0%</td>
#       <td id="T_efbe2_row1_col6" class="data row1 col6" >69.4%</td>
#       <td id="T_efbe2_row1_col7" class="data row1 col7" >69.8%</td>
#       <td id="T_efbe2_row1_col8" class="data row1 col8" >5.3%</td>
#     </tr>
#     <tr>
#       <th id="T_efbe2_level0_row2" class="row_heading level0 row2" >Call</th>
#       <td id="T_efbe2_row2_col0" class="data row2 col0" >54.2%</td>
#       <td id="T_efbe2_row2_col1" class="data row2 col1" >37.5%</td>
#       <td id="T_efbe2_row2_col2" class="data row2 col2" >30.1%</td>
#       <td id="T_efbe2_row2_col3" class="data row2 col3" >28.0%</td>
#       <td id="T_efbe2_row2_col4" class="data row2 col4" >29.6%</td>
#       <td id="T_efbe2_row2_col5" class="data row2 col5" >0.0%</td>
#       <td id="T_efbe2_row2_col6" class="data row2 col6" >19.4%</td>
#       <td id="T_efbe2_row2_col7" class="data row2 col7" >16.3%</td>
#       <td id="T_efbe2_row2_col8" class="data row2 col8" >84.2%</td>
#     </tr>
#     <tr>
#       <th id="T_efbe2_level0_row3" class="row_heading level0 row3" >Raise</th>
#       <td id="T_efbe2_row3_col0" class="data row3 col0" >11.9%</td>
#       <td id="T_efbe2_row3_col1" class="data row3 col1" >4.2%</td>
#       <td id="T_efbe2_row3_col2" class="data row3 col2" >4.9%</td>
#       <td id="T_efbe2_row3_col3" class="data row3 col3" >4.0%</td>
#       <td id="T_efbe2_row3_col4" class="data row3 col4" >11.1%</td>
#       <td id="T_efbe2_row3_col5" class="data row3 col5" >0.0%</td>
#       <td id="T_efbe2_row3_col6" class="data row3 col6" >11.1%</td>
#       <td id="T_efbe2_row3_col7" class="data row3 col7" >14.0%</td>
#       <td id="T_efbe2_row3_col8" class="data row3 col8" >10.5%</td>
#     </tr>
#     <tr>
#       <th id="T_efbe2_level0_row4" class="row_heading level0 row4" >Continue</th>
#       <td id="T_efbe2_row4_col0" class="data row4 col0" >66.1%</td>
#       <td id="T_efbe2_row4_col1" class="data row4 col1" >41.7%</td>
#       <td id="T_efbe2_row4_col2" class="data row4 col2" >35.0%</td>
#       <td id="T_efbe2_row4_col3" class="data row4 col3" >32.0%</td>
#       <td id="T_efbe2_row4_col4" class="data row4 col4" >40.7%</td>
#       <td id="T_efbe2_row4_col5" class="data row4 col5" >0.0%</td>
#       <td id="T_efbe2_row4_col6" class="data row4 col6" >30.6%</td>
#       <td id="T_efbe2_row4_col7" class="data row4 col7" >30.2%</td>
#       <td id="T_efbe2_row4_col8" class="data row4 col8" >94.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
if not responses_df.empty:
    raise_rows = responses_df[responses_df['response'] == 'Raise']
    if raise_rows.empty:
        print('No raise responses recorded.')
    else:
        raise_records = []
        for _, row in raise_rows.iterrows():
            primary = row.get('responder_primary')
            if not primary:
                continue
            raise_records.append(
                {
                    'ratio': float(row['ratio']),
                    'primary': primary,
                    'has_flush_draw': bool(row.get('responder_has_flush_draw')),
                    'has_oesd_dg': bool(row.get('responder_has_oesd_dg')),
                }
            )
        if raise_records:
            raise_primary_groups = {cat: [cat] for cat in available_primary_categories(raise_records)}
            raise_draw_flags = {
                'Flush Draw': 'has_flush_draw',
                'OESD/DG': 'has_oesd_dg',
            }
            raise_summary = summarize_events(raise_records, BUCKETS, raise_primary_groups, raise_draw_flags)
            print("Opponent holdings when they raise the hero's c-bet (bucketed by hero's sizing).")
            display_heatmap_tables(
                raise_summary,
                'Opponent Raise Holdings vs Hero C-Bet',
                base_color='#cb181d',
                group_color='#88419d',
            )
        else:
            print('Raise responses lack classified hands.')
    call_rows = responses_df[responses_df['response'] == 'Call']
    if call_rows.empty:
        print('No call responses recorded.')
    else:
        call_records = []
        for _, row in call_rows.iterrows():
            primary = row.get('responder_primary')
            if not primary:
                continue
            call_records.append(
                {
                    'ratio': float(row['ratio']),
                    'primary': primary,
                    'has_flush_draw': bool(row.get('responder_has_flush_draw')),
                    'has_oesd_dg': bool(row.get('responder_has_oesd_dg')),
                }
            )
        if call_records:
            call_primary_groups = {cat: [cat] for cat in available_primary_categories(call_records)}
            call_draw_flags = {
                'Flush Draw': 'has_flush_draw',
                'OESD/DG': 'has_oesd_dg',
            }
            call_summary = summarize_events(call_records, BUCKETS, call_primary_groups, call_draw_flags)
            print("Opponent holdings when they call the hero's c-bet (bucketed by hero's sizing).")
            display_heatmap_tables(
                call_summary,
                'Opponent Call Holdings vs Hero C-Bet',
                base_color='#2171b5',
                group_color='#6baed6',
            )
        else:
            print('Call responses lack classified hands.')

    if turn_events:
        display_turn_response_holdings(turn_events, turn_responses, 'Barrel', 'Raise', 'Opponent Raise Holdings vs Hero Barrel', base_color='#cb181d', group_color='#88419d')
        display_turn_response_holdings(turn_events, turn_responses, 'Delayed', 'Raise', 'Opponent Raise Holdings vs Hero Delayed C-Bet', base_color='#cb181d', group_color='#88419d')
        display_turn_response_holdings(turn_events, turn_responses, 'Barrel', 'Call', 'Opponent Call Holdings vs Hero Barrel', base_color='#2171b5', group_color='#6baed6')
        display_turn_response_holdings(turn_events, turn_responses, 'Delayed', 'Call', 'Opponent Call Holdings vs Hero Delayed C-Bet', base_color='#2171b5', group_color='#6baed6')
else:
    print('No c-bet response events available.')
# Out:
# Opponent holdings when they raise the hero's c-bet (bucketed by hero's sizing).
# <style type="text/css">
# #T_40c58_row1_col0 {
#   background-color: #de6e71;
#   color: #f1f1f1;
# }
# #T_40c58_row1_col1 {
#   background-color: #e28083;
#   color: #f1f1f1;
# }
# #T_40c58_row1_col2, #T_40c58_row1_col3 {
#   background-color: #e99d9f;
#   color: #000000;
# }
# #T_40c58_row1_col4 {
#   background-color: #e89a9c;
#   color: #000000;
# }
# #T_40c58_row1_col5 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_40c58_row1_col6 {
#   background-color: #e1787b;
#   color: #f1f1f1;
# }
# #T_40c58_row2_col0, #T_40c58_row3_col3, #T_40c58_row6_col0, #T_40c58_row8_col0, #T_40c58_row14_col3 {
#   background-color: #fefafb;
#   color: #000000;
# }
# #T_40c58_row2_col1, #T_40c58_row4_col1, #T_40c58_row4_col2, #T_40c58_row8_col1 {
#   background-color: #fefbfb;
#   color: #000000;
# }
# #T_40c58_row2_col2, #T_40c58_row6_col4, #T_40c58_row10_col4, #T_40c58_row12_col4 {
#   background-color: #fbeeee;
#   color: #000000;
# }
# #T_40c58_row2_col3, #T_40c58_row6_col2 {
#   background-color: #fcf1f1;
#   color: #000000;
# }
# #T_40c58_row2_col4, #T_40c58_row5_col4 {
#   background-color: #fae7e8;
#   color: #000000;
# }
# #T_40c58_row2_col5, #T_40c58_row3_col2, #T_40c58_row3_col4, #T_40c58_row3_col5, #T_40c58_row3_col6, #T_40c58_row4_col0, #T_40c58_row4_col3, #T_40c58_row4_col4, #T_40c58_row4_col5, #T_40c58_row4_col6, #T_40c58_row5_col5, #T_40c58_row6_col5, #T_40c58_row7_col0, #T_40c58_row7_col1, #T_40c58_row7_col2, #T_40c58_row7_col3, #T_40c58_row7_col5, #T_40c58_row7_col6, #T_40c58_row8_col5, #T_40c58_row8_col6, #T_40c58_row9_col5, #T_40c58_row11_col5, #T_40c58_row12_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_40c58_row2_col6, #T_40c58_row14_col6 {
#   background-color: #f9e6e6;
#   color: #000000;
# }
# #T_40c58_row3_col0, #T_40c58_row5_col2, #T_40c58_row8_col3, #T_40c58_row12_col3 {
#   background-color: #fdf6f6;
#   color: #000000;
# }
# #T_40c58_row3_col1 {
#   background-color: #fefcfc;
#   color: #000000;
# }
# #T_40c58_row5_col0, #T_40c58_row14_col0 {
#   background-color: #f7dadb;
#   color: #000000;
# }
# #T_40c58_row5_col1, #T_40c58_row12_col0 {
#   background-color: #fcf1f2;
#   color: #000000;
# }
# #T_40c58_row5_col3, #T_40c58_row13_col2 {
#   background-color: #f9e7e7;
#   color: #000000;
# }
# #T_40c58_row5_col6, #T_40c58_row10_col6 {
#   background-color: #f7ddde;
#   color: #000000;
# }
# #T_40c58_row6_col1, #T_40c58_row12_col6 {
#   background-color: #fdf7f7;
#   color: #000000;
# }
# #T_40c58_row6_col3 {
#   background-color: #f8e2e3;
#   color: #000000;
# }
# #T_40c58_row6_col6, #T_40c58_row11_col6 {
#   background-color: #fbefef;
#   color: #000000;
# }
# #T_40c58_row7_col4, #T_40c58_row8_col4 {
#   background-color: #fefafa;
#   color: #000000;
# }
# #T_40c58_row8_col2 {
#   background-color: #fdf8f8;
#   color: #000000;
# }
# #T_40c58_row9_col0 {
#   background-color: #eeb4b5;
#   color: #000000;
# }
# #T_40c58_row9_col1 {
#   background-color: #ecaaac;
#   color: #000000;
# }
# #T_40c58_row9_col2 {
#   background-color: #ecabad;
#   color: #000000;
# }
# #T_40c58_row9_col3 {
#   background-color: #ecadae;
#   color: #000000;
# }
# #T_40c58_row9_col4 {
#   background-color: #edb1b3;
#   color: #000000;
# }
# #T_40c58_row9_col6 {
#   background-color: #eeb3b5;
#   color: #000000;
# }
# #T_40c58_row10_col0 {
#   background-color: #fbeded;
#   color: #000000;
# }
# #T_40c58_row10_col1 {
#   background-color: #f9e4e4;
#   color: #000000;
# }
# #T_40c58_row10_col2 {
#   background-color: #f7dddd;
#   color: #000000;
# }
# #T_40c58_row10_col3 {
#   background-color: #fbecec;
#   color: #000000;
# }
# #T_40c58_row10_col5, #T_40c58_row13_col5, #T_40c58_row14_col5 {
#   background-color: #e58b8e;
#   color: #f1f1f1;
# }
# #T_40c58_row11_col0 {
#   background-color: #f8dedf;
#   color: #000000;
# }
# #T_40c58_row11_col1 {
#   background-color: #f3cacc;
#   color: #000000;
# }
# #T_40c58_row11_col2 {
#   background-color: #f3c8c9;
#   color: #000000;
# }
# #T_40c58_row11_col3, #T_40c58_row11_col4 {
#   background-color: #f3cacb;
#   color: #000000;
# }
# #T_40c58_row12_col1, #T_40c58_row14_col1 {
#   background-color: #fcf0f0;
#   color: #000000;
# }
# #T_40c58_row12_col2, #T_40c58_row13_col1 {
#   background-color: #faeaeb;
#   color: #000000;
# }
# #T_40c58_row13_col0 {
#   background-color: #f2c7c8;
#   color: #000000;
# }
# #T_40c58_row13_col3 {
#   background-color: #f5d4d4;
#   color: #000000;
# }
# #T_40c58_row13_col4 {
#   background-color: #f4d0d1;
#   color: #000000;
# }
# #T_40c58_row13_col6 {
#   background-color: #f4cccd;
#   color: #000000;
# }
# #T_40c58_row14_col2 {
#   background-color: #f9e5e5;
#   color: #000000;
# }
# #T_40c58_row14_col4 {
#   background-color: #fcf3f3;
#   color: #000000;
# }
# </style>
# <table id="T_40c58">
#   <caption>Opponent Raise Holdings vs Hero C-Bet</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_40c58_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_40c58_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_40c58_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_40c58_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_40c58_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_40c58_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_40c58_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40c58_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_40c58_row0_col0" class="data row0 col0" >74.0</td>
#       <td id="T_40c58_row0_col1" class="data row0 col1" >241.0</td>
#       <td id="T_40c58_row0_col2" class="data row0 col2" >181.0</td>
#       <td id="T_40c58_row0_col3" class="data row0 col3" >71.0</td>
#       <td id="T_40c58_row0_col4" class="data row0 col4" >58.0</td>
#       <td id="T_40c58_row0_col5" class="data row0 col5" >3.0</td>
#       <td id="T_40c58_row0_col6" class="data row0 col6" >41.0</td>
#     </tr>
#     <tr>
#       <th id="T_40c58_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_40c58_row1_col0" class="data row1 col0" >41.9</td>
#       <td id="T_40c58_row1_col1" class="data row1 col1" >36.5</td>
#       <td id="T_40c58_row1_col2" class="data row1 col2" >28.2</td>
#       <td id="T_40c58_row1_col3" class="data row1 col3" >28.2</td>
#       <td id="T_40c58_row1_col4" class="data row1 col4" >29.3</td>
#       <td id="T_40c58_row1_col5" class="data row1 col5" >66.7</td>
#       <td id="T_40c58_row1_col6" class="data row1 col6" >39.0</td>
#     </tr>
#     <tr>
#       <th id="T_40c58_level0_row2" class="row_heading level0 row2" >Bottom Pair</th>
#       <td id="T_40c58_row2_col0" class="data row2 col0" >1.4</td>
#       <td id="T_40c58_row2_col1" class="data row2 col1" >1.2</td>
#       <td id="T_40c58_row2_col2" class="data row2 col2" >5.0</td>
#       <td id="T_40c58_row2_col3" class="data row2 col3" >4.2</td>
#       <td id="T_40c58_row2_col4" class="data row2 col4" >6.9</td>
#       <td id="T_40c58_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_40c58_row2_col6" class="data row2 col6" >7.3</td>
#     </tr>
#     <tr>
#       <th id="T_40c58_level0_row3" class="row_heading level0 row3" >Flush</th>
#       <td id="T_40c58_row3_col0" class="data row3 col0" >2.7</td>
#       <td id="T_40c58_row3_col1" class="data row3 col1" >0.8</td>
#       <td id="T_40c58_row3_col2" class="data row3 col2" >0.0</td>
#       <td id="T_40c58_row3_col3" class="data row3 col3" >1.4</td>
#       <td id="T_40c58_row3_col4" class="data row3 col4" >0.0</td>
#       <td id="T_40c58_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_40c58_row3_col6" class="data row3 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_40c58_level0_row4" class="row_heading level0 row4" >Full House</th>
#       <td id="T_40c58_row4_col0" class="data row4 col0" >0.0</td>
#       <td id="T_40c58_row4_col1" class="data row4 col1" >1.2</td>
#       <td id="T_40c58_row4_col2" class="data row4 col2" >1.1</td>
#       <td id="T_40c58_row4_col3" class="data row4 col3" >0.0</td>
#       <td id="T_40c58_row4_col4" class="data row4 col4" >0.0</td>
#       <td id="T_40c58_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_40c58_row4_col6" class="data row4 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id=
# <style type="text/css">
# #T_f0ce1_row1_col0 {
#   background-color: #b488c2;
#   color: #f1f1f1;
# }
# #T_f0ce1_row1_col1 {
#   background-color: #be97c9;
#   color: #f1f1f1;
# }
# #T_f0ce1_row1_col2, #T_f0ce1_row1_col3 {
#   background-color: #cdafd5;
#   color: #000000;
# }
# #T_f0ce1_row1_col4 {
#   background-color: #cbacd4;
#   color: #000000;
# }
# #T_f0ce1_row1_col5, #T_f0ce1_row8_col5 {
#   background-color: #88419d;
#   color: #f1f1f1;
# }
# #T_f0ce1_row1_col6 {
#   background-color: #b990c6;
#   color: #f1f1f1;
# }
# #T_f0ce1_row2_col0 {
#   background-color: #e2d1e7;
#   color: #000000;
# }
# #T_f0ce1_row2_col1, #T_f0ce1_row6_col2 {
#   background-color: #ede3f0;
#   color: #000000;
# }
# #T_f0ce1_row2_col2 {
#   background-color: #e6d8eb;
#   color: #000000;
# }
# #T_f0ce1_row2_col3, #T_f0ce1_row8_col3 {
#   background-color: #e6d7ea;
#   color: #000000;
# }
# #T_f0ce1_row2_col4 {
#   background-color: #ddc9e3;
#   color: #000000;
# }
# #T_f0ce1_row2_col5, #T_f0ce1_row3_col5, #T_f0ce1_row4_col5, #T_f0ce1_row5_col5, #T_f0ce1_row7_col5, #T_f0ce1_row7_col6 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_f0ce1_row2_col6 {
#   background-color: #dcc8e3;
#   color: #000000;
# }
# #T_f0ce1_row3_col0 {
#   background-color: #d8c1df;
#   color: #000000;
# }
# #T_f0ce1_row3_col1 {
#   background-color: #d3b9db;
#   color: #000000;
# }
# #T_f0ce1_row3_col2 {
#   background-color: #d4badb;
#   color: #000000;
# }
# #T_f0ce1_row3_col3 {
#   background-color: #d5bbdc;
#   color: #000000;
# }
# #T_f0ce1_row3_col4 {
#   background-color: #d7bfde;
#   color: #000000;
# }
# #T_f0ce1_row3_col6, #T_f0ce1_row8_col6 {
#   background-color: #d8c0df;
#   color: #000000;
# }
# #T_f0ce1_row4_col0 {
#   background-color: #fdfbfd;
#   color: #000000;
# }
# #T_f0ce1_row4_col1 {
#   background-color: #fbf8fc;
#   color: #000000;
# }
# #T_f0ce1_row4_col2, #T_f0ce1_row7_col3 {
#   background-color: #f8f3f9;
#   color: #000000;
# }
# #T_f0ce1_row4_col3 {
#   background-color: #f0e7f3;
#   color: #000000;
# }
# #T_f0ce1_row4_col4, #T_f0ce1_row6_col4 {
#   background-color: #f6f1f8;
#   color: #000000;
# }
# #T_f0ce1_row4_col6, #T_f0ce1_row5_col6 {
#   background-color: #f7f2f8;
#   color: #000000;
# }
# #T_f0ce1_row5_col0 {
#   background-color: #eee4f1;
#   color: #000000;
# }
# #T_f0ce1_row5_col1 {
#   background-color: #e4d4e9;
#   color: #000000;
# }
# #T_f0ce1_row5_col2 {
#   background-color: #e3d2e8;
#   color: #000000;
# }
# #T_f0ce1_row5_col3, #T_f0ce1_row5_col4 {
#   background-color: #e3d3e8;
#   color: #000000;
# }
# #T_f0ce1_row6_col0 {
#   background-color: #f6f0f7;
#   color: #000000;
# }
# #T_f0ce1_row6_col1 {
#   background-color: #f1e9f3;
#   color: #000000;
# }
# #T_f0ce1_row6_col3 {
#   background-color: #f5eff7;
#   color: #000000;
# }
# #T_f0ce1_row6_col5 {
#   background-color: #c3a0ce;
#   color: #000000;
# }
# #T_f0ce1_row6_col6 {
#   background-color: #eee3f1;
#   color: #000000;
# }
# #T_f0ce1_row7_col0 {
#   background-color: #f8f4f9;
#   color: #000000;
# }
# #T_f0ce1_row7_col1, #T_f0ce1_row7_col2 {
#   background-color: #f9f6fa;
#   color: #000000;
# }
# #T_f0ce1_row7_col4 {
#   background-color: #f9f5fa;
#   color: #000000;
# }
# #T_f0ce1_row8_col0 {
#   background-color: #cfb2d7;
#   color: #000000;
# }
# #T_f0ce1_row8_col1 {
#   background-color: #ece0ef;
#   color: #000000;
# }
# #T_f0ce1_row8_col2 {
#   background-color: #e4d5e9;
#   color: #000000;
# }
# #T_f0ce1_row8_col4 {
#   background-color: #e0cee6;
#   color: #000000;
# }
# </style>
# <table id="T_f0ce1">
#   <caption>Opponent Raise Holdings vs Hero C-Bet (Grouped)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_f0ce1_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_f0ce1_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_f0ce1_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_f0ce1_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_f0ce1_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_f0ce1_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_f0ce1_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0ce1_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_f0ce1_row0_col0" class="data row0 col0" >74.0</td>
#       <td id="T_f0ce1_row0_col1" class="data row0 col1" >241.0</td>
#       <td id="T_f0ce1_row0_col2" class="data row0 col2" >181.0</td>
#       <td id="T_f0ce1_row0_col3" class="data row0 col3" >71.0</td>
#       <td id="T_f0ce1_row0_col4" class="data row0 col4" >58.0</td>
#       <td id="T_f0ce1_row0_col5" class="data row0 col5" >3.0</td>
#       <td id="T_f0ce1_row0_col6" class="data row0 col6" >41.0</td>
#     </tr>
#     <tr>
#       <th id="T_f0ce1_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_f0ce1_row1_col0" class="data row1 col0" >41.9</td>
#       <td id="T_f0ce1_row1_col1" class="data row1 col1" >36.5</td>
#       <td id="T_f0ce1_row1_col2" class="data row1 col2" >28.2</td>
#       <td id="T_f0ce1_row1_col3" class="data row1 col3" >28.2</td>
#       <td id="T_f0ce1_row1_col4" class="data row1 col4" >29.3</td>
#       <td id="T_f0ce1_row1_col5" class="data row1 col5" >66.7</td>
#       <td id="T_f0ce1_row1_col6" class="data row1 col6" >39.0</td>
#     </tr>
#     <tr>
#       <th id="T_f0ce1_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_f0ce1_row2_col0" class="data row2 col0" >16.2</td>
#       <td id="T_f0ce1_row2_col1" class="data row2 col1" >10.0</td>
#       <td id="T_f0ce1_row2_col2" class="data row2 col2" >13.8</td>
#       <td id="T_f0ce1_row2_col3" class="data row2 col3" >14.1</td>
#       <td id="T_f0ce1_row2_col4" class="data row2 col4" >19.0</td>
#       <td id="T_f0ce1_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_f0ce1_row2_col6" class="data row2 col6" >19.5</td>
#     </tr>
#     <tr>
#       <th id="T_f0ce1_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_f0ce1_row3_col0" class="data row3 col0" >21.6</td>
#       <td id="T_f0ce1_row3_col1" class="data row3 col1" >24.5</td>
#       <td id="T_f0ce1_row3_col2" class="data row3 col2" >24.3</td>
#       <td id="T_f0ce1_row3_col3" class="data row3 col3" >23.9</td>
#       <td id="T_f0ce1_row3_col4" class="data row3 col4" >22.4</td>
#       <td id="T_f0ce1_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_f0ce1_row3_col6" class="data row3 col6" >22.0</td>
#     </tr>
#     <tr>
#       <th id="T_f0ce1_level0_row4" class="row_heading level0 row4" >Overpair</th>
#       <td id="T_f0ce1_row4_col0" class="data row4 col0" >1.4</td>
#       <td id="T_f0ce1_row4_col1" class="data row4 col1" >2.5</td>
#       <td id="T_f0ce1_row4_col2" class="data row4 col2" >4.4</td>
#       <td id="T_f0ce1_row4_col3" class="data row4 col3" >8.5</td>
#       <td id="T_f0ce1_row4_col4" class="data row4 col4" >5.2</td>
#       <td id="T_f0ce1_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_f0ce1_row4_col6" class="data row4 col6" >4.9</td>
#     </tr>
#     <tr>
#       <th id="T_f0ce1_level0_row5" class="row_heading level0 row5" >Two Pair</th>
#       <td id="T_f0ce1_row5_col0" class="data row5 col0" >9.5</td>
#       <td id="T_f0ce1_row5_col1" class="data row5 col1" >15.4</td>
#       <td id="T_f0ce1_row5_col2" class="data row5 col2" >16.0</td>
#       <td id="T_f0ce1_row5_col3" class="data row5 col3" >15.5</td>
#       <td id="T_f0ce1_row5_col4" class="data row5 col4" >15.5</td>
#       <td id="T_f0ce1_row5_col5" class="data row5 col5" >0.0</td>
#       <td id="T_f0ce1_row5_col6" class="data row5 col6" >4.9</td>
#     </tr>
#     <tr>
#       <th id="T_f0ce1_level0_row6" class="row_heading level0 row6" >Trips/Set</th>
#       <td id="T_f0ce1_row6_col0" class="data row6 col0" >5.4</td>
#       <td id="T_f0ce1_row6_col1" class="data row6 col1" >7.9</td>
#       <td id="T_f0ce1_row6_col2" class="data row6 col2" >9.9</td>
#       <td id="T_f0ce1_row6_col3" class="data row6 col3" >5.6</td>
#       <td id="T_f0ce1_row6_col4" class="data row6 col4" >5.2</td>
#       <td id="T_f0ce1_row6_col5" class="data row6 col5" >33.3</td>
#       <td id="T_f0ce1_row6_col6" class="data row6 col6" >9.8</td>
#     </tr>
#     <tr>
#       <th id="T_f0ce1_level0_row7"
# Opponent holdings when they call the hero's c-bet (bucketed by hero's sizing).
# <style type="text/css">
# #T_f6357_row1_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_f6357_row1_col1 {
#   background-color: #508fc5;
#   color: #f1f1f1;
# }
# #T_f6357_row1_col2 {
#   background-color: #5391c6;
#   color: #f1f1f1;
# }
# #T_f6357_row1_col3 {
#   background-color: #5190c5;
#   color: #f1f1f1;
# }
# #T_f6357_row1_col4 {
#   background-color: #90b8da;
#   color: #000000;
# }
# #T_f6357_row1_col5 {
#   background-color: #3f84bf;
#   color: #f1f1f1;
# }
# #T_f6357_row1_col6 {
#   background-color: #78a9d2;
#   color: #f1f1f1;
# }
# #T_f6357_row2_col0 {
#   background-color: #e6eff7;
#   color: #000000;
# }
# #T_f6357_row2_col1, #T_f6357_row11_col0, #T_f6357_row14_col2 {
#   background-color: #e7eff7;
#   color: #000000;
# }
# #T_f6357_row2_col2, #T_f6357_row6_col4, #T_f6357_row10_col4, #T_f6357_row12_col2, #T_f6357_row14_col4 {
#   background-color: #e5eef6;
#   color: #000000;
# }
# #T_f6357_row2_col3, #T_f6357_row13_col2, #T_f6357_row14_col3 {
#   background-color: #e1ecf5;
#   color: #000000;
# }
# #T_f6357_row2_col4, #T_f6357_row12_col4 {
#   background-color: #e0ebf5;
#   color: #000000;
# }
# #T_f6357_row2_col5, #T_f6357_row3_col1, #T_f6357_row3_col3, #T_f6357_row3_col5, #T_f6357_row3_col6, #T_f6357_row4_col4, #T_f6357_row4_col5, #T_f6357_row4_col6, #T_f6357_row6_col5, #T_f6357_row7_col1, #T_f6357_row7_col2, #T_f6357_row7_col3, #T_f6357_row7_col5, #T_f6357_row7_col6, #T_f6357_row8_col5, #T_f6357_row8_col6, #T_f6357_row12_col5, #T_f6357_row14_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_f6357_row2_col6, #T_f6357_row10_col6, #T_f6357_row14_col6 {
#   background-color: #f5f8fc;
#   color: #000000;
# }
# #T_f6357_row3_col0, #T_f6357_row6_col0, #T_f6357_row7_col0, #T_f6357_row8_col0, #T_f6357_row8_col3 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_f6357_row3_col2, #T_f6357_row3_col4, #T_f6357_row6_col3, #T_f6357_row7_col4, #T_f6357_row8_col2, #T_f6357_row8_col4 {
#   background-color: #fcfdfe;
#   color: #000000;
# }
# #T_f6357_row4_col0, #T_f6357_row4_col1, #T_f6357_row4_col2, #T_f6357_row4_col3, #T_f6357_row6_col1, #T_f6357_row8_col1 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_f6357_row5_col0, #T_f6357_row14_col0 {
#   background-color: #eef4f9;
#   color: #000000;
# }
# #T_f6357_row5_col1 {
#   background-color: #d1e1f0;
#   color: #000000;
# }
# #T_f6357_row5_col2, #T_f6357_row13_col3 {
#   background-color: #ccdeee;
#   color: #000000;
# }
# #T_f6357_row5_col3 {
#   background-color: #d2e2f0;
#   color: #000000;
# }
# #T_f6357_row5_col4 {
#   background-color: #d8e6f2;
#   color: #000000;
# }
# #T_f6357_row5_col5, #T_f6357_row10_col5, #T_f6357_row11_col5 {
#   background-color: #e4eef6;
#   color: #000000;
# }
# #T_f6357_row5_col6, #T_f6357_row9_col6 {
#   background-color: #d3e3f0;
#   color: #000000;
# }
# #T_f6357_row6_col2 {
#   background-color: #fafcfd;
#   color: #000000;
# }
# #T_f6357_row6_col6, #T_f6357_row12_col1 {
#   background-color: #deeaf4;
#   color: #000000;
# }
# #T_f6357_row9_col0 {
#   background-color: #d9e6f2;
#   color: #000000;
# }
# #T_f6357_row9_col1 {
#   background-color: #c9dced;
#   color: #000000;
# }
# #T_f6357_row9_col2 {
#   background-color: #c8dced;
#   color: #000000;
# }
# #T_f6357_row9_col3 {
#   background-color: #b5d0e6;
#   color: #000000;
# }
# #T_f6357_row9_col4 {
#   background-color: #abc9e3;
#   color: #000000;
# }
# #T_f6357_row9_col5 {
#   background-color: #92b9db;
#   color: #000000;
# }
# #T_f6357_row10_col0 {
#   background-color: #f9fbfd;
#   color: #000000;
# }
# #T_f6357_row10_col1 {
#   background-color: #f2f7fb;
#   color: #000000;
# }
# #T_f6357_row10_col2 {
#   background-color: #f1f6fa;
#   color: #000000;
# }
# #T_f6357_row10_col3, #T_f6357_row12_col3 {
#   background-color: #ebf2f8;
#   color: #000000;
# }
# #T_f6357_row11_col1, #T_f6357_row13_col1 {
#   background-color: #e2edf5;
#   color: #000000;
# }
# #T_f6357_row11_col2, #T_f6357_row13_col4 {
#   background-color: #e7f0f7;
#   color: #000000;
# }
# #T_f6357_row11_col3 {
#   background-color: #f4f8fb;
#   color: #000000;
# }
# #T_f6357_row11_col4 {
#   background-color: #eaf2f8;
#   color: #000000;
# }
# #T_f6357_row11_col6 {
#   background-color: #b1cde5;
#   color: #000000;
# }
# #T_f6357_row12_col0 {
#   background-color: #dce9f3;
#   color: #000000;
# }
# #T_f6357_row12_col6 {
#   background-color: #e9f1f8;
#   color: #000000;
# }
# #T_f6357_row13_col0 {
#   background-color: #dbe8f3;
#   color: #000000;
# }
# #T_f6357_row13_col5 {
#   background-color: #76a8d1;
#   color: #f1f1f1;
# }
# #T_f6357_row13_col6 {
#   background-color: #a5c6e1;
#   color: #000000;
# }
# #T_f6357_row14_col1 {
#   background-color: #edf3f9;
#   color: #000000;
# }
# </style>
# <table id="T_f6357">
#   <caption>Opponent Call Holdings vs Hero C-Bet</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_f6357_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_f6357_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_f6357_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_f6357_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_f6357_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_f6357_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_f6357_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6357_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_f6357_row0_col0" class="data row0 col0" >296.0</td>
#       <td id="T_f6357_row0_col1" class="data row0 col1" >1454.0</td>
#       <td id="T_f6357_row0_col2" class="data row0 col2" >992.0</td>
#       <td id="T_f6357_row0_col3" class="data row0 col3" >360.0</td>
#       <td id="T_f6357_row0_col4" class="data row0 col4" >144.0</td>
#       <td id="T_f6357_row0_col5" class="data row0 col5" >14.0</td>
#       <td id="T_f6357_row0_col6" class="data row0 col6" >34.0</td>
#     </tr>
#     <tr>
#       <th id="T_f6357_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_f6357_row1_col0" class="data row1 col0" >58.1</td>
#       <td id="T_f6357_row1_col1" class="data row1 col1" >45.7</td>
#       <td id="T_f6357_row1_col2" class="data row1 col2" >44.8</td>
#       <td id="T_f6357_row1_col3" class="data row1 col3" >45.6</td>
#       <td id="T_f6357_row1_col4" class="data row1 col4" >29.2</td>
#       <td id="T_f6357_row1_col5" class="data row1 col5" >50.0</td>
#       <td id="T_f6357_row1_col6" class="data row1 col6" >35.3</td>
#     </tr>
#     <tr>
#       <th id="T_f6357_level0_row2" class="row_heading level0 row2" >Bottom Pair</th>
#       <td id="T_f6357_row2_col0" class="data row2 col0" >6.8</td>
#       <td id="T_f6357_row2_col1" class="data row2 col1" >6.5</td>
#       <td id="T_f6357_row2_col2" class="data row2 col2" >6.9</td>
#       <td id="T_f6357_row2_col3" class="data row2 col3" >7.8</td>
#       <td id="T_f6357_row2_col4" class="data row2 col4" >8.3</td>
#       <td id="T_f6357_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_f6357_row2_col6" class="data row2 col6" >2.9</td>
#     </tr>
#     <tr>
#       <th id="T_f6357_level0_row3" class="row_heading level0 row3" >Flush</th>
#       <td id="T_f6357_row3_col0" class="data row3 col0" >0.7</td>
#       <td id="T_f6357_row3_col1" class="data row3 col1" >0.2</td>
#       <td id="T_f6357_row3_col2" class="data row3 col2" >0.7</td>
#       <td id="T_f6357_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_f6357_row3_col4" class="data row3 col4" >0.7</td>
#       <td id="T_f6357_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_f6357_row3_col6" class="data row3 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f6357_level0_row4" class="row_heading level0 row4" >Full House</th>
#       <td id="T_f6357_row4_col0" class="data row4 col0" >0.3</td>
#       <td id="T_f6357_row4_col1" class="data row4 col1" >0.3</td>
#       <td id="T_f6357_row4_col2" class="data row4 col2" >0.4</td>
#       <td id="T_f6357_row4_col3" class="data row4 col3" >0.3</td>
#       <td id="T_f6357_row4_col4" class="data row4 col4" >0.0</td>
#       <td id="T_f6357_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_f6357_row4_col6" class="data row4 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th
# <style type="text/css">
# #T_8b9dd_row1_col0 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# #T_8b9dd_row1_col1 {
#   background-color: #8abfdf;
#   color: #000000;
# }
# #T_8b9dd_row1_col2 {
#   background-color: #8dc0df;
#   color: #000000;
# }
# #T_8b9dd_row1_col3 {
#   background-color: #8bbfdf;
#   color: #000000;
# }
# #T_8b9dd_row1_col4 {
#   background-color: #b5d6ea;
#   color: #000000;
# }
# #T_8b9dd_row1_col5 {
#   background-color: #7fb9dc;
#   color: #000000;
# }
# #T_8b9dd_row1_col6 {
#   background-color: #a5cee6;
#   color: #000000;
# }
# #T_8b9dd_row2_col0, #T_8b9dd_row2_col6, #T_8b9dd_row5_col6 {
#   background-color: #cbe2f1;
#   color: #000000;
# }
# #T_8b9dd_row2_col1, #T_8b9dd_row2_col2 {
#   background-color: #b9d9ec;
#   color: #000000;
# }
# #T_8b9dd_row2_col3 {
#   background-color: #bfdced;
#   color: #000000;
# }
# #T_8b9dd_row2_col4 {
#   background-color: #bad9ec;
#   color: #000000;
# }
# #T_8b9dd_row2_col5, #T_8b9dd_row5_col5, #T_8b9dd_row6_col5 {
#   background-color: #edf5fa;
#   color: #000000;
# }
# #T_8b9dd_row3_col0 {
#   background-color: #e5f1f8;
#   color: #000000;
# }
# #T_8b9dd_row3_col1, #T_8b9dd_row8_col0 {
#   background-color: #dbebf5;
#   color: #000000;
# }
# #T_8b9dd_row3_col2, #T_8b9dd_row8_col2 {
#   background-color: #daebf5;
#   color: #000000;
# }
# #T_8b9dd_row3_col3 {
#   background-color: #cee4f1;
#   color: #000000;
# }
# #T_8b9dd_row3_col4 {
#   background-color: #c7e0ef;
#   color: #000000;
# }
# #T_8b9dd_row3_col5 {
#   background-color: #b6d7eb;
#   color: #000000;
# }
# #T_8b9dd_row3_col6 {
#   background-color: #e1eff7;
#   color: #000000;
# }
# #T_8b9dd_row4_col0 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_8b9dd_row4_col1 {
#   background-color: #feffff;
#   color: #000000;
# }
# #T_8b9dd_row4_col2 {
#   background-color: #fcfdfe;
#   color: #000000;
# }
# #T_8b9dd_row4_col3, #T_8b9dd_row7_col3 {
#   background-color: #fdfeff;
#   color: #000000;
# }
# #T_8b9dd_row4_col4, #T_8b9dd_row6_col4 {
#   background-color: #eef5fa;
#   color: #000000;
# }
# #T_8b9dd_row4_col5, #T_8b9dd_row7_col5, #T_8b9dd_row7_col6 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_8b9dd_row4_col6 {
#   background-color: #e9f3f9;
#   color: #000000;
# }
# #T_8b9dd_row5_col0 {
#   background-color: #eff6fa;
#   color: #000000;
# }
# #T_8b9dd_row5_col1 {
#   background-color: #ecf5fa;
#   color: #000000;
# }
# #T_8b9dd_row5_col2 {
#   background-color: #eff6fb;
#   color: #000000;
# }
# #T_8b9dd_row5_col3 {
#   background-color: #f7fbfd;
#   color: #000000;
# }
# #T_8b9dd_row5_col4 {
#   background-color: #f1f7fb;
#   color: #000000;
# }
# #T_8b9dd_row6_col0 {
#   background-color: #fbfdfe;
#   color: #000000;
# }
# #T_8b9dd_row6_col1 {
#   background-color: #f6fafd;
#   color: #000000;
# }
# #T_8b9dd_row6_col2 {
#   background-color: #f6fafc;
#   color: #000000;
# }
# #T_8b9dd_row6_col3 {
#   background-color: #f2f8fb;
#   color: #000000;
# }
# #T_8b9dd_row6_col6 {
#   background-color: #f8fbfd;
#   color: #000000;
# }
# #T_8b9dd_row7_col0 {
#   background-color: #f9fcfd;
#   color: #000000;
# }
# #T_8b9dd_row7_col1 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_8b9dd_row7_col2, #T_8b9dd_row7_col4 {
#   background-color: #fafcfe;
#   color: #000000;
# }
# #T_8b9dd_row8_col1 {
#   background-color: #dfeef6;
#   color: #000000;
# }
# #T_8b9dd_row8_col3 {
#   background-color: #c8e1f0;
#   color: #000000;
# }
# #T_8b9dd_row8_col4 {
#   background-color: #ddedf6;
#   color: #000000;
# }
# #T_8b9dd_row8_col5 {
#   background-color: #a4cde6;
#   color: #000000;
# }
# #T_8b9dd_row8_col6 {
#   background-color: #bcdaec;
#   color: #000000;
# }
# </style>
# <table id="T_8b9dd">
#   <caption>Opponent Call Holdings vs Hero C-Bet (Grouped)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_8b9dd_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_8b9dd_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_8b9dd_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_8b9dd_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_8b9dd_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_8b9dd_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_8b9dd_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b9dd_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_8b9dd_row0_col0" class="data row0 col0" >296.0</td>
#       <td id="T_8b9dd_row0_col1" class="data row0 col1" >1454.0</td>
#       <td id="T_8b9dd_row0_col2" class="data row0 col2" >992.0</td>
#       <td id="T_8b9dd_row0_col3" class="data row0 col3" >360.0</td>
#       <td id="T_8b9dd_row0_col4" class="data row0 col4" >144.0</td>
#       <td id="T_8b9dd_row0_col5" class="data row0 col5" >14.0</td>
#       <td id="T_8b9dd_row0_col6" class="data row0 col6" >34.0</td>
#     </tr>
#     <tr>
#       <th id="T_8b9dd_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_8b9dd_row1_col0" class="data row1 col0" >58.1</td>
#       <td id="T_8b9dd_row1_col1" class="data row1 col1" >45.7</td>
#       <td id="T_8b9dd_row1_col2" class="data row1 col2" >44.8</td>
#       <td id="T_8b9dd_row1_col3" class="data row1 col3" >45.6</td>
#       <td id="T_8b9dd_row1_col4" class="data row1 col4" >29.2</td>
#       <td id="T_8b9dd_row1_col5" class="data row1 col5" >50.0</td>
#       <td id="T_8b9dd_row1_col6" class="data row1 col6" >35.3</td>
#     </tr>
#     <tr>
#       <th id="T_8b9dd_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_8b9dd_row2_col0" class="data row2 col0" >20.6</td>
#       <td id="T_8b9dd_row2_col1" class="data row2 col1" >27.4</td>
#       <td id="T_8b9dd_row2_col2" class="data row2 col2" >27.3</td>
#       <td id="T_8b9dd_row2_col3" class="data row2 col3" >25.0</td>
#       <td id="T_8b9dd_row2_col4" class="data row2 col4" >27.1</td>
#       <td id="T_8b9dd_row2_col5" class="data row2 col5" >7.1</td>
#       <td id="T_8b9dd_row2_col6" class="data row2 col6" >20.6</td>
#     </tr>
#     <tr>
#       <th id="T_8b9dd_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_8b9dd_row3_col0" class="data row3 col0" >10.1</td>
#       <td id="T_8b9dd_row3_col1" class="data row3 col1" >14.2</td>
#       <td id="T_8b9dd_row3_col2" class="data row3 col2" >14.3</td>
#       <td id="T_8b9dd_row3_col3" class="data row3 col3" >19.4</td>
#       <td id="T_8b9dd_row3_col4" class="data row3 col4" >22.2</td>
#       <td id="T_8b9dd_row3_col5" class="data row3 col5" >28.6</td>
#       <td id="T_8b9dd_row3_col6" class="data row3 col6" >11.8</td>
#     </tr>
#     <tr>
#       <th id="T_8b9dd_level0_row4" class="row_heading level0 row4" >Overpair</th>
#       <td id="T_8b9dd_row4_col0" class="data row4 col0" >0.7</td>
#       <td id="T_8b9dd_row4_col1" class="data row4 col1" >0.4</td>
#       <td id="T_8b9dd_row4_col2" class="data row4 col2" >1.5</td>
#       <td id="T_8b9dd_row4_col3" class="data row4 col3" >0.8</td>
#       <td id="T_8b9dd_row4_col4" class="data row4 col4" >6.9</td>
#       <td id="T_8b9dd_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_8b9dd_row4_col6" class="data row4 col6" >8.8</td>
#     </tr>
#     <tr>
#       <th id="T_8b9dd_level0_row5" class="row_heading level0 row5" >Two Pair</th>
#       <td id="T_8b9dd_row5_col0" class="data row5 col0" >6.4</td>
#       <td id="T_8b9dd_row5_col1" class="data row5 col1" >7.6</td>
#       <td id="T_8b9dd_row5_col2" class="data row5 col2" >6.4</td>
#       <td id="T_8b9dd_row5_col3" class="data row5 col3" >3.1</td>
#       <td id="T_8b9dd_row5_col4" class="data row5 col4" >5.6</td>
#       <td id="T_8b9dd_row5_col5" class="data row5 col5" >7.1</td>
#       <td id="T_8b9dd_row5_col6" class="data row5 col6" >20.6</td>
#     </tr>
#     <tr>
#       <th id="T_8b9dd_level0_row6" class="row_heading level0 row6" >Trips/Set</th>
#       <td id="T_8b9dd_row6_col0" class="data row6 col0" >1.7</td>
#       <td id="T_8b9dd_row6_col1" class="data row6 col1" >3.6</td>
#       <td id="T_8b9dd_row6_col2" class="data row6 col2" >3.8</td>
#       <td id="T_8b9dd_row6_col3" class="data row6 col3" >5.3</td>
#       <td id="T_8b9dd_row6_col4" class="data row6 col4" >6.9</td>
#       <td id="T_8b9dd_row6_col5" cl
# <style type="text/css">
# #T_e1963_row1_col0 {
#   background-color: #d13136;
#   color: #f1f1f1;
# }
# #T_e1963_row1_col1, #T_e1963_row7_col4 {
#   background-color: #d2373b;
#   color: #f1f1f1;
# }
# #T_e1963_row1_col2 {
#   background-color: #cd2227;
#   color: #f1f1f1;
# }
# #T_e1963_row1_col3, #T_e1963_row7_col3 {
#   background-color: #d43f43;
#   color: #f1f1f1;
# }
# #T_e1963_row1_col4, #T_e1963_row14_col4 {
#   background-color: #df7073;
#   color: #f1f1f1;
# }
# #T_e1963_row1_col5, #T_e1963_row7_col5, #T_e1963_row8_col5, #T_e1963_row13_col5 {
#   background-color: #cc1e23;
#   color: #f1f1f1;
# }
# #T_e1963_row1_col6, #T_e1963_row5_col6, #T_e1963_row13_col6 {
#   background-color: #d03034;
#   color: #f1f1f1;
# }
# #T_e1963_row2_col0, #T_e1963_row3_col0, #T_e1963_row3_col2, #T_e1963_row11_col2 {
#   background-color: #fbefef;
#   color: #000000;
# }
# #T_e1963_row2_col1 {
#   background-color: #f7dadb;
#   color: #000000;
# }
# #T_e1963_row2_col2, #T_e1963_row2_col5, #T_e1963_row2_col6, #T_e1963_row3_col5, #T_e1963_row4_col5, #T_e1963_row9_col5, #T_e1963_row10_col5, #T_e1963_row10_col6, #T_e1963_row11_col5, #T_e1963_row11_col6, #T_e1963_row12_col1, #T_e1963_row12_col2, #T_e1963_row12_col4, #T_e1963_row12_col5, #T_e1963_row12_col6 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_e1963_row2_col3, #T_e1963_row3_col3, #T_e1963_row4_col3, #T_e1963_row11_col0 {
#   background-color: #f7ddde;
#   color: #000000;
# }
# #T_e1963_row2_col4, #T_e1963_row6_col0, #T_e1963_row8_col4 {
#   background-color: #f5d4d5;
#   color: #000000;
# }
# #T_e1963_row3_col1, #T_e1963_row4_col4, #T_e1963_row9_col4, #T_e1963_row13_col1, #T_e1963_row13_col4 {
#   background-color: #e99b9e;
#   color: #000000;
# }
# #T_e1963_row3_col4, #T_e1963_row6_col4, #T_e1963_row11_col3, #T_e1963_row11_col4 {
#   background-color: #fcf1f2;
#   color: #000000;
# }
# #T_e1963_row3_col6, #T_e1963_row4_col6, #T_e1963_row6_col6, #T_e1963_row14_col6 {
#   background-color: #f7dddd;
#   color: #000000;
# }
# #T_e1963_row4_col0 {
#   background-color: #f9e6e6;
#   color: #000000;
# }
# #T_e1963_row4_col1, #T_e1963_row4_col2, #T_e1963_row6_col1, #T_e1963_row11_col1 {
#   background-color: #f9e7e7;
#   color: #000000;
# }
# #T_e1963_row5_col0 {
#   background-color: #ecaaac;
#   color: #000000;
# }
# #T_e1963_row5_col1 {
#   background-color: #e38285;
#   color: #f1f1f1;
# }
# #T_e1963_row5_col2, #T_e1963_row8_col2 {
#   background-color: #e38587;
#   color: #f1f1f1;
# }
# #T_e1963_row5_col3 {
#   background-color: #f0bbbd;
#   color: #000000;
# }
# #T_e1963_row5_col4, #T_e1963_row10_col4 {
#   background-color: #e58d8f;
#   color: #f1f1f1;
# }
# #T_e1963_row5_col5, #T_e1963_row6_col5, #T_e1963_row14_col5 {
#   background-color: #e68f91;
#   color: #f1f1f1;
# }
# #T_e1963_row6_col2 {
#   background-color: #f6d6d7;
#   color: #000000;
# }
# #T_e1963_row6_col3 {
#   background-color: #f9e4e4;
#   color: #000000;
# }
# #T_e1963_row7_col0 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_e1963_row7_col1 {
#   background-color: #d85054;
#   color: #f1f1f1;
# }
# #T_e1963_row7_col2 {
#   background-color: #d13237;
#   color: #f1f1f1;
# }
# #T_e1963_row7_col6 {
#   background-color: #d85256;
#   color: #f1f1f1;
# }
# #T_e1963_row8_col0 {
#   background-color: #e8999b;
#   color: #000000;
# }
# #T_e1963_row8_col1 {
#   background-color: #eeb5b6;
#   color: #000000;
# }
# #T_e1963_row8_col3, #T_e1963_row13_col3 {
#   background-color: #dd686b;
#   color: #f1f1f1;
# }
# #T_e1963_row8_col6 {
#   background-color: #f0babc;
#   color: #000000;
# }
# #T_e1963_row9_col0, #T_e1963_row14_col0 {
#   background-color: #eeb2b4;
#   color: #000000;
# }
# #T_e1963_row9_col1 {
#   background-color: #f1c0c2;
#   color: #000000;
# }
# #T_e1963_row9_col2, #T_e1963_row14_col2 {
#   background-color: #e99d9f;
#   color: #000000;
# }
# #T_e1963_row9_col3 {
#   background-color: #e99fa1;
#   color: #000000;
# }
# #T_e1963_row9_col6 {
#   background-color: #e07477;
#   color: #f1f1f1;
# }
# #T_e1963_row10_col0 {
#   background-color: #f4cccd;
#   color: #000000;
# }
# #T_e1963_row10_col1 {
#   background-color: #f4cdce;
#   color: #000000;
# }
# #T_e1963_row10_col2 {
#   background-color: #f8dedf;
#   color: #000000;
# }
# #T_e1963_row10_col3 {
#   background-color: #f4cfd0;
#   color: #000000;
# }
# #T_e1963_row12_col0 {
#   background-color: #fdf7f7;
#   color: #000000;
# }
# #T_e1963_row12_col3 {
#   background-color: #fef9f9;
#   color: #000000;
# }
# #T_e1963_row13_col0 {
#   background-color: #e4878a;
#   color: #f1f1f1;
# }
# #T_e1963_row13_col2 {
#   background-color: #e27d7f;
#   color: #f1f1f1;
# }
# #T_e1963_row14_col1 {
#   background-color: #eba8aa;
#   color: #000000;
# }
# #T_e1963_row14_col3 {
#   background-color: #ecadae;
#   color: #000000;
# }
# </style>
# <table id="T_e1963">
#   <caption>Opponent Raise Holdings vs Hero Barrel</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_e1963_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_e1963_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_e1963_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_e1963_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_e1963_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_e1963_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_e1963_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1963_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_e1963_row0_col0" class="data row0 col0" >105.0</td>
#       <td id="T_e1963_row0_col1" class="data row0 col1" >72.0</td>
#       <td id="T_e1963_row0_col2" class="data row0 col2" >110.0</td>
#       <td id="T_e1963_row0_col3" class="data row0 col3" >131.0</td>
#       <td id="T_e1963_row0_col4" class="data row0 col4" >63.0</td>
#       <td id="T_e1963_row0_col5" class="data row0 col5" >8.0</td>
#       <td id="T_e1963_row0_col6" class="data row0 col6" >26.0</td>
#     </tr>
#     <tr>
#       <th id="T_e1963_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_e1963_row1_col0" class="data row1 col0" >22.9</td>
#       <td id="T_e1963_row1_col1" class="data row1 col1" >22.2</td>
#       <td id="T_e1963_row1_col2" class="data row1 col2" >24.5</td>
#       <td id="T_e1963_row1_col3" class="data row1 col3" >21.4</td>
#       <td id="T_e1963_row1_col4" class="data row1 col4" >15.9</td>
#       <td id="T_e1963_row1_col5" class="data row1 col5" >25.0</td>
#       <td id="T_e1963_row1_col6" class="data row1 col6" >23.1</td>
#     </tr>
#     <tr>
#       <th id="T_e1963_level0_row2" class="row_heading level0 row2" >Underpair</th>
#       <td id="T_e1963_row2_col0" class="data row2 col0" >1.9</td>
#       <td id="T_e1963_row2_col1" class="data row2 col1" >4.2</td>
#       <td id="T_e1963_row2_col2" class="data row2 col2" >0.0</td>
#       <td id="T_e1963_row2_col3" class="data row2 col3" >3.8</td>
#       <td id="T_e1963_row2_col4" class="data row2 col4" >4.8</td>
#       <td id="T_e1963_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_e1963_row2_col6" class="data row2 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_e1963_level0_row3" class="row_heading level0 row3" >Bottom Pair</th>
#       <td id="T_e1963_row3_col0" class="data row3 col0" >1.9</td>
#       <td id="T_e1963_row3_col1" class="data row3 col1" >11.1</td>
#       <td id="T_e1963_row3_col2" class="data row3 col2" >1.8</td>
#       <td id="T_e1963_row3_col3" class="data row3 col3" >3.8</td>
#       <td id="T_e1963_row3_col4" class="data row3 col4" >1.6</td>
#       <td id="T_e1963_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_e1963_row3_col6" class="data row3 col6" >3.8</td>
#     </tr>
#     <tr>
#       <th id="T_e1963_level0_row4" class="row_heading level0 row4" >Middle Pair</th>
#       <td id="T_e1963_row4_col0" class="data row4 col0" >2.9</td>
#       <td id="T_e1963_row4_col1" class="data row4 col1" >2.8</td>
#       <td id="T_e1963_row4_col2" class="data row4 col2" >2.7</td>
#       <td id="T_e1963_row4_col3" class="data row4 col3" >3.8</td>
#       <td id="T_e1963_row4_col4" class="data row4 col4" >11.1</td>
#       <td id="T_e1963_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_e1963_row4_col6" class=
# <style type="text/css">
# #T_92c05_row1_col0 {
#   background-color: #b68bc3;
#   color: #f1f1f1;
# }
# #T_92c05_row1_col1, #T_92c05_row5_col4 {
#   background-color: #b98ec5;
#   color: #f1f1f1;
# }
# #T_92c05_row1_col2 {
#   background-color: #b183bf;
#   color: #f1f1f1;
# }
# #T_92c05_row1_col3, #T_92c05_row5_col3 {
#   background-color: #bb93c7;
#   color: #f1f1f1;
# }
# #T_92c05_row1_col4 {
#   background-color: #cdafd5;
#   color: #000000;
# }
# #T_92c05_row1_col5, #T_92c05_row5_col5, #T_92c05_row6_col5 {
#   background-color: #b080be;
#   color: #f1f1f1;
# }
# #T_92c05_row1_col6, #T_92c05_row3_col6 {
#   background-color: #b68ac3;
#   color: #f1f1f1;
# }
# #T_92c05_row2_col0 {
#   background-color: #eaddee;
#   color: #000000;
# }
# #T_92c05_row2_col1 {
#   background-color: #c6a3d0;
#   color: #000000;
# }
# #T_92c05_row2_col2, #T_92c05_row4_col2 {
#   background-color: #f1e8f3;
#   color: #000000;
# }
# #T_92c05_row2_col3, #T_92c05_row6_col0 {
#   background-color: #dbc5e1;
#   color: #000000;
# }
# #T_92c05_row2_col4 {
#   background-color: #c7a6d1;
#   color: #000000;
# }
# #T_92c05_row2_col5, #T_92c05_row7_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_92c05_row2_col6, #T_92c05_row3_col3, #T_92c05_row6_col6 {
#   background-color: #e7d8eb;
#   color: #000000;
# }
# #T_92c05_row3_col0 {
#   background-color: #e1cfe6;
#   color: #000000;
# }
# #T_92c05_row3_col1 {
#   background-color: #d3b9db;
#   color: #000000;
# }
# #T_92c05_row3_col2, #T_92c05_row6_col2 {
#   background-color: #d4badb;
#   color: #000000;
# }
# #T_92c05_row3_col4 {
#   background-color: #d7bfde;
#   color: #000000;
# }
# #T_92c05_row3_col5, #T_92c05_row4_col5 {
#   background-color: #d7c0de;
#   color: #000000;
# }
# #T_92c05_row4_col0, #T_92c05_row6_col4 {
#   background-color: #f0e7f3;
#   color: #000000;
# }
# #T_92c05_row4_col1 {
#   background-color: #f7f2f8;
#   color: #000000;
# }
# #T_92c05_row4_col3 {
#   background-color: #f6f0f7;
#   color: #000000;
# }
# #T_92c05_row4_col4 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_92c05_row4_col6 {
#   background-color: #f3ecf5;
#   color: #000000;
# }
# #T_92c05_row5_col0 {
#   background-color: #ad7dbc;
#   color: #f1f1f1;
# }
# #T_92c05_row5_col1 {
#   background-color: #c19dcc;
#   color: #f1f1f1;
# }
# #T_92c05_row5_col2 {
#   background-color: #b78cc3;
#   color: #f1f1f1;
# }
# #T_92c05_row5_col6 {
#   background-color: #c29dcd;
#   color: #f1f1f1;
# }
# #T_92c05_row6_col1 {
#   background-color: #e5d5e9;
#   color: #000000;
# }
# #T_92c05_row6_col3 {
#   background-color: #caaad3;
#   color: #000000;
# }
# #T_92c05_row7_col0 {
#   background-color: #c29ecd;
#   color: #f1f1f1;
# }
# #T_92c05_row7_col1 {
#   background-color: #ceb2d7;
#   color: #000000;
# }
# #T_92c05_row7_col2 {
#   background-color: #cbacd4;
#   color: #000000;
# }
# #T_92c05_row7_col3 {
#   background-color: #c5a2cf;
#   color: #000000;
# }
# #T_92c05_row7_col4, #T_92c05_row8_col2 {
#   background-color: #ae7ebd;
#   color: #f1f1f1;
# }
# #T_92c05_row7_col6 {
#   background-color: #ceb1d7;
#   color: #000000;
# }
# #T_92c05_row8_col0 {
#   background-color: #b990c6;
#   color: #f1f1f1;
# }
# #T_92c05_row8_col1 {
#   background-color: #bd95c8;
#   color: #f1f1f1;
# }
# #T_92c05_row8_col3 {
#   background-color: #ac7bbb;
#   color: #f1f1f1;
# }
# #T_92c05_row8_col4 {
#   background-color: #a976b8;
#   color: #f1f1f1;
# }
# #T_92c05_row8_col5 {
#   background-color: #88419d;
#   color: #f1f1f1;
# }
# #T_92c05_row8_col6 {
#   background-color: #aa77b9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_92c05">
#   <caption>Opponent Raise Holdings vs Hero Barrel (Grouped)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_92c05_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_92c05_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_92c05_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_92c05_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_92c05_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_92c05_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_92c05_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92c05_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_92c05_row0_col0" class="data row0 col0" >105.0</td>
#       <td id="T_92c05_row0_col1" class="data row0 col1" >72.0</td>
#       <td id="T_92c05_row0_col2" class="data row0 col2" >110.0</td>
#       <td id="T_92c05_row0_col3" class="data row0 col3" >131.0</td>
#       <td id="T_92c05_row0_col4" class="data row0 col4" >63.0</td>
#       <td id="T_92c05_row0_col5" class="data row0 col5" >8.0</td>
#       <td id="T_92c05_row0_col6" class="data row0 col6" >26.0</td>
#     </tr>
#     <tr>
#       <th id="T_92c05_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_92c05_row1_col0" class="data row1 col0" >22.9</td>
#       <td id="T_92c05_row1_col1" class="data row1 col1" >22.2</td>
#       <td id="T_92c05_row1_col2" class="data row1 col2" >24.5</td>
#       <td id="T_92c05_row1_col3" class="data row1 col3" >21.4</td>
#       <td id="T_92c05_row1_col4" class="data row1 col4" >15.9</td>
#       <td id="T_92c05_row1_col5" class="data row1 col5" >25.0</td>
#       <td id="T_92c05_row1_col6" class="data row1 col6" >23.1</td>
#     </tr>
#     <tr>
#       <th id="T_92c05_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_92c05_row2_col0" class="data row2 col0" >6.7</td>
#       <td id="T_92c05_row2_col1" class="data row2 col1" >18.1</td>
#       <td id="T_92c05_row2_col2" class="data row2 col2" >4.5</td>
#       <td id="T_92c05_row2_col3" class="data row2 col3" >11.5</td>
#       <td id="T_92c05_row2_col4" class="data row2 col4" >17.5</td>
#       <td id="T_92c05_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_92c05_row2_col6" class="data row2 col6" >7.7</td>
#     </tr>
#     <tr>
#       <th id="T_92c05_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_92c05_row3_col0" class="data row3 col0" >9.5</td>
#       <td id="T_92c05_row3_col1" class="data row3 col1" >13.9</td>
#       <td id="T_92c05_row3_col2" class="data row3 col2" >13.6</td>
#       <td id="T_92c05_row3_col3" class="data row3 col3" >7.6</td>
#       <td id="T_92c05_row3_col4" class="data row3 col4" >12.7</td>
#       <td id="T_92c05_row3_col5" class="data row3 col5" >12.5</td>
#       <td id="T_92c05_row3_col6" class="data row3 col6" >23.1</td>
#     </tr>
#     <tr>
#       <th id="T_92c05_level0_row4" class="row_heading level0 row4" >Overpair</th>
#       <td id="T_92c05_row4_col0" class="data row4 col0" >4.8</td>
#       <td id="T_92c05_row4_col1" class="data row4 col1" >2.8</td>
#       <td id="T_92c05_row4_col2" class="data row4 col2" >4.5</td>
#       <td id="T_92c05_row4_col3" class="data row4 col3" >3.1</td>
#       <td id="T_92c05_row4_col4" class="data row4 col4" >1.6</td>
#       <td id="T_92c05_row4_col5" class="data row4 col5" >12.5</td>
#       <td id="T_92c05_row4_col6" class="data row4 col6" >3.8</td>
#     </tr>
#     <tr>
#       <th id="T_92c05_level0_row5" class="row_heading level0 row5" >Two Pair</th>
#       <td id="T_92c05_row5_col0" class="data row5 col0" >25.7</td>
#       <td id="T_92c05_row5_col1" class="data row5 col1" >19.4</td>
#       <td id="T_92c05_row5_col2" class="data row5 col2" >22.7</td>
#       <td id="T_92c05_row5_col3" class="data row5 col3" >21.4</td>
#       <td id="T_92c05_row5_col4" class="data row5 col4" >22.2</td>
#       <td id="T_92c05_row5_col5" class="data row5 col5" >25.0</td>
#       <td id="T_92c05_row5_col6" class="data row5 col6" >19.2</td>
#     </tr>
#     <tr>
#       <th id="T_92c05_level0_row6" class="row_heading level0 row6" >Trips/Set</th>
#       <td id="T_92c05_row6_col0" class="data row6 col0" >11.4</td>
#       <td id="T_92c05_row6_col1" class="data row6 col1" >8.3</td>
#       <td id="T_92c05_row6_col2" class="data row6 col2" >13.6</td>
#       <td id="T_92c05_row6_col3" class="data row6 col3" >16.8</td>
# ...
# #T_9b82a_row1_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_9b82a_row1_col1 {
#   background-color: #4e8ec4;
#   color: #f1f1f1;
# }
# #T_9b82a_row1_col2 {
#   background-color: #5391c6;
#   color: #f1f1f1;
# }
# #T_9b82a_row1_col3 {
#   background-color: #4b8cc3;
#   color: #f1f1f1;
# }
# #T_9b82a_row1_col4 {
#   background-color: #81aed5;
#   color: #f1f1f1;
# }
# #T_9b82a_row1_col5 {
#   background-color: #2473b6;
#   color: #f1f1f1;
# }
# #T_9b82a_row1_col6 {
#   background-color: #669dcc;
#   color: #f1f1f1;
# }
# #T_9b82a_row2_col0 {
#   background-color: #d7e5f2;
#   color: #000000;
# }
# #T_9b82a_row2_col1, #T_9b82a_row3_col1, #T_9b82a_row8_col4 {
#   background-color: #e8f1f7;
#   color: #000000;
# }
# #T_9b82a_row2_col2, #T_9b82a_row2_col3, #T_9b82a_row2_col6, #T_9b82a_row3_col6, #T_9b82a_row11_col6 {
#   background-color: #eef4f9;
#   color: #000000;
# }
# #T_9b82a_row2_col4, #T_9b82a_row3_col4 {
#   background-color: #e6eff7;
#   color: #000000;
# }
# #T_9b82a_row2_col5, #T_9b82a_row5_col1, #T_9b82a_row8_col5, #T_9b82a_row9_col5 {
#   background-color: #e4eef6;
#   color: #000000;
# }
# #T_9b82a_row3_col0, #T_9b82a_row4_col0 {
#   background-color: #f3f7fb;
#   color: #000000;
# }
# #T_9b82a_row3_col2 {
#   background-color: #ecf3f9;
#   color: #000000;
# }
# #T_9b82a_row3_col3, #T_9b82a_row5_col0, #T_9b82a_row7_col0 {
#   background-color: #e7eff7;
#   color: #000000;
# }
# #T_9b82a_row3_col5, #T_9b82a_row4_col5, #T_9b82a_row6_col0, #T_9b82a_row6_col1, #T_9b82a_row6_col5, #T_9b82a_row6_col6, #T_9b82a_row7_col5, #T_9b82a_row9_col0, #T_9b82a_row9_col6, #T_9b82a_row10_col0, #T_9b82a_row10_col5, #T_9b82a_row10_col6, #T_9b82a_row11_col0, #T_9b82a_row11_col5, #T_9b82a_row12_col0, #T_9b82a_row12_col1, #T_9b82a_row12_col2, #T_9b82a_row12_col4, #T_9b82a_row12_col5, #T_9b82a_row12_col6 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_9b82a_row4_col1 {
#   background-color: #e5eef6;
#   color: #000000;
# }
# #T_9b82a_row4_col2, #T_9b82a_row4_col4 {
#   background-color: #d8e6f2;
#   color: #000000;
# }
# #T_9b82a_row4_col3, #T_9b82a_row5_col2 {
#   background-color: #e1ecf5;
#   color: #000000;
# }
# #T_9b82a_row4_col6, #T_9b82a_row13_col0, #T_9b82a_row13_col6, #T_9b82a_row14_col2 {
#   background-color: #cddfee;
#   color: #000000;
# }
# #T_9b82a_row5_col3 {
#   background-color: #dae7f3;
#   color: #000000;
# }
# #T_9b82a_row5_col4 {
#   background-color: #dfeaf4;
#   color: #000000;
# }
# #T_9b82a_row5_col5 {
#   background-color: #c8dced;
#   color: #000000;
# }
# #T_9b82a_row5_col6, #T_9b82a_row7_col6, #T_9b82a_row8_col6 {
#   background-color: #dde9f4;
#   color: #000000;
# }
# #T_9b82a_row6_col2, #T_9b82a_row10_col3, #T_9b82a_row11_col3 {
#   background-color: #fcfdfe;
#   color: #000000;
# }
# #T_9b82a_row6_col3, #T_9b82a_row10_col1 {
#   background-color: #fbfcfe;
#   color: #000000;
# }
# #T_9b82a_row6_col4, #T_9b82a_row9_col1, #T_9b82a_row9_col3, #T_9b82a_row10_col2, #T_9b82a_row11_col2, #T_9b82a_row11_col4 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_9b82a_row7_col1, #T_9b82a_row7_col2, #T_9b82a_row7_col4, #T_9b82a_row13_col4 {
#   background-color: #ccdeee;
#   color: #000000;
# }
# #T_9b82a_row7_col3 {
#   background-color: #d6e5f1;
#   color: #000000;
# }
# #T_9b82a_row8_col0 {
#   background-color: #edf3f9;
#   color: #000000;
# }
# #T_9b82a_row8_col1, #T_9b82a_row8_col2 {
#   background-color: #f2f7fb;
#   color: #000000;
# }
# #T_9b82a_row8_col3 {
#   background-color: #f5f8fc;
#   color: #000000;
# }
# #T_9b82a_row9_col2 {
#   background-color: #f9fbfd;
#   color: #000000;
# }
# #T_9b82a_row9_col4, #T_9b82a_row10_col4 {
#   background-color: #f1f6fa;
#   color: #000000;
# }
# #T_9b82a_row11_col1 {
#   background-color: #f6f9fc;
#   color: #000000;
# }
# #T_9b82a_row12_col3 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_9b82a_row13_col1, #T_9b82a_row13_col3 {
#   background-color: #cadded;
#   color: #000000;
# }
# #T_9b82a_row13_col2 {
#   background-color: #bfd6ea;
#   color: #000000;
# }
# #T_9b82a_row13_col5 {
#   background-color: #91b9da;
#   color: #000000;
# }
# #T_9b82a_row14_col0 {
#   background-color: #c4d9eb;
#   color: #000000;
# }
# #T_9b82a_row14_col1 {
#   background-color: #c6daec;
#   color: #000000;
# }
# #T_9b82a_row14_col3 {
#   background-color: #b8d2e7;
#   color: #000000;
# }
# #T_9b82a_row14_col4 {
#   background-color: #c0d7ea;
#   color: #000000;
# }
# #T_9b82a_row14_col5 {
#   background-color: #adcbe4;
#   color: #000000;
# }
# #T_9b82a_row14_col6 {
#   background-color: #99bedd;
#   color: #000000;
# }
# </style>
# <table id="T_9b82a">
#   <caption>Opponent Call Holdings vs Hero Delayed C-Bet</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_9b82a_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_9b82a_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_9b82a_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_9b82a_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_9b82a_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_9b82a_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_9b82a_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b82a_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_9b82a_row0_col0" class="data row0 col0" >114.0</td>
#       <td id="T_9b82a_row0_col1" class="data row0 col1" >313.0</td>
#       <td id="T_9b82a_row0_col2" class="data row0 col2" >519.0</td>
#       <td id="T_9b82a_row0_col3" class="data row0 col3" >301.0</td>
#       <td id="T_9b82a_row0_col4" class="data row0 col4" >153.0</td>
#       <td id="T_9b82a_row0_col5" class="data row0 col5" >13.0</td>
#       <td id="T_9b82a_row0_col6" class="data row0 col6" >21.0</td>
#     </tr>
#     <tr>
#       <th id="T_9b82a_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_9b82a_row1_col0" class="data row1 col0" >62.3</td>
#       <td id="T_9b82a_row1_col1" class="data row1 col1" >49.5</td>
#       <td id="T_9b82a_row1_col2" class="data row1 col2" >48.0</td>
#       <td id="T_9b82a_row1_col3" class="data row1 col3" >50.5</td>
#       <td id="T_9b82a_row1_col4" class="data row1 col4" >35.3</td>
#       <td id="T_9b82a_row1_col5" class="data row1 col5" >61.5</td>
#       <td id="T_9b82a_row1_col6" class="data row1 col6" >42.9</td>
#     </tr>
#     <tr>
#       <th id="T_9b82a_level0_row2" class="row_heading level0 row2" >Underpair</th>
#       <td id="T_9b82a_row2_col0" class="data row2 col0" >11.4</td>
#       <td id="T_9b82a_row2_col1" class="data row2 col1" >6.4</td>
#       <td id="T_9b82a_row2_col2" class="data row2 col2" >4.8</td>
#       <td id="T_9b82a_row2_col3" class="data row2 col3" >4.7</td>
#       <td id="T_9b82a_row2_col4" class="data row2 col4" >7.2</td>
#       <td id="T_9b82a_row2_col5" class="data row2 col5" >7.7</td>
#       <td id="T_9b82a_row2_col6" class="data row2 col6" >4.8</td>
#     </tr>
#     <tr>
#       <th id="T_9b82a_level0_row3" class="row_heading level0 row3" >Bottom Pair</th>
#       <td id="T_9b82a_row3_col0" class="data row3 col0" >3.5</td>
#       <td id="T_9b82a_row3_col1" class="data row3 col1" >6.4</td>
#       <td id="T_9b82a_row3_col2" class="data row3 col2" >5.4</td>
#       <td id="T_9b82a_row3_col3" class="data row3 col3" >7.0</td>
#       <td id="T_9b82a_row3_col4" class="data row3 col4" >7.2</td>
#       <td id="T_9b82a_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_9b82a_row3_col6" class="data row3 col6" >4.8</td>
#     </tr>
#     <tr>
#       <th id="T_9b82a_level0_row4" class="row_heading level0 row4" >Middle Pair</th>
#       <td id="T_9b82a_row4_col0" class="data row4 col0" >3.5</td>
#       <td id="T_9b82a_row4_col1" class="data row4 col1" >7.3</td>
#       <td id="T_9b82a_row4_col2" class="data row4 col2" >11.0</td>
#       <td id="T_9b82a_row4_col3" class="data row4 col3" >8.3</td>
#       <td id="T_9b82a_row4_col4" class="data row4 col4" >11.1</td>
#       <td id="T_9b82a_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_9b82a_row4_col6" class="data row4 col6" >14.3</td>
#     </tr>
#     <tr>
#       <th id="T_9b82a_level0_row5" class="row_heading level0 row5" >Top Pair</th>
#       <td i
# <style type="text/css">
# #T_9cd2b_row1_col0 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# #T_9cd2b_row1_col1 {
#   background-color: #89bfde;
#   color: #000000;
# }
# #T_9cd2b_row1_col2 {
#   background-color: #8dc0df;
#   color: #000000;
# }
# #T_9cd2b_row1_col3 {
#   background-color: #87bdde;
#   color: #000000;
# }
# #T_9cd2b_row1_col4 {
#   background-color: #abd1e8;
#   color: #000000;
# }
# #T_9cd2b_row1_col5 {
#   background-color: #6dafd6;
#   color: #f1f1f1;
# }
# #T_9cd2b_row1_col6, #T_9cd2b_row8_col6 {
#   background-color: #99c7e3;
#   color: #000000;
# }
# #T_9cd2b_row2_col0 {
#   background-color: #d3e7f3;
#   color: #000000;
# }
# #T_9cd2b_row2_col1 {
#   background-color: #cfe5f2;
#   color: #000000;
# }
# #T_9cd2b_row2_col2 {
#   background-color: #cde3f1;
#   color: #000000;
# }
# #T_9cd2b_row2_col3 {
#   background-color: #d0e5f2;
#   color: #000000;
# }
# #T_9cd2b_row2_col4 {
#   background-color: #c3deee;
#   color: #000000;
# }
# #T_9cd2b_row2_col5, #T_9cd2b_row3_col1, #T_9cd2b_row6_col5, #T_9cd2b_row7_col5 {
#   background-color: #edf5fa;
#   color: #000000;
# }
# #T_9cd2b_row2_col6 {
#   background-color: #c7e0ef;
#   color: #000000;
# }
# #T_9cd2b_row3_col0, #T_9cd2b_row5_col0 {
#   background-color: #eff6fa;
#   color: #000000;
# }
# #T_9cd2b_row3_col2 {
#   background-color: #ebf4f9;
#   color: #000000;
# }
# #T_9cd2b_row3_col3 {
#   background-color: #e6f1f8;
#   color: #000000;
# }
# #T_9cd2b_row3_col4 {
#   background-color: #eaf3f9;
#   color: #000000;
# }
# #T_9cd2b_row3_col5 {
#   background-color: #daebf5;
#   color: #000000;
# }
# #T_9cd2b_row3_col6, #T_9cd2b_row5_col6, #T_9cd2b_row6_col6 {
#   background-color: #e8f3f9;
#   color: #000000;
# }
# #T_9cd2b_row4_col0, #T_9cd2b_row4_col1, #T_9cd2b_row4_col5, #T_9cd2b_row4_col6, #T_9cd2b_row5_col5, #T_9cd2b_row7_col0 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_9cd2b_row4_col2 {
#   background-color: #fdfeff;
#   color: #000000;
# }
# #T_9cd2b_row4_col3 {
#   background-color: #fcfdfe;
#   color: #000000;
# }
# #T_9cd2b_row4_col4 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_9cd2b_row5_col1, #T_9cd2b_row5_col2, #T_9cd2b_row5_col4 {
#   background-color: #ddecf6;
#   color: #000000;
# }
# #T_9cd2b_row5_col3 {
#   background-color: #e4f0f7;
#   color: #000000;
# }
# #T_9cd2b_row6_col0 {
#   background-color: #f3f8fc;
#   color: #000000;
# }
# #T_9cd2b_row6_col1, #T_9cd2b_row6_col2 {
#   background-color: #f6fafd;
#   color: #000000;
# }
# #T_9cd2b_row6_col3, #T_9cd2b_row7_col2, #T_9cd2b_row7_col3 {
#   background-color: #f8fbfd;
#   color: #000000;
# }
# #T_9cd2b_row6_col4 {
#   background-color: #f0f7fb;
#   color: #000000;
# }
# #T_9cd2b_row7_col1 {
#   background-color: #f5f9fc;
#   color: #000000;
# }
# #T_9cd2b_row7_col4 {
#   background-color: #ebf4fa;
#   color: #000000;
# }
# #T_9cd2b_row7_col6 {
#   background-color: #f4f9fc;
#   color: #000000;
# }
# #T_9cd2b_row8_col0 {
#   background-color: #b6d7eb;
#   color: #000000;
# }
# #T_9cd2b_row8_col1 {
#   background-color: #b5d6ea;
#   color: #000000;
# }
# #T_9cd2b_row8_col2, #T_9cd2b_row8_col4 {
#   background-color: #b3d5ea;
#   color: #000000;
# }
# #T_9cd2b_row8_col3 {
#   background-color: #acd2e8;
#   color: #000000;
# }
# #T_9cd2b_row8_col5 {
#   background-color: #7fb9db;
#   color: #000000;
# }
# </style>
# <table id="T_9cd2b">
#   <caption>Opponent Call Holdings vs Hero Delayed C-Bet (Grouped)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_9cd2b_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_9cd2b_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_9cd2b_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_9cd2b_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_9cd2b_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_9cd2b_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_9cd2b_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cd2b_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_9cd2b_row0_col0" class="data row0 col0" >114.0</td>
#       <td id="T_9cd2b_row0_col1" class="data row0 col1" >313.0</td>
#       <td id="T_9cd2b_row0_col2" class="data row0 col2" >519.0</td>
#       <td id="T_9cd2b_row0_col3" class="data row0 col3" >301.0</td>
#       <td id="T_9cd2b_row0_col4" class="data row0 col4" >153.0</td>
#       <td id="T_9cd2b_row0_col5" class="data row0 col5" >13.0</td>
#       <td id="T_9cd2b_row0_col6" class="data row0 col6" >21.0</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2b_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_9cd2b_row1_col0" class="data row1 col0" >62.3</td>
#       <td id="T_9cd2b_row1_col1" class="data row1 col1" >49.5</td>
#       <td id="T_9cd2b_row1_col2" class="data row1 col2" >48.0</td>
#       <td id="T_9cd2b_row1_col3" class="data row1 col3" >50.5</td>
#       <td id="T_9cd2b_row1_col4" class="data row1 col4" >35.3</td>
#       <td id="T_9cd2b_row1_col5" class="data row1 col5" >61.5</td>
#       <td id="T_9cd2b_row1_col6" class="data row1 col6" >42.9</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2b_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_9cd2b_row2_col0" class="data row2 col0" >18.4</td>
#       <td id="T_9cd2b_row2_col1" class="data row2 col1" >20.1</td>
#       <td id="T_9cd2b_row2_col2" class="data row2 col2" >21.2</td>
#       <td id="T_9cd2b_row2_col3" class="data row2 col3" >19.9</td>
#       <td id="T_9cd2b_row2_col4" class="data row2 col4" >25.5</td>
#       <td id="T_9cd2b_row2_col5" class="data row2 col5" >7.7</td>
#       <td id="T_9cd2b_row2_col6" class="data row2 col6" >23.8</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2b_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_9cd2b_row3_col0" class="data row3 col0" >7.0</td>
#       <td id="T_9cd2b_row3_col1" class="data row3 col1" >7.7</td>
#       <td id="T_9cd2b_row3_col2" class="data row3 col2" >8.7</td>
#       <td id="T_9cd2b_row3_col3" class="data row3 col3" >10.6</td>
#       <td id="T_9cd2b_row3_col4" class="data row3 col4" >9.2</td>
#       <td id="T_9cd2b_row3_col5" class="data row3 col5" >15.4</td>
#       <td id="T_9cd2b_row3_col6" class="data row3 col6" >9.5</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2b_level0_row4" class="row_heading level0 row4" >Overpair</th>
#       <td id="T_9cd2b_row4_col0" class="data row4 col0" >0.0</td>
#       <td id="T_9cd2b_row4_col1" class="data row4 col1" >0.0</td>
#       <td id="T_9cd2b_row4_col2" class="data row4 col2" >1.0</td>
#       <td id="T_9cd2b_row4_col3" class="data row4 col3" >1.3</td>
#       <td id="T_9cd2b_row4_col4" class="data row4 col4" >0.7</td>
#       <td id="T_9cd2b_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_9cd2b_row4_col6" class="data row4 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2b_level0_row5" class="row_heading level0 row5" >Two Pair</th>
#       <td id="T_9cd2b_row5_col0" class="data row5 col0" >7.0</td>
#       <td id="T_9cd2b_row5_col1" class="data row5 col1" >14.4</td>
#       <td id="T_9cd2b_row5_col2" class="data row5 col2" >14.5</td>
#       <td id="T_9cd2b_row5_col3" class="data row5 col3" >11.6</td>
#       <td id="T_9cd2b_row5_col4" class="data row5 col4" >14.4</td>
#       <td id="T_9cd2b_row5_col5" class="data row5 col5" >0.0</td>
#       <td id="T_9cd2b_row5_col6" class="data row5 col6" >9.5</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2b_level0_row6" class="row_heading level0 row6" >Trips/Set</th>
#       <td id="T_9cd2b_row6_col0" class="data row6 col0" >5.3</td>
#       <td id="T_9cd2b_row6_col1" class="data row6 col1" >3.8</td>
#       <td id="T_9cd2b_row6_col2" class="data row6 col2" >3.7</td>
#       <td id="T_9cd2b_row6_col3" class="data row6 col3" >3.0</td>
#       <td id="T_9cd2b_row6_col4" class="data row6 col4" >6.5</td>
#       <td id="T_9cd2b_row6_col5" class="data row6 col5" >7.7</td>
#       <td id="T_9cd2b_row6_col6" class="data row6 col6" >9.5</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2b_level0_row7" class="row_heading level0 row7" >Monster</th>
#       <td id="T_9cd2b_row7_col0" class="data row7 col0" >0.0</td>
#       <td id="T_9cd2b_row7_col1"

# %%
from IPython.display import display

DRAW_FIELDS = [
    ('Flush Draw', 'responder_has_flush_draw'),
    ('OESD/DG', 'responder_has_oesd_dg'),
]

def _summarize_holdings(responses_subset):
    classified = responses_subset.dropna(subset=['responder_primary'])
    if classified.empty:
        return None
    total = len(classified)
    cat_counts = {cat: int((classified['responder_primary'] == cat).sum()) for cat in BASE_PRIMARY_CATEGORIES}

    base_index = ['Events'] + BASE_PRIMARY_CATEGORIES + [label for label, _ in DRAW_FIELDS]
    base_values = []
    for entry in base_index:
        if entry == 'Events':
            base_values.append(float(total))
        elif entry in BASE_PRIMARY_CATEGORIES:
            base_values.append(cat_counts.get(entry, 0) / total * 100 if total else 0.0)
        else:
            field = dict(DRAW_FIELDS)[entry]
            base_values.append(classified[field].mean() * 100 if total else 0.0)
    base_series = pd.Series(base_values, index=base_index, dtype=float)

    any_draw_pct = (classified['responder_has_flush_draw'] | classified['responder_has_oesd_dg']).mean() * 100 if total else 0.0
    group_index = ['Events'] + [label for label, members in GROUPED_PRIMARY_ORDER if members is not None]
    group_values = []
    for label in group_index:
        if label == 'Events':
            group_values.append(float(total))
        elif label == 'Draw':
            group_values.append(any_draw_pct)
        else:
            members = dict(GROUPED_PRIMARY_ORDER).get(label, [])
            group_values.append(sum(cat_counts.get(member, 0) for member in members) / total * 100 if total else 0.0)
    group_series = pd.Series(group_values, index=group_index, dtype=float)
    return base_series, group_series

if responses_df.empty:
    print('No c-bet response events available.')
else:
    raise_rows = responses_df[responses_df['response'] == 'Raise']
    call_rows = responses_df[responses_df['response'] == 'Call']

    raise_summary = _summarize_holdings(raise_rows) if not raise_rows.empty else None
    call_summary = _summarize_holdings(call_rows) if not call_rows.empty else None

    if not raise_summary and not call_summary:
        print('No raise or call responses with classified hands.')
    else:
        base_columns = []
        if raise_summary:
            base_columns.append(('C-Bet Raise Holdings (%)', raise_summary[0]))
        if call_summary:
            base_columns.append(('C-Bet Call Holdings (%)', call_summary[0]))

        if base_columns:
            base_df = pd.concat([series.rename(col) for col, series in base_columns], axis=1)
            base_df = base_df.reindex(['Events'] + BASE_PRIMARY_CATEGORIES + [label for label, _ in DRAW_FIELDS])
            styler = base_df.style
            value_rows = base_df.index.difference(['Events'])
            if not value_rows.empty:
                styler = styler.background_gradient(
                    cmap=_gradient_cmap('#d95f02'),
                    axis=None,
                    subset=pd.IndexSlice[value_rows, base_df.columns]
                )
            styler = (
                styler
                .format('{:.0f}', subset=pd.IndexSlice[['Events'], base_df.columns])
                .format('{:.1f}%', subset=pd.IndexSlice[value_rows, base_df.columns])
                .set_caption('C-Bet Raise vs Call Holdings')
            )
            display(styler)

        group_columns = []
        if raise_summary:
            group_columns.append(('C-Bet Raise Holdings (%)', raise_summary[1]))
        if call_summary:
            group_columns.append(('C-Bet Call Holdings (%)', call_summary[1]))

        if group_columns:
            group_df = pd.concat([series.rename(col) for col, series in group_columns], axis=1)
            group_df = group_df.reindex(['Events'] + [label for label, members in GROUPED_PRIMARY_ORDER if members is not None])
            group_styler = group_df.style
            group_value_rows = group_df.index.difference(['Events'])
            if not group_value_rows.empty:
                group_styler = group_styler.background_gradient(
                    cmap=_gradient_cmap('#3182bd'),
                    axis=None,
                    subset=pd.IndexSlice[group_value_rows, group_df.columns]
                )
            group_styler = (
                group_styler
                .format('{:.0f}', subset=pd.IndexSlice[['Events'], group_df.columns])
                .format('{:.1f}%', subset=pd.IndexSlice[group_value_rows, group_df.columns])
                .set_caption('C-Bet Raise vs Call Holdings (Grouped)')
            )
            display(group_styler)
# Out:
# <style type="text/css">
# #T_dd92d_row1_col0 {
#   background-color: #e38944;
#   color: #f1f1f1;
# }
# #T_dd92d_row1_col1 {
#   background-color: #d95f02;
#   color: #f1f1f1;
# }
# #T_dd92d_row2_col0 {
#   background-color: #fbefe6;
#   color: #000000;
# }
# #T_dd92d_row2_col1 {
#   background-color: #f9e5d5;
#   color: #000000;
# }
# #T_dd92d_row3_col0 {
#   background-color: #fcf4ed;
#   color: #000000;
# }
# #T_dd92d_row3_col1 {
#   background-color: #f9e8da;
#   color: #000000;
# }
# #T_dd92d_row4_col0 {
#   background-color: #fbede2;
#   color: #000000;
# }
# #T_dd92d_row4_col1 {
#   background-color: #f5d6bf;
#   color: #000000;
# }
# #T_dd92d_row5_col0 {
#   background-color: #ebad7d;
#   color: #000000;
# }
# #T_dd92d_row5_col1 {
#   background-color: #f3ccae;
#   color: #000000;
# }
# #T_dd92d_row6_col0, #T_dd92d_row8_col1 {
#   background-color: #fcf2eb;
#   color: #000000;
# }
# #T_dd92d_row6_col1 {
#   background-color: #fefcfa;
#   color: #000000;
# }
# #T_dd92d_row7_col0 {
#   background-color: #f3ceb2;
#   color: #000000;
# }
# #T_dd92d_row7_col1 {
#   background-color: #fae8db;
#   color: #000000;
# }
# #T_dd92d_row8_col0 {
#   background-color: #f9e4d4;
#   color: #000000;
# }
# #T_dd92d_row9_col0 {
#   background-color: #fefaf7;
#   color: #000000;
# }
# #T_dd92d_row9_col1 {
#   background-color: #fffefd;
#   color: #000000;
# }
# #T_dd92d_row10_col0, #T_dd92d_row11_col0 {
#   background-color: #fffdfc;
#   color: #000000;
# }
# #T_dd92d_row10_col1 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_dd92d_row11_col1, #T_dd92d_row12_col0, #T_dd92d_row12_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_dd92d_row13_col0 {
#   background-color: #f7decb;
#   color: #000000;
# }
# #T_dd92d_row13_col1 {
#   background-color: #f8e1cf;
#   color: #000000;
# }
# #T_dd92d_row14_col0 {
#   background-color: #faebdf;
#   color: #000000;
# }
# #T_dd92d_row14_col1 {
#   background-color: #faece0;
#   color: #000000;
# }
# </style>
# <table id="T_dd92d">
#   <caption>C-Bet Raise vs Call Holdings</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd92d_level0_col0" class="col_heading level0 col0" >C-Bet Raise Holdings (%)</th>
#       <th id="T_dd92d_level0_col1" class="col_heading level0 col1" >C-Bet Call Holdings (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd92d_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_dd92d_row0_col0" class="data row0 col0" >669</td>
#       <td id="T_dd92d_row0_col1" class="data row0 col1" >3294</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_dd92d_row1_col0" class="data row1 col0" >33.6%</td>
#       <td id="T_dd92d_row1_col1" class="data row1 col1" >45.7%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row2" class="row_heading level0 row2" >Underpair</th>
#       <td id="T_dd92d_row2_col0" class="data row2 col0" >4.6%</td>
#       <td id="T_dd92d_row2_col1" class="data row2 col1" >7.8%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row3" class="row_heading level0 row3" >Bottom Pair</th>
#       <td id="T_dd92d_row3_col0" class="data row3 col0" >3.4%</td>
#       <td id="T_dd92d_row3_col1" class="data row3 col1" >6.8%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row4" class="row_heading level0 row4" >Middle Pair</th>
#       <td id="T_dd92d_row4_col0" class="data row4 col0" >5.4%</td>
#       <td id="T_dd92d_row4_col1" class="data row4 col1" >11.8%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row5" class="row_heading level0 row5" >Top Pair</th>
#       <td id="T_dd92d_row5_col0" class="data row5 col0" >23.6%</td>
#       <td id="T_dd92d_row5_col1" class="data row5 col1" >14.8%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row6" class="row_heading level0 row6" >Overpair</th>
#       <td id="T_dd92d_row6_col0" class="data row6 col0" >3.9%</td>
#       <td id="T_dd92d_row6_col1" class="data row6 col1" >1.2%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row7" class="row_heading level0 row7" >Two Pair</th>
#       <td id="T_dd92d_row7_col0" class="data row7 col0" >14.2%</td>
#       <td id="T_dd92d_row7_col1" class="data row7 col1" >6.6%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row8" class="row_heading level0 row8" >Trips/Set</th>
#       <td id="T_dd92d_row8_col0" class="data row8 col0" >7.9%</td>
#       <td id="T_dd92d_row8_col1" class="data row8 col1" >3.8%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row9" class="row_heading level0 row9" >Straight</th>
#       <td id="T_dd92d_row9_col0" class="data row9 col0" >1.6%</td>
#       <td id="T_dd92d_row9_col1" class="data row9 col1" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row10" class="row_heading level0 row10" >Flush</th>
#       <td id="T_dd92d_row10_col0" class="data row10 col0" >0.7%</td>
#       <td id="T_dd92d_row10_col1" class="data row10 col1" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row11" class="row_heading level0 row11" >Full House</th>
#       <td id="T_dd92d_row11_col0" class="data row11 col0" >0.7%</td>
#       <td id="T_dd92d_row11_col1" class="data row11 col1" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row12" class="row_heading level0 row12" >Quads</th>
#       <td id="T_dd92d_row12_col0" class="data row12 col0" >0.1%</td>
#       <td id="T_dd92d_row12_col1" class="data row12 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row13" class="row_heading level0 row13" >Flush Draw</th>
#       <td id="T_dd92d_row13_col0" class="data row13 col0" >9.6%</td>
#       <td id="T_dd92d_row13_col1" class="data row13 col1" >8.9%</td>
#     </tr>
#     <tr>
#       <th id="T_dd92d_level0_row14" class="row_heading level0 row14" >OESD/DG</th>
#       <td id="T_dd92d_row14_col0" class="data row14 col0" >6.0%</td>
#       <td id="T_dd92d_row14_col1" class="data row14 col1" >5.8%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_217f5_row1_col0 {
#   background-color: #69a4cf;
#   color: #f1f1f1;
# }
# #T_217f5_row1_col1 {
#   background-color: #3182bd;
#   color: #f1f1f1;
# }
# #T_217f5_row2_col0 {
#   background-color: #c6dded;
#   color: #000000;
# }
# #T_217f5_row2_col1 {
#   background-color: #8bb8da;
#   color: #000000;
# }
# #T_217f5_row3_col0 {
#   background-color: #98c0de;
#   color: #000000;
# }
# #T_217f5_row3_col1 {
#   background-color: #c0d9eb;
#   color: #000000;
# }
# #T_217f5_row4_col0, #T_217f5_row6_col1 {
#   background-color: #f3f8fb;
#   color: #000000;
# }
# #T_217f5_row4_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_217f5_row5_col0 {
#   background-color: #c3dbec;
#   color: #000000;
# }
# #T_217f5_row5_col1 {
#   background-color: #e6f0f7;
#   color: #000000;
# }
# #T_217f5_row6_col0 {
#   background-color: #e0ecf5;
#   color: #000000;
# }
# #T_217f5_row7_col0 {
#   background-color: #f5f9fc;
#   color: #000000;
# }
# #T_217f5_row7_col1 {
#   background-color: #feffff;
#   color: #000000;
# }
# #T_217f5_row8_col0 {
#   background-color: #c1d9eb;
#   color: #000000;
# }
# #T_217f5_row8_col1 {
#   background-color: #c2daec;
#   color: #000000;
# }
# </style>
# <table id="T_217f5">
#   <caption>C-Bet Raise vs Call Holdings (Grouped)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_217f5_level0_col0" class="col_heading level0 col0" >C-Bet Raise Holdings (%)</th>
#       <th id="T_217f5_level0_col1" class="col_heading level0 col1" >C-Bet Call Holdings (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_217f5_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_217f5_row0_col0" class="data row0 col0" >669</td>
#       <td id="T_217f5_row0_col1" class="data row0 col1" >3294</td>
#     </tr>
#     <tr>
#       <th id="T_217f5_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_217f5_row1_col0" class="data row1 col0" >33.6%</td>
#       <td id="T_217f5_row1_col1" class="data row1 col1" >45.7%</td>
#     </tr>
#     <tr>
#       <th id="T_217f5_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_217f5_row2_col0" class="data row2 col0" >13.5%</td>
#       <td id="T_217f5_row2_col1" class="data row2 col1" >26.4%</td>
#     </tr>
#     <tr>
#       <th id="T_217f5_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_217f5_row3_col0" class="data row3 col0" >23.6%</td>
#       <td id="T_217f5_row3_col1" class="data row3 col1" >14.8%</td>
#     </tr>
#     <tr>
#       <th id="T_217f5_level0_row4" class="row_heading level0 row4" >Overpair</th>
#       <td id="T_217f5_row4_col0" class="data row4 col0" >3.9%</td>
#       <td id="T_217f5_row4_col1" class="data row4 col1" >1.2%</td>
#     </tr>
#     <tr>
#       <th id="T_217f5_level0_row5" class="row_heading level0 row5" >Two Pair</th>
#       <td id="T_217f5_row5_col0" class="data row5 col0" >14.2%</td>
#       <td id="T_217f5_row5_col1" class="data row5 col1" >6.6%</td>
#     </tr>
#     <tr>
#       <th id="T_217f5_level0_row6" class="row_heading level0 row6" >Trips/Set</th>
#       <td id="T_217f5_row6_col0" class="data row6 col0" >7.9%</td>
#       <td id="T_217f5_row6_col1" class="data row6 col1" >3.8%</td>
#     </tr>
#     <tr>
#       <th id="T_217f5_level0_row7" class="row_heading level0 row7" >Monster</th>
#       <td id="T_217f5_row7_col0" class="data row7 col0" >3.3%</td>
#       <td id="T_217f5_row7_col1" class="data row7 col1" >1.4%</td>
#     </tr>
#     <tr>
#       <th id="T_217f5_level0_row8" class="row_heading level0 row8" >Draw</th>
#       <td id="T_217f5_row8_col0" class="data row8 col0" >14.6%</td>
#       <td id="T_217f5_row8_col1" class="data row8 col1" >14.2%</td>
#     </tr>
#   </tbody>
# </table>
