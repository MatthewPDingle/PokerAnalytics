# %% [markdown]
# # Turn Barrel Explorer
#
# Analyse turn double barrels and delayed c-bets by hand strength, bet sizing, and opponent responses.
# Adjust the configuration below to experiment with alternative sizing buckets or grouping schemes.
#
# > Buckets use left-inclusive, right-exclusive ranges (e.g., a 0.25 bet falls into [0.25, 0.40)).

# %%
from pathlib import Path
import os

def _locate_project_root() -> Path:
    current = Path().resolve()
    for candidate in (current, *current.parents):
        if (candidate / "AGENTS.md").exists():
            return candidate
    raise FileNotFoundError("Repository root not found from notebook location.")

PROJECT_ROOT = _locate_project_root()
del _locate_project_root

DB_CANDIDATES = [
    Path(r"T:\Dev\ignition\drivehud\drivehud.db"),
    Path("/mnt/t/Dev/ignition/drivehud/drivehud.db"),
    PROJECT_ROOT / "drivehud" / "drivehud.db",
]

for candidate in DB_CANDIDATES:
    if candidate.exists():
        DB_PATH = candidate
        break
else:
    checked = os.linesep.join(str(p) for p in DB_CANDIDATES)
    message = "Database not found. Checked:" + os.linesep + checked
    raise FileNotFoundError(message)

CACHE_PATH = PROJECT_ROOT / "analysis" / "cache" / "turn_events.json"

if not DB_PATH.exists():
    raise FileNotFoundError(f"Database not found at {DB_PATH}")

# %%
import sys
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

from analysis.turn_utils import (
    TURN_BUCKETS,
    available_primary_categories as available_turn_categories,
    load_turn_events,
    load_turn_first_actions,
    turn_response_events,
)
from analysis.cbet_utils import BASE_PRIMARY_CATEGORIES

# %%
# --- Configuration ---
RAW_BUCKET_BOUNDS = [
    (0.00, 0.25),
    (0.25, 0.40),
    (0.40, 0.60),
    (0.60, 0.80),
    (0.80, 1.00),
    (1.00, 1.25),
    (1.25, float('inf')),
]

def _bucket_label(low: float, high: float) -> str:
    if high == float('inf'):
        return f">={low:.2f}"
    return f"[{low:.2f}, {high:.2f})"

TURN_BUCKETS = [(low, high, _bucket_label(low, high)) for (low, high) in RAW_BUCKET_BOUNDS]
del _bucket_label

PRIMARY_GROUPS = {cat: [cat] for cat in BASE_PRIMARY_CATEGORIES}
GROUPED_PRIMARY_ORDER = [
    ('Events', None),
    ('Air', ['Air']),
    ('Weak Pair', ['Underpair', 'Bottom Pair', 'Middle Pair']),
    ('Top Pair', ['Top Pair']),
    ('Overpair', ['Overpair']),
    ('Two Pair', ['Two Pair']),
    ('Trips/Set', ['Trips/Set']),
    ('Monster', ['Straight', 'Flush', 'Full House', 'Quads']),
    ('Draw', ['Flush Draw', 'OESD/DG']),
]

FORCE_RELOAD = True

# %%
events = load_turn_events(DB_PATH, cache_path=CACHE_PATH, force=FORCE_RELOAD)
print(f'Loaded {len(events)} turn bet events.')
print('Line types:', ', '.join(sorted({e["line_type"] for e in events})))
available_categories = available_turn_categories(events)
print('Observed primary categories:', ', '.join(available_categories))

events_df = pd.DataFrame(events)
responses_df = pd.DataFrame(turn_response_events(events))
bucket_edges = [bucket[0] for bucket in TURN_BUCKETS] + [TURN_BUCKETS[-1][1]]
bucket_labels = [bucket[2] for bucket in TURN_BUCKETS]
events_df['bucket'] = pd.cut(
    events_df['ratio'],
    bins=bucket_edges,
    labels=bucket_labels,
    right=False,
    include_lowest=True,
)
# Out:
# Loaded 6776 turn bet events.
# Line types: Barrel, Delayed, Other
# Observed primary categories: Air, Bottom Pair, Flush, Full House, Middle Pair, Overpair, Quads, Straight, Top Pair, Trips/Set, Two Pair, Underpair

# %%
DRAW_FIELDS = [('Flush Draw', 'has_flush_draw'), ('OESD/DG', 'has_oesd_dg')]
RESPONSE_DRAW_FIELDS = [('Flush Draw', 'responder_has_flush_draw'), ('OESD/DG', 'responder_has_oesd_dg')]
HAND_ORDER = BASE_PRIMARY_CATEGORIES
LINE_DISPLAY_ORDER = ['Barrel', 'Delayed', 'Other']
SPECIAL_FIELD_CANDIDATES = {
    'All-In': ('is_all_in', 'is_all_in_bet', 'is_all_in_cbet'),
    '1 BB': ('is_one_bb', 'is_one_bb_bet', 'is_one_bb_cbet'),
}

def _gradient_cmap_turn(base_color: str) -> LinearSegmentedColormap:
    name = f'turn_gradient_{base_color.strip("#")}'
    return LinearSegmentedColormap.from_list(name, ['#ffffff', base_color])


def _percent(value, total):
    return (value / total * 100) if total else 0.0

def _select_flag_field(df, candidates):
    for field in candidates:
        if field in df.columns:
            return field
    return None

def _subset_for_flag(df, candidates):
    field = _select_flag_field(df, candidates)
    if field is None:
        return None
    subset = df[df[field]]
    return subset if not subset.empty else None

def summarize_line(df):
    total = len(df)
    summary = {'Events': float(total)}
    for cat in HAND_ORDER:
        summary[cat] = df['primary'].eq(cat).mean() * 100 if total else 0.0
    for label, field in DRAW_FIELDS:
        summary[label] = df[field].mean() * 100 if total else 0.0
    return summary

def summarize_line_grouped(df):
    total = len(df)
    grouped = {'Events': float(total)}
    for label, members in GROUPED_PRIMARY_ORDER:
        if members is None or label == 'Events':
            continue
        if label == 'Draw':
            draws = df['has_flush_draw'].fillna(False) | df['has_oesd_dg'].fillna(False)
            grouped[label] = draws.mean() * 100 if total else 0.0
        else:
            grouped[label] = df['primary'].isin(members).mean() * 100 if total else 0.0
    return grouped

def display_line_comparison(df, caption):
    data = {}
    for line in LINE_DISPLAY_ORDER:
        subset = df[df['line_type'] == line]
        if subset.empty:
            continue
        data[line] = summarize_line(subset)
    if not data:
        print('No data for requested lines.')
        return
    summary_df = pd.DataFrame(data)
    summary_df = summary_df.reindex(['Events'] + HAND_ORDER + [label for label, _ in DRAW_FIELDS])
    styled = (
        summary_df.style
        .format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
        .format('{:.1f}%', subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .background_gradient(cmap='YlOrRd', axis=None, subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .set_caption(caption)
    )
    display(styled)

def display_line_comparison_grouped(df, caption):
    data = {}
    for line in LINE_DISPLAY_ORDER:
        subset = df[df['line_type'] == line]
        if subset.empty:
            continue
        data[line] = summarize_line_grouped(subset)
    if not data:
        print('No data for requested lines.')
        return
    summary_df = pd.DataFrame(data)
    summary_df = summary_df.reindex(['Events'] + [label for label, members in GROUPED_PRIMARY_ORDER if members is not None])
    styled = (
        summary_df.style
        .format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
        .format('{:.1f}%', subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .background_gradient(cmap='YlOrRd', axis=None, subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .set_caption(caption)
    )
    display(styled)

def summarize_bucket(df):
    total = len(df)
    result = {'Events': float(total)}
    for cat in HAND_ORDER:
        result[cat] = df['primary'].eq(cat).mean() * 100 if total else 0.0
    for label, field in DRAW_FIELDS:
        result[label] = df[field].mean() * 100 if total else 0.0
    return result

def _style_bucket_table(summary_df, caption, special_cols):
    styled = (
        summary_df.style
        .format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
        .format('{:.1f}%', subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .background_gradient(cmap='YlOrRd', axis=None, subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .set_caption(caption)
    )
    if special_cols:
        first = special_cols[0]
        idx = summary_df.columns.get_loc(first)
        styled = styled.set_table_styles([
            {'selector': f'th.col_heading.level0.col{idx}', 'props': [('border-left', '2px solid #64748b')]},
            {'selector': f'td.col{idx}', 'props': [('border-left', '2px solid #64748b')]},
        ], overwrite=False)
    return styled



def summarize_bucket_grouped(df):
    total = len(df)
    grouped = {'Events': float(total)}
    for label, members in GROUPED_PRIMARY_ORDER:
        if members is None or label == 'Events':
            continue
        if label == 'Draw':
            draws = df['has_flush_draw'].fillna(False) | df['has_oesd_dg'].fillna(False)
            grouped[label] = draws.mean() * 100 if total else 0.0
        else:
            grouped[label] = df['primary'].isin(members).mean() * 100 if total else 0.0
    return grouped

def _style_bucket_table_grouped(summary_df, caption, special_cols):
    styled = (
        summary_df.style
        .format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
        .format('{:.1f}%', subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .background_gradient(cmap='YlOrRd', axis=None, subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .set_caption(caption)
    )
    if special_cols:
        first = special_cols[0]
        idx = summary_df.columns.get_loc(first)
        styled = styled.set_table_styles([
            {'selector': f'th.col_heading.level0.col{idx}', 'props': [('border-left', '2px solid #64748b')]},
            {'selector': f'td.col{idx}', 'props': [('border-left', '2px solid #64748b')]},
        ], overwrite=False)
    return styled

def display_bucket_table_grouped(df, caption):
    bucket_labels_local = [bucket[2] for bucket in TURN_BUCKETS]
    rows = []
    index = []
    for bucket in bucket_labels_local:
        subset = df[df['bucket'] == bucket]
        if subset.empty:
            continue
        rows.append(summarize_bucket_grouped(subset))
        index.append(bucket)
    if not rows:
        print('No data for selected line.')
        return
    summary_df = pd.DataFrame(rows, index=index).T
    summary_df = summary_df.reindex(['Events'] + [label for label, members in GROUPED_PRIMARY_ORDER if members is not None])
    special_cols = []
    for label, candidates in SPECIAL_FIELD_CANDIDATES.items():
        subset = _subset_for_flag(df, candidates)
        if subset is None:
            continue
        summary_df[label] = pd.Series(summarize_bucket_grouped(subset))
        special_cols.append(label)
    ordered_columns = [col for col in bucket_labels_local if col in summary_df.columns]
    ordered_columns += [col for col in special_cols if col in summary_df.columns]
    summary_df = summary_df[ordered_columns]
    styled = _style_bucket_table_grouped(summary_df, caption, special_cols)
    display(styled)
def display_bucket_table(df, caption):
    bucket_labels_local = [bucket[2] for bucket in TURN_BUCKETS]
    rows = []
    index = []
    for bucket in bucket_labels_local:
        subset = df[df['bucket'] == bucket]
        if subset.empty:
            continue
        rows.append(summarize_bucket(subset))
        index.append(bucket)
    if not rows:
        print('No data for selected line.')
        return
    summary_df = pd.DataFrame(rows, index=index).T
    summary_df = summary_df.reindex(['Events'] + HAND_ORDER + [label for label, _ in DRAW_FIELDS])
    special_cols = []
    for label, candidates in SPECIAL_FIELD_CANDIDATES.items():
        subset = _subset_for_flag(df, candidates)
        if subset is None:
            continue
        summary_df[label] = pd.Series(summarize_bucket(subset))
        special_cols.append(label)
    ordered_columns = [col for col in bucket_labels_local if col in summary_df.columns]
    ordered_columns += [col for col in special_cols if col in summary_df.columns]
    summary_df = summary_df[ordered_columns]
    styled = _style_bucket_table(summary_df, caption, special_cols)
    display(styled)



def summarize_responses_grouped(df, response_type):
    df = df[df['response'] == response_type].dropna(subset=['responder_primary'])
    if df.empty:
        return None
    data = {}
    for line in ['Barrel', 'Delayed']:
        subset = df[df['line_type'] == line]
        if subset.empty:
            continue
        total = len(subset)
        entry = {'Events': float(total)}
        for label, members in GROUPED_PRIMARY_ORDER:
            if members is None or label == 'Events':
                continue
            if label == 'Draw':
                draws = subset['responder_has_flush_draw'].fillna(False) | subset['responder_has_oesd_dg'].fillna(False)
                entry[label] = draws.mean() * 100 if total else 0.0
            else:
                entry[label] = subset['responder_primary'].isin(members).mean() * 100 if total else 0.0
        data[line] = entry
    if not data:
        return None
    summary_df = pd.DataFrame(data)
    summary_df = summary_df.reindex(['Events'] + [label for label, members in GROUPED_PRIMARY_ORDER if members is not None])
    return summary_df

def _style_response_table_grouped(summary_df, caption):
    styled = (
        summary_df.style
        .format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
        .format('{:.1f}%', subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .background_gradient(cmap='PuBu', axis=None, subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .set_caption(caption)
    )
    return styled
def summarize_responses(df, response_type):
    df = df[df['response'] == response_type].dropna(subset=['responder_primary'])
    if df.empty:
        return None
    data = {}
    for line in ['Barrel', 'Delayed']:
        subset = df[df['line_type'] == line]
        if subset.empty:
            continue
        total = len(subset)
        entry = {'Events': float(total)}
        for cat in HAND_ORDER:
            entry[cat] = subset['responder_primary'].eq(cat).mean() * 100 if total else 0.0
        for label, field in RESPONSE_DRAW_FIELDS:
            entry[label] = subset[field].mean() * 100 if total else 0.0
        data[line] = entry
    if not data:
        return None
    summary_df = pd.DataFrame(data)
    summary_df = summary_df.reindex(['Events'] + HAND_ORDER + [label for label, _ in RESPONSE_DRAW_FIELDS])
    return summary_df

def display_response_table(response_type):
    summary_df = summarize_responses(responses_df, response_type)
    if summary_df is None:
        print(f'No responder data for {response_type} events.')
        return
    styled = (
        summary_df.style
        .format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
        .format('{:.1f}%', subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .background_gradient(cmap='PuBu', axis=None, subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .set_caption(f'{response_type} vs Turn Bets (Responder Holdings)')
    )
    display(styled)



def summarize_responses_df_turn(responses_df, buckets=TURN_BUCKETS):
    summary = []
    for low, high, label in buckets:
        subset = responses_df[(responses_df['ratio'] >= low) & (responses_df['ratio'] < high)]
        if subset.empty:
            summary.append({
                'Bucket': label,
                'Events': 0,
                'Fold': 0.0,
                'Call': 0.0,
                'Raise': 0.0,
                'Continue': 0.0,
            })
            continue
        events_count = len(subset)
        response_counts = subset['response'].value_counts()
        continue_count = int(response_counts.get('Call', 0) + response_counts.get('Raise', 0))
        summary.append({
            'Bucket': label,
            'Events': events_count,
            'Fold': response_counts.get('Fold', 0) / events_count * 100,
            'Call': response_counts.get('Call', 0) / events_count * 100,
            'Raise': response_counts.get('Raise', 0) / events_count * 100,
            'Continue': continue_count / events_count * 100,
        })
    return summary

def _prepare_response_table_turn(records):
    if not records:
        return pd.DataFrame()
    df = pd.DataFrame(records)
    if 'Bucket' not in df.columns:
        return pd.DataFrame()
    df = df.set_index('Bucket').T.apply(pd.to_numeric, errors='coerce')
    row_order = ['Events', 'Fold', 'Call', 'Raise', 'Continue']
    ordered = [row for row in row_order if row in df.index]
    extras = [row for row in df.index if row not in row_order]
    if ordered or extras:
        df = df.loc[ordered + extras]
    return df

def _response_summary_turn(subset_df):
    if subset_df is None or subset_df.empty:
        return {
            'Events': 0,
            'Fold': 0.0,
            'Call': 0.0,
            'Raise': 0.0,
            'Continue': 0.0,
        }
    events_count = len(subset_df)
    response_counts = subset_df['response'].value_counts()
    continue_count = int(response_counts.get('Call', 0) + response_counts.get('Raise', 0))
    return {
        'Events': events_count,
        'Fold': response_counts.get('Fold', 0) / events_count * 100,
        'Call': response_counts.get('Call', 0) / events_count * 100,
        'Raise': response_counts.get('Raise', 0) / events_count * 100,
        'Continue': continue_count / events_count * 100,
    }

def _compute_special_columns_turn(source_df):
    specials = {}
    if source_df is None:
        return specials
    if 'is_all_in_bet' in source_df.columns:
        specials['All-In'] = _response_summary_turn(source_df[source_df['is_all_in_bet']])
    if 'is_one_bb_bet' in source_df.columns:
        specials['1 BB'] = _response_summary_turn(source_df[source_df['is_one_bb_bet']])
    return specials

def _style_response_table_turn(df, title, base_color='#6baed6'):
    if df.empty:
        return None
    percent_rows = [row for row in ['Fold', 'Call', 'Raise', 'Continue'] if row in df.index]
    styled = df.style
    if 'Events' in df.index:
        styled = styled.format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
    if percent_rows:
        styled = styled.format('{:.1f}%', subset=pd.IndexSlice[percent_rows, :])
        styled = styled.background_gradient(
            cmap=_gradient_cmap_turn(base_color),
            axis=None,
            subset=pd.IndexSlice[percent_rows, :]
        )
    special_cols = [col for col in ['All-In', '1 BB'] if col in df.columns]
    if special_cols:
        first = special_cols[0]
        idx = df.columns.get_loc(first)
        styled = styled.set_table_styles([
            {'selector': f'th.col_heading.level0.col{idx}', 'props': [('border-left', '2px solid #64748b')]},
            {'selector': f'td.col{idx}', 'props': [('border-left', '2px solid #64748b')]},
        ], overwrite=False)
    return styled.set_caption(title)

def display_response_tables_turn(summary_records, title, base_color='#6baed6', source_df=None):
    df = _prepare_response_table_turn(summary_records)
    if df.empty:
        display(pd.DataFrame({'Bucket': bucket_labels, 'Message': 'No events'}))
        return
    specials = _compute_special_columns_turn(source_df)
    if specials:
        for col_name, values in specials.items():
            for row in df.index:
                df.loc[row, col_name] = values.get(row, 0.0)
    styled = _style_response_table_turn(df, title, base_color=base_color)
    if styled is not None:
        display(styled)

def display_line_response_tables(line_type, title_prefix, base_color='#6baed6'):
    subset = responses_df[responses_df['line_type'] == line_type]
    if subset.empty:
        print(f'No response events recorded for {line_type}.')
        return
    overall = summarize_responses_df_turn(subset, TURN_BUCKETS)
    display_response_tables_turn(overall, f"{title_prefix} (Overall)", base_color=base_color, source_df=subset)

    ip_subset = subset[subset['bettor_in_position']]
    ip_summary = summarize_responses_df_turn(ip_subset, TURN_BUCKETS)
    display_response_tables_turn(ip_summary, f"{title_prefix} (In Position)", base_color=base_color, source_df=ip_subset)

    oop_subset = subset[~subset['bettor_in_position']]
    oop_summary = summarize_responses_df_turn(oop_subset, TURN_BUCKETS)
    display_response_tables_turn(oop_summary, f"{title_prefix} (Out of Position)", base_color=base_color, source_df=oop_subset)

# %%
def _filter_standard_turn_events(df):
    if df is None or df.empty:
        return df.iloc[0:0].copy()
    mask = pd.Series(True, index=df.index)
    if 'is_all_in' in df.columns:
        mask &= ~df['is_all_in']
    if 'is_one_bb' in df.columns:
        mask &= ~df['is_one_bb']
    return df.loc[mask].copy()


def _filter_standard_turn_responses(df):
    if df is None or df.empty:
        return df.iloc[0:0].copy()
    mask = pd.Series(True, index=df.index)
    if 'is_all_in_bet' in df.columns:
        mask &= ~df['is_all_in_bet']
    if 'is_one_bb_bet' in df.columns:
        mask &= ~df['is_one_bb_bet']
    return df.loc[mask].copy()


def _safe_mean(series):
    if series is None or len(series) == 0:
        return 0.0
    cleaned = series.dropna()
    if cleaned.empty:
        return 0.0
    value = cleaned.mean()
    return float(value) if pd.notna(value) else 0.0


def _prepare_turn_event_metrics(events_subset, responses_subset, *, exclude_special=True):
    if events_subset is None or events_subset.empty:
        return pd.DataFrame()
    events_work = events_subset.copy()
    responses_work = responses_subset.copy()
    if exclude_special:
        events_work = _filter_standard_turn_events(events_work)
        responses_work = _filter_standard_turn_responses(responses_work)
    if events_work.empty:
        return pd.DataFrame()
    events_work = events_work.rename(columns={'player': 'bettor'})
    base_cols = [
        'hand_number',
        'bettor',
        'line_type',
        'ratio',
        'bucket',
        'bet_amount',
        'bet_amount_bb',
        'big_blind',
        'pot_before',
        'bettor_in_position',
    ]
    missing = [col for col in base_cols if col not in events_work.columns]
    if missing:
        raise KeyError(f"Missing columns in events dataframe: {', '.join(missing)}")
    events_work = events_work[base_cols].copy()
    if responses_work.empty:
        agg = pd.DataFrame(
            columns=[
                'hand_number',
                'bettor',
                'continue_amount',
                'call_amount',
                'raise_amount',
                'call_flag',
                'raise_flag',
            ]
        )
    else:
        prepped = responses_work.copy()
        prepped['continue_amount'] = np.where(
            prepped['response'].isin(['Call', 'Raise']),
            prepped['response_amount'],
            0.0,
        )
        prepped['call_amount'] = np.where(
            prepped['response'] == 'Call',
            prepped['response_amount'],
            0.0,
        )
        prepped['raise_amount'] = np.where(
            prepped['response'] == 'Raise',
            prepped['response_amount'],
            0.0,
        )
        prepped['call_flag'] = (prepped['response'] == 'Call').astype(int)
        prepped['raise_flag'] = (prepped['response'] == 'Raise').astype(int)
        agg = (
            prepped.groupby(['hand_number', 'bettor'], as_index=False)
            .agg({
                'continue_amount': 'sum',
                'call_amount': 'sum',
                'raise_amount': 'sum',
                'call_flag': 'max',
                'raise_flag': 'max',
            })
        )
    metrics = events_work.merge(agg, on=['hand_number', 'bettor'], how='left')
    for column in ['continue_amount', 'call_amount', 'raise_amount']:
        metrics[column] = metrics[column].fillna(0.0)
    for column in ['call_flag', 'raise_flag']:
        metrics[column] = metrics[column].fillna(0).astype(int)
    metrics['continue_flag'] = metrics['continue_amount'] > 0
    metrics['call_only_flag'] = (metrics['call_flag'] > 0) & (metrics['raise_flag'] == 0)
    with np.errstate(divide='ignore', invalid='ignore'):
        metrics['bet_ratio_pct'] = metrics['ratio'].astype(float) * 100.0
        metrics['raise_ratio_pct'] = np.where(
            (metrics['raise_flag'] > 0) & (metrics['pot_before'] > 0),
            (metrics['raise_amount'] / metrics['pot_before']) * 100.0,
            np.nan,
        )
    metrics['breakeven_fold_pct'] = np.where(
        (metrics['bet_amount'] + metrics['pot_before']) > 0,
        metrics['bet_amount'] / (metrics['bet_amount'] + metrics['pot_before']) * 100,
        np.nan,
    )
    return metrics


def _compute_turn_event_bucket_metrics(metrics_df, buckets=TURN_BUCKETS):
    results = []
    if metrics_df is None or metrics_df.empty:
        for _, _, label in buckets:
            results.append({'Bucket': label, 'Events': 0.0})
        return results
    for low, high, label in buckets:
        bucket_mask = (metrics_df['ratio'] >= low) & (metrics_df['ratio'] < high)
        bucket_events = metrics_df.loc[bucket_mask]
        total = len(bucket_events)
        if total == 0:
            results.append({'Bucket': label, 'Events': 0.0})
            continue
        continue_events = int(bucket_events['continue_flag'].sum())
        raise_events = int(bucket_events['raise_flag'].sum())
        call_only_events = int(bucket_events['call_only_flag'].sum())
        fold_pct = (total - continue_events) / total * 100
        continue_pct = continue_events / total * 100
        raise_pct = raise_events / total * 100
        call_only_pct = call_only_events / total * 100
        avg_ratio_pct = _safe_mean(bucket_events['bet_ratio_pct'])
        raise_mask = bucket_events['raise_flag'] > 0
        avg_raise_ratio_pct = _safe_mean(bucket_events.loc[raise_mask, 'raise_ratio_pct'])
        avg_breakeven = _safe_mean(bucket_events['breakeven_fold_pct'])
        expected_call_contrib_pct = (call_only_pct * avg_ratio_pct) / 100.0
        expected_raise_contrib_pct = (raise_pct * avg_raise_ratio_pct) / 100.0
        total_contrib_pct = expected_call_contrib_pct + expected_raise_contrib_pct
        row = {
            'Bucket': label,
            'Events': float(total),
            'Fold%': fold_pct,
            'Continue%': continue_pct,
            'Call-Only%': call_only_pct,
            'Raise%': raise_pct,
            'Avg Size (Pot%)': avg_ratio_pct,
            'Avg Raise Size (Pot%)': avg_raise_ratio_pct,
            'Expected Call Contribution (Pot%)': expected_call_contrib_pct,
            'Expected Raise Contribution (Pot%)': expected_raise_contrib_pct,
            'Raise Contribution Total (Pot%)': total_contrib_pct,
            'Breakeven Fold%': avg_breakeven,
        }
        row['Fold Surplus'] = row['Fold%'] - row['Breakeven Fold%']
        results.append(row)
    return results


VALUE_COLUMNS_TURN = [
    'Bucket',
    'Events',
    'Continue%',
    'Call-Only%',
    'Raise%',
    'Avg Size (Pot%)',
    'Avg Raise Size (Pot%)',
    'Expected Call Contribution (Pot%)',
    'Expected Raise Contribution (Pot%)',
    'Raise Contribution Total (Pot%)',
]


PRESSURE_COLUMNS_TURN = [
    'Bucket',
    'Events',
    'Fold%',
    'Avg Size (Pot%)',
    'Breakeven Fold%',
    'Fold Surplus',
]


_FOLD_SURPLUS_CMAP = LinearSegmentedColormap.from_list(
    'fold_surplus_cmp', ['#b91c1c', '#ffffff', '#15803d']
)


def _style_turn_value_table(table_df, title):
    if table_df.empty:
        return None
    df = table_df.set_index('Bucket').T
    percent_rows = [row for row in df.index if row != 'Events']
    styled = df.style
    if 'Events' in df.index:
        styled = styled.format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
    if percent_rows:
        styled = styled.format('{:.1f}%', subset=pd.IndexSlice[percent_rows, :])
        contribution_rows = [row for row in percent_rows if 'Contribution' in row]
        size_rows = [row for row in percent_rows if 'Size' in row]
        pct_rows_other = [row for row in percent_rows if row not in contribution_rows + size_rows]
        if pct_rows_other:
            styled = styled.background_gradient(
                cmap='YlOrRd',
                axis=None,
                subset=pd.IndexSlice[pct_rows_other, :],
            )
        if size_rows:
            styled = styled.background_gradient(
                cmap='BuGn',
                axis=None,
                subset=pd.IndexSlice[size_rows, :],
            )
        if contribution_rows:
            styled = styled.background_gradient(
                cmap='PuBu',
                axis=None,
                subset=pd.IndexSlice[contribution_rows, :],
            )
    return styled.set_caption(title)


def _style_turn_pressure_table(table_df, title):
    if table_df.empty:
        return None
    df = table_df.set_index('Bucket').T
    desired_order = ['Events', 'Fold%', 'Avg Size (Pot%)', 'Breakeven Fold%', 'Fold Surplus']
    existing_order = [row for row in desired_order if row in df.index]
    df = df.loc[existing_order]
    styled = df.style
    if 'Events' in df.index:
        styled = styled.format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
    percent_rows = [row for row in df.index if row != 'Events']
    if percent_rows:
        styled = styled.format('{:.1f}%', subset=pd.IndexSlice[percent_rows, :])
    if 'Fold%' in df.index:
        styled = styled.background_gradient(
            cmap='YlOrRd',
            axis=None,
            subset=pd.IndexSlice[['Fold%'], :],
        )
    if 'Avg Size (Pot%)' in df.index:
        styled = styled.background_gradient(
            cmap='BuGn',
            axis=None,
            subset=pd.IndexSlice[['Avg Size (Pot%)'], :],
        )
    if 'Fold Surplus' in df.index:
        fold_values = df.loc['Fold Surplus'].dropna().astype(float)
        if not fold_values.empty:
            max_abs = max(abs(fold_values.min()), abs(fold_values.max()))
            if max_abs == 0:
                max_abs = 1.0
            styled = styled.background_gradient(
                cmap=_FOLD_SURPLUS_CMAP,
                axis=None,
                subset=pd.IndexSlice[['Fold Surplus'], :],
                vmin=-max_abs,
                vmax=max_abs,
            )
    return styled.set_caption(title)


def _display_turn_event_tables(metrics_df, title_prefix):
    if metrics_df is None or metrics_df.empty:
        print(f'No events available for {title_prefix}.')
        return
    records = _compute_turn_event_bucket_metrics(metrics_df)
    if not records:
        print(f'No bucketed metrics available for {title_prefix}.')
        return
    metrics_table = pd.DataFrame(records)
    value_columns = [col for col in VALUE_COLUMNS_TURN if col in metrics_table.columns]
    pressure_columns = [col for col in PRESSURE_COLUMNS_TURN if col in metrics_table.columns]
    value_table = metrics_table[value_columns]
    pressure_table = metrics_table[pressure_columns]
    value_styled = _style_turn_value_table(value_table, f"{title_prefix} - Value Profile")
    if value_styled is not None:
        display(value_styled)
    pressure_styled = _style_turn_pressure_table(pressure_table, f"{title_prefix} - Fold Pressure")
    if pressure_styled is not None:
        display(pressure_styled)


def display_turn_event_ev_tables(line_type, title_prefix, *, exclude_special=True):
    line_events = events_df[events_df['line_type'] == line_type]
    if line_events.empty:
        print(f'No {line_type.lower()} events available for analysis.')
        return
    line_responses = responses_df[responses_df['line_type'] == line_type]
    base_metrics = _prepare_turn_event_metrics(line_events, line_responses, exclude_special=exclude_special)
    if base_metrics.empty:
        print(f'No {line_type.lower()} events remain after filtering special cases.')
        return
    subsets = [
        (base_metrics, f"{title_prefix} (Overall)"),
        (base_metrics[base_metrics['bettor_in_position']], f"{title_prefix} (In Position)"),
        (base_metrics[~base_metrics['bettor_in_position']], f"{title_prefix} (Out of Position)"),
    ]
    for subset_df, label in subsets:
        if subset_df is None or subset_df.empty:
            continue
        _display_turn_event_tables(subset_df, label)


def display_all_turn_event_tables():
    if responses_df.empty or events_df.empty:
        print('No turn events or responses available for event-level contribution tables.')
        return
    display_turn_event_ev_tables('Barrel', 'Turn Barrel Event Outcomes')
    display_turn_event_ev_tables('Delayed', 'Turn Delayed C-Bet Event Outcomes')

# %%
display_line_comparison(events_df, 'Turn Hand Types by Line')
display_line_comparison_grouped(events_df, 'Turn Hand Types by Line (Grouped)')
# Out:
# <style type="text/css">
# #T_6abce_row1_col0 {
#   background-color: #ea2920;
#   color: #f1f1f1;
# }
# #T_6abce_row1_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_6abce_row1_col2 {
#   background-color: #d9131f;
#   color: #f1f1f1;
# }
# #T_6abce_row2_col0, #T_6abce_row2_col1, #T_6abce_row6_col0 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_6abce_row2_col2 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_6abce_row3_col0 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_6abce_row3_col1 {
#   background-color: #ffeea3;
#   color: #000000;
# }
# #T_6abce_row3_col2 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_6abce_row4_col0 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_6abce_row4_col1, #T_6abce_row8_col1 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_6abce_row4_col2, #T_6abce_row14_col2 {
#   background-color: #fee085;
#   color: #000000;
# }
# #T_6abce_row5_col0 {
#   background-color: #fd9c42;
#   color: #000000;
# }
# #T_6abce_row5_col1 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_6abce_row5_col2 {
#   background-color: #feb953;
#   color: #000000;
# }
# #T_6abce_row6_col1 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_6abce_row6_col2 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_6abce_row7_col0 {
#   background-color: #fd883b;
#   color: #f1f1f1;
# }
# #T_6abce_row7_col1 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_6abce_row7_col2 {
#   background-color: #fd8f3d;
#   color: #f1f1f1;
# }
# #T_6abce_row8_col0, #T_6abce_row8_col2 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_6abce_row9_col0 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_6abce_row9_col1 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_6abce_row9_col2 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_6abce_row10_col0 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_6abce_row10_col1 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_6abce_row10_col2 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_6abce_row11_col0, #T_6abce_row11_col1, #T_6abce_row11_col2 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_6abce_row12_col0, #T_6abce_row12_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_6abce_row12_col1 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_6abce_row13_col0 {
#   background-color: #febb56;
#   color: #000000;
# }
# #T_6abce_row13_col1 {
#   background-color: #febd57;
#   color: #000000;
# }
# #T_6abce_row13_col2 {
#   background-color: #fea747;
#   color: #000000;
# }
# #T_6abce_row14_col0 {
#   background-color: #fedb7a;
#   color: #000000;
# }
# #T_6abce_row14_col1 {
#   background-color: #fed774;
#   color: #000000;
# }
# </style>
# <table id="T_6abce">
#   <caption>Turn Hand Types by Line</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6abce_level0_col0" class="col_heading level0 col0" >Barrel</th>
#       <th id="T_6abce_level0_col1" class="col_heading level0 col1" >Delayed</th>
#       <th id="T_6abce_level0_col2" class="col_heading level0 col2" >Other</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6abce_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_6abce_row0_col0" class="data row0 col0" >3140</td>
#       <td id="T_6abce_row0_col1" class="data row0 col1" >2843</td>
#       <td id="T_6abce_row0_col2" class="data row0 col2" >793</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_6abce_row1_col0" class="data row1 col0" >28.0%</td>
#       <td id="T_6abce_row1_col1" class="data row1 col1" >39.2%</td>
#       <td id="T_6abce_row1_col2" class="data row1 col2" >30.8%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row2" class="row_heading level0 row2" >Underpair</th>
#       <td id="T_6abce_row2_col0" class="data row2 col0" >4.2%</td>
#       <td id="T_6abce_row2_col1" class="data row2 col1" >4.3%</td>
#       <td id="T_6abce_row2_col2" class="data row2 col2" >4.4%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row3" class="row_heading level0 row3" >Bottom Pair</th>
#       <td id="T_6abce_row3_col0" class="data row3 col0" >3.3%</td>
#       <td id="T_6abce_row3_col1" class="data row3 col1" >4.6%</td>
#       <td id="T_6abce_row3_col2" class="data row3 col2" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row4" class="row_heading level0 row4" >Middle Pair</th>
#       <td id="T_6abce_row4_col0" class="data row4 col0" >7.6%</td>
#       <td id="T_6abce_row4_col1" class="data row4 col1" >7.1%</td>
#       <td id="T_6abce_row4_col2" class="data row4 col2" >8.1%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row5" class="row_heading level0 row5" >Top Pair</th>
#       <td id="T_6abce_row5_col0" class="data row5 col0" >17.7%</td>
#       <td id="T_6abce_row5_col1" class="data row5 col1" >13.1%</td>
#       <td id="T_6abce_row5_col2" class="data row5 col2" >13.9%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row6" class="row_heading level0 row6" >Overpair</th>
#       <td id="T_6abce_row6_col0" class="data row6 col0" >4.3%</td>
#       <td id="T_6abce_row6_col1" class="data row6 col1" >0.8%</td>
#       <td id="T_6abce_row6_col2" class="data row6 col2" >1.6%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row7" class="row_heading level0 row7" >Two Pair</th>
#       <td id="T_6abce_row7_col0" class="data row7 col0" >20.0%</td>
#       <td id="T_6abce_row7_col1" class="data row7 col1" >16.4%</td>
#       <td id="T_6abce_row7_col2" class="data row7 col2" >19.4%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row8" class="row_heading level0 row8" >Trips/Set</th>
#       <td id="T_6abce_row8_col0" class="data row8 col0" >6.9%</td>
#       <td id="T_6abce_row8_col1" class="data row8 col1" >7.1%</td>
#       <td id="T_6abce_row8_col2" class="data row8 col2" >6.9%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row9" class="row_heading level0 row9" >Straight</th>
#       <td id="T_6abce_row9_col0" class="data row9 col0" >3.7%</td>
#       <td id="T_6abce_row9_col1" class="data row9 col1" >3.4%</td>
#       <td id="T_6abce_row9_col2" class="data row9 col2" >6.1%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row10" class="row_heading level0 row10" >Flush</th>
#       <td id="T_6abce_row10_col0" class="data row10 col0" >2.6%</td>
#       <td id="T_6abce_row10_col1" class="data row10 col1" >2.0%</td>
#       <td id="T_6abce_row10_col2" class="data row10 col2" >3.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row11" class="row_heading level0 row11" >Full House</th>
#       <td id="T_6abce_row11_col0" class="data row11 col0" >1.7%</td>
#       <td id="T_6abce_row11_col1" class="data row11 col1" >1.8%</td>
#       <td id="T_6abce_row11_col2" class="data row11 col2" >1.8%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row12" class="row_heading level0 row12" >Quads</th>
#       <td id="T_6abce_row12_col0" class="data row12 col0" >0.0%</td>
#       <td id="T_6abce_row12_col1" class="data row12 col1" >0.2%</td>
#       <td id="T_6abce_row12_col2" class="data row12 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row13" class="row_heading level0 row13" >Flush Draw</th>
#       <td id="T_6abce_row13_col0" class="data row13 col0" >13.6%</td>
#       <td id="T_6abce_row13_col1" class="data row13 col1" >13.3%</td>
#       <td id="T_6abce_row13_col2" class="data row13 col2" >16.1%</td>
#     </tr>
#     <tr>
#       <th id="T_6abce_level0_row14" class="row_heading level0 row14" >OESD/DG</th>
#       <td id="T_6abce_row14_col0" class="data row14 col0" >9.4%</td>
#       <td id="T_6abce_row14_col1" class="data row14 col1" >10.1%</td>
#       <td id="T_6abce_row14_col2" class="data row14 col2" >8.1%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ae868_row1_col0 {
#   background-color: #ec2c21;
#   color: #f1f1f1;
# }
# #T_ae868_row1_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_ae868_row1_col2 {
#   background-color: #da141e;
#   color: #f1f1f1;
# }
# #T_ae868_row2_col0 {
#   background-color: #feb44e;
#   color: #000000;
# }
# #T_ae868_row2_col1 {
#   background-color: #feac49;
#   color: #000000;
# }
# #T_ae868_row2_col2 {
#   background-color: #fea848;
#   color: #000000;
# }
# #T_ae868_row3_col0 {
#   background-color: #fd9f44;
#   color: #000000;
# }
# #T_ae868_row3_col1 {
#   background-color: #fec45f;
#   color: #000000;
# }
# #T_ae868_row3_col2 {
#   background-color: #febd57;
#   color: #000000;
# }
# #T_ae868_row4_col0 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_ae868_row4_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_ae868_row4_col2 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_ae868_row5_col0 {
#   background-color: #fd8e3c;
#   color: #f1f1f1;
# }
# #T_ae868_row5_col1 {
#   background-color: #fea948;
#   color: #000000;
# }
# #T_ae868_row5_col2 {
#   background-color: #fd913e;
#   color: #000000;
# }
# #T_ae868_row6_col0, #T_ae868_row6_col2 {
#   background-color: #ffe895;
#   color: #000000;
# }
# #T_ae868_row6_col1 {
#   background-color: #ffe794;
#   color: #000000;
# }
# #T_ae868_row7_col0 {
#   background-color: #fee38b;
#   color: #000000;
# }
# #T_ae868_row7_col1 {
#   background-color: #ffe590;
#   color: #000000;
# }
# #T_ae868_row7_col2 {
#   background-color: #fed673;
#   color: #000000;
# }
# #T_ae868_row8_col0 {
#   background-color: #fd7a37;
#   color: #f1f1f1;
# }
# #T_ae868_row8_col1 {
#   background-color: #fd7836;
#   color: #f1f1f1;
# }
# #T_ae868_row8_col2 {
#   background-color: #fd6e33;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ae868">
#   <caption>Turn Hand Types by Line (Grouped)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae868_level0_col0" class="col_heading level0 col0" >Barrel</th>
#       <th id="T_ae868_level0_col1" class="col_heading level0 col1" >Delayed</th>
#       <th id="T_ae868_level0_col2" class="col_heading level0 col2" >Other</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae868_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_ae868_row0_col0" class="data row0 col0" >3140</td>
#       <td id="T_ae868_row0_col1" class="data row0 col1" >2843</td>
#       <td id="T_ae868_row0_col2" class="data row0 col2" >793</td>
#     </tr>
#     <tr>
#       <th id="T_ae868_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_ae868_row1_col0" class="data row1 col0" >28.0%</td>
#       <td id="T_ae868_row1_col1" class="data row1 col1" >39.2%</td>
#       <td id="T_ae868_row1_col2" class="data row1 col2" >30.8%</td>
#     </tr>
#     <tr>
#       <th id="T_ae868_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_ae868_row2_col0" class="data row2 col0" >15.0%</td>
#       <td id="T_ae868_row2_col1" class="data row2 col1" >16.0%</td>
#       <td id="T_ae868_row2_col2" class="data row2 col2" >16.5%</td>
#     </tr>
#     <tr>
#       <th id="T_ae868_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_ae868_row3_col0" class="data row3 col0" >17.7%</td>
#       <td id="T_ae868_row3_col1" class="data row3 col1" >13.1%</td>
#       <td id="T_ae868_row3_col2" class="data row3 col2" >13.9%</td>
#     </tr>
#     <tr>
#       <th id="T_ae868_level0_row4" class="row_heading level0 row4" >Overpair</th>
#       <td id="T_ae868_row4_col0" class="data row4 col0" >4.3%</td>
#       <td id="T_ae868_row4_col1" class="data row4 col1" >0.8%</td>
#       <td id="T_ae868_row4_col2" class="data row4 col2" >1.6%</td>
#     </tr>
#     <tr>
#       <th id="T_ae868_level0_row5" class="row_heading level0 row5" >Two Pair</th>
#       <td id="T_ae868_row5_col0" class="data row5 col0" >20.0%</td>
#       <td id="T_ae868_row5_col1" class="data row5 col1" >16.4%</td>
#       <td id="T_ae868_row5_col2" class="data row5 col2" >19.4%</td>
#     </tr>
#     <tr>
#       <th id="T_ae868_level0_row6" class="row_heading level0 row6" >Trips/Set</th>
#       <td id="T_ae868_row6_col0" class="data row6 col0" >6.9%</td>
#       <td id="T_ae868_row6_col1" class="data row6 col1" >7.1%</td>
#       <td id="T_ae868_row6_col2" class="data row6 col2" >6.9%</td>
#     </tr>
#     <tr>
#       <th id="T_ae868_level0_row7" class="row_heading level0 row7" >Monster</th>
#       <td id="T_ae868_row7_col0" class="data row7 col0" >8.1%</td>
#       <td id="T_ae868_row7_col1" class="data row7 col1" >7.5%</td>
#       <td id="T_ae868_row7_col2" class="data row7 col2" >10.8%</td>
#     </tr>
#     <tr>
#       <th id="T_ae868_level0_row8" class="row_heading level0 row8" >Draw</th>
#       <td id="T_ae868_row8_col0" class="data row8 col0" >21.4%</td>
#       <td id="T_ae868_row8_col1" class="data row8 col1" >21.5%</td>
#       <td id="T_ae868_row8_col2" class="data row8 col2" >22.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
display_bucket_table(events_df[events_df['line_type'] == 'Barrel'], 'Turn Bet Sizing vs Hand Type (Barrel)')
display_bucket_table_grouped(events_df[events_df['line_type'] == 'Barrel'], 'Turn Bet Sizing vs Hand Type (Barrel) — Grouped')
display_bucket_table(events_df[events_df['line_type'] == 'Delayed'], 'Turn Bet Sizing vs Hand Type (Delayed)')
display_bucket_table_grouped(events_df[events_df['line_type'] == 'Delayed'], 'Turn Bet Sizing vs Hand Type (Delayed) — Grouped')
# Out:
# <style type="text/css">
# #T_a09a7 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_a09a7 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_a09a7_row1_col0 {
#   background-color: #b20026;
#   color: #f1f1f1;
# }
# #T_a09a7_row1_col1 {
#   background-color: #eb2b21;
#   color: #f1f1f1;
# }
# #T_a09a7_row1_col2 {
#   background-color: #b00026;
#   color: #f1f1f1;
# }
# #T_a09a7_row1_col3 {
#   background-color: #aa0026;
#   color: #f1f1f1;
# }
# #T_a09a7_row1_col4, #T_a09a7_row7_col6 {
#   background-color: #fb4b29;
#   color: #f1f1f1;
# }
# #T_a09a7_row1_col5 {
#   background-color: #9f0026;
#   color: #f1f1f1;
# }
# #T_a09a7_row1_col6 {
#   background-color: #a60026;
#   color: #f1f1f1;
# }
# #T_a09a7_row1_col7 {
#   background-color: #fd8038;
#   color: #f1f1f1;
# }
# #T_a09a7_row1_col8 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_a09a7_row2_col0, #T_a09a7_row8_col2 {
#   background-color: #ffe895;
#   color: #000000;
# }
# #T_a09a7_row2_col1 {
#   background-color: #ffe590;
#   color: #000000;
# }
# #T_a09a7_row2_col2, #T_a09a7_row2_col7 {
#   background-color: #ffea99;
#   color: #000000;
# }
# #T_a09a7_row2_col3, #T_a09a7_row6_col6, #T_a09a7_row9_col7, #T_a09a7_row11_col6 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_a09a7_row2_col4, #T_a09a7_row2_col8, #T_a09a7_row3_col4 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_a09a7_row2_col5, #T_a09a7_row3_col5, #T_a09a7_row3_col7, #T_a09a7_row6_col0, #T_a09a7_row10_col5, #T_a09a7_row11_col3, #T_a09a7_row11_col5, #T_a09a7_row11_col8 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_a09a7_row2_col6 {
#   background-color: #ffeea3;
#   color: #000000;
# }
# #T_a09a7_row3_col0, #T_a09a7_row4_col0, #T_a09a7_row4_col8 {
#   background-color: #feda78;
#   color: #000000;
# }
# #T_a09a7_row3_col1 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_a09a7_row3_col2, #T_a09a7_row10_col2, #T_a09a7_row10_col4 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_a09a7_row3_col3, #T_a09a7_row4_col6 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_a09a7_row3_col6 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_a09a7_row3_col8, #T_a09a7_row13_col8 {
#   background-color: #feba55;
#   color: #000000;
# }
# #T_a09a7_row4_col1 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_a09a7_row4_col2 {
#   background-color: #feca66;
#   color: #000000;
# }
# #T_a09a7_row4_col3, #T_a09a7_row8_col7 {
#   background-color: #ffe794;
#   color: #000000;
# }
# #T_a09a7_row4_col4, #T_a09a7_row8_col4 {
#   background-color: #fedb7b;
#   color: #000000;
# }
# #T_a09a7_row4_col5, #T_a09a7_row9_col2, #T_a09a7_row10_col3 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_a09a7_row4_col7 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_a09a7_row5_col0 {
#   background-color: #fea546;
#   color: #000000;
# }
# #T_a09a7_row5_col1 {
#   background-color: #fd8e3c;
#   color: #f1f1f1;
# }
# #T_a09a7_row5_col2 {
#   background-color: #fd863a;
#   color: #f1f1f1;
# }
# #T_a09a7_row5_col3 {
#   background-color: #fc592d;
#   color: #f1f1f1;
# }
# #T_a09a7_row5_col4 {
#   background-color: #fd7836;
#   color: #f1f1f1;
# }
# #T_a09a7_row5_col5 {
#   background-color: #fd9d43;
#   color: #000000;
# }
# #T_a09a7_row5_col6 {
#   background-color: #f84528;
#   color: #f1f1f1;
# }
# #T_a09a7_row5_col7 {
#   background-color: #f64227;
#   color: #f1f1f1;
# }
# #T_a09a7_row5_col8 {
#   background-color: #fead4a;
#   color: #000000;
# }
# #T_a09a7_row6_col1, #T_a09a7_row9_col1 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_a09a7_row6_col2 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_a09a7_row6_col3 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_a09a7_row6_col4 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_a09a7_row6_col5, #T_a09a7_row8_col5 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_a09a7_row6_col7 {
#   background-color: #fec863;
#   color: #000000;
# }
# #T_a09a7_row6_col8, #T_a09a7_row12_col0, #T_a09a7_row12_col1, #T_a09a7_row12_col2, #T_a09a7_row12_col3, #T_a09a7_row12_col5, #T_a09a7_row12_col6, #T_a09a7_row12_col7, #T_a09a7_row12_col8 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_a09a7_row7_col0 {
#   background-color: #ec2c21;
#   color: #f1f1f1;
# }
# #T_a09a7_row7_col1 {
#   background-color: #fa4a29;
#   color: #f1f1f1;
# }
# #T_a09a7_row7_col2 {
#   background-color: #fc6330;
#   color: #f1f1f1;
# }
# #T_a09a7_row7_col3 {
#   background-color: #fd7a37;
#   color: #f1f1f1;
# }
# #T_a09a7_row7_col4 {
#   background-color: #f13824;
#   color: #f1f1f1;
# }
# #T_a09a7_row7_col5 {
#   background-color: #fc4f2a;
#   color: #f1f1f1;
# }
# #T_a09a7_row7_col7 {
#   background-color: #e41c1d;
#   color: #f1f1f1;
# }
# #T_a09a7_row7_col8 {
#   background-color: #ea2920;
#   color: #f1f1f1;
# }
# #T_a09a7_row8_col0 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_a09a7_row8_col1 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_a09a7_row8_col3 {
#   background-color: #fedb7a;
#   color: #000000;
# }
# #T_a09a7_row8_col6, #T_a09a7_row9_col4 {
#   background-color: #fee085;
#   color: #000000;
# }
# #T_a09a7_row8_col8 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_a09a7_row9_col0, #T_a09a7_row10_col6, #T_a09a7_row11_col1 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_a09a7_row9_col3, #T_a09a7_row11_col4 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_a09a7_row9_col5 {
#   background-color: #ffec9d;
#   color: #000000;
# }
# #T_a09a7_row9_col6 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_a09a7_row9_col8, #T_a09a7_row10_col8 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_a09a7_row10_col0 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_a09a7_row10_col1 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_a09a7_row10_col7 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_a09a7_row11_col0 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_a09a7_row11_col2 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_a09a7_row11_col7 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_a09a7_row12_col4 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_a09a7_row13_col0, #T_a09a7_row13_col6, #T_a09a7_row14_col0, #T_a09a7_row14_col5 {
#   background-color: #feb852;
#   color: #000000;
# }
# #T_a09a7_row13_col1 {
#   background-color: #fd9740;
#   color: #000000;
# }
# #T_a09a7_row13_col2 {
#   background-color: #feac49;
#   color: #000000;
# }
# #T_a09a7_row13_col3 {
#   background-color: #fea044;
#   color: #000000;
# }
# #T_a09a7_row13_col4 {
#   background-color: #feae4a;
#   color: #000000;
# }
# #T_a09a7_row13_col5 {
#   background-color: #fd903d;
#   color: #000000;
# }
# #T_a09a7_row13_col7, #T_a09a7_row14_col6 {
#   background-color: #fecc68;
#   color: #000000;
# }
# #T_a09a7_row14_col1, #T_a09a7_row14_col3 {
#   background-color: #fed16e;
#   color: #000000;
# }
# #T_a09a7_row14_col2 {
#   background-color: #fec561;
#   color: #000000;
# }
# #T_a09a7_row14_col4 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_a09a7_row14_col7 {
#   background-color: #fed572;
#   color: #000000;
# }
# #T_a09a7_row14_col8 {
#   background-color: #feb24c;
#   color: #000000;
# }
# </style>
# <table id="T_a09a7">
#   <caption>Turn Bet Sizing vs Hand Type (Barrel)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a09a7_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_a09a7_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_a09a7_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_a09a7_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_a09a7_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_a09a7_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_a09a7_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_a09a7_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_a09a7_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a09a7_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_a09a7_row0_col0" class="data row0 col0" >348</td>
#       <td id="T_a09a7_row0_col1" class="data row0 col1" >397</td>
#       <td id="T_a09a7_row0_col2" class="data row0 col2" >823</td>
#       <t
# <style type="text/css">
# #T_6ad7d th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_6ad7d td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_6ad7d_row1_col0 {
#   background-color: #b20026;
#   color: #f1f1f1;
# }
# #T_6ad7d_row1_col1, #T_6ad7d_row8_col1 {
#   background-color: #eb2b21;
#   color: #f1f1f1;
# }
# #T_6ad7d_row1_col2 {
#   background-color: #b00026;
#   color: #f1f1f1;
# }
# #T_6ad7d_row1_col3 {
#   background-color: #aa0026;
#   color: #f1f1f1;
# }
# #T_6ad7d_row1_col4, #T_6ad7d_row5_col6 {
#   background-color: #fb4b29;
#   color: #f1f1f1;
# }
# #T_6ad7d_row1_col5 {
#   background-color: #9f0026;
#   color: #f1f1f1;
# }
# #T_6ad7d_row1_col6 {
#   background-color: #a60026;
#   color: #f1f1f1;
# }
# #T_6ad7d_row1_col7 {
#   background-color: #fd8038;
#   color: #f1f1f1;
# }
# #T_6ad7d_row1_col8 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_6ad7d_row2_col0 {
#   background-color: #f84628;
#   color: #f1f1f1;
# }
# #T_6ad7d_row2_col1, #T_6ad7d_row2_col8 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_6ad7d_row2_col2, #T_6ad7d_row8_col4 {
#   background-color: #fd7636;
#   color: #f1f1f1;
# }
# #T_6ad7d_row2_col3 {
#   background-color: #fec45f;
#   color: #000000;
# }
# #T_6ad7d_row2_col4 {
#   background-color: #feae4a;
#   color: #000000;
# }
# #T_6ad7d_row2_col5, #T_6ad7d_row4_col3 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_6ad7d_row2_col6 {
#   background-color: #ffe48c;
#   color: #000000;
# }
# #T_6ad7d_row2_col7 {
#   background-color: #fea848;
#   color: #000000;
# }
# #T_6ad7d_row3_col0 {
#   background-color: #fea546;
#   color: #000000;
# }
# #T_6ad7d_row3_col1 {
#   background-color: #fd8e3c;
#   color: #f1f1f1;
# }
# #T_6ad7d_row3_col2 {
#   background-color: #fd863a;
#   color: #f1f1f1;
# }
# #T_6ad7d_row3_col3 {
#   background-color: #fc592d;
#   color: #f1f1f1;
# }
# #T_6ad7d_row3_col4 {
#   background-color: #fd7836;
#   color: #f1f1f1;
# }
# #T_6ad7d_row3_col5 {
#   background-color: #fd9d43;
#   color: #000000;
# }
# #T_6ad7d_row3_col6 {
#   background-color: #f84528;
#   color: #f1f1f1;
# }
# #T_6ad7d_row3_col7, #T_6ad7d_row8_col0 {
#   background-color: #f64227;
#   color: #f1f1f1;
# }
# #T_6ad7d_row3_col8 {
#   background-color: #fead4a;
#   color: #000000;
# }
# #T_6ad7d_row4_col0 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_6ad7d_row4_col1 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_6ad7d_row4_col2 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_6ad7d_row4_col4 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_6ad7d_row4_col5, #T_6ad7d_row6_col5 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_6ad7d_row4_col6 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_6ad7d_row4_col7 {
#   background-color: #fec863;
#   color: #000000;
# }
# #T_6ad7d_row4_col8 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_6ad7d_row5_col0 {
#   background-color: #ec2c21;
#   color: #f1f1f1;
# }
# #T_6ad7d_row5_col1 {
#   background-color: #fa4a29;
#   color: #f1f1f1;
# }
# #T_6ad7d_row5_col2 {
#   background-color: #fc6330;
#   color: #f1f1f1;
# }
# #T_6ad7d_row5_col3, #T_6ad7d_row8_col7 {
#   background-color: #fd7a37;
#   color: #f1f1f1;
# }
# #T_6ad7d_row5_col4 {
#   background-color: #f13824;
#   color: #f1f1f1;
# }
# #T_6ad7d_row5_col5 {
#   background-color: #fc4f2a;
#   color: #f1f1f1;
# }
# #T_6ad7d_row5_col7 {
#   background-color: #e41c1d;
#   color: #f1f1f1;
# }
# #T_6ad7d_row5_col8, #T_6ad7d_row8_col5 {
#   background-color: #ea2920;
#   color: #f1f1f1;
# }
# #T_6ad7d_row6_col0 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_6ad7d_row6_col1 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_6ad7d_row6_col2 {
#   background-color: #ffe895;
#   color: #000000;
# }
# #T_6ad7d_row6_col3, #T_6ad7d_row7_col3 {
#   background-color: #fedb7a;
#   color: #000000;
# }
# #T_6ad7d_row6_col4 {
#   background-color: #fedb7b;
#   color: #000000;
# }
# #T_6ad7d_row6_col6 {
#   background-color: #fee085;
#   color: #000000;
# }
# #T_6ad7d_row6_col7 {
#   background-color: #ffe794;
#   color: #000000;
# }
# #T_6ad7d_row6_col8 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_6ad7d_row7_col0 {
#   background-color: #ffec9f;
#   color: #000000;
# }
# #T_6ad7d_row7_col1 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_6ad7d_row7_col2 {
#   background-color: #fee084;
#   color: #000000;
# }
# #T_6ad7d_row7_col4 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_6ad7d_row7_col5 {
#   background-color: #fedd7f;
#   color: #000000;
# }
# #T_6ad7d_row7_col6 {
#   background-color: #febd57;
#   color: #000000;
# }
# #T_6ad7d_row7_col7 {
#   background-color: #fedc7c;
#   color: #000000;
# }
# #T_6ad7d_row7_col8 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_6ad7d_row8_col2 {
#   background-color: #f43e26;
#   color: #f1f1f1;
# }
# #T_6ad7d_row8_col3 {
#   background-color: #f54026;
#   color: #f1f1f1;
# }
# #T_6ad7d_row8_col6 {
#   background-color: #fc552c;
#   color: #f1f1f1;
# }
# #T_6ad7d_row8_col8 {
#   background-color: #f13624;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6ad7d">
#   <caption>Turn Bet Sizing vs Hand Type (Barrel) — Grouped</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ad7d_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_6ad7d_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_6ad7d_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_6ad7d_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_6ad7d_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_6ad7d_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_6ad7d_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_6ad7d_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_6ad7d_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ad7d_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_6ad7d_row0_col0" class="data row0 col0" >348</td>
#       <td id="T_6ad7d_row0_col1" class="data row0 col1" >397</td>
#       <td id="T_6ad7d_row0_col2" class="data row0 col2" >823</td>
#       <td id="T_6ad7d_row0_col3" class="data row0 col3" >927</td>
#       <td id="T_6ad7d_row0_col4" class="data row0 col4" >399</td>
#       <td id="T_6ad7d_row0_col5" class="data row0 col5" >68</td>
#       <td id="T_6ad7d_row0_col6" class="data row0 col6" >178</td>
#       <td id="T_6ad7d_row0_col7" class="data row0 col7" >208</td>
#       <td id="T_6ad7d_row0_col8" class="data row0 col8" >200</td>
#     </tr>
#     <tr>
#       <th id="T_6ad7d_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_6ad7d_row1_col0" class="data row1 col0" >29.6%</td>
#       <td id="T_6ad7d_row1_col1" class="data row1 col1" >23.4%</td>
#       <td id="T_6ad7d_row1_col2" class="data row1 col2" >29.8%</td>
#       <td id="T_6ad7d_row1_col3" class="data row1 col3" >30.1%</td>
#       <td id="T_6ad7d_row1_col4" class="data row1 col4" >20.8%</td>
#       <td id="T_6ad7d_row1_col5" class="data row1 col5" >30.9%</td>
#       <td id="T_6ad7d_row1_col6" class="data row1 col6" >30.3%</td>
#       <td id="T_6ad7d_row1_col7" class="data row1 col7" >17.3%</td>
#       <td id="T_6ad7d_row1_col8" class="data row1 col8" >33.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6ad7d_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_6ad7d_row2_col0" class="data row2 col0" >21.3%</td>
#       <td id="T_6ad7d_row2_col1" class="data row2 col1" >21.9%</td>
#       <td id="T_6ad7d_row2_col2" class="data row2 col2" >18.0%</td>
#       <td id="T_6ad7d_row2_col3" class="data row2 col3" >10.5%</td>
#       <td id="T_6ad7d_row2_col4" class="data row2 col4" >12.8%</td>
#       <td id="T_6ad7d_row2_col5" class="data row2 col5" >5.9%</td>
#       <td id="T_6ad7d_row2_col6" class="data row2 col6" >6.2%</td>
#       <td id="T_6ad7d_row2_col7" class="data row2 col7" >13.5%</td>
#       <td id="T_6ad7d_row2_col8" class="data row2 col8" >22.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6ad7d_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_6ad7d_row3_col0" class="data row3 col0" >13.8%</td>
#       <td id="T_6ad7d_row3_col1" class="data row3 col1" >16.4%</td>
#       <td id="T_6ad7d
# <style type="text/css">
# #T_0f953 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_0f953 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_0f953_row1_col0 {
#   background-color: #970026;
#   color: #f1f1f1;
# }
# #T_0f953_row1_col1 {
#   background-color: #e61f1d;
#   color: #f1f1f1;
# }
# #T_0f953_row1_col2 {
#   background-color: #c70723;
#   color: #f1f1f1;
# }
# #T_0f953_row1_col3 {
#   background-color: #da141e;
#   color: #f1f1f1;
# }
# #T_0f953_row1_col4, #T_0f953_row1_col6 {
#   background-color: #ef3323;
#   color: #f1f1f1;
# }
# #T_0f953_row1_col5 {
#   background-color: #c90823;
#   color: #f1f1f1;
# }
# #T_0f953_row1_col7, #T_0f953_row5_col7, #T_0f953_row7_col7 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_0f953_row1_col8 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_0f953_row2_col0 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_0f953_row2_col1, #T_0f953_row4_col1, #T_0f953_row4_col3, #T_0f953_row8_col3 {
#   background-color: #ffec9d;
#   color: #000000;
# }
# #T_0f953_row2_col2, #T_0f953_row3_col5 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_0f953_row2_col3 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_0f953_row2_col4, #T_0f953_row9_col0 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_0f953_row2_col5, #T_0f953_row3_col7, #T_0f953_row6_col5, #T_0f953_row6_col6, #T_0f953_row6_col7, #T_0f953_row11_col5, #T_0f953_row11_col7, #T_0f953_row12_col0, #T_0f953_row12_col2, #T_0f953_row12_col3, #T_0f953_row12_col5, #T_0f953_row12_col6, #T_0f953_row12_col7 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_0f953_row2_col6, #T_0f953_row3_col6, #T_0f953_row10_col3 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_0f953_row2_col7, #T_0f953_row9_col7, #T_0f953_row9_col8, #T_0f953_row10_col7, #T_0f953_row14_col7 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_0f953_row2_col8, #T_0f953_row4_col6, #T_0f953_row10_col1 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_0f953_row3_col0, #T_0f953_row6_col0, #T_0f953_row8_col0, #T_0f953_row11_col0 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_0f953_row3_col1 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_0f953_row3_col2, #T_0f953_row3_col8 {
#   background-color: #ffeea3;
#   color: #000000;
# }
# #T_0f953_row3_col3 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_0f953_row3_col4 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_0f953_row4_col0 {
#   background-color: #ffe794;
#   color: #000000;
# }
# #T_0f953_row4_col2 {
#   background-color: #ffe895;
#   color: #000000;
# }
# #T_0f953_row4_col4, #T_0f953_row4_col7, #T_0f953_row4_col8, #T_0f953_row8_col7 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_0f953_row4_col5, #T_0f953_row5_col8, #T_0f953_row9_col5, #T_0f953_row13_col5 {
#   background-color: #ffea99;
#   color: #000000;
# }
# #T_0f953_row5_col0 {
#   background-color: #fee38b;
#   color: #000000;
# }
# #T_0f953_row5_col1, #T_0f953_row13_col2 {
#   background-color: #fed673;
#   color: #000000;
# }
# #T_0f953_row5_col2 {
#   background-color: #fedd7f;
#   color: #000000;
# }
# #T_0f953_row5_col3, #T_0f953_row7_col0 {
#   background-color: #fec35e;
#   color: #000000;
# }
# #T_0f953_row5_col4, #T_0f953_row7_col8 {
#   background-color: #fec965;
#   color: #000000;
# }
# #T_0f953_row5_col5, #T_0f953_row7_col5, #T_0f953_row8_col5 {
#   background-color: #feda78;
#   color: #000000;
# }
# #T_0f953_row5_col6, #T_0f953_row8_col6 {
#   background-color: #fed977;
#   color: #000000;
# }
# #T_0f953_row6_col1, #T_0f953_row6_col4, #T_0f953_row10_col8, #T_0f953_row11_col8 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_0f953_row6_col2, #T_0f953_row12_col1 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_0f953_row6_col3, #T_0f953_row11_col6 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_0f953_row6_col8, #T_0f953_row12_col4, #T_0f953_row12_col8 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_0f953_row7_col1 {
#   background-color: #feb953;
#   color: #000000;
# }
# #T_0f953_row7_col2, #T_0f953_row13_col8 {
#   background-color: #fec561;
#   color: #000000;
# }
# #T_0f953_row7_col3 {
#   background-color: #feb852;
#   color: #000000;
# }
# #T_0f953_row7_col4 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_0f953_row7_col6 {
#   background-color: #feab49;
#   color: #000000;
# }
# #T_0f953_row8_col1, #T_0f953_row8_col2 {
#   background-color: #ffeda1;
#   color: #000000;
# }
# #T_0f953_row8_col4, #T_0f953_row14_col4 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_0f953_row8_col8 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_0f953_row9_col1, #T_0f953_row11_col1 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_0f953_row9_col2, #T_0f953_row9_col3, #T_0f953_row11_col4 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_0f953_row9_col4 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_0f953_row9_col6, #T_0f953_row14_col8 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_0f953_row10_col0, #T_0f953_row11_col2 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_0f953_row10_col2 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_0f953_row10_col4, #T_0f953_row10_col5 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_0f953_row10_col6 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_0f953_row11_col3 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_0f953_row13_col0 {
#   background-color: #fed774;
#   color: #000000;
# }
# #T_0f953_row13_col1, #T_0f953_row13_col6 {
#   background-color: #fed470;
#   color: #000000;
# }
# #T_0f953_row13_col3 {
#   background-color: #fed16e;
#   color: #000000;
# }
# #T_0f953_row13_col4 {
#   background-color: #fecc68;
#   color: #000000;
# }
# #T_0f953_row13_col7 {
#   background-color: #fea145;
#   color: #000000;
# }
# #T_0f953_row14_col0 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_0f953_row14_col1 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_0f953_row14_col2 {
#   background-color: #fee085;
#   color: #000000;
# }
# #T_0f953_row14_col3 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_0f953_row14_col5 {
#   background-color: #fead4a;
#   color: #000000;
# }
# #T_0f953_row14_col6 {
#   background-color: #ffe997;
#   color: #000000;
# }
# </style>
# <table id="T_0f953">
#   <caption>Turn Bet Sizing vs Hand Type (Delayed)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f953_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_0f953_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_0f953_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_0f953_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_0f953_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_0f953_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_0f953_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_0f953_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_0f953_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f953_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_0f953_row0_col0" class="data row0 col0" >150</td>
#       <td id="T_0f953_row0_col1" class="data row0 col1" >474</td>
#       <td id="T_0f953_row0_col2" class="data row0 col2" >1034</td>
#       <td id="T_0f953_row0_col3" class="data row0 col3" >633</td>
#       <td id="T_0f953_row0_col4" class="data row0 col4" >406</td>
#       <td id="T_0f953_row0_col5" class="data row0 col5" >41</td>
#       <td id="T_0f953_row0_col6" class="data row0 col6" >105</td>
#       <td id="T_0f953_row0_col7" class="data row0 col7" >28</td>
#       <td id="T_0f953_row0_col8" class="data row0 col8" >366</td>
#     </tr>
#     <tr>
#       <th id="T_0f953_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_0f953_row1_col0" class="data row1 col0" >47.3%</td>
#       <td id="T_0f953_row1_col1" class="data row1 col1" >36.7%</td>
#       <td id="T_0f953_row1_col2" class="data row1 col2" >41.9%</td>
#       <td id="T_0f953_row1_col3" class="data row1 col3" >38.7%</td>
#       <td id="T_0f953_row1_col4" class="data
# <style type="text/css">
# #T_19be5 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_19be5 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_19be5_row1_col0 {
#   background-color: #970026;
#   color: #f1f1f1;
# }
# #T_19be5_row1_col1 {
#   background-color: #e61f1d;
#   color: #f1f1f1;
# }
# #T_19be5_row1_col2 {
#   background-color: #c70723;
#   color: #f1f1f1;
# }
# #T_19be5_row1_col3 {
#   background-color: #da141e;
#   color: #f1f1f1;
# }
# #T_19be5_row1_col4, #T_19be5_row1_col6 {
#   background-color: #ef3323;
#   color: #f1f1f1;
# }
# #T_19be5_row1_col5 {
#   background-color: #c90823;
#   color: #f1f1f1;
# }
# #T_19be5_row1_col7, #T_19be5_row3_col7, #T_19be5_row5_col7 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_19be5_row1_col8 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_19be5_row2_col0, #T_19be5_row3_col3, #T_19be5_row5_col0 {
#   background-color: #fec35e;
#   color: #000000;
# }
# #T_19be5_row2_col1 {
#   background-color: #feb651;
#   color: #000000;
# }
# #T_19be5_row2_col2 {
#   background-color: #feb24c;
#   color: #000000;
# }
# #T_19be5_row2_col3 {
#   background-color: #fed470;
#   color: #000000;
# }
# #T_19be5_row2_col4 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_19be5_row2_col5, #T_19be5_row3_col5, #T_19be5_row5_col5, #T_19be5_row6_col5 {
#   background-color: #feda78;
#   color: #000000;
# }
# #T_19be5_row2_col6, #T_19be5_row6_col3, #T_19be5_row7_col3 {
#   background-color: #ffec9d;
#   color: #000000;
# }
# #T_19be5_row2_col7, #T_19be5_row6_col4, #T_19be5_row7_col4 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_19be5_row2_col8 {
#   background-color: #fec45f;
#   color: #000000;
# }
# #T_19be5_row3_col0 {
#   background-color: #fee38b;
#   color: #000000;
# }
# #T_19be5_row3_col1 {
#   background-color: #fed673;
#   color: #000000;
# }
# #T_19be5_row3_col2 {
#   background-color: #fedd7f;
#   color: #000000;
# }
# #T_19be5_row3_col4, #T_19be5_row5_col8 {
#   background-color: #fec965;
#   color: #000000;
# }
# #T_19be5_row3_col6, #T_19be5_row6_col6 {
#   background-color: #fed977;
#   color: #000000;
# }
# #T_19be5_row3_col8 {
#   background-color: #ffea99;
#   color: #000000;
# }
# #T_19be5_row4_col0, #T_19be5_row6_col0 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_19be5_row4_col1, #T_19be5_row4_col4 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_19be5_row4_col2 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_19be5_row4_col3 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_19be5_row4_col5, #T_19be5_row4_col6, #T_19be5_row4_col7 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_19be5_row4_col8 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_19be5_row5_col1 {
#   background-color: #feb953;
#   color: #000000;
# }
# #T_19be5_row5_col2 {
#   background-color: #fec561;
#   color: #000000;
# }
# #T_19be5_row5_col3 {
#   background-color: #feb852;
#   color: #000000;
# }
# #T_19be5_row5_col4, #T_19be5_row7_col6 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_19be5_row5_col6 {
#   background-color: #feab49;
#   color: #000000;
# }
# #T_19be5_row6_col1, #T_19be5_row6_col2 {
#   background-color: #ffeda1;
#   color: #000000;
# }
# #T_19be5_row6_col7, #T_19be5_row7_col7 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_19be5_row6_col8 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_19be5_row7_col0, #T_19be5_row7_col2, #T_19be5_row7_col8 {
#   background-color: #ffeea3;
#   color: #000000;
# }
# #T_19be5_row7_col1 {
#   background-color: #ffe895;
#   color: #000000;
# }
# #T_19be5_row7_col5 {
#   background-color: #fee288;
#   color: #000000;
# }
# #T_19be5_row8_col0 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_19be5_row8_col1 {
#   background-color: #feaf4b;
#   color: #000000;
# }
# #T_19be5_row8_col2 {
#   background-color: #fd9f44;
#   color: #000000;
# }
# #T_19be5_row8_col3 {
#   background-color: #fd9941;
#   color: #000000;
# }
# #T_19be5_row8_col4 {
#   background-color: #fd9a42;
#   color: #000000;
# }
# #T_19be5_row8_col5 {
#   background-color: #fd903d;
#   color: #000000;
# }
# #T_19be5_row8_col6 {
#   background-color: #feb54f;
#   color: #000000;
# }
# #T_19be5_row8_col7 {
#   background-color: #fea145;
#   color: #000000;
# }
# #T_19be5_row8_col8 {
#   background-color: #fd933f;
#   color: #000000;
# }
# </style>
# <table id="T_19be5">
#   <caption>Turn Bet Sizing vs Hand Type (Delayed) — Grouped</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19be5_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_19be5_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_19be5_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_19be5_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_19be5_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_19be5_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_19be5_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_19be5_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_19be5_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19be5_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_19be5_row0_col0" class="data row0 col0" >150</td>
#       <td id="T_19be5_row0_col1" class="data row0 col1" >474</td>
#       <td id="T_19be5_row0_col2" class="data row0 col2" >1034</td>
#       <td id="T_19be5_row0_col3" class="data row0 col3" >633</td>
#       <td id="T_19be5_row0_col4" class="data row0 col4" >406</td>
#       <td id="T_19be5_row0_col5" class="data row0 col5" >41</td>
#       <td id="T_19be5_row0_col6" class="data row0 col6" >105</td>
#       <td id="T_19be5_row0_col7" class="data row0 col7" >28</td>
#       <td id="T_19be5_row0_col8" class="data row0 col8" >366</td>
#     </tr>
#     <tr>
#       <th id="T_19be5_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_19be5_row1_col0" class="data row1 col0" >47.3%</td>
#       <td id="T_19be5_row1_col1" class="data row1 col1" >36.7%</td>
#       <td id="T_19be5_row1_col2" class="data row1 col2" >41.9%</td>
#       <td id="T_19be5_row1_col3" class="data row1 col3" >38.7%</td>
#       <td id="T_19be5_row1_col4" class="data row1 col4" >34.2%</td>
#       <td id="T_19be5_row1_col5" class="data row1 col5" >41.5%</td>
#       <td id="T_19be5_row1_col6" class="data row1 col6" >34.3%</td>
#       <td id="T_19be5_row1_col7" class="data row1 col7" >25.0%</td>
#       <td id="T_19be5_row1_col8" class="data row1 col8" >49.7%</td>
#     </tr>
#     <tr>
#       <th id="T_19be5_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_19be5_row2_col0" class="data row2 col0" >16.0%</td>
#       <td id="T_19be5_row2_col1" class="data row2 col1" >17.9%</td>
#       <td id="T_19be5_row2_col2" class="data row2 col2" >18.8%</td>
#       <td id="T_19be5_row2_col3" class="data row2 col3" >13.3%</td>
#       <td id="T_19be5_row2_col4" class="data row2 col4" >13.8%</td>
#       <td id="T_19be5_row2_col5" class="data row2 col5" >12.2%</td>
#       <td id="T_19be5_row2_col6" class="data row2 col6" >6.7%</td>
#       <td id="T_19be5_row2_col7" class="data row2 col7" >10.7%</td>
#       <td id="T_19be5_row2_col8" class="data row2 col8" >15.8%</td>
#     </tr>
#     <tr>
#       <th id="T_19be5_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_19be5_row3_col0" class="data row3 col0" >9.3%</td>
#       <td id="T_19be5_row3_col1" class="data row3 col1" >12.9%</td>
#       <td id="T_19be5_row3_col2" class="data row3 col2" >11.2%</td>
#       <td id="T_19be5_row3_col3" class="data row3 col3" >16.1%</td>
#       <td id="T_19be5_row3_col4" class="data row3 col4" >15.0%</td>
#       <td id="T_19be5_row3_col5" class="data row3 col5" >12.2%</td>
#       <td id="T_19be5_row3_col6" class="data row3 col6" >12.4%</td>
#       <td id="T_19be5_row3_col7" class="data row3 col7" >25.0%</td>
#       <td id="T_19be5_row3_col8" class="data row3 col8" >7.4%</td>
#     </tr>
#     <tr>
#       <th id="T_19be5_level0_row4" class="row_heading level0 row4" >Overpair</th>
#       <td id="T_19be5_row4_col0" class="data row4 col0" >2.7%</td>
#       <td id="T_19be5_row4_

# %%
summary_df = summarize_responses(responses_df, 'Call')
if summary_df is not None:
    styled = (
        summary_df.style
        .format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
        .format('{:.1f}%', subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .background_gradient(cmap='PuBu', axis=None, subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .set_caption('Call vs Turn Bets (Responder Holdings)')
    )
    display(styled)
grouped_call = summarize_responses_grouped(responses_df, 'Call')
if grouped_call is not None:
    display(_style_response_table_grouped(grouped_call, 'Call vs Turn Bets (Responder Holdings) — Grouped'))
summary_df = summarize_responses(responses_df, 'Raise')
if summary_df is not None:
    styled = (
        summary_df.style
        .format('{:.0f}', subset=pd.IndexSlice[['Events'], :])
        .format('{:.1f}%', subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .background_gradient(cmap='PuBu', axis=None, subset=pd.IndexSlice[summary_df.index.difference(['Events']), :])
        .set_caption('Raise vs Turn Bets (Responder Holdings)')
    )
    display(styled)
grouped_raise = summarize_responses_grouped(responses_df, 'Raise')
if grouped_raise is not None:
    display(_style_response_table_grouped(grouped_raise, 'Raise vs Turn Bets (Responder Holdings) — Grouped'))
# Out:
# <style type="text/css">
# #T_25be7_row1_col0 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_25be7_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_25be7_row2_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_25be7_row2_col1, #T_25be7_row3_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_25be7_row3_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_25be7_row4_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_25be7_row4_col1 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_25be7_row5_col0 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_25be7_row5_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_25be7_row6_col0, #T_25be7_row9_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_25be7_row6_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_25be7_row7_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_25be7_row7_col1, #T_25be7_row14_col0 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_25be7_row8_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_25be7_row8_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_25be7_row9_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_25be7_row10_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_25be7_row10_col1, #T_25be7_row11_col0, #T_25be7_row11_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_25be7_row12_col0, #T_25be7_row12_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_25be7_row13_col0 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_25be7_row13_col1 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_25be7_row14_col1 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# </style>
# <table id="T_25be7">
#   <caption>Call vs Turn Bets (Responder Holdings)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25be7_level0_col0" class="col_heading level0 col0" >Barrel</th>
#       <th id="T_25be7_level0_col1" class="col_heading level0 col1" >Delayed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25be7_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_25be7_row0_col0" class="data row0 col0" >1600</td>
#       <td id="T_25be7_row0_col1" class="data row0 col1" >1434</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_25be7_row1_col0" class="data row1 col0" >34.0%</td>
#       <td id="T_25be7_row1_col1" class="data row1 col1" >48.7%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row2" class="row_heading level0 row2" >Underpair</th>
#       <td id="T_25be7_row2_col0" class="data row2 col0" >5.1%</td>
#       <td id="T_25be7_row2_col1" class="data row2 col1" >5.9%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row3" class="row_heading level0 row3" >Bottom Pair</th>
#       <td id="T_25be7_row3_col0" class="data row3 col0" >5.6%</td>
#       <td id="T_25be7_row3_col1" class="data row3 col1" >5.9%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row4" class="row_heading level0 row4" >Middle Pair</th>
#       <td id="T_25be7_row4_col0" class="data row4 col0" >9.9%</td>
#       <td id="T_25be7_row4_col1" class="data row4 col1" >9.0%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row5" class="row_heading level0 row5" >Top Pair</th>
#       <td id="T_25be7_row5_col0" class="data row5 col0" >17.2%</td>
#       <td id="T_25be7_row5_col1" class="data row5 col1" >8.9%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row6" class="row_heading level0 row6" >Overpair</th>
#       <td id="T_25be7_row6_col0" class="data row6 col0" >1.3%</td>
#       <td id="T_25be7_row6_col1" class="data row6 col1" >0.7%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row7" class="row_heading level0 row7" >Two Pair</th>
#       <td id="T_25be7_row7_col0" class="data row7 col0" >16.3%</td>
#       <td id="T_25be7_row7_col1" class="data row7 col1" >13.0%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row8" class="row_heading level0 row8" >Trips/Set</th>
#       <td id="T_25be7_row8_col0" class="data row8 col0" >4.6%</td>
#       <td id="T_25be7_row8_col1" class="data row8 col1" >4.1%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row9" class="row_heading level0 row9" >Straight</th>
#       <td id="T_25be7_row9_col0" class="data row9 col0" >1.9%</td>
#       <td id="T_25be7_row9_col1" class="data row9 col1" >1.4%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row10" class="row_heading level0 row10" >Flush</th>
#       <td id="T_25be7_row10_col0" class="data row10 col0" >2.4%</td>
#       <td id="T_25be7_row10_col1" class="data row10 col1" >1.1%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row11" class="row_heading level0 row11" >Full House</th>
#       <td id="T_25be7_row11_col0" class="data row11 col0" >1.2%</td>
#       <td id="T_25be7_row11_col1" class="data row11 col1" >1.1%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row12" class="row_heading level0 row12" >Quads</th>
#       <td id="T_25be7_row12_col0" class="data row12 col0" >0.2%</td>
#       <td id="T_25be7_row12_col1" class="data row12 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row13" class="row_heading level0 row13" >Flush Draw</th>
#       <td id="T_25be7_row13_col0" class="data row13 col0" >22.6%</td>
#       <td id="T_25be7_row13_col1" class="data row13 col1" >16.1%</td>
#     </tr>
#     <tr>
#       <th id="T_25be7_level0_row14" class="row_heading level0 row14" >OESD/DG</th>
#       <td id="T_25be7_row14_col0" class="data row14 col0" >13.1%</td>
#       <td id="T_25be7_row14_col1" class="data row14 col1" >16.6%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d3020_row1_col0 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_d3020_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d3020_row2_col0 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_d3020_row2_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_d3020_row3_col0 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_d3020_row3_col1 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_d3020_row4_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d3020_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d3020_row5_col0 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_d3020_row5_col1 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_d3020_row6_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_d3020_row6_col1 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_d3020_row7_col0 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_d3020_row7_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_d3020_row8_col0 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_d3020_row8_col1 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d3020">
#   <caption>Call vs Turn Bets (Responder Holdings) — Grouped</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3020_level0_col0" class="col_heading level0 col0" >Barrel</th>
#       <th id="T_d3020_level0_col1" class="col_heading level0 col1" >Delayed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3020_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_d3020_row0_col0" class="data row0 col0" >1600</td>
#       <td id="T_d3020_row0_col1" class="data row0 col1" >1434</td>
#     </tr>
#     <tr>
#       <th id="T_d3020_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_d3020_row1_col0" class="data row1 col0" >34.0%</td>
#       <td id="T_d3020_row1_col1" class="data row1 col1" >48.7%</td>
#     </tr>
#     <tr>
#       <th id="T_d3020_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_d3020_row2_col0" class="data row2 col0" >20.6%</td>
#       <td id="T_d3020_row2_col1" class="data row2 col1" >20.9%</td>
#     </tr>
#     <tr>
#       <th id="T_d3020_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_d3020_row3_col0" class="data row3 col0" >17.2%</td>
#       <td id="T_d3020_row3_col1" class="data row3 col1" >8.9%</td>
#     </tr>
#     <tr>
#       <th id="T_d3020_level0_row4" class="row_heading level0 row4" >Overpair</th>
#       <td id="T_d3020_row4_col0" class="data row4 col0" >1.3%</td>
#       <td id="T_d3020_row4_col1" class="data row4 col1" >0.7%</td>
#     </tr>
#     <tr>
#       <th id="T_d3020_level0_row5" class="row_heading level0 row5" >Two Pair</th>
#       <td id="T_d3020_row5_col0" class="data row5 col0" >16.3%</td>
#       <td id="T_d3020_row5_col1" class="data row5 col1" >13.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d3020_level0_row6" class="row_heading level0 row6" >Trips/Set</th>
#       <td id="T_d3020_row6_col0" class="data row6 col0" >4.6%</td>
#       <td id="T_d3020_row6_col1" class="data row6 col1" >4.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d3020_level0_row7" class="row_heading level0 row7" >Monster</th>
#       <td id="T_d3020_row7_col0" class="data row7 col0" >5.9%</td>
#       <td id="T_d3020_row7_col1" class="data row7 col1" >3.8%</td>
#     </tr>
#     <tr>
#       <th id="T_d3020_level0_row8" class="row_heading level0 row8" >Draw</th>
#       <td id="T_d3020_row8_col0" class="data row8 col0" >33.5%</td>
#       <td id="T_d3020_row8_col1" class="data row8 col1" >30.7%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_14feb_row1_col0 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_14feb_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_14feb_row2_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_14feb_row2_col1, #T_14feb_row3_col1, #T_14feb_row6_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_14feb_row3_col0, #T_14feb_row6_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_14feb_row4_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_14feb_row4_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_14feb_row5_col0 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_14feb_row5_col1 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_14feb_row7_col0 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_14feb_row7_col1, #T_14feb_row8_col1, #T_14feb_row13_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_14feb_row8_col0 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_14feb_row9_col0 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_14feb_row9_col1 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_14feb_row10_col0 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_14feb_row10_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_14feb_row11_col0 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_14feb_row11_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_14feb_row12_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_14feb_row12_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_14feb_row13_col0 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_14feb_row14_col0 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_14feb_row14_col1 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# </style>
# <table id="T_14feb">
#   <caption>Raise vs Turn Bets (Responder Holdings)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14feb_level0_col0" class="col_heading level0 col0" >Barrel</th>
#       <th id="T_14feb_level0_col1" class="col_heading level0 col1" >Delayed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14feb_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_14feb_row0_col0" class="data row0 col0" >515</td>
#       <td id="T_14feb_row0_col1" class="data row0 col1" >236</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_14feb_row1_col0" class="data row1 col0" >21.9%</td>
#       <td id="T_14feb_row1_col1" class="data row1 col1" >27.5%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row2" class="row_heading level0 row2" >Underpair</th>
#       <td id="T_14feb_row2_col0" class="data row2 col0" >2.5%</td>
#       <td id="T_14feb_row2_col1" class="data row2 col1" >1.3%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row3" class="row_heading level0 row3" >Bottom Pair</th>
#       <td id="T_14feb_row3_col0" class="data row3 col0" >3.7%</td>
#       <td id="T_14feb_row3_col1" class="data row3 col1" >1.3%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row4" class="row_heading level0 row4" >Middle Pair</th>
#       <td id="T_14feb_row4_col0" class="data row4 col0" >4.1%</td>
#       <td id="T_14feb_row4_col1" class="data row4 col1" >6.8%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row5" class="row_heading level0 row5" >Top Pair</th>
#       <td id="T_14feb_row5_col0" class="data row5 col0" >11.7%</td>
#       <td id="T_14feb_row5_col1" class="data row5 col1" >15.7%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row6" class="row_heading level0 row6" >Overpair</th>
#       <td id="T_14feb_row6_col0" class="data row6 col0" >3.7%</td>
#       <td id="T_14feb_row6_col1" class="data row6 col1" >1.3%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row7" class="row_heading level0 row7" >Two Pair</th>
#       <td id="T_14feb_row7_col0" class="data row7 col0" >22.3%</td>
#       <td id="T_14feb_row7_col1" class="data row7 col1" >14.0%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row8" class="row_heading level0 row8" >Trips/Set</th>
#       <td id="T_14feb_row8_col0" class="data row8 col0" >12.0%</td>
#       <td id="T_14feb_row8_col1" class="data row8 col1" >14.0%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row9" class="row_heading level0 row9" >Straight</th>
#       <td id="T_14feb_row9_col0" class="data row9 col0" >9.9%</td>
#       <td id="T_14feb_row9_col1" class="data row9 col1" >11.0%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row10" class="row_heading level0 row10" >Flush</th>
#       <td id="T_14feb_row10_col0" class="data row10 col0" >5.6%</td>
#       <td id="T_14feb_row10_col1" class="data row10 col1" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row11" class="row_heading level0 row11" >Full House</th>
#       <td id="T_14feb_row11_col0" class="data row11 col0" >2.1%</td>
#       <td id="T_14feb_row11_col1" class="data row11 col1" >3.8%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row12" class="row_heading level0 row12" >Quads</th>
#       <td id="T_14feb_row12_col0" class="data row12 col0" >0.4%</td>
#       <td id="T_14feb_row12_col1" class="data row12 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row13" class="row_heading level0 row13" >Flush Draw</th>
#       <td id="T_14feb_row13_col0" class="data row13 col0" >14.6%</td>
#       <td id="T_14feb_row13_col1" class="data row13 col1" >14.0%</td>
#     </tr>
#     <tr>
#       <th id="T_14feb_level0_row14" class="row_heading level0 row14" >OESD/DG</th>
#       <td id="T_14feb_row14_col0" class="data row14 col0" >10.1%</td>
#       <td id="T_14feb_row14_col1" class="data row14 col1" >6.4%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_75fc3_row1_col0 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_75fc3_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_75fc3_row2_col0 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_75fc3_row2_col1 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_75fc3_row3_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_75fc3_row3_col1 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_75fc3_row4_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_75fc3_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_75fc3_row5_col0 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_75fc3_row5_col1, #T_75fc3_row6_col1 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_75fc3_row6_col0 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_75fc3_row7_col0 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_75fc3_row7_col1 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_75fc3_row8_col0 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_75fc3_row8_col1 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_75fc3">
#   <caption>Raise vs Turn Bets (Responder Holdings) — Grouped</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75fc3_level0_col0" class="col_heading level0 col0" >Barrel</th>
#       <th id="T_75fc3_level0_col1" class="col_heading level0 col1" >Delayed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75fc3_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_75fc3_row0_col0" class="data row0 col0" >515</td>
#       <td id="T_75fc3_row0_col1" class="data row0 col1" >236</td>
#     </tr>
#     <tr>
#       <th id="T_75fc3_level0_row1" class="row_heading level0 row1" >Air</th>
#       <td id="T_75fc3_row1_col0" class="data row1 col0" >21.9%</td>
#       <td id="T_75fc3_row1_col1" class="data row1 col1" >27.5%</td>
#     </tr>
#     <tr>
#       <th id="T_75fc3_level0_row2" class="row_heading level0 row2" >Weak Pair</th>
#       <td id="T_75fc3_row2_col0" class="data row2 col0" >10.3%</td>
#       <td id="T_75fc3_row2_col1" class="data row2 col1" >9.3%</td>
#     </tr>
#     <tr>
#       <th id="T_75fc3_level0_row3" class="row_heading level0 row3" >Top Pair</th>
#       <td id="T_75fc3_row3_col0" class="data row3 col0" >11.7%</td>
#       <td id="T_75fc3_row3_col1" class="data row3 col1" >15.7%</td>
#     </tr>
#     <tr>
#       <th id="T_75fc3_level0_row4" class="row_heading level0 row4" >Overpair</th>
#       <td id="T_75fc3_row4_col0" class="data row4 col0" >3.7%</td>
#       <td id="T_75fc3_row4_col1" class="data row4 col1" >1.3%</td>
#     </tr>
#     <tr>
#       <th id="T_75fc3_level0_row5" class="row_heading level0 row5" >Two Pair</th>
#       <td id="T_75fc3_row5_col0" class="data row5 col0" >22.3%</td>
#       <td id="T_75fc3_row5_col1" class="data row5 col1" >14.0%</td>
#     </tr>
#     <tr>
#       <th id="T_75fc3_level0_row6" class="row_heading level0 row6" >Trips/Set</th>
#       <td id="T_75fc3_row6_col0" class="data row6 col0" >12.0%</td>
#       <td id="T_75fc3_row6_col1" class="data row6 col1" >14.0%</td>
#     </tr>
#     <tr>
#       <th id="T_75fc3_level0_row7" class="row_heading level0 row7" >Monster</th>
#       <td id="T_75fc3_row7_col0" class="data row7 col0" >18.1%</td>
#       <td id="T_75fc3_row7_col1" class="data row7 col1" >18.2%</td>
#     </tr>
#     <tr>
#       <th id="T_75fc3_level0_row8" class="row_heading level0 row8" >Draw</th>
#       <td id="T_75fc3_row8_col0" class="data row8 col0" >22.9%</td>
#       <td id="T_75fc3_row8_col1" class="data row8 col1" >19.1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
if not responses_df.empty:
    display_line_response_tables('Barrel', 'Responses vs Turn Barrel')
    display_line_response_tables('Delayed', 'Responses vs Turn Delayed C-Bet')
else:
    print('No turn responses available for line breakdown.')
# Out:
# <style type="text/css">
# #T_36dd5 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_36dd5 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_36dd5_row1_col0, #T_36dd5_row3_col6 {
#   background-color: #fbfdfe;
#   color: #000000;
# }
# #T_36dd5_row1_col1 {
#   background-color: #daebf5;
#   color: #000000;
# }
# #T_36dd5_row1_col2 {
#   background-color: #d5e8f3;
#   color: #000000;
# }
# #T_36dd5_row1_col3 {
#   background-color: #bddbed;
#   color: #000000;
# }
# #T_36dd5_row1_col4 {
#   background-color: #b7d8eb;
#   color: #000000;
# }
# #T_36dd5_row1_col5 {
#   background-color: #a0cbe5;
#   color: #000000;
# }
# #T_36dd5_row1_col6 {
#   background-color: #8cc0df;
#   color: #000000;
# }
# #T_36dd5_row1_col7 {
#   background-color: #b5d7eb;
#   color: #000000;
# }
# #T_36dd5_row1_col8, #T_36dd5_row3_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_36dd5_row2_col0 {
#   background-color: #9ecae4;
#   color: #000000;
# }
# #T_36dd5_row2_col1 {
#   background-color: #afd3e9;
#   color: #000000;
# }
# #T_36dd5_row2_col2 {
#   background-color: #acd2e8;
#   color: #000000;
# }
# #T_36dd5_row2_col3 {
#   background-color: #c6e0ef;
#   color: #000000;
# }
# #T_36dd5_row2_col4 {
#   background-color: #cfe5f2;
#   color: #000000;
# }
# #T_36dd5_row2_col5 {
#   background-color: #e0eef6;
#   color: #000000;
# }
# #T_36dd5_row2_col6, #T_36dd5_row3_col7 {
#   background-color: #f8fbfd;
#   color: #000000;
# }
# #T_36dd5_row2_col7 {
#   background-color: #d2e6f2;
#   color: #000000;
# }
# #T_36dd5_row2_col8 {
#   background-color: #9fcae4;
#   color: #000000;
# }
# #T_36dd5_row3_col0 {
#   background-color: #e6f1f8;
#   color: #000000;
# }
# #T_36dd5_row3_col1 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# #T_36dd5_row3_col2 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_36dd5_row3_col3 {
#   background-color: #fcfdfe;
#   color: #000000;
# }
# #T_36dd5_row3_col4 {
#   background-color: #f9fcfd;
#   color: #000000;
# }
# #T_36dd5_row3_col8 {
#   background-color: #e1eff7;
#   color: #000000;
# }
# #T_36dd5_row4_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_36dd5_row4_col1 {
#   background-color: #90c2e0;
#   color: #000000;
# }
# #T_36dd5_row4_col2 {
#   background-color: #95c5e2;
#   color: #000000;
# }
# #T_36dd5_row4_col3 {
#   background-color: #add2e8;
#   color: #000000;
# }
# #T_36dd5_row4_col4 {
#   background-color: #b3d5ea;
#   color: #000000;
# }
# #T_36dd5_row4_col5 {
#   background-color: #cae2f0;
#   color: #000000;
# }
# #T_36dd5_row4_col6 {
#   background-color: #deedf6;
#   color: #000000;
# }
# #T_36dd5_row4_col7 {
#   background-color: #b5d6ea;
#   color: #000000;
# }
# #T_36dd5_row4_col8 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_36dd5">
#   <caption>Responses vs Turn Barrel (Overall)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_36dd5_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_36dd5_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_36dd5_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_36dd5_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_36dd5_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_36dd5_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_36dd5_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_36dd5_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_36dd5_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36dd5_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_36dd5_row0_col0" class="data row0 col0" >429</td>
#       <td id="T_36dd5_row0_col1" class="data row0 col1" >434</td>
#       <td id="T_36dd5_row0_col2" class="data row0 col2" >908</td>
#       <td id="T_36dd5_row0_col3" class="data row0 col3" >984</td>
#       <td id="T_36dd5_row0_col4" class="data row0 col4" >432</td>
#       <td id="T_36dd5_row0_col5" class="data row0 col5" >69</td>
#       <td id="T_36dd5_row0_col6" class="data row0 col6" >192</td>
#       <td id="T_36dd5_row0_col7" class="data row0 col7" >245</td>
#       <td id="T_36dd5_row0_col8" class="data row0 col8" >237</td>
#     </tr>
#     <tr>
#       <th id="T_36dd5_level0_row1" class="row_heading level0 row1" >Fold</th>
#       <td id="T_36dd5_row1_col0" class="data row1 col0" >13.8%</td>
#       <td id="T_36dd5_row1_col1" class="data row1 col1" >30.6%</td>
#       <td id="T_36dd5_row1_col2" class="data row1 col2" >33.1%</td>
#       <td id="T_36dd5_row1_col3" class="data row1 col3" >45.7%</td>
#       <td id="T_36dd5_row1_col4" class="data row1 col4" >48.8%</td>
#       <td id="T_36dd5_row1_col5" class="data row1 col5" >60.9%</td>
#       <td id="T_36dd5_row1_col6" class="data row1 col6" >71.4%</td>
#       <td id="T_36dd5_row1_col7" class="data row1 col7" >49.8%</td>
#       <td id="T_36dd5_row1_col8" class="data row1 col8" >11.4%</td>
#     </tr>
#     <tr>
#       <th id="T_36dd5_level0_row2" class="row_heading level0 row2" >Call</th>
#       <td id="T_36dd5_row2_col0" class="data row2 col0" >61.8%</td>
#       <td id="T_36dd5_row2_col1" class="data row2 col1" >52.8%</td>
#       <td id="T_36dd5_row2_col2" class="data row2 col2" >54.7%</td>
#       <td id="T_36dd5_row2_col3" class="data row2 col3" >41.0%</td>
#       <td id="T_36dd5_row2_col4" class="data row2 col4" >36.6%</td>
#       <td id="T_36dd5_row2_col5" class="data row2 col5" >27.5%</td>
#       <td id="T_36dd5_row2_col6" class="data row2 col6" >15.1%</td>
#       <td id="T_36dd5_row2_col7" class="data row2 col7" >35.1%</td>
#       <td id="T_36dd5_row2_col8" class="data row2 col8" >61.6%</td>
#     </tr>
#     <tr>
#       <th id="T_36dd5_level0_row3" class="row_heading level0 row3" >Raise</th>
#       <td id="T_36dd5_row3_col0" class="data row3 col0" >24.5%</td>
#       <td id="T_36dd5_row3_col1" class="data row3 col1" >16.6%</td>
#       <td id="T_36dd5_row3_col2" class="data row3 col2" >12.1%</td>
#       <td id="T_36dd5_row3_col3" class="data row3 col3" >13.3%</td>
#       <td id="T_36dd5_row3_col4" class="data row3 col4" >14.6%</td>
#       <td id="T_36dd5_row3_col5" class="data row3 col5" >11.6%</td>
#       <td id="T_36dd5_row3_col6" class="data row3 col6" >13.5%</td>
#       <td id="T_36dd5_row3_col7" class="data row3 col7" >15.1%</td>
#       <td id="T_36dd5_row3_col8" class="data row3 col8" >27.0%</td>
#     </tr>
#     <tr>
#       <th id="T_36dd5_level0_row4" class="row_heading level0 row4" >Continue</th>
#       <td id="T_36dd5_row4_col0" class="data row4 col0" >86.2%</td>
#       <td id="T_36dd5_row4_col1" class="data row4 col1" >69.4%</td>
#       <td id="T_36dd5_row4_col2" class="data row4 col2" >66.9%</td>
#       <td id="T_36dd5_row4_col3" class="data row4 col3" >54.3%</td>
#       <td id="T_36dd5_row4_col4" class="data row4 col4" >51.2%</td>
#       <td id="T_36dd5_row4_col5" class="data row4 col5" >39.1%</td>
#       <td id="T_36dd5_row4_col6" class="data row4 col6" >28.6%</td>
#       <td id="T_36dd5_row4_col7" class="data row4 col7" >50.2%</td>
#       <td id="T_36dd5_row4_col8" class="data row4 col8" >88.6%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9a10e th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_9a10e td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_9a10e_row1_col0 {
#   background-color: #e6f1f8;
#   color: #000000;
# }
# #T_9a10e_row1_col1 {
#   background-color: #c4dfef;
#   color: #000000;
# }
# #T_9a10e_row1_col2 {
#   background-color: #c0ddee;
#   color: #000000;
# }
# #T_9a10e_row1_col3 {
#   background-color: #aed3e8;
#   color: #000000;
# }
# #T_9a10e_row1_col4 {
#   background-color: #9ecae4;
#   color: #000000;
# }
# #T_9a10e_row1_col5 {
#   background-color: #96c6e2;
#   color: #000000;
# }
# #T_9a10e_row1_col6 {
#   background-color: #7fb9db;
#   color: #000000;
# }
# #T_9a10e_row1_col7 {
#   background-color: #a1cce5;
#   color: #000000;
# }
# #T_9a10e_row1_col8 {
#   background-color: #eef6fa;
#   color: #000000;
# }
# #T_9a10e_row2_col0, #T_9a10e_row4_col1 {
#   background-color: #94c5e1;
#   color: #000000;
# }
# #T_9a10e_row2_col1 {
#   background-color: #b2d5ea;
#   color: #000000;
# }
# #T_9a10e_row2_col2 {
#   background-color: #aad0e7;
#   color: #000000;
# }
# #T_9a10e_row2_col3, #T_9a10e_row4_col5 {
#   background-color: #c3deee;
#   color: #000000;
# }
# #T_9a10e_row2_col4 {
#   background-color: #cde4f1;
#   color: #000000;
# }
# #T_9a10e_row2_col5, #T_9a10e_row2_col7 {
#   background-color: #cee4f1;
#   color: #000000;
# }
# #T_9a10e_row2_col6, #T_9a10e_row3_col1 {
#   background-color: #edf5fa;
#   color: #000000;
# }
# #T_9a10e_row2_col8 {
#   background-color: #89bfde;
#   color: #000000;
# }
# #T_9a10e_row3_col0 {
#   background-color: #e9f3f9;
#   color: #000000;
# }
# #T_9a10e_row3_col2 {
#   background-color: #f9fcfd;
#   color: #000000;
# }
# #T_9a10e_row3_col3 {
#   background-color: #f2f8fb;
#   color: #000000;
# }
# #T_9a10e_row3_col4 {
#   background-color: #f8fbfd;
#   color: #000000;
# }
# #T_9a10e_row3_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_9a10e_row3_col6 {
#   background-color: #f7fbfd;
#   color: #000000;
# }
# #T_9a10e_row3_col7 {
#   background-color: #f5f9fc;
#   color: #000000;
# }
# #T_9a10e_row3_col8 {
#   background-color: #ecf5fa;
#   color: #000000;
# }
# #T_9a10e_row4_col0 {
#   background-color: #73b2d8;
#   color: #f1f1f1;
# }
# #T_9a10e_row4_col2 {
#   background-color: #98c7e3;
#   color: #000000;
# }
# #T_9a10e_row4_col3 {
#   background-color: #abd1e8;
#   color: #000000;
# }
# #T_9a10e_row4_col4 {
#   background-color: #bbdaec;
#   color: #000000;
# }
# #T_9a10e_row4_col6 {
#   background-color: #daebf5;
#   color: #000000;
# }
# #T_9a10e_row4_col7 {
#   background-color: #b8d8eb;
#   color: #000000;
# }
# #T_9a10e_row4_col8 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9a10e">
#   <caption>Responses vs Turn Barrel (In Position)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_9a10e_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_9a10e_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_9a10e_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_9a10e_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_9a10e_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_9a10e_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_9a10e_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_9a10e_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_9a10e_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a10e_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_9a10e_row0_col0" class="data row0 col0" >170</td>
#       <td id="T_9a10e_row0_col1" class="data row0 col1" >217</td>
#       <td id="T_9a10e_row0_col2" class="data row0 col2" >462</td>
#       <td id="T_9a10e_row0_col3" class="data row0 col3" >584</td>
#       <td id="T_9a10e_row0_col4" class="data row0 col4" >234</td>
#       <td id="T_9a10e_row0_col5" class="data row0 col5" >34</td>
#       <td id="T_9a10e_row0_col6" class="data row0 col6" >116</td>
#       <td id="T_9a10e_row0_col7" class="data row0 col7" >130</td>
#       <td id="T_9a10e_row0_col8" class="data row0 col8" >86</td>
#     </tr>
#     <tr>
#       <th id="T_9a10e_level0_row1" class="row_heading level0 row1" >Fold</th>
#       <td id="T_9a10e_row1_col0" class="data row1 col0" >19.4%</td>
#       <td id="T_9a10e_row1_col1" class="data row1 col1" >37.3%</td>
#       <td id="T_9a10e_row1_col2" class="data row1 col2" >39.4%</td>
#       <td id="T_9a10e_row1_col3" class="data row1 col3" >49.3%</td>
#       <td id="T_9a10e_row1_col4" class="data row1 col4" >57.7%</td>
#       <td id="T_9a10e_row1_col5" class="data row1 col5" >61.8%</td>
#       <td id="T_9a10e_row1_col6" class="data row1 col6" >74.1%</td>
#       <td id="T_9a10e_row1_col7" class="data row1 col7" >56.2%</td>
#       <td id="T_9a10e_row1_col8" class="data row1 col8" >15.1%</td>
#     </tr>
#     <tr>
#       <th id="T_9a10e_level0_row2" class="row_heading level0 row2" >Call</th>
#       <td id="T_9a10e_row2_col0" class="data row2 col0" >62.9%</td>
#       <td id="T_9a10e_row2_col1" class="data row2 col1" >47.0%</td>
#       <td id="T_9a10e_row2_col2" class="data row2 col2" >51.3%</td>
#       <td id="T_9a10e_row2_col3" class="data row2 col3" >37.7%</td>
#       <td id="T_9a10e_row2_col4" class="data row2 col4" >32.5%</td>
#       <td id="T_9a10e_row2_col5" class="data row2 col5" >32.4%</td>
#       <td id="T_9a10e_row2_col6" class="data row2 col6" >15.5%</td>
#       <td id="T_9a10e_row2_col7" class="data row2 col7" >32.3%</td>
#       <td id="T_9a10e_row2_col8" class="data row2 col8" >68.6%</td>
#     </tr>
#     <tr>
#       <th id="T_9a10e_level0_row3" class="row_heading level0 row3" >Raise</th>
#       <td id="T_9a10e_row3_col0" class="data row3 col0" >17.6%</td>
#       <td id="T_9a10e_row3_col1" class="data row3 col1" >15.7%</td>
#       <td id="T_9a10e_row3_col2" class="data row3 col2" >9.3%</td>
#       <td id="T_9a10e_row3_col3" class="data row3 col3" >13.0%</td>
#       <td id="T_9a10e_row3_col4" class="data row3 col4" >9.8%</td>
#       <td id="T_9a10e_row3_col5" class="data row3 col5" >5.9%</td>
#       <td id="T_9a10e_row3_col6" class="data row3 col6" >10.3%</td>
#       <td id="T_9a10e_row3_col7" class="data row3 col7" >11.5%</td>
#       <td id="T_9a10e_row3_col8" class="data row3 col8" >16.3%</td>
#     </tr>
#     <tr>
#       <th id="T_9a10e_level0_row4" class="row_heading level0 row4" >Continue</th>
#       <td id="T_9a10e_row4_col0" class="data row4 col0" >80.6%</td>
#       <td id="T_9a10e_row4_col1" class="data row4 col1" >62.7%</td>
#       <td id="T_9a10e_row4_col2" class="data row4 col2" >60.6%</td>
#       <td id="T_9a10e_row4_col3" class="data row4 col3" >50.7%</td>
#       <td id="T_9a10e_row4_col4" class="data row4 col4" >42.3%</td>
#       <td id="T_9a10e_row4_col5" class="data row4 col5" >38.2%</td>
#       <td id="T_9a10e_row4_col6" class="data row4 col6" >25.9%</td>
#       <td id="T_9a10e_row4_col7" class="data row4 col7" >43.8%</td>
#       <td id="T_9a10e_row4_col8" class="data row4 col8" >84.9%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cbc5a th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_cbc5a td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_cbc5a_row1_col0 {
#   background-color: #fefeff;
#   color: #000000;
# }
# #T_cbc5a_row1_col1 {
#   background-color: #e4f0f8;
#   color: #000000;
# }
# #T_cbc5a_row1_col2 {
#   background-color: #e0eef6;
#   color: #000000;
# }
# #T_cbc5a_row1_col3 {
#   background-color: #c6e0ef;
#   color: #000000;
# }
# #T_cbc5a_row1_col4, #T_cbc5a_row2_col7 {
#   background-color: #cae2f0;
#   color: #000000;
# }
# #T_cbc5a_row1_col5 {
#   background-color: #a3cce5;
#   color: #000000;
# }
# #T_cbc5a_row1_col6 {
#   background-color: #96c6e2;
#   color: #000000;
# }
# #T_cbc5a_row1_col7 {
#   background-color: #c3deee;
#   color: #000000;
# }
# #T_cbc5a_row1_col8 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_cbc5a_row2_col0 {
#   background-color: #a1cce5;
#   color: #000000;
# }
# #T_cbc5a_row2_col1, #T_cbc5a_row2_col2 {
#   background-color: #a6cee6;
#   color: #000000;
# }
# #T_cbc5a_row2_col3 {
#   background-color: #bddbed;
#   color: #000000;
# }
# #T_cbc5a_row2_col4 {
#   background-color: #c4dfef;
#   color: #000000;
# }
# #T_cbc5a_row2_col5 {
#   background-color: #e7f2f8;
#   color: #000000;
# }
# #T_cbc5a_row2_col6 {
#   background-color: #f6fafc;
#   color: #000000;
# }
# #T_cbc5a_row2_col8, #T_cbc5a_row4_col7 {
#   background-color: #a7cfe7;
#   color: #000000;
# }
# #T_cbc5a_row3_col0 {
#   background-color: #dcecf5;
#   color: #000000;
# }
# #T_cbc5a_row3_col1 {
#   background-color: #f0f7fb;
#   color: #000000;
# }
# #T_cbc5a_row3_col2 {
#   background-color: #f5f9fc;
#   color: #000000;
# }
# #T_cbc5a_row3_col3 {
#   background-color: #f7fbfd;
#   color: #000000;
# }
# #T_cbc5a_row3_col4 {
#   background-color: #ebf4fa;
#   color: #000000;
# }
# #T_cbc5a_row3_col5 {
#   background-color: #f1f7fb;
#   color: #000000;
# }
# #T_cbc5a_row3_col6 {
#   background-color: #eff6fa;
#   color: #000000;
# }
# #T_cbc5a_row3_col7 {
#   background-color: #eef5fa;
#   color: #000000;
# }
# #T_cbc5a_row3_col8, #T_cbc5a_row4_col6 {
#   background-color: #d4e7f3;
#   color: #000000;
# }
# #T_cbc5a_row4_col0 {
#   background-color: #6cafd6;
#   color: #f1f1f1;
# }
# #T_cbc5a_row4_col1 {
#   background-color: #86bddd;
#   color: #000000;
# }
# #T_cbc5a_row4_col2 {
#   background-color: #8abfdf;
#   color: #000000;
# }
# #T_cbc5a_row4_col3 {
#   background-color: #a4cde6;
#   color: #000000;
# }
# #T_cbc5a_row4_col4 {
#   background-color: #a0cbe5;
#   color: #000000;
# }
# #T_cbc5a_row4_col5 {
#   background-color: #c7e1f0;
#   color: #000000;
# }
# #T_cbc5a_row4_col8 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cbc5a">
#   <caption>Responses vs Turn Barrel (Out of Position)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_cbc5a_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_cbc5a_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_cbc5a_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_cbc5a_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_cbc5a_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_cbc5a_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_cbc5a_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_cbc5a_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_cbc5a_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbc5a_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_cbc5a_row0_col0" class="data row0 col0" >259</td>
#       <td id="T_cbc5a_row0_col1" class="data row0 col1" >217</td>
#       <td id="T_cbc5a_row0_col2" class="data row0 col2" >446</td>
#       <td id="T_cbc5a_row0_col3" class="data row0 col3" >400</td>
#       <td id="T_cbc5a_row0_col4" class="data row0 col4" >198</td>
#       <td id="T_cbc5a_row0_col5" class="data row0 col5" >35</td>
#       <td id="T_cbc5a_row0_col6" class="data row0 col6" >76</td>
#       <td id="T_cbc5a_row0_col7" class="data row0 col7" >115</td>
#       <td id="T_cbc5a_row0_col8" class="data row0 col8" >151</td>
#     </tr>
#     <tr>
#       <th id="T_cbc5a_level0_row1" class="row_heading level0 row1" >Fold</th>
#       <td id="T_cbc5a_row1_col0" class="data row1 col0" >10.0%</td>
#       <td id="T_cbc5a_row1_col1" class="data row1 col1" >24.0%</td>
#       <td id="T_cbc5a_row1_col2" class="data row1 col2" >26.7%</td>
#       <td id="T_cbc5a_row1_col3" class="data row1 col3" >40.5%</td>
#       <td id="T_cbc5a_row1_col4" class="data row1 col4" >38.4%</td>
#       <td id="T_cbc5a_row1_col5" class="data row1 col5" >60.0%</td>
#       <td id="T_cbc5a_row1_col6" class="data row1 col6" >67.1%</td>
#       <td id="T_cbc5a_row1_col7" class="data row1 col7" >42.6%</td>
#       <td id="T_cbc5a_row1_col8" class="data row1 col8" >9.3%</td>
#     </tr>
#     <tr>
#       <th id="T_cbc5a_level0_row2" class="row_heading level0 row2" >Call</th>
#       <td id="T_cbc5a_row2_col0" class="data row2 col0" >61.0%</td>
#       <td id="T_cbc5a_row2_col1" class="data row2 col1" >58.5%</td>
#       <td id="T_cbc5a_row2_col2" class="data row2 col2" >58.3%</td>
#       <td id="T_cbc5a_row2_col3" class="data row2 col3" >45.8%</td>
#       <td id="T_cbc5a_row2_col4" class="data row2 col4" >41.4%</td>
#       <td id="T_cbc5a_row2_col5" class="data row2 col5" >22.9%</td>
#       <td id="T_cbc5a_row2_col6" class="data row2 col6" >14.5%</td>
#       <td id="T_cbc5a_row2_col7" class="data row2 col7" >38.3%</td>
#       <td id="T_cbc5a_row2_col8" class="data row2 col8" >57.6%</td>
#     </tr>
#     <tr>
#       <th id="T_cbc5a_level0_row3" class="row_heading level0 row3" >Raise</th>
#       <td id="T_cbc5a_row3_col0" class="data row3 col0" >29.0%</td>
#       <td id="T_cbc5a_row3_col1" class="data row3 col1" >17.5%</td>
#       <td id="T_cbc5a_row3_col2" class="data row3 col2" >15.0%</td>
#       <td id="T_cbc5a_row3_col3" class="data row3 col3" >13.8%</td>
#       <td id="T_cbc5a_row3_col4" class="data row3 col4" >20.2%</td>
#       <td id="T_cbc5a_row3_col5" class="data row3 col5" >17.1%</td>
#       <td id="T_cbc5a_row3_col6" class="data row3 col6" >18.4%</td>
#       <td id="T_cbc5a_row3_col7" class="data row3 col7" >19.1%</td>
#       <td id="T_cbc5a_row3_col8" class="data row3 col8" >33.1%</td>
#     </tr>
#     <tr>
#       <th id="T_cbc5a_level0_row4" class="row_heading level0 row4" >Continue</th>
#       <td id="T_cbc5a_row4_col0" class="data row4 col0" >90.0%</td>
#       <td id="T_cbc5a_row4_col1" class="data row4 col1" >76.0%</td>
#       <td id="T_cbc5a_row4_col2" class="data row4 col2" >73.3%</td>
#       <td id="T_cbc5a_row4_col3" class="data row4 col3" >59.5%</td>
#       <td id="T_cbc5a_row4_col4" class="data row4 col4" >61.6%</td>
#       <td id="T_cbc5a_row4_col5" class="data row4 col5" >40.0%</td>
#       <td id="T_cbc5a_row4_col6" class="data row4 col6" >32.9%</td>
#       <td id="T_cbc5a_row4_col7" class="data row4 col7" >57.4%</td>
#       <td id="T_cbc5a_row4_col8" class="data row4 col8" >90.7%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b7c8e th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_b7c8e td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_b7c8e_row1_col0, #T_b7c8e_row2_col3 {
#   background-color: #bddbed;
#   color: #000000;
# }
# #T_b7c8e_row1_col1 {
#   background-color: #a9d0e7;
#   color: #000000;
# }
# #T_b7c8e_row1_col2 {
#   background-color: #94c5e1;
#   color: #000000;
# }
# #T_b7c8e_row1_col3 {
#   background-color: #89bede;
#   color: #000000;
# }
# #T_b7c8e_row1_col4 {
#   background-color: #7cb7db;
#   color: #000000;
# }
# #T_b7c8e_row1_col5 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# #T_b7c8e_row1_col6 {
#   background-color: #6dafd6;
#   color: #f1f1f1;
# }
# #T_b7c8e_row1_col7 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_b7c8e_row1_col8, #T_b7c8e_row2_col1 {
#   background-color: #a7cfe7;
#   color: #000000;
# }
# #T_b7c8e_row2_col0 {
#   background-color: #9cc9e4;
#   color: #000000;
# }
# #T_b7c8e_row2_col2, #T_b7c8e_row4_col3 {
#   background-color: #b5d7eb;
#   color: #000000;
# }
# #T_b7c8e_row2_col4 {
#   background-color: #cae2f0;
#   color: #000000;
# }
# #T_b7c8e_row2_col5 {
#   background-color: #d7e9f4;
#   color: #000000;
# }
# #T_b7c8e_row2_col6 {
#   background-color: #e4f0f8;
#   color: #000000;
# }
# #T_b7c8e_row2_col7 {
#   background-color: #e5f1f8;
#   color: #000000;
# }
# #T_b7c8e_row2_col8 {
#   background-color: #aad0e7;
#   color: #000000;
# }
# #T_b7c8e_row3_col0 {
#   background-color: #e7f2f8;
#   color: #000000;
# }
# #T_b7c8e_row3_col1 {
#   background-color: #f1f7fb;
#   color: #000000;
# }
# #T_b7c8e_row3_col2 {
#   background-color: #f7fbfd;
#   color: #000000;
# }
# #T_b7c8e_row3_col3 {
#   background-color: #fafcfe;
#   color: #000000;
# }
# #T_b7c8e_row3_col4 {
#   background-color: #fbfdfe;
#   color: #000000;
# }
# #T_b7c8e_row3_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_b7c8e_row3_col6, #T_b7c8e_row3_col8 {
#   background-color: #f0f7fb;
#   color: #000000;
# }
# #T_b7c8e_row3_col7 {
#   background-color: #eaf3f9;
#   color: #000000;
# }
# #T_b7c8e_row4_col0 {
#   background-color: #80badc;
#   color: #000000;
# }
# #T_b7c8e_row4_col1 {
#   background-color: #95c5e2;
#   color: #000000;
# }
# #T_b7c8e_row4_col2 {
#   background-color: #aad1e8;
#   color: #000000;
# }
# #T_b7c8e_row4_col4 {
#   background-color: #c3deee;
#   color: #000000;
# }
# #T_b7c8e_row4_col5 {
#   background-color: #d3e7f3;
#   color: #000000;
# }
# #T_b7c8e_row4_col6 {
#   background-color: #d1e6f2;
#   color: #000000;
# }
# #T_b7c8e_row4_col7 {
#   background-color: #cce3f1;
#   color: #000000;
# }
# #T_b7c8e_row4_col8 {
#   background-color: #97c6e2;
#   color: #000000;
# }
# </style>
# <table id="T_b7c8e">
#   <caption>Responses vs Turn Delayed C-Bet (Overall)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_b7c8e_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_b7c8e_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_b7c8e_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_b7c8e_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_b7c8e_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_b7c8e_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_b7c8e_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_b7c8e_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_b7c8e_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7c8e_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_b7c8e_row0_col0" class="data row0 col0" >222</td>
#       <td id="T_b7c8e_row0_col1" class="data row0 col1" >678</td>
#       <td id="T_b7c8e_row0_col2" class="data row0 col2" >1336</td>
#       <td id="T_b7c8e_row0_col3" class="data row0 col3" >866</td>
#       <td id="T_b7c8e_row0_col4" class="data row0 col4" >540</td>
#       <td id="T_b7c8e_row0_col5" class="data row0 col5" >59</td>
#       <td id="T_b7c8e_row0_col6" class="data row0 col6" >137</td>
#       <td id="T_b7c8e_row0_col7" class="data row0 col7" >40</td>
#       <td id="T_b7c8e_row0_col8" class="data row0 col8" >481</td>
#     </tr>
#     <tr>
#       <th id="T_b7c8e_level0_row1" class="row_heading level0 row1" >Fold</th>
#       <td id="T_b7c8e_row1_col0" class="data row1 col0" >34.7%</td>
#       <td id="T_b7c8e_row1_col1" class="data row1 col1" >45.0%</td>
#       <td id="T_b7c8e_row1_col2" class="data row1 col2" >55.5%</td>
#       <td id="T_b7c8e_row1_col3" class="data row1 col3" >61.2%</td>
#       <td id="T_b7c8e_row1_col4" class="data row1 col4" >67.8%</td>
#       <td id="T_b7c8e_row1_col5" class="data row1 col5" >76.3%</td>
#       <td id="T_b7c8e_row1_col6" class="data row1 col6" >75.2%</td>
#       <td id="T_b7c8e_row1_col7" class="data row1 col7" >72.5%</td>
#       <td id="T_b7c8e_row1_col8" class="data row1 col8" >45.9%</td>
#     </tr>
#     <tr>
#       <th id="T_b7c8e_level0_row2" class="row_heading level0 row2" >Call</th>
#       <td id="T_b7c8e_row2_col0" class="data row2 col0" >51.4%</td>
#       <td id="T_b7c8e_row2_col1" class="data row2 col1" >46.2%</td>
#       <td id="T_b7c8e_row2_col2" class="data row2 col2" >38.8%</td>
#       <td id="T_b7c8e_row2_col3" class="data row2 col3" >34.8%</td>
#       <td id="T_b7c8e_row2_col4" class="data row2 col4" >28.3%</td>
#       <td id="T_b7c8e_row2_col5" class="data row2 col5" >22.0%</td>
#       <td id="T_b7c8e_row2_col6" class="data row2 col6" >15.3%</td>
#       <td id="T_b7c8e_row2_col7" class="data row2 col7" >15.0%</td>
#       <td id="T_b7c8e_row2_col8" class="data row2 col8" >44.7%</td>
#     </tr>
#     <tr>
#       <th id="T_b7c8e_level0_row3" class="row_heading level0 row3" >Raise</th>
#       <td id="T_b7c8e_row3_col0" class="data row3 col0" >14.0%</td>
#       <td id="T_b7c8e_row3_col1" class="data row3 col1" >8.8%</td>
#       <td id="T_b7c8e_row3_col2" class="data row3 col2" >5.6%</td>
#       <td id="T_b7c8e_row3_col3" class="data row3 col3" >4.0%</td>
#       <td id="T_b7c8e_row3_col4" class="data row3 col4" >3.9%</td>
#       <td id="T_b7c8e_row3_col5" class="data row3 col5" >1.7%</td>
#       <td id="T_b7c8e_row3_col6" class="data row3 col6" >9.5%</td>
#       <td id="T_b7c8e_row3_col7" class="data row3 col7" >12.5%</td>
#       <td id="T_b7c8e_row3_col8" class="data row3 col8" >9.4%</td>
#     </tr>
#     <tr>
#       <th id="T_b7c8e_level0_row4" class="row_heading level0 row4" >Continue</th>
#       <td id="T_b7c8e_row4_col0" class="data row4 col0" >65.3%</td>
#       <td id="T_b7c8e_row4_col1" class="data row4 col1" >55.0%</td>
#       <td id="T_b7c8e_row4_col2" class="data row4 col2" >44.5%</td>
#       <td id="T_b7c8e_row4_col3" class="data row4 col3" >38.8%</td>
#       <td id="T_b7c8e_row4_col4" class="data row4 col4" >32.2%</td>
#       <td id="T_b7c8e_row4_col5" class="data row4 col5" >23.7%</td>
#       <td id="T_b7c8e_row4_col6" class="data row4 col6" >24.8%</td>
#       <td id="T_b7c8e_row4_col7" class="data row4 col7" >27.5%</td>
#       <td id="T_b7c8e_row4_col8" class="data row4 col8" >54.1%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b518b th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_b518b td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_b518b_row1_col0 {
#   background-color: #a6cee6;
#   color: #000000;
# }
# #T_b518b_row1_col1 {
#   background-color: #a9d0e7;
#   color: #000000;
# }
# #T_b518b_row1_col2 {
#   background-color: #91c3e0;
#   color: #000000;
# }
# #T_b518b_row1_col3 {
#   background-color: #81badc;
#   color: #000000;
# }
# #T_b518b_row1_col4 {
#   background-color: #79b6da;
#   color: #000000;
# }
# #T_b518b_row1_col5 {
#   background-color: #6eb0d7;
#   color: #f1f1f1;
# }
# #T_b518b_row1_col6 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# #T_b518b_row1_col7 {
#   background-color: #7eb8db;
#   color: #000000;
# }
# #T_b518b_row1_col8 {
#   background-color: #9bc8e3;
#   color: #000000;
# }
# #T_b518b_row2_col0, #T_b518b_row2_col8 {
#   background-color: #b6d7eb;
#   color: #000000;
# }
# #T_b518b_row2_col1 {
#   background-color: #add2e8;
#   color: #000000;
# }
# #T_b518b_row2_col2 {
#   background-color: #c0dced;
#   color: #000000;
# }
# #T_b518b_row2_col3 {
#   background-color: #cde3f1;
#   color: #000000;
# }
# #T_b518b_row2_col4 {
#   background-color: #d5e8f3;
#   color: #000000;
# }
# #T_b518b_row2_col5, #T_b518b_row4_col5 {
#   background-color: #dcecf5;
#   color: #000000;
# }
# #T_b518b_row2_col6 {
#   background-color: #e5f1f8;
#   color: #000000;
# }
# #T_b518b_row2_col7 {
#   background-color: #d8e9f4;
#   color: #000000;
# }
# #T_b518b_row3_col0 {
#   background-color: #eef5fa;
#   color: #000000;
# }
# #T_b518b_row3_col1 {
#   background-color: #f4f9fc;
#   color: #000000;
# }
# #T_b518b_row3_col2, #T_b518b_row3_col8 {
#   background-color: #f9fcfd;
#   color: #000000;
# }
# #T_b518b_row3_col3 {
#   background-color: #fcfdfe;
#   color: #000000;
# }
# #T_b518b_row3_col4 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_b518b_row3_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_b518b_row3_col6 {
#   background-color: #fafcfe;
#   color: #000000;
# }
# #T_b518b_row3_col7 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# #T_b518b_row4_col0 {
#   background-color: #a4cde6;
#   color: #000000;
# }
# #T_b518b_row4_col1 {
#   background-color: #a2cce5;
#   color: #000000;
# }
# #T_b518b_row4_col2 {
#   background-color: #bad9ec;
#   color: #000000;
# }
# #T_b518b_row4_col3 {
#   background-color: #cae2f0;
#   color: #000000;
# }
# #T_b518b_row4_col4 {
#   background-color: #d2e6f2;
#   color: #000000;
# }
# #T_b518b_row4_col6 {
#   background-color: #e0eef6;
#   color: #000000;
# }
# #T_b518b_row4_col7 {
#   background-color: #cde4f1;
#   color: #000000;
# }
# #T_b518b_row4_col8 {
#   background-color: #b0d4e9;
#   color: #000000;
# }
# </style>
# <table id="T_b518b">
#   <caption>Responses vs Turn Delayed C-Bet (In Position)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_b518b_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_b518b_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_b518b_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_b518b_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_b518b_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_b518b_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_b518b_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_b518b_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_b518b_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b518b_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_b518b_row0_col0" class="data row0 col0" >81</td>
#       <td id="T_b518b_row0_col1" class="data row0 col1" >332</td>
#       <td id="T_b518b_row0_col2" class="data row0 col2" >610</td>
#       <td id="T_b518b_row0_col3" class="data row0 col3" >401</td>
#       <td id="T_b518b_row0_col4" class="data row0 col4" >257</td>
#       <td id="T_b518b_row0_col5" class="data row0 col5" >41</td>
#       <td id="T_b518b_row0_col6" class="data row0 col6" >69</td>
#       <td id="T_b518b_row0_col7" class="data row0 col7" >18</td>
#       <td id="T_b518b_row0_col8" class="data row0 col8" >218</td>
#     </tr>
#     <tr>
#       <th id="T_b518b_level0_row1" class="row_heading level0 row1" >Fold</th>
#       <td id="T_b518b_row1_col0" class="data row1 col0" >49.4%</td>
#       <td id="T_b518b_row1_col1" class="data row1 col1" >47.9%</td>
#       <td id="T_b518b_row1_col2" class="data row1 col2" >61.3%</td>
#       <td id="T_b518b_row1_col3" class="data row1 col3" >70.1%</td>
#       <td id="T_b518b_row1_col4" class="data row1 col4" >74.7%</td>
#       <td id="T_b518b_row1_col5" class="data row1 col5" >80.5%</td>
#       <td id="T_b518b_row1_col6" class="data row1 col6" >82.6%</td>
#       <td id="T_b518b_row1_col7" class="data row1 col7" >72.2%</td>
#       <td id="T_b518b_row1_col8" class="data row1 col8" >56.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b518b_level0_row2" class="row_heading level0 row2" >Call</th>
#       <td id="T_b518b_row2_col0" class="data row2 col0" >40.7%</td>
#       <td id="T_b518b_row2_col1" class="data row2 col1" >45.8%</td>
#       <td id="T_b518b_row2_col2" class="data row2 col2" >35.2%</td>
#       <td id="T_b518b_row2_col3" class="data row2 col3" >28.2%</td>
#       <td id="T_b518b_row2_col4" class="data row2 col4" >23.7%</td>
#       <td id="T_b518b_row2_col5" class="data row2 col5" >19.5%</td>
#       <td id="T_b518b_row2_col6" class="data row2 col6" >14.5%</td>
#       <td id="T_b518b_row2_col7" class="data row2 col7" >22.2%</td>
#       <td id="T_b518b_row2_col8" class="data row2 col8" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_b518b_level0_row3" class="row_heading level0 row3" >Raise</th>
#       <td id="T_b518b_row3_col0" class="data row3 col0" >9.9%</td>
#       <td id="T_b518b_row3_col1" class="data row3 col1" >6.3%</td>
#       <td id="T_b518b_row3_col2" class="data row3 col2" >3.4%</td>
#       <td id="T_b518b_row3_col3" class="data row3 col3" >1.7%</td>
#       <td id="T_b518b_row3_col4" class="data row3 col4" >1.6%</td>
#       <td id="T_b518b_row3_col5" class="data row3 col5" >0.0%</td>
#       <td id="T_b518b_row3_col6" class="data row3 col6" >2.9%</td>
#       <td id="T_b518b_row3_col7" class="data row3 col7" >5.6%</td>
#       <td id="T_b518b_row3_col8" class="data row3 col8" >3.7%</td>
#     </tr>
#     <tr>
#       <th id="T_b518b_level0_row4" class="row_heading level0 row4" >Continue</th>
#       <td id="T_b518b_row4_col0" class="data row4 col0" >50.6%</td>
#       <td id="T_b518b_row4_col1" class="data row4 col1" >52.1%</td>
#       <td id="T_b518b_row4_col2" class="data row4 col2" >38.7%</td>
#       <td id="T_b518b_row4_col3" class="data row4 col3" >29.9%</td>
#       <td id="T_b518b_row4_col4" class="data row4 col4" >25.3%</td>
#       <td id="T_b518b_row4_col5" class="data row4 col5" >19.5%</td>
#       <td id="T_b518b_row4_col6" class="data row4 col6" >17.4%</td>
#       <td id="T_b518b_row4_col7" class="data row4 col7" >27.8%</td>
#       <td id="T_b518b_row4_col8" class="data row4 col8" >44.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_64bd7 th.col_heading.level0.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_64bd7 td.col7 {
#   border-left: 2px solid #64748b;
# }
# #T_64bd7_row1_col0 {
#   background-color: #d2e7f3;
#   color: #000000;
# }
# #T_64bd7_row1_col1 {
#   background-color: #afd3e9;
#   color: #000000;
# }
# #T_64bd7_row1_col2 {
#   background-color: #9dc9e4;
#   color: #000000;
# }
# #T_64bd7_row1_col3 {
#   background-color: #97c6e2;
#   color: #000000;
# }
# #T_64bd7_row1_col4 {
#   background-color: #86bddd;
#   color: #000000;
# }
# #T_64bd7_row1_col5 {
#   background-color: #7ab6da;
#   color: #000000;
# }
# #T_64bd7_row1_col6 {
#   background-color: #78b5da;
#   color: #000000;
# }
# #T_64bd7_row1_col7 {
#   background-color: #6dafd6;
#   color: #f1f1f1;
# }
# #T_64bd7_row1_col8 {
#   background-color: #b9d9ec;
#   color: #000000;
# }
# #T_64bd7_row2_col0 {
#   background-color: #8ec1e0;
#   color: #000000;
# }
# #T_64bd7_row2_col1, #T_64bd7_row4_col3 {
#   background-color: #a6cee6;
#   color: #000000;
# }
# #T_64bd7_row2_col2 {
#   background-color: #b0d4e9;
#   color: #000000;
# }
# #T_64bd7_row2_col3 {
#   background-color: #b4d6ea;
#   color: #000000;
# }
# #T_64bd7_row2_col4 {
#   background-color: #c4dfef;
#   color: #000000;
# }
# #T_64bd7_row2_col5 {
#   background-color: #cfe5f2;
#   color: #000000;
# }
# #T_64bd7_row2_col6, #T_64bd7_row3_col6 {
#   background-color: #e8f3f9;
#   color: #000000;
# }
# #T_64bd7_row2_col7 {
#   background-color: #f7fbfd;
#   color: #000000;
# }
# #T_64bd7_row2_col8 {
#   background-color: #a2cce5;
#   color: #000000;
# }
# #T_64bd7_row3_col0 {
#   background-color: #e8f2f9;
#   color: #000000;
# }
# #T_64bd7_row3_col1 {
#   background-color: #f3f8fc;
#   color: #000000;
# }
# #T_64bd7_row3_col2 {
#   background-color: #fbfdfe;
#   color: #000000;
# }
# #T_64bd7_row3_col3, #T_64bd7_row3_col4 {
#   background-color: #feffff;
#   color: #000000;
# }
# #T_64bd7_row3_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_64bd7_row3_col7 {
#   background-color: #e4f0f7;
#   color: #000000;
# }
# #T_64bd7_row3_col8 {
#   background-color: #edf5fa;
#   color: #000000;
# }
# #T_64bd7_row4_col0 {
#   background-color: #6baed6;
#   color: #f1f1f1;
# }
# #T_64bd7_row4_col1 {
#   background-color: #8dc1df;
#   color: #000000;
# }
# #T_64bd7_row4_col2 {
#   background-color: #a0cbe5;
#   color: #000000;
# }
# #T_64bd7_row4_col4 {
#   background-color: #b8d8eb;
#   color: #000000;
# }
# #T_64bd7_row4_col5 {
#   background-color: #c3deee;
#   color: #000000;
# }
# #T_64bd7_row4_col6 {
#   background-color: #c5dfef;
#   color: #000000;
# }
# #T_64bd7_row4_col7 {
#   background-color: #d0e5f2;
#   color: #000000;
# }
# #T_64bd7_row4_col8 {
#   background-color: #83bbdd;
#   color: #000000;
# }
# </style>
# <table id="T_64bd7">
#   <caption>Responses vs Turn Delayed C-Bet (Out of Position)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_64bd7_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_64bd7_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_64bd7_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_64bd7_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_64bd7_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_64bd7_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_64bd7_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#       <th id="T_64bd7_level0_col7" class="col_heading level0 col7" >All-In</th>
#       <th id="T_64bd7_level0_col8" class="col_heading level0 col8" >1 BB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64bd7_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_64bd7_row0_col0" class="data row0 col0" >141</td>
#       <td id="T_64bd7_row0_col1" class="data row0 col1" >346</td>
#       <td id="T_64bd7_row0_col2" class="data row0 col2" >726</td>
#       <td id="T_64bd7_row0_col3" class="data row0 col3" >465</td>
#       <td id="T_64bd7_row0_col4" class="data row0 col4" >283</td>
#       <td id="T_64bd7_row0_col5" class="data row0 col5" >18</td>
#       <td id="T_64bd7_row0_col6" class="data row0 col6" >68</td>
#       <td id="T_64bd7_row0_col7" class="data row0 col7" >22</td>
#       <td id="T_64bd7_row0_col8" class="data row0 col8" >263</td>
#     </tr>
#     <tr>
#       <th id="T_64bd7_level0_row1" class="row_heading level0 row1" >Fold</th>
#       <td id="T_64bd7_row1_col0" class="data row1 col0" >26.2%</td>
#       <td id="T_64bd7_row1_col1" class="data row1 col1" >42.2%</td>
#       <td id="T_64bd7_row1_col2" class="data row1 col2" >50.7%</td>
#       <td id="T_64bd7_row1_col3" class="data row1 col3" >53.5%</td>
#       <td id="T_64bd7_row1_col4" class="data row1 col4" >61.5%</td>
#       <td id="T_64bd7_row1_col5" class="data row1 col5" >66.7%</td>
#       <td id="T_64bd7_row1_col6" class="data row1 col6" >67.6%</td>
#       <td id="T_64bd7_row1_col7" class="data row1 col7" >72.7%</td>
#       <td id="T_64bd7_row1_col8" class="data row1 col8" >37.6%</td>
#     </tr>
#     <tr>
#       <th id="T_64bd7_level0_row2" class="row_heading level0 row2" >Call</th>
#       <td id="T_64bd7_row2_col0" class="data row2 col0" >57.4%</td>
#       <td id="T_64bd7_row2_col1" class="data row2 col1" >46.5%</td>
#       <td id="T_64bd7_row2_col2" class="data row2 col2" >41.9%</td>
#       <td id="T_64bd7_row2_col3" class="data row2 col3" >40.4%</td>
#       <td id="T_64bd7_row2_col4" class="data row2 col4" >32.5%</td>
#       <td id="T_64bd7_row2_col5" class="data row2 col5" >27.8%</td>
#       <td id="T_64bd7_row2_col6" class="data row2 col6" >16.2%</td>
#       <td id="T_64bd7_row2_col7" class="data row2 col7" >9.1%</td>
#       <td id="T_64bd7_row2_col8" class="data row2 col8" >48.3%</td>
#     </tr>
#     <tr>
#       <th id="T_64bd7_level0_row3" class="row_heading level0 row3" >Raise</th>
#       <td id="T_64bd7_row3_col0" class="data row3 col0" >16.3%</td>
#       <td id="T_64bd7_row3_col1" class="data row3 col1" >11.3%</td>
#       <td id="T_64bd7_row3_col2" class="data row3 col2" >7.4%</td>
#       <td id="T_64bd7_row3_col3" class="data row3 col3" >6.0%</td>
#       <td id="T_64bd7_row3_col4" class="data row3 col4" >6.0%</td>
#       <td id="T_64bd7_row3_col5" class="data row3 col5" >5.6%</td>
#       <td id="T_64bd7_row3_col6" class="data row3 col6" >16.2%</td>
#       <td id="T_64bd7_row3_col7" class="data row3 col7" >18.2%</td>
#       <td id="T_64bd7_row3_col8" class="data row3 col8" >14.1%</td>
#     </tr>
#     <tr>
#       <th id="T_64bd7_level0_row4" class="row_heading level0 row4" >Continue</th>
#       <td id="T_64bd7_row4_col0" class="data row4 col0" >73.8%</td>
#       <td id="T_64bd7_row4_col1" class="data row4 col1" >57.8%</td>
#       <td id="T_64bd7_row4_col2" class="data row4 col2" >49.3%</td>
#       <td id="T_64bd7_row4_col3" class="data row4 col3" >46.5%</td>
#       <td id="T_64bd7_row4_col4" class="data row4 col4" >38.5%</td>
#       <td id="T_64bd7_row4_col5" class="data row4 col5" >33.3%</td>
#       <td id="T_64bd7_row4_col6" class="data row4 col6" >32.4%</td>
#       <td id="T_64bd7_row4_col7" class="data row4 col7" >27.3%</td>
#       <td id="T_64bd7_row4_col8" class="data row4 col8" >62.4%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Turn Event-Level Outcomes
#
# These tables look at entire betting rounds rather than individual responses.
# The Value Profile highlights how much money flows into the pot when villains
# continue, while the Fold Pressure view compares actual folds to the break-even
# threshold for each bet size. One big blind probes and all-in bets are excluded
# to keep the focus on the main sizing buckets.

# %%
if events_df.empty or responses_df.empty:
    print('No turn events or responses available for event-level analysis.')
else:
    display_all_turn_event_tables()
# Out:
# <style type="text/css">
# #T_a1742_row1_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_a1742_row1_col1 {
#   background-color: #d9131f;
#   color: #f1f1f1;
# }
# #T_a1742_row1_col2 {
#   background-color: #db141e;
#   color: #f1f1f1;
# }
# #T_a1742_row1_col3 {
#   background-color: #fc592d;
#   color: #f1f1f1;
# }
# #T_a1742_row1_col4 {
#   background-color: #fc6a32;
#   color: #f1f1f1;
# }
# #T_a1742_row1_col5 {
#   background-color: #feb44e;
#   color: #000000;
# }
# #T_a1742_row1_col6 {
#   background-color: #fee288;
#   color: #000000;
# }
# #T_a1742_row2_col0 {
#   background-color: #fa4a29;
#   color: #f1f1f1;
# }
# #T_a1742_row2_col1 {
#   background-color: #fc6631;
#   color: #f1f1f1;
# }
# #T_a1742_row2_col2 {
#   background-color: #fc512b;
#   color: #f1f1f1;
# }
# #T_a1742_row2_col3 {
#   background-color: #fd9f44;
#   color: #000000;
# }
# #T_a1742_row2_col4 {
#   background-color: #feb24c;
#   color: #000000;
# }
# #T_a1742_row2_col5 {
#   background-color: #fecc68;
#   color: #000000;
# }
# #T_a1742_row2_col6 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_a1742_row3_col0 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_a1742_row3_col1 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_a1742_row3_col2 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_a1742_row3_col3 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_a1742_row3_col4 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_a1742_row3_col5 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_a1742_row3_col6 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_a1742_row4_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_a1742_row4_col1 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_a1742_row4_col2 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_a1742_row4_col3, #T_a1742_row5_col0 {
#   background-color: #e2f4f7;
#   color: #000000;
# }
# #T_a1742_row4_col4 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_a1742_row4_col5 {
#   background-color: #c5e9e2;
#   color: #000000;
# }
# #T_a1742_row4_col6 {
#   background-color: #8ad2be;
#   color: #000000;
# }
# #T_a1742_row5_col1 {
#   background-color: #b4e2d8;
#   color: #000000;
# }
# #T_a1742_row5_col2 {
#   background-color: #82ceb8;
#   color: #000000;
# }
# #T_a1742_row5_col3 {
#   background-color: #4cb484;
#   color: #f1f1f1;
# }
# #T_a1742_row5_col4 {
#   background-color: #45b07b;
#   color: #f1f1f1;
# }
# #T_a1742_row5_col5 {
#   background-color: #4eb586;
#   color: #f1f1f1;
# }
# #T_a1742_row5_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a1742_row6_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a1742_row6_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_a1742_row6_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_a1742_row6_col3 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_a1742_row6_col4 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_a1742_row6_col5 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_a1742_row6_col6 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_a1742_row7_col0 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_a1742_row7_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_a1742_row7_col2 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_a1742_row7_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_a1742_row7_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_a1742_row7_col5 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_a1742_row7_col6 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_a1742_row8_col0 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_a1742_row8_col1 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_a1742_row8_col2 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_a1742_row8_col3 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_a1742_row8_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a1742_row8_col5 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_a1742_row8_col6 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a1742">
#   <caption>Turn Barrel Event Outcomes (Overall) - Value Profile</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_a1742_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_a1742_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_a1742_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_a1742_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_a1742_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_a1742_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_a1742_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1742_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_a1742_row0_col0" class="data row0 col0" >153</td>
#       <td id="T_a1742_row0_col1" class="data row0 col1" >366</td>
#       <td id="T_a1742_row0_col2" class="data row0 col2" >800</td>
#       <td id="T_a1742_row0_col3" class="data row0 col3" >902</td>
#       <td id="T_a1742_row0_col4" class="data row0 col4" >381</td>
#       <td id="T_a1742_row0_col5" class="data row0 col5" >46</td>
#       <td id="T_a1742_row0_col6" class="data row0 col6" >84</td>
#     </tr>
#     <tr>
#       <th id="T_a1742_level0_row1" class="row_heading level0 row1" >Continue%</th>
#       <td id="T_a1742_row1_col0" class="data row1 col0" >88.9%</td>
#       <td id="T_a1742_row1_col1" class="data row1 col1" >71.0%</td>
#       <td id="T_a1742_row1_col2" class="data row1 col2" >70.5%</td>
#       <td id="T_a1742_row1_col3" class="data row1 col3" >56.3%</td>
#       <td id="T_a1742_row1_col4" class="data row1 col4" >53.3%</td>
#       <td id="T_a1742_row1_col5" class="data row1 col5" >37.0%</td>
#       <td id="T_a1742_row1_col6" class="data row1 col6" >22.6%</td>
#     </tr>
#     <tr>
#       <th id="T_a1742_level0_row2" class="row_heading level0 row2" >Call-Only%</th>
#       <td id="T_a1742_row2_col0" class="data row2 col0" >58.8%</td>
#       <td id="T_a1742_row2_col1" class="data row2 col1" >54.1%</td>
#       <td id="T_a1742_row2_col2" class="data row2 col2" >57.4%</td>
#       <td id="T_a1742_row2_col3" class="data row2 col3" >42.7%</td>
#       <td id="T_a1742_row2_col4" class="data row2 col4" >37.5%</td>
#       <td id="T_a1742_row2_col5" class="data row2 col5" >30.4%</td>
#       <td id="T_a1742_row2_col6" class="data row2 col6" >11.9%</td>
#     </tr>
#     <tr>
#       <th id="T_a1742_level0_row3" class="row_heading level0 row3" >Raise%</th>
#       <td id="T_a1742_row3_col0" class="data row3 col0" >30.1%</td>
#       <td id="T_a1742_row3_col1" class="data row3 col1" >16.9%</td>
#       <td id="T_a1742_row3_col2" class="data row3 col2" >13.1%</td>
#       <td id="T_a1742_row3_col3" class="data row3 col3" >13.6%</td>
#       <td id="T_a1742_row3_col4" class="data row3 col4" >15.7%</td>
#       <td id="T_a1742_row3_col5" class="data row3 col5" >6.5%</td>
#       <td id="T_a1742_row3_col6" class="data row3 col6" >10.7%</td>
#     </tr>
#     <tr>
#       <th id="T_a1742_level0_row4" class="row_heading level0 row4" >Avg Size (Pot%)</th>
#       <td id="T_a1742_row4_col0" class="data row4 col0" >18.2%</td>
#       <td id="T_a1742_row4_col1" class="data row4 col1" >31.9%</td>
#       <td id="T_a1742_row4_col2" class="data row4 col2" >48.1%</td>
#       <td id="T_a1742_row4_col3" class="data row4 col3" >69.5%</td>
#       <td id="T_a1742_row4_col4" class="data row4 col4" >93.3%</td>
#       <td id="T_a1742_row4_col5" class="data row4 col5" >113.3%</td>
#       <td id="T_a1742_row4_col6" class="data row4 col6" >164.5%</td>
#     </tr>
#     <tr>
#       <th id="T_a1742_level0_row5" class="row_heading level0 row5" >Avg Raise Size (Pot%)</th>
#       <td id="T_a1742_row5_col0" class="data row5 col0" >69.7%</td>
#       <td id="T_a1742_row5_col1" class="data row5 col1" >128.2%</td>
#       <td id="T_a1742_row5_col2" class="data row5 col2" >172.6%</td>
#       <td id="T_a1742_row5_col3" class="data row5 col3" >227.2%</td>
#       <td id="T_a1742_row5_col4" class="data row5 co
# <style type="text/css">
# #T_bb8da_row1_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_bb8da_row1_col1 {
#   background-color: #fed470;
#   color: #000000;
# }
# #T_bb8da_row1_col2 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_bb8da_row1_col3 {
#   background-color: #fd903d;
#   color: #000000;
# }
# #T_bb8da_row1_col4 {
#   background-color: #fd7a37;
#   color: #f1f1f1;
# }
# #T_bb8da_row1_col5 {
#   background-color: #d9131f;
#   color: #f1f1f1;
# }
# #T_bb8da_row1_col6 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_bb8da_row2_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_bb8da_row2_col1 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_bb8da_row2_col2 {
#   background-color: #d5efed;
#   color: #000000;
# }
# #T_bb8da_row2_col3 {
#   background-color: #a4dccf;
#   color: #000000;
# }
# #T_bb8da_row2_col4 {
#   background-color: #62c09f;
#   color: #000000;
# }
# #T_bb8da_row2_col5 {
#   background-color: #3ba76c;
#   color: #f1f1f1;
# }
# #T_bb8da_row2_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_bb8da_row4_col0 {
#   background-color: #edc5c5;
#   color: #000000;
# }
# #T_bb8da_row4_col1 {
#   background-color: #badac6;
#   color: #000000;
# }
# #T_bb8da_row4_col2 {
#   background-color: #f2d5d5;
#   color: #000000;
# }
# #T_bb8da_row4_col3 {
#   background-color: #d8eade;
#   color: #000000;
# }
# #T_bb8da_row4_col4 {
#   background-color: #f9ebeb;
#   color: #000000;
# }
# #T_bb8da_row4_col5 {
#   background-color: #6fb188;
#   color: #f1f1f1;
# }
# #T_bb8da_row4_col6 {
#   background-color: #15803d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bb8da">
#   <caption>Turn Barrel Event Outcomes (Overall) - Fold Pressure</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_bb8da_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_bb8da_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_bb8da_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_bb8da_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_bb8da_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_bb8da_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_bb8da_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb8da_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_bb8da_row0_col0" class="data row0 col0" >153</td>
#       <td id="T_bb8da_row0_col1" class="data row0 col1" >366</td>
#       <td id="T_bb8da_row0_col2" class="data row0 col2" >800</td>
#       <td id="T_bb8da_row0_col3" class="data row0 col3" >902</td>
#       <td id="T_bb8da_row0_col4" class="data row0 col4" >381</td>
#       <td id="T_bb8da_row0_col5" class="data row0 col5" >46</td>
#       <td id="T_bb8da_row0_col6" class="data row0 col6" >84</td>
#     </tr>
#     <tr>
#       <th id="T_bb8da_level0_row1" class="row_heading level0 row1" >Fold%</th>
#       <td id="T_bb8da_row1_col0" class="data row1 col0" >11.1%</td>
#       <td id="T_bb8da_row1_col1" class="data row1 col1" >29.0%</td>
#       <td id="T_bb8da_row1_col2" class="data row1 col2" >29.5%</td>
#       <td id="T_bb8da_row1_col3" class="data row1 col3" >43.7%</td>
#       <td id="T_bb8da_row1_col4" class="data row1 col4" >46.7%</td>
#       <td id="T_bb8da_row1_col5" class="data row1 col5" >63.0%</td>
#       <td id="T_bb8da_row1_col6" class="data row1 col6" >77.4%</td>
#     </tr>
#     <tr>
#       <th id="T_bb8da_level0_row2" class="row_heading level0 row2" >Avg Size (Pot%)</th>
#       <td id="T_bb8da_row2_col0" class="data row2 col0" >18.2%</td>
#       <td id="T_bb8da_row2_col1" class="data row2 col1" >31.9%</td>
#       <td id="T_bb8da_row2_col2" class="data row2 col2" >48.1%</td>
#       <td id="T_bb8da_row2_col3" class="data row2 col3" >69.5%</td>
#       <td id="T_bb8da_row2_col4" class="data row2 col4" >93.3%</td>
#       <td id="T_bb8da_row2_col5" class="data row2 col5" >113.3%</td>
#       <td id="T_bb8da_row2_col6" class="data row2 col6" >164.5%</td>
#     </tr>
#     <tr>
#       <th id="T_bb8da_level0_row3" class="row_heading level0 row3" >Breakeven Fold%</th>
#       <td id="T_bb8da_row3_col0" class="data row3 col0" >15.2%</td>
#       <td id="T_bb8da_row3_col1" class="data row3 col1" >24.1%</td>
#       <td id="T_bb8da_row3_col2" class="data row3 col2" >32.5%</td>
#       <td id="T_bb8da_row3_col3" class="data row3 col3" >41.0%</td>
#       <td id="T_bb8da_row3_col4" class="data row3 col4" >48.2%</td>
#       <td id="T_bb8da_row3_col5" class="data row3 col5" >53.1%</td>
#       <td id="T_bb8da_row3_col6" class="data row3 col6" >61.1%</td>
#     </tr>
#     <tr>
#       <th id="T_bb8da_level0_row4" class="row_heading level0 row4" >Fold Surplus</th>
#       <td id="T_bb8da_row4_col0" class="data row4 col0" >-4.1%</td>
#       <td id="T_bb8da_row4_col1" class="data row4 col1" >4.8%</td>
#       <td id="T_bb8da_row4_col2" class="data row4 col2" >-3.0%</td>
#       <td id="T_bb8da_row4_col3" class="data row4 col3" >2.7%</td>
#       <td id="T_bb8da_row4_col4" class="data row4 col4" >-1.5%</td>
#       <td id="T_bb8da_row4_col5" class="data row4 col5" >10.0%</td>
#       <td id="T_bb8da_row4_col6" class="data row4 col6" >16.3%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a2748_row1_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_a2748_row1_col1 {
#   background-color: #d30f20;
#   color: #f1f1f1;
# }
# #T_a2748_row1_col2 {
#   background-color: #d6111f;
#   color: #f1f1f1;
# }
# #T_a2748_row1_col3 {
#   background-color: #f74327;
#   color: #f1f1f1;
# }
# #T_a2748_row1_col4 {
#   background-color: #fd8038;
#   color: #f1f1f1;
# }
# #T_a2748_row1_col5 {
#   background-color: #fd9d43;
#   color: #000000;
# }
# #T_a2748_row1_col6 {
#   background-color: #fedc7c;
#   color: #000000;
# }
# #T_a2748_row2_col0 {
#   background-color: #f84528;
#   color: #f1f1f1;
# }
# #T_a2748_row2_col1 {
#   background-color: #fc5d2e;
#   color: #f1f1f1;
# }
# #T_a2748_row2_col2 {
#   background-color: #f43e26;
#   color: #f1f1f1;
# }
# #T_a2748_row2_col3 {
#   background-color: #fd953f;
#   color: #000000;
# }
# #T_a2748_row2_col4 {
#   background-color: #feaf4b;
#   color: #000000;
# }
# #T_a2748_row2_col5 {
#   background-color: #feab49;
#   color: #000000;
# }
# #T_a2748_row2_col6, #T_a2748_row3_col4, #T_a2748_row3_col6 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_a2748_row3_col0 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_a2748_row3_col1 {
#   background-color: #ffe794;
#   color: #000000;
# }
# #T_a2748_row3_col2 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_a2748_row3_col3 {
#   background-color: #ffec9f;
#   color: #000000;
# }
# #T_a2748_row3_col5 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_a2748_row4_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_a2748_row4_col1 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_a2748_row4_col2 {
#   background-color: #eef8fb;
#   color: #000000;
# }
# #T_a2748_row4_col3 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_a2748_row4_col4 {
#   background-color: #dff3f4;
#   color: #000000;
# }
# #T_a2748_row4_col5 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_a2748_row4_col6 {
#   background-color: #b7e4da;
#   color: #000000;
# }
# #T_a2748_row5_col0 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_a2748_row5_col1 {
#   background-color: #c4e9e1;
#   color: #000000;
# }
# #T_a2748_row5_col2 {
#   background-color: #b5e3d9;
#   color: #000000;
# }
# #T_a2748_row5_col3 {
#   background-color: #6fc6aa;
#   color: #000000;
# }
# #T_a2748_row5_col4 {
#   background-color: #7acbb3;
#   color: #000000;
# }
# #T_a2748_row5_col5 {
#   background-color: #72c7ad;
#   color: #000000;
# }
# #T_a2748_row5_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a2748_row6_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_a2748_row6_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_a2748_row6_col2 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_a2748_row6_col3 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_a2748_row6_col4 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_a2748_row6_col5 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_a2748_row6_col6 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_a2748_row7_col0 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_a2748_row7_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_a2748_row7_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_a2748_row7_col3 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_a2748_row7_col4 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_a2748_row7_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a2748_row7_col6 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_a2748_row8_col0 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_a2748_row8_col1 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_a2748_row8_col2 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_a2748_row8_col3 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_a2748_row8_col4 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_a2748_row8_col5 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_a2748_row8_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a2748">
#   <caption>Turn Barrel Event Outcomes (In Position) - Value Profile</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_a2748_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_a2748_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_a2748_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_a2748_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_a2748_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_a2748_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_a2748_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2748_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_a2748_row0_col0" class="data row0 col0" >62</td>
#       <td id="T_a2748_row0_col1" class="data row0 col1" >180</td>
#       <td id="T_a2748_row0_col2" class="data row0 col2" >395</td>
#       <td id="T_a2748_row0_col3" class="data row0 col3" >524</td>
#       <td id="T_a2748_row0_col4" class="data row0 col4" >205</td>
#       <td id="T_a2748_row0_col5" class="data row0 col5" >29</td>
#       <td id="T_a2748_row0_col6" class="data row0 col6" >56</td>
#     </tr>
#     <tr>
#       <th id="T_a2748_level0_row1" class="row_heading level0 row1" >Continue%</th>
#       <td id="T_a2748_row1_col0" class="data row1 col0" >80.6%</td>
#       <td id="T_a2748_row1_col1" class="data row1 col1" >65.6%</td>
#       <td id="T_a2748_row1_col2" class="data row1 col2" >64.6%</td>
#       <td id="T_a2748_row1_col3" class="data row1 col3" >53.6%</td>
#       <td id="T_a2748_row1_col4" class="data row1 col4" >43.9%</td>
#       <td id="T_a2748_row1_col5" class="data row1 col5" >37.9%</td>
#       <td id="T_a2748_row1_col6" class="data row1 col6" >21.4%</td>
#     </tr>
#     <tr>
#       <th id="T_a2748_level0_row2" class="row_heading level0 row2" >Call-Only%</th>
#       <td id="T_a2748_row2_col0" class="data row2 col0" >53.2%</td>
#       <td id="T_a2748_row2_col1" class="data row2 col1" >49.4%</td>
#       <td id="T_a2748_row2_col2" class="data row2 col2" >54.4%</td>
#       <td id="T_a2748_row2_col3" class="data row2 col3" >40.1%</td>
#       <td id="T_a2748_row2_col4" class="data row2 col4" >33.2%</td>
#       <td id="T_a2748_row2_col5" class="data row2 col5" >34.5%</td>
#       <td id="T_a2748_row2_col6" class="data row2 col6" >10.7%</td>
#     </tr>
#     <tr>
#       <th id="T_a2748_level0_row3" class="row_heading level0 row3" >Raise%</th>
#       <td id="T_a2748_row3_col0" class="data row3 col0" >27.4%</td>
#       <td id="T_a2748_row3_col1" class="data row3 col1" >16.1%</td>
#       <td id="T_a2748_row3_col2" class="data row3 col2" >10.1%</td>
#       <td id="T_a2748_row3_col3" class="data row3 col3" >13.5%</td>
#       <td id="T_a2748_row3_col4" class="data row3 col4" >10.7%</td>
#       <td id="T_a2748_row3_col5" class="data row3 col5" >3.4%</td>
#       <td id="T_a2748_row3_col6" class="data row3 col6" >10.7%</td>
#     </tr>
#     <tr>
#       <th id="T_a2748_level0_row4" class="row_heading level0 row4" >Avg Size (Pot%)</th>
#       <td id="T_a2748_row4_col0" class="data row4 col0" >18.6%</td>
#       <td id="T_a2748_row4_col1" class="data row4 col1" >32.3%</td>
#       <td id="T_a2748_row4_col2" class="data row4 col2" >48.3%</td>
#       <td id="T_a2748_row4_col3" class="data row4 col3" >69.7%</td>
#       <td id="T_a2748_row4_col4" class="data row4 col4" >93.3%</td>
#       <td id="T_a2748_row4_col5" class="data row4 col5" >113.6%</td>
#       <td id="T_a2748_row4_col6" class="data row4 col6" >162.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a2748_level0_row5" class="row_heading level0 row5" >Avg Raise Size (Pot%)</th>
#       <td id="T_a2748_row5_col0" class="data row5 col0" >72.3%</td>
#       <td id="T_a2748_row5_col1" class="data row5 col1" >148.2%</td>
#       <td id="T_a2748_row5_col2" class="data row5 col2" >163.5%</td>
#       <td id="T_a2748_row5_col3" class="data row5 col3" >246.0%</td>
#       <td id="T_a2748_row5_col4" class="data row5 col4" >231.8%</td>
#       <td id="T_a2748_row5_col
# <style type="text/css">
# #T_768d6_row1_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_768d6_row1_col1 {
#   background-color: #fed774;
#   color: #000000;
# }
# #T_768d6_row1_col2 {
#   background-color: #fed36f;
#   color: #000000;
# }
# #T_768d6_row1_col3 {
#   background-color: #fd9a42;
#   color: #000000;
# }
# #T_768d6_row1_col4 {
#   background-color: #fc512b;
#   color: #f1f1f1;
# }
# #T_768d6_row1_col5 {
#   background-color: #e9261f;
#   color: #f1f1f1;
# }
# #T_768d6_row1_col6 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_768d6_row2_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_768d6_row2_col1 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_768d6_row2_col2 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_768d6_row2_col3 {
#   background-color: #a0dbcd;
#   color: #000000;
# }
# #T_768d6_row2_col4 {
#   background-color: #60bf9c;
#   color: #000000;
# }
# #T_768d6_row2_col5 {
#   background-color: #38a367;
#   color: #f1f1f1;
# }
# #T_768d6_row2_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_768d6_row4_col0 {
#   background-color: #cbe3d4;
#   color: #000000;
# }
# #T_768d6_row4_col1 {
#   background-color: #78b68f;
#   color: #f1f1f1;
# }
# #T_768d6_row4_col2 {
#   background-color: #d8eade;
#   color: #000000;
# }
# #T_768d6_row4_col3 {
#   background-color: #b8d9c4;
#   color: #000000;
# }
# #T_768d6_row4_col4 {
#   background-color: #95c6a8;
#   color: #000000;
# }
# #T_768d6_row4_col5 {
#   background-color: #87be9b;
#   color: #000000;
# }
# #T_768d6_row4_col6 {
#   background-color: #15803d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_768d6">
#   <caption>Turn Barrel Event Outcomes (In Position) - Fold Pressure</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_768d6_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_768d6_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_768d6_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_768d6_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_768d6_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_768d6_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_768d6_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_768d6_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_768d6_row0_col0" class="data row0 col0" >62</td>
#       <td id="T_768d6_row0_col1" class="data row0 col1" >180</td>
#       <td id="T_768d6_row0_col2" class="data row0 col2" >395</td>
#       <td id="T_768d6_row0_col3" class="data row0 col3" >524</td>
#       <td id="T_768d6_row0_col4" class="data row0 col4" >205</td>
#       <td id="T_768d6_row0_col5" class="data row0 col5" >29</td>
#       <td id="T_768d6_row0_col6" class="data row0 col6" >56</td>
#     </tr>
#     <tr>
#       <th id="T_768d6_level0_row1" class="row_heading level0 row1" >Fold%</th>
#       <td id="T_768d6_row1_col0" class="data row1 col0" >19.4%</td>
#       <td id="T_768d6_row1_col1" class="data row1 col1" >34.4%</td>
#       <td id="T_768d6_row1_col2" class="data row1 col2" >35.4%</td>
#       <td id="T_768d6_row1_col3" class="data row1 col3" >46.4%</td>
#       <td id="T_768d6_row1_col4" class="data row1 col4" >56.1%</td>
#       <td id="T_768d6_row1_col5" class="data row1 col5" >62.1%</td>
#       <td id="T_768d6_row1_col6" class="data row1 col6" >78.6%</td>
#     </tr>
#     <tr>
#       <th id="T_768d6_level0_row2" class="row_heading level0 row2" >Avg Size (Pot%)</th>
#       <td id="T_768d6_row2_col0" class="data row2 col0" >18.6%</td>
#       <td id="T_768d6_row2_col1" class="data row2 col1" >32.3%</td>
#       <td id="T_768d6_row2_col2" class="data row2 col2" >48.3%</td>
#       <td id="T_768d6_row2_col3" class="data row2 col3" >69.7%</td>
#       <td id="T_768d6_row2_col4" class="data row2 col4" >93.3%</td>
#       <td id="T_768d6_row2_col5" class="data row2 col5" >113.6%</td>
#       <td id="T_768d6_row2_col6" class="data row2 col6" >162.0%</td>
#     </tr>
#     <tr>
#       <th id="T_768d6_level0_row3" class="row_heading level0 row3" >Breakeven Fold%</th>
#       <td id="T_768d6_row3_col0" class="data row3 col0" >15.5%</td>
#       <td id="T_768d6_row3_col1" class="data row3 col1" >24.4%</td>
#       <td id="T_768d6_row3_col2" class="data row3 col2" >32.5%</td>
#       <td id="T_768d6_row3_col3" class="data row3 col3" >41.0%</td>
#       <td id="T_768d6_row3_col4" class="data row3 col4" >48.2%</td>
#       <td id="T_768d6_row3_col5" class="data row3 col5" >53.1%</td>
#       <td id="T_768d6_row3_col6" class="data row3 col6" >61.0%</td>
#     </tr>
#     <tr>
#       <th id="T_768d6_level0_row4" class="row_heading level0 row4" >Fold Surplus</th>
#       <td id="T_768d6_row4_col0" class="data row4 col0" >3.9%</td>
#       <td id="T_768d6_row4_col1" class="data row4 col1" >10.1%</td>
#       <td id="T_768d6_row4_col2" class="data row4 col2" >2.9%</td>
#       <td id="T_768d6_row4_col3" class="data row4 col3" >5.3%</td>
#       <td id="T_768d6_row4_col4" class="data row4 col4" >7.9%</td>
#       <td id="T_768d6_row4_col5" class="data row4 col5" >8.9%</td>
#       <td id="T_768d6_row4_col6" class="data row4 col6" >17.5%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_14db2_row1_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_14db2_row1_col1, #T_14db2_row1_col2 {
#   background-color: #d9131f;
#   color: #f1f1f1;
# }
# #T_14db2_row1_col3 {
#   background-color: #fc612f;
#   color: #f1f1f1;
# }
# #T_14db2_row1_col4 {
#   background-color: #f94828;
#   color: #f1f1f1;
# }
# #T_14db2_row1_col5 {
#   background-color: #fecb67;
#   color: #000000;
# }
# #T_14db2_row1_col6 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_14db2_row2_col0 {
#   background-color: #fc512b;
#   color: #f1f1f1;
# }
# #T_14db2_row2_col1 {
#   background-color: #fc6832;
#   color: #f1f1f1;
# }
# #T_14db2_row2_col2 {
#   background-color: #fc5f2f;
#   color: #f1f1f1;
# }
# #T_14db2_row2_col3 {
#   background-color: #fea446;
#   color: #000000;
# }
# #T_14db2_row2_col4 {
#   background-color: #feb04b;
#   color: #000000;
# }
# #T_14db2_row2_col5 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_14db2_row2_col6 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_14db2_row3_col0 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_14db2_row3_col1 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_14db2_row3_col2 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_14db2_row3_col3 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_14db2_row3_col4 {
#   background-color: #ffec9f;
#   color: #000000;
# }
# #T_14db2_row3_col5 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_14db2_row3_col6 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_14db2_row4_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_14db2_row4_col1 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_14db2_row4_col2 {
#   background-color: #e3f4f8;
#   color: #000000;
# }
# #T_14db2_row4_col3 {
#   background-color: #d0ede9;
#   color: #000000;
# }
# #T_14db2_row4_col4 {
#   background-color: #a7ddd1;
#   color: #000000;
# }
# #T_14db2_row4_col5 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_14db2_row4_col6 {
#   background-color: #329d5e;
#   color: #f1f1f1;
# }
# #T_14db2_row5_col0 {
#   background-color: #d1eee9;
#   color: #000000;
# }
# #T_14db2_row5_col1 {
#   background-color: #87d0bc;
#   color: #000000;
# }
# #T_14db2_row5_col2 {
#   background-color: #29924f;
#   color: #f1f1f1;
# }
# #T_14db2_row5_col3 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_14db2_row5_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_14db2_row5_col5 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_14db2_row5_col6 {
#   background-color: #5abb95;
#   color: #f1f1f1;
# }
# #T_14db2_row6_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_14db2_row6_col1 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_14db2_row6_col2 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_14db2_row6_col3 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_14db2_row6_col4 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_14db2_row6_col5 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_14db2_row6_col6 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_14db2_row7_col0 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_14db2_row7_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_14db2_row7_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_14db2_row7_col3 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_14db2_row7_col4 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_14db2_row7_col5 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_14db2_row7_col6 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_14db2_row8_col0 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_14db2_row8_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_14db2_row8_col2 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_14db2_row8_col3 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_14db2_row8_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_14db2_row8_col5 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_14db2_row8_col6 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# </style>
# <table id="T_14db2">
#   <caption>Turn Barrel Event Outcomes (Out of Position) - Value Profile</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_14db2_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_14db2_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_14db2_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_14db2_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_14db2_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_14db2_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_14db2_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14db2_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_14db2_row0_col0" class="data row0 col0" >91</td>
#       <td id="T_14db2_row0_col1" class="data row0 col1" >186</td>
#       <td id="T_14db2_row0_col2" class="data row0 col2" >405</td>
#       <td id="T_14db2_row0_col3" class="data row0 col3" >378</td>
#       <td id="T_14db2_row0_col4" class="data row0 col4" >176</td>
#       <td id="T_14db2_row0_col5" class="data row0 col5" >17</td>
#       <td id="T_14db2_row0_col6" class="data row0 col6" >28</td>
#     </tr>
#     <tr>
#       <th id="T_14db2_level0_row1" class="row_heading level0 row1" >Continue%</th>
#       <td id="T_14db2_row1_col0" class="data row1 col0" >94.5%</td>
#       <td id="T_14db2_row1_col1" class="data row1 col1" >76.3%</td>
#       <td id="T_14db2_row1_col2" class="data row1 col2" >76.3%</td>
#       <td id="T_14db2_row1_col3" class="data row1 col3" >60.1%</td>
#       <td id="T_14db2_row1_col4" class="data row1 col4" >64.2%</td>
#       <td id="T_14db2_row1_col5" class="data row1 col5" >35.3%</td>
#       <td id="T_14db2_row1_col6" class="data row1 col6" >25.0%</td>
#     </tr>
#     <tr>
#       <th id="T_14db2_level0_row2" class="row_heading level0 row2" >Call-Only%</th>
#       <td id="T_14db2_row2_col0" class="data row2 col0" >62.6%</td>
#       <td id="T_14db2_row2_col1" class="data row2 col1" >58.6%</td>
#       <td id="T_14db2_row2_col2" class="data row2 col2" >60.2%</td>
#       <td id="T_14db2_row2_col3" class="data row2 col3" >46.3%</td>
#       <td id="T_14db2_row2_col4" class="data row2 col4" >42.6%</td>
#       <td id="T_14db2_row2_col5" class="data row2 col5" >23.5%</td>
#       <td id="T_14db2_row2_col6" class="data row2 col6" >14.3%</td>
#     </tr>
#     <tr>
#       <th id="T_14db2_level0_row3" class="row_heading level0 row3" >Raise%</th>
#       <td id="T_14db2_row3_col0" class="data row3 col0" >31.9%</td>
#       <td id="T_14db2_row3_col1" class="data row3 col1" >17.7%</td>
#       <td id="T_14db2_row3_col2" class="data row3 col2" >16.0%</td>
#       <td id="T_14db2_row3_col3" class="data row3 col3" >13.8%</td>
#       <td id="T_14db2_row3_col4" class="data row3 col4" >21.6%</td>
#       <td id="T_14db2_row3_col5" class="data row3 col5" >11.8%</td>
#       <td id="T_14db2_row3_col6" class="data row3 col6" >10.7%</td>
#     </tr>
#     <tr>
#       <th id="T_14db2_level0_row4" class="row_heading level0 row4" >Avg Size (Pot%)</th>
#       <td id="T_14db2_row4_col0" class="data row4 col0" >17.9%</td>
#       <td id="T_14db2_row4_col1" class="data row4 col1" >31.5%</td>
#       <td id="T_14db2_row4_col2" class="data row4 col2" >48.0%</td>
#       <td id="T_14db2_row4_col3" class="data row4 col3" >69.1%</td>
#       <td id="T_14db2_row4_col4" class="data row4 col4" >93.3%</td>
#       <td id="T_14db2_row4_col5" class="data row4 col5" >112.8%</td>
#       <td id="T_14db2_row4_col6" class="data row4 col6" >169.7%</td>
#     </tr>
#     <tr>
#       <th id="T_14db2_level0_row5" class="row_heading level0 row5" >Avg Raise Size (Pot%)</th>
#       <td id="T_14db2_row5_col0" class="data row5 col0" >68.1%</td>
#       <td id="T_14db2_row5_col1" class="data row5 col1" >110.6%</td>
#       <td id="T_14db2_row5_col2" class="data row5 col2" >178.1%</td>
#       <td id="T_14db2_row5_col3" class="data row5 col3" >201.5%</td>
#       <td id="T_14db2_row5_col4" class="data
# <style type="text/css">
# #T_766ec_row1_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_766ec_row1_col1 {
#   background-color: #fed673;
#   color: #000000;
# }
# #T_766ec_row1_col2 {
#   background-color: #fed572;
#   color: #000000;
# }
# #T_766ec_row1_col3 {
#   background-color: #fd8f3d;
#   color: #f1f1f1;
# }
# #T_766ec_row1_col4 {
#   background-color: #fea044;
#   color: #000000;
# }
# #T_766ec_row1_col5 {
#   background-color: #c30424;
#   color: #f1f1f1;
# }
# #T_766ec_row1_col6 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_766ec_row2_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_766ec_row2_col1 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_766ec_row2_col2 {
#   background-color: #d7f0ee;
#   color: #000000;
# }
# #T_766ec_row2_col3 {
#   background-color: #a8ded2;
#   color: #000000;
# }
# #T_766ec_row2_col4 {
#   background-color: #67c2a5;
#   color: #000000;
# }
# #T_766ec_row2_col5 {
#   background-color: #40ad75;
#   color: #f1f1f1;
# }
# #T_766ec_row2_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_766ec_row4_col0 {
#   background-color: #ce6161;
#   color: #f1f1f1;
# }
# #T_766ec_row4_col1 {
#   background-color: #fefbfb;
#   color: #000000;
# }
# #T_766ec_row4_col2 {
#   background-color: #d37070;
#   color: #f1f1f1;
# }
# #T_766ec_row4_col3 {
#   background-color: #faf0f0;
#   color: #000000;
# }
# #T_766ec_row4_col4 {
#   background-color: #c03131;
#   color: #f1f1f1;
# }
# #T_766ec_row4_col5 {
#   background-color: #369258;
#   color: #f1f1f1;
# }
# #T_766ec_row4_col6 {
#   background-color: #15803d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_766ec">
#   <caption>Turn Barrel Event Outcomes (Out of Position) - Fold Pressure</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_766ec_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_766ec_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_766ec_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_766ec_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_766ec_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_766ec_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_766ec_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_766ec_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_766ec_row0_col0" class="data row0 col0" >91</td>
#       <td id="T_766ec_row0_col1" class="data row0 col1" >186</td>
#       <td id="T_766ec_row0_col2" class="data row0 col2" >405</td>
#       <td id="T_766ec_row0_col3" class="data row0 col3" >378</td>
#       <td id="T_766ec_row0_col4" class="data row0 col4" >176</td>
#       <td id="T_766ec_row0_col5" class="data row0 col5" >17</td>
#       <td id="T_766ec_row0_col6" class="data row0 col6" >28</td>
#     </tr>
#     <tr>
#       <th id="T_766ec_level0_row1" class="row_heading level0 row1" >Fold%</th>
#       <td id="T_766ec_row1_col0" class="data row1 col0" >5.5%</td>
#       <td id="T_766ec_row1_col1" class="data row1 col1" >23.7%</td>
#       <td id="T_766ec_row1_col2" class="data row1 col2" >23.7%</td>
#       <td id="T_766ec_row1_col3" class="data row1 col3" >39.9%</td>
#       <td id="T_766ec_row1_col4" class="data row1 col4" >35.8%</td>
#       <td id="T_766ec_row1_col5" class="data row1 col5" >64.7%</td>
#       <td id="T_766ec_row1_col6" class="data row1 col6" >75.0%</td>
#     </tr>
#     <tr>
#       <th id="T_766ec_level0_row2" class="row_heading level0 row2" >Avg Size (Pot%)</th>
#       <td id="T_766ec_row2_col0" class="data row2 col0" >17.9%</td>
#       <td id="T_766ec_row2_col1" class="data row2 col1" >31.5%</td>
#       <td id="T_766ec_row2_col2" class="data row2 col2" >48.0%</td>
#       <td id="T_766ec_row2_col3" class="data row2 col3" >69.1%</td>
#       <td id="T_766ec_row2_col4" class="data row2 col4" >93.3%</td>
#       <td id="T_766ec_row2_col5" class="data row2 col5" >112.8%</td>
#       <td id="T_766ec_row2_col6" class="data row2 col6" >169.7%</td>
#     </tr>
#     <tr>
#       <th id="T_766ec_level0_row3" class="row_heading level0 row3" >Breakeven Fold%</th>
#       <td id="T_766ec_row3_col0" class="data row3 col0" >15.0%</td>
#       <td id="T_766ec_row3_col1" class="data row3 col1" >23.9%</td>
#       <td id="T_766ec_row3_col2" class="data row3 col2" >32.4%</td>
#       <td id="T_766ec_row3_col3" class="data row3 col3" >40.8%</td>
#       <td id="T_766ec_row3_col4" class="data row3 col4" >48.2%</td>
#       <td id="T_766ec_row3_col5" class="data row3 col5" >52.9%</td>
#       <td id="T_766ec_row3_col6" class="data row3 col6" >61.2%</td>
#     </tr>
#     <tr>
#       <th id="T_766ec_level0_row4" class="row_heading level0 row4" >Fold Surplus</th>
#       <td id="T_766ec_row4_col0" class="data row4 col0" >-9.5%</td>
#       <td id="T_766ec_row4_col1" class="data row4 col1" >-0.2%</td>
#       <td id="T_766ec_row4_col2" class="data row4 col2" >-8.7%</td>
#       <td id="T_766ec_row4_col3" class="data row4 col3" >-0.9%</td>
#       <td id="T_766ec_row4_col4" class="data row4 col4" >-12.4%</td>
#       <td id="T_766ec_row4_col5" class="data row4 col5" >11.8%</td>
#       <td id="T_766ec_row4_col6" class="data row4 col6" >13.8%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_fc33e_row1_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_fc33e_row1_col1 {
#   background-color: #aa0026;
#   color: #f1f1f1;
# }
# #T_fc33e_row1_col2 {
#   background-color: #e31a1c;
#   color: #f1f1f1;
# }
# #T_fc33e_row1_col3 {
#   background-color: #f23924;
#   color: #f1f1f1;
# }
# #T_fc33e_row1_col4 {
#   background-color: #fd7034;
#   color: #f1f1f1;
# }
# #T_fc33e_row1_col5, #T_fc33e_row1_col6 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_fc33e_row2_col0 {
#   background-color: #d7121f;
#   color: #f1f1f1;
# }
# #T_fc33e_row2_col1 {
#   background-color: #e61f1d;
#   color: #f1f1f1;
# }
# #T_fc33e_row2_col2 {
#   background-color: #f94828;
#   color: #f1f1f1;
# }
# #T_fc33e_row2_col3 {
#   background-color: #fc5b2e;
#   color: #f1f1f1;
# }
# #T_fc33e_row2_col4 {
#   background-color: #fd923e;
#   color: #000000;
# }
# #T_fc33e_row2_col5 {
#   background-color: #feb24c;
#   color: #000000;
# }
# #T_fc33e_row2_col6 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_fc33e_row3_col0 {
#   background-color: #ffe590;
#   color: #000000;
# }
# #T_fc33e_row3_col1 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_fc33e_row3_col2 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_fc33e_row3_col3 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_fc33e_row3_col4 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_fc33e_row3_col5 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_fc33e_row3_col6 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_fc33e_row4_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_fc33e_row4_col1 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_fc33e_row4_col2 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_fc33e_row4_col3 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_fc33e_row4_col4 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_fc33e_row4_col5 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_fc33e_row4_col6 {
#   background-color: #ddf2f3;
#   color: #000000;
# }
# #T_fc33e_row5_col0 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_fc33e_row5_col1 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_fc33e_row5_col2 {
#   background-color: #def2f4;
#   color: #000000;
# }
# #T_fc33e_row5_col3 {
#   background-color: #cdece6;
#   color: #000000;
# }
# #T_fc33e_row5_col4 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_fc33e_row5_col5 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_fc33e_row5_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_fc33e_row6_col0, #T_fc33e_row7_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_fc33e_row6_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_fc33e_row6_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_fc33e_row6_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_fc33e_row6_col4 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_fc33e_row6_col5 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_fc33e_row6_col6 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_fc33e_row7_col1, #T_fc33e_row7_col2 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_fc33e_row7_col3 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_fc33e_row7_col4 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_fc33e_row7_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_fc33e_row7_col6 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_fc33e_row8_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_fc33e_row8_col1 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_fc33e_row8_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_fc33e_row8_col3 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_fc33e_row8_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_fc33e_row8_col5 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_fc33e_row8_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fc33e">
#   <caption>Turn Delayed C-Bet Event Outcomes (Overall) - Value Profile</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_fc33e_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_fc33e_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_fc33e_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_fc33e_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_fc33e_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_fc33e_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_fc33e_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc33e_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_fc33e_row0_col0" class="data row0 col0" >54</td>
#       <td id="T_fc33e_row0_col1" class="data row0 col1" >407</td>
#       <td id="T_fc33e_row0_col2" class="data row0 col2" >829</td>
#       <td id="T_fc33e_row0_col3" class="data row0 col3" >633</td>
#       <td id="T_fc33e_row0_col4" class="data row0 col4" >406</td>
#       <td id="T_fc33e_row0_col5" class="data row0 col5" >38</td>
#       <td id="T_fc33e_row0_col6" class="data row0 col6" >82</td>
#     </tr>
#     <tr>
#       <th id="T_fc33e_level0_row1" class="row_heading level0 row1" >Continue%</th>
#       <td id="T_fc33e_row1_col0" class="data row1 col0" >72.2%</td>
#       <td id="T_fc33e_row1_col1" class="data row1 col1" >66.1%</td>
#       <td id="T_fc33e_row1_col2" class="data row1 col2" >54.6%</td>
#       <td id="T_fc33e_row1_col3" class="data row1 col3" >49.6%</td>
#       <td id="T_fc33e_row1_col4" class="data row1 col4" >41.4%</td>
#       <td id="T_fc33e_row1_col5" class="data row1 col5" >31.6%</td>
#       <td id="T_fc33e_row1_col6" class="data row1 col6" >31.7%</td>
#     </tr>
#     <tr>
#       <th id="T_fc33e_level0_row2" class="row_heading level0 row2" >Call-Only%</th>
#       <td id="T_fc33e_row2_col0" class="data row2 col0" >57.4%</td>
#       <td id="T_fc33e_row2_col1" class="data row2 col1" >53.8%</td>
#       <td id="T_fc33e_row2_col2" class="data row2 col2" >47.0%</td>
#       <td id="T_fc33e_row2_col3" class="data row2 col3" >44.2%</td>
#       <td id="T_fc33e_row2_col4" class="data row2 col4" >36.2%</td>
#       <td id="T_fc33e_row2_col5" class="data row2 col5" >28.9%</td>
#       <td id="T_fc33e_row2_col6" class="data row2 col6" >22.0%</td>
#     </tr>
#     <tr>
#       <th id="T_fc33e_level0_row3" class="row_heading level0 row3" >Raise%</th>
#       <td id="T_fc33e_row3_col0" class="data row3 col0" >14.8%</td>
#       <td id="T_fc33e_row3_col1" class="data row3 col1" >12.3%</td>
#       <td id="T_fc33e_row3_col2" class="data row3 col2" >7.6%</td>
#       <td id="T_fc33e_row3_col3" class="data row3 col3" >5.4%</td>
#       <td id="T_fc33e_row3_col4" class="data row3 col4" >5.2%</td>
#       <td id="T_fc33e_row3_col5" class="data row3 col5" >2.6%</td>
#       <td id="T_fc33e_row3_col6" class="data row3 col6" >9.8%</td>
#     </tr>
#     <tr>
#       <th id="T_fc33e_level0_row4" class="row_heading level0 row4" >Avg Size (Pot%)</th>
#       <td id="T_fc33e_row4_col0" class="data row4 col0" >20.1%</td>
#       <td id="T_fc33e_row4_col1" class="data row4 col1" >31.8%</td>
#       <td id="T_fc33e_row4_col2" class="data row4 col2" >47.7%</td>
#       <td id="T_fc33e_row4_col3" class="data row4 col3" >69.6%</td>
#       <td id="T_fc33e_row4_col4" class="data row4 col4" >93.0%</td>
#       <td id="T_fc33e_row4_col5" class="data row4 col5" >108.7%</td>
#       <td id="T_fc33e_row4_col6" class="data row4 col6" >169.4%</td>
#     </tr>
#     <tr>
#       <th id="T_fc33e_level0_row5" class="row_heading level0 row5" >Avg Raise Size (Pot%)</th>
#       <td id="T_fc33e_row5_col0" class="data row5 col0" >80.0%</td>
#       <td id="T_fc33e_row5_col1" class="data row5 col1" >101.9%</td>
#       <td id="T_fc33e_row5_col2" class="data row5 col2" >164.6%</td>
#       <td id="T_fc33e_row5_col3" class="data row5 col3" >241.5%</td>
#       <td id="T_fc33e_row5_col4" class="data row5 col4" >402.5%</td>
#       <td id="T_fc33e_row5_col5" class="data row5 col5" >200.0%</td>
#       <td id
# <style type="text/css">
# #T_a65e4_row1_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_a65e4_row1_col1 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_a65e4_row1_col2 {
#   background-color: #fea145;
#   color: #000000;
# }
# #T_a65e4_row1_col3 {
#   background-color: #fd7034;
#   color: #f1f1f1;
# }
# #T_a65e4_row1_col4 {
#   background-color: #e0181d;
#   color: #f1f1f1;
# }
# ...
#       <td id="T_27ad8_row0_col1" class="data row0 col1" >169</td>
#       <td id="T_27ad8_row0_col2" class="data row0 col2" >340</td>
#       <td id="T_27ad8_row0_col3" class="data row0 col3" >267</td>
#       <td id="T_27ad8_row0_col4" class="data row0 col4" >176</td>
#       <td id="T_27ad8_row0_col5" class="data row0 col5" >24</td>
#       <td id="T_27ad8_row0_col6" class="data row0 col6" >43</td>
#     </tr>
#     <tr>
#       <th id="T_27ad8_level0_row1" class="row_heading level0 row1" >Fold%</th>
#       <td id="T_27ad8_row1_col0" class="data row1 col0" >40.0%</td>
#       <td id="T_27ad8_row1_col1" class="data row1 col1" >32.0%</td>
#       <td id="T_27ad8_row1_col2" class="data row1 col2" >48.2%</td>
#       <td id="T_27ad8_row1_col3" class="data row1 col3" >58.4%</td>
#       <td id="T_27ad8_row1_col4" class="data row1 col4" >65.3%</td>
#       <td id="T_27ad8_row1_col5" class="data row1 col5" >75.0%</td>
#       <td id="T_27ad8_row1_col6" class="data row1 col6" >74.4%</td>
#     </tr>
#     <tr>
#       <th id="T_27ad8_level0_row2" class="row_heading level0 row2" >Avg Size (Pot%)</th>
#       <td id="T_27ad8_row2_col0" class="data row2 col0" >18.9%</td>
#       <td id="T_27ad8_row2_col1" class="data row2 col1" >32.0%</td>
#       <td id="T_27ad8_row2_col2" class="data row2 col2" >47.7%</td>
#       <td id="T_27ad8_row2_col3" class="data row2 col3" >69.7%</td>
#       <td id="T_27ad8_row2_col4" class="data row2 col4" >94.1%</td>
#       <td id="T_27ad8_row2_col5" class="data row2 col5" >110.4%</td>
#       <td id="T_27ad8_row2_col6" class="data row2 col6" >165.9%</td>
#     </tr>
#     <tr>
#       <th id="T_27ad8_level0_row3" class="row_heading level0 row3" >Breakeven Fold%</th>
#       <td id="T_27ad8_row3_col0" class="data row3 col0" >15.7%</td>
#       <td id="T_27ad8_row3_col1" class="data row3 col1" >24.2%</td>
#       <td id="T_27ad8_row3_col2" class="data row3 col2" >32.2%</td>
#       <td id="T_27ad8_row3_col3" class="data row3 col3" >41.0%</td>
#       <td id="T_27ad8_row3_col4" class="data row3 col4" >48.4%</td>
#       <td id="T_27ad8_row3_col5" class="data row3 col5" >52.4%</td>
#       <td id="T_27ad8_row3_col6" class="data row3 col6" >61.5%</td>
#     </tr>
#     <tr>
#       <th id="T_27ad8_level0_row4" class="row_heading level0 row4" >Fold Surplus</th>
#       <td id="T_27ad8_row4_col0" class="data row4 col0" >24.3%</td>
#       <td id="T_27ad8_row4_col1" class="data row4 col1" >7.8%</td>
#       <td id="T_27ad8_row4_col2" class="data row4 col2" >16.0%</td>
#       <td id="T_27ad8_row4_col3" class="data row4 col3" >17.4%</td>
#       <td id="T_27ad8_row4_col4" class="data row4 col4" >16.9%</td>
#       <td id="T_27ad8_row4_col5" class="data row4 col5" >22.6%</td>
#       <td id="T_27ad8_row4_col6" class="data row4 col6" >12.9%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_767d9_row1_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_767d9_row1_col1, #T_767d9_row2_col0 {
#   background-color: #d51020;
#   color: #f1f1f1;
# }
# #T_767d9_row1_col2 {
#   background-color: #f03523;
#   color: #f1f1f1;
# }
# #T_767d9_row1_col3 {
#   background-color: #f33b25;
#   color: #f1f1f1;
# }
# #T_767d9_row1_col4 {
#   background-color: #fd7636;
#   color: #f1f1f1;
# }
# #T_767d9_row1_col5 {
#   background-color: #fd8f3d;
#   color: #f1f1f1;
# }
# #T_767d9_row1_col6 {
#   background-color: #fea145;
#   color: #000000;
# }
# #T_767d9_row2_col1 {
#   background-color: #fc532b;
#   color: #f1f1f1;
# }
# #T_767d9_row2_col2 {
#   background-color: #fc6c33;
#   color: #f1f1f1;
# }
# #T_767d9_row2_col3 {
#   background-color: #fc6a32;
#   color: #f1f1f1;
# }
# #T_767d9_row2_col4 {
#   background-color: #fd9e43;
#   color: #000000;
# }
# #T_767d9_row2_col5 {
#   background-color: #feac49;
#   color: #000000;
# }
# #T_767d9_row2_col6 {
#   background-color: #ffe48c;
#   color: #000000;
# }
# #T_767d9_row3_col0 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_767d9_row3_col1 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_767d9_row3_col2 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_767d9_row3_col3, #T_767d9_row3_col4, #T_767d9_row3_col5 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_767d9_row3_col6 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_767d9_row4_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_767d9_row4_col1 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_767d9_row4_col2 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_767d9_row4_col3 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_767d9_row4_col4 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_767d9_row4_col5 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_767d9_row4_col6 {
#   background-color: #def2f4;
#   color: #000000;
# }
# #T_767d9_row5_col0 {
#   background-color: #eef8fb;
#   color: #000000;
# }
# #T_767d9_row5_col1 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_767d9_row5_col2 {
#   background-color: #e1f4f6;
#   color: #000000;
# }
# #T_767d9_row5_col3 {
#   background-color: #ccece6;
#   color: #000000;
# }
# #T_767d9_row5_col4 {
#   background-color: #78cab1;
#   color: #000000;
# }
# #T_767d9_row5_col5 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_767d9_row5_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_767d9_row6_col0, #T_767d9_row7_col1, #T_767d9_row7_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_767d9_row6_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_767d9_row6_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_767d9_row6_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_767d9_row6_col4, #T_767d9_row6_col6 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_767d9_row6_col5 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_767d9_row7_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_767d9_row7_col3 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_767d9_row7_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_767d9_row7_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_767d9_row7_col6 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_767d9_row8_col0 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_767d9_row8_col1 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_767d9_row8_col2 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_767d9_row8_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_767d9_row8_col4 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_767d9_row8_col5 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_767d9_row8_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_767d9">
#   <caption>Turn Delayed C-Bet Event Outcomes (Out of Position) - Value Profile</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_767d9_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_767d9_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_767d9_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_767d9_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_767d9_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_767d9_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_767d9_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_767d9_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_767d9_row0_col0" class="data row0 col0" >34</td>
#       <td id="T_767d9_row0_col1" class="data row0 col1" >238</td>
#       <td id="T_767d9_row0_col2" class="data row0 col2" >489</td>
#       <td id="T_767d9_row0_col3" class="data row0 col3" >366</td>
#       <td id="T_767d9_row0_col4" class="data row0 col4" >230</td>
#       <td id="T_767d9_row0_col5" class="data row0 col5" >14</td>
#       <td id="T_767d9_row0_col6" class="data row0 col6" >39</td>
#     </tr>
#     <tr>
#       <th id="T_767d9_level0_row1" class="row_heading level0 row1" >Continue%</th>
#       <td id="T_767d9_row1_col0" class="data row1 col0" >79.4%</td>
#       <td id="T_767d9_row1_col1" class="data row1 col1" >64.7%</td>
#       <td id="T_767d9_row1_col2" class="data row1 col2" >56.6%</td>
#       <td id="T_767d9_row1_col3" class="data row1 col3" >55.5%</td>
#       <td id="T_767d9_row1_col4" class="data row1 col4" >46.5%</td>
#       <td id="T_767d9_row1_col5" class="data row1 col5" >42.9%</td>
#       <td id="T_767d9_row1_col6" class="data row1 col6" >38.5%</td>
#     </tr>
#     <tr>
#       <th id="T_767d9_level0_row2" class="row_heading level0 row2" >Call-Only%</th>
#       <td id="T_767d9_row2_col0" class="data row2 col0" >64.7%</td>
#       <td id="T_767d9_row2_col1" class="data row2 col1" >51.7%</td>
#       <td id="T_767d9_row2_col2" class="data row2 col2" >47.9%</td>
#       <td id="T_767d9_row2_col3" class="data row2 col3" >48.1%</td>
#       <td id="T_767d9_row2_col4" class="data row2 col4" >39.1%</td>
#       <td id="T_767d9_row2_col5" class="data row2 col5" >35.7%</td>
#       <td id="T_767d9_row2_col6" class="data row2 col6" >20.5%</td>
#     </tr>
#     <tr>
#       <th id="T_767d9_level0_row3" class="row_heading level0 row3" >Raise%</th>
#       <td id="T_767d9_row3_col0" class="data row3 col0" >14.7%</td>
#       <td id="T_767d9_row3_col1" class="data row3 col1" >13.0%</td>
#       <td id="T_767d9_row3_col2" class="data row3 col2" >8.8%</td>
#       <td id="T_767d9_row3_col3" class="data row3 col3" >7.4%</td>
#       <td id="T_767d9_row3_col4" class="data row3 col4" >7.4%</td>
#       <td id="T_767d9_row3_col5" class="data row3 col5" >7.1%</td>
#       <td id="T_767d9_row3_col6" class="data row3 col6" >17.9%</td>
#     </tr>
#     <tr>
#       <th id="T_767d9_level0_row4" class="row_heading level0 row4" >Avg Size (Pot%)</th>
#       <td id="T_767d9_row4_col0" class="data row4 col0" >20.8%</td>
#       <td id="T_767d9_row4_col1" class="data row4 col1" >31.6%</td>
#       <td id="T_767d9_row4_col2" class="data row4 col2" >47.7%</td>
#       <td id="T_767d9_row4_col3" class="data row4 col3" >69.6%</td>
#       <td id="T_767d9_row4_col4" class="data row4 col4" >92.3%</td>
#       <td id="T_767d9_row4_col5" class="data row4 col5" >105.6%</td>
#       <td id="T_767d9_row4_col6" class="data row4 col6" >173.2%</td>
#     </tr>
#     <tr>
#       <th id="T_767d9_level0_row5" class="row_heading level0 row5" >Avg Raise Size (Pot%)</th>
#       <td id="T_767d9_row5_col0" class="data row5 col0" >79.6%</td>
#       <td id="T_767d9_row5_col1" class="data row5 col1" >103.9%</td>
#       <td id="T_767d9_row5_col2" class="data row5 col2" >158.8%</td>
#       <td id="T_767d9_row5_col3" class="data row5 col3" >256.3%</td>
#       <td id="T_767d9_row5_col4" class="data row5 col4" >447.4%</td>
#       <td id="T_767d9_row5_col5" class="data row5 col5" >200.0%</td>
#       <td id="T_767d9_row5_col6" class="data row5 col6" >956.9%</td>
#     </tr>
#     <tr>
#       <th id="T_767d9_level0_row6" class="row_heading level0 row6
# <style type="text/css">
# #T_84fe4_row1_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_84fe4_row1_col1 {
#   background-color: #feb852;
#   color: #000000;
# }
# #T_84fe4_row1_col2 {
#   background-color: #fd7034;
#   color: #f1f1f1;
# }
# #T_84fe4_row1_col3 {
#   background-color: #fc6330;
#   color: #f1f1f1;
# }
# #T_84fe4_row1_col4 {
#   background-color: #d30f20;
#   color: #f1f1f1;
# }
# #T_84fe4_row1_col5 {
#   background-color: #b40026;
#   color: #f1f1f1;
# }
# #T_84fe4_row1_col6 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_84fe4_row2_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_84fe4_row2_col1 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_84fe4_row2_col2 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_84fe4_row2_col3 {
#   background-color: #b0e1d6;
#   color: #000000;
# }
# #T_84fe4_row2_col4 {
#   background-color: #72c7ad;
#   color: #000000;
# }
# #T_84fe4_row2_col5 {
#   background-color: #55b98f;
#   color: #f1f1f1;
# }
# #T_84fe4_row2_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_84fe4_row4_col0 {
#   background-color: #b7d8c3;
#   color: #000000;
# }
# #T_84fe4_row4_col1 {
#   background-color: #15803d;
#   color: #f1f1f1;
# }
# #T_84fe4_row4_col2 {
#   background-color: #198240;
#   color: #f1f1f1;
# }
# #T_84fe4_row4_col3 {
#   background-color: #b5d7c1;
#   color: #000000;
# }
# #T_84fe4_row4_col4 {
#   background-color: #8cc1a0;
#   color: #000000;
# }
# #T_84fe4_row4_col5 {
#   background-color: #85bd9a;
#   color: #000000;
# }
# #T_84fe4_row4_col6 {
#   background-color: #fdf7f7;
#   color: #000000;
# }
# </style>
# <table id="T_84fe4">
#   <caption>Turn Delayed C-Bet Event Outcomes (Out of Position) - Fold Pressure</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th id="T_84fe4_level0_col0" class="col_heading level0 col0" >[0.00, 0.25)</th>
#       <th id="T_84fe4_level0_col1" class="col_heading level0 col1" >[0.25, 0.40)</th>
#       <th id="T_84fe4_level0_col2" class="col_heading level0 col2" >[0.40, 0.60)</th>
#       <th id="T_84fe4_level0_col3" class="col_heading level0 col3" >[0.60, 0.80)</th>
#       <th id="T_84fe4_level0_col4" class="col_heading level0 col4" >[0.80, 1.00)</th>
#       <th id="T_84fe4_level0_col5" class="col_heading level0 col5" >[1.00, 1.25)</th>
#       <th id="T_84fe4_level0_col6" class="col_heading level0 col6" >>=1.25</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84fe4_level0_row0" class="row_heading level0 row0" >Events</th>
#       <td id="T_84fe4_row0_col0" class="data row0 col0" >34</td>
#       <td id="T_84fe4_row0_col1" class="data row0 col1" >238</td>
#       <td id="T_84fe4_row0_col2" class="data row0 col2" >489</td>
#       <td id="T_84fe4_row0_col3" class="data row0 col3" >366</td>
#       <td id="T_84fe4_row0_col4" class="data row0 col4" >230</td>
#       <td id="T_84fe4_row0_col5" class="data row0 col5" >14</td>
#       <td id="T_84fe4_row0_col6" class="data row0 col6" >39</td>
#     </tr>
#     <tr>
#       <th id="T_84fe4_level0_row1" class="row_heading level0 row1" >Fold%</th>
#       <td id="T_84fe4_row1_col0" class="data row1 col0" >20.6%</td>
#       <td id="T_84fe4_row1_col1" class="data row1 col1" >35.3%</td>
#       <td id="T_84fe4_row1_col2" class="data row1 col2" >43.4%</td>
#       <td id="T_84fe4_row1_col3" class="data row1 col3" >44.5%</td>
#       <td id="T_84fe4_row1_col4" class="data row1 col4" >53.5%</td>
#       <td id="T_84fe4_row1_col5" class="data row1 col5" >57.1%</td>
#       <td id="T_84fe4_row1_col6" class="data row1 col6" >61.5%</td>
#     </tr>
#     <tr>
#       <th id="T_84fe4_level0_row2" class="row_heading level0 row2" >Avg Size (Pot%)</th>
#       <td id="T_84fe4_row2_col0" class="data row2 col0" >20.8%</td>
#       <td id="T_84fe4_row2_col1" class="data row2 col1" >31.6%</td>
#       <td id="T_84fe4_row2_col2" class="data row2 col2" >47.7%</td>
#       <td id="T_84fe4_row2_col3" class="data row2 col3" >69.6%</td>
#       <td id="T_84fe4_row2_col4" class="data row2 col4" >92.3%</td>
#       <td id="T_84fe4_row2_col5" class="data row2 col5" >105.6%</td>
#       <td id="T_84fe4_row2_col6" class="data row2 col6" >173.2%</td>
#     </tr>
#     <tr>
#       <th id="T_84fe4_level0_row3" class="row_heading level0 row3" >Breakeven Fold%</th>
#       <td id="T_84fe4_row3_col0" class="data row3 col0" >17.1%</td>
#       <td id="T_84fe4_row3_col1" class="data row3 col1" >24.0%</td>
#       <td id="T_84fe4_row3_col2" class="data row3 col2" >32.3%</td>
#       <td id="T_84fe4_row3_col3" class="data row3 col3" >41.0%</td>
#       <td id="T_84fe4_row3_col4" class="data row3 col4" >47.9%</td>
#       <td id="T_84fe4_row3_col5" class="data row3 col5" >51.3%</td>
#       <td id="T_84fe4_row3_col6" class="data row3 col6" >61.9%</td>
#     </tr>
#     <tr>
#       <th id="T_84fe4_level0_row4" class="row_heading level0 row4" >Fold Surplus</th>
#       <td id="T_84fe4_row4_col0" class="data row4 col0" >3.5%</td>
#       <td id="T_84fe4_row4_col1" class="data row4 col1" >11.3%</td>
#       <td id="T_84fe4_row4_col2" class="data row4 col2" >11.1%</td>
#       <td id="T_84fe4_row4_col3" class="data row4 col3" >3.5%</td>
#       <td id="T_84fe4_row4_col4" class="data row4 col4" >5.5%</td>
#       <td id="T_84fe4_row4_col5" class="data row4 col5" >5.9%</td>
#       <td id="T_84fe4_row4_col6" class="data row4 col6" >-0.4%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Turn Nuts and Near-Nuts: First-Bet Tendencies
#
# Evaluate how often players lead the turn when holding trips or better.

# %%
TURN_FIRST_ACTIONS_CACHE = PROJECT_ROOT / 'analysis' / 'cache' / 'turn_first_actions.json'
turn_first_action_records = load_turn_first_actions(
    DB_PATH, cache_path=TURN_FIRST_ACTIONS_CACHE, force=FORCE_RELOAD
)
turn_first_actions_df = pd.DataFrame(turn_first_action_records)

if turn_first_actions_df.empty:
    print('No turn first-action opportunities available.')
else:
    strong_categories = ['Trips/Set', 'Straight', 'Flush', 'Full House', 'Quads']
    strong_df = turn_first_actions_df[turn_first_actions_df['primary'].isin(strong_categories)].copy()
    if strong_df.empty:
        print('No turn opportunities with trips or better available.')
    else:
        position_order = ['Out of Position', 'In Position']
        strong_df['position'] = np.where(strong_df['in_position'], 'In Position', 'Out of Position')
        summary = (
            strong_df.groupby('position', sort=False)
            .agg(Opportunities=('bet_flag', 'count'), Bets=('bet_flag', 'sum'))
            .reindex(position_order)
        )
        summary['Bets'] = summary['Bets'].fillna(0.0)
        summary['Opportunities'] = summary['Opportunities'].fillna(0.0)
        summary['Bet %'] = np.where(
            summary['Opportunities'] > 0,
            summary['Bets'] / summary['Opportunities'] * 100,
            0.0,
        )
        summary = summary[['Opportunities', 'Bets', 'Bet %']]
        summary_styled = (
            summary.style
            .format({'Opportunities': '{:.0f}', 'Bets': '{:.0f}', 'Bet %': '{:.1f}%'})
            .set_caption('Turn First-Bet Frequency with Trips or Better')
        )
        display(summary_styled)

        bet_df = strong_df[strong_df['bet_flag']].copy()
        if bet_df.empty:
            print('No qualifying bets to bucket.')
        else:
            bucket_edges = [bucket[0] for bucket in TURN_BUCKETS] + [TURN_BUCKETS[-1][1]]
            bucket_labels = [bucket[2] for bucket in TURN_BUCKETS]
            bet_df['bucket'] = pd.cut(
                pd.to_numeric(bet_df['ratio'], errors='coerce'),
                bins=bucket_edges,
                labels=bucket_labels,
                right=False,
                include_lowest=True,
            )
            bucket_counts = (
                bet_df.groupby(['bucket', 'position'], observed=False)
                .size()
                .unstack('position', fill_value=0.0)
                .reindex(bucket_labels, fill_value=0.0)
                .reindex(columns=position_order, fill_value=0.0)
            )
            column_totals = bucket_counts.sum(axis=0).replace(0.0, np.nan)
            bucket_pct = bucket_counts.div(column_totals, axis=1) * 100.0
            bucket_pct = bucket_pct.fillna(0.0)
            bucket_styled = (
                bucket_pct.style
                .format('{:.1f}%')
                .set_caption('Bet Size Distribution (Trips or Better)')
            )
            display(bucket_styled)
# Out:
# <style type="text/css">
# </style>
# <table id="T_48738">
#   <caption>Turn First-Bet Frequency with Trips or Better</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48738_level0_col0" class="col_heading level0 col0" >Opportunities</th>
#       <th id="T_48738_level0_col1" class="col_heading level0 col1" >Bets</th>
#       <th id="T_48738_level0_col2" class="col_heading level0 col2" >Bet %</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48738_level0_row0" class="row_heading level0 row0" >Out of Position</th>
#       <td id="T_48738_row0_col0" class="data row0 col0" >1055</td>
#       <td id="T_48738_row0_col1" class="data row0 col1" >564</td>
#       <td id="T_48738_row0_col2" class="data row0 col2" >53.5%</td>
#     </tr>
#     <tr>
#       <th id="T_48738_level0_row1" class="row_heading level0 row1" >In Position</th>
#       <td id="T_48738_row1_col0" class="data row1 col0" >602</td>
#       <td id="T_48738_row1_col1" class="data row1 col1" >462</td>
#       <td id="T_48738_row1_col2" class="data row1 col2" >76.7%</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_6429/1263857639.py:51: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bet_df.groupby(['bucket', 'position'])
# <style type="text/css">
# </style>
# <table id="T_5510c">
#   <caption>Bet Size Distribution (Trips or Better)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >position</th>
#       <th id="T_5510c_level0_col0" class="col_heading level0 col0" >Out of Position</th>
#       <th id="T_5510c_level0_col1" class="col_heading level0 col1" >In Position</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >bucket</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5510c_level0_row0" class="row_heading level0 row0" >[0.00, 0.25)</th>
#       <td id="T_5510c_row0_col0" class="data row0 col0" >6.6%</td>
#       <td id="T_5510c_row0_col1" class="data row0 col1" >4.8%</td>
#     </tr>
#     <tr>
#       <th id="T_5510c_level0_row1" class="row_heading level0 row1" >[0.25, 0.40)</th>
#       <td id="T_5510c_row1_col0" class="data row1 col0" >15.4%</td>
#       <td id="T_5510c_row1_col1" class="data row1 col1" >12.8%</td>
#     </tr>
#     <tr>
#       <th id="T_5510c_level0_row2" class="row_heading level0 row2" >[0.40, 0.60)</th>
#       <td id="T_5510c_row2_col0" class="data row2 col0" >25.7%</td>
#       <td id="T_5510c_row2_col1" class="data row2 col1" >27.3%</td>
#     </tr>
#     <tr>
#       <th id="T_5510c_level0_row3" class="row_heading level0 row3" >[0.60, 0.80)</th>
#       <td id="T_5510c_row3_col0" class="data row3 col0" >24.6%</td>
#       <td id="T_5510c_row3_col1" class="data row3 col1" >26.8%</td>
#     </tr>
#     <tr>
#       <th id="T_5510c_level0_row4" class="row_heading level0 row4" >[0.80, 1.00)</th>
#       <td id="T_5510c_row4_col0" class="data row4 col0" >19.7%</td>
#       <td id="T_5510c_row4_col1" class="data row4 col1" >17.7%</td>
#     </tr>
#     <tr>
#       <th id="T_5510c_level0_row5" class="row_heading level0 row5" >[1.00, 1.25)</th>
#       <td id="T_5510c_row5_col0" class="data row5 col0" >2.0%</td>
#       <td id="T_5510c_row5_col1" class="data row5 col1" >3.0%</td>
#     </tr>
#     <tr>
#       <th id="T_5510c_level0_row6" class="row_heading level0 row6" >>=1.25</th>
#       <td id="T_5510c_row6_col0" class="data row6 col0" >6.0%</td>
#       <td id="T_5510c_row6_col1" class="data row6 col1" >7.6%</td>
#     </tr>
#   </tbody>
# </table>
