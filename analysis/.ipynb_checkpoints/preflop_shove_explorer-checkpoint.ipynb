# %% [markdown]
# # Preflop Shove Explorer
#
# Investigate preflop all-in ranges by action depth (open shoves, 3-bet shoves, and deeper).

# %%
from pathlib import Path
import os

def _locate_project_root() -> Path:
    current = Path().resolve()
    for candidate in (current, *current.parents):
        if (candidate / 'AGENTS.md').exists():
            return candidate
    raise FileNotFoundError('Repository root not found from notebook location.')

PROJECT_ROOT = _locate_project_root()
del _locate_project_root

# %%
import sys
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

DB_CANDIDATES = [
    Path(r'T:\Dev\ignition\drivehud\drivehud.db'),
    Path('/mnt/t/Dev/ignition/drivehud/drivehud.db'),
    PROJECT_ROOT / 'drivehud' / 'drivehud.db',
]

for candidate in DB_CANDIDATES:
    if candidate.exists():
        DB_PATH = candidate
        break
else:
    checked = os.linesep.join(str(p) for p in DB_CANDIDATES)
    message = 'Database not found. Checked:' + os.linesep + checked
    raise FileNotFoundError(message)

CACHE_PATH = PROJECT_ROOT / 'analysis' / 'cache' / 'preflop_shove_events.json'
FORCE_RELOAD = False

# %%
import json
import sqlite3
import xml.etree.ElementTree as ET

import numpy as np
import math
import pandas as pd
from IPython.display import display, HTML
from matplotlib.colors import LinearSegmentedColormap, TwoSlopeNorm

from analysis.sqlite_utils import connect_readonly
from analysis.cbet_utils import (
    BET_TYPES,
    RAISE_TYPES,
    parse_cards_text,
    extract_big_blind,
)

# %%
RANKS = ['A', 'K', 'Q', 'J', 'T', '9', '8', '7', '6', '5', '4', '3', '2']
RANK_INDEX = {rank: idx for idx, rank in enumerate(RANKS)}
CATEGORY_LABELS = {
    1: 'First to Bet Shove',
    2: '3-Bet Shove',
    3: '4-Bet Shove',
    4: '5+ Bet Shove',
}
CATEGORY_ORDER = [
    'First to Bet Shove',
    '3-Bet Shove',
    '4-Bet Shove',
    '5+ Bet Shove',
]
BLUE_CMAP = LinearSegmentedColormap.from_list('shove_blue', ['#ffffff', '#1d4ed8'])
HAND_GROUPS_ORDER = [
    'AA',
    'KK',
    'QQ',
    'JJ',
    'TT',
    'Other Pair',
    'AK',
    'ATs - AQs',
    'A2s - A9s',
    'ATo - AQo',
    'A2o - A9o',
    'Other Broadway Pair',
    'Other',
]
SUMMARY2_GROUPS_ORDER = [
    'KK - AA',
    'TT - QQ',
    '22 - 99',
    'AK',
    'Any Other Ace',
    'All Others',
]
BROADWAY_RANKS = {'A', 'K', 'Q', 'J', 'T'}
BROADWAY_COMBOS = {
    frozenset({'K', 'Q'}),
    frozenset({'K', 'J'}),
    frozenset({'K', 'T'}),
    frozenset({'Q', 'J'}),
    frozenset({'Q', 'T'}),
    frozenset({'J', 'T'}),
}

# %%
def _categorise_shove(level: int) -> str | None:
    if level <= 0:
        return None
    if level == 1:
        return CATEGORY_LABELS[1]
    if level == 2:
        return CATEGORY_LABELS[2]
    if level == 3:
        return CATEGORY_LABELS[3]
    return CATEGORY_LABELS[4]


def _is_all_in_action(action) -> bool:
    act_type = action.attrib.get('type')
    if act_type == '7':
        return True
    return action.attrib.get('allin', '').lower() in {'1', 'true', 'yes'}


def load_preflop_shove_events(db_path: Path, cache_path: Path | None = None, force: bool = False):
    if cache_path and cache_path.exists() and not force:
        with cache_path.open('r', encoding='utf-8') as fh:
            cached = json.load(fh)
        if cached:
            return cached

    events: list[dict] = []
    with connect_readonly(db_path) as conn:
        conn.row_factory = sqlite3.Row
        cur = conn.cursor()
        cur.execute('SELECT HandHistoryId, HandNumber, HandHistory FROM HandHistories')
        for row in cur:
            try:
                root = ET.fromstring(row['HandHistory'])
            except ET.ParseError:
                continue

            big_blind = extract_big_blind(root)
            if big_blind is None or big_blind <= 0:
                continue

            pocket_cards: dict[str, list] = {}
            for node in root.findall('.//round[@no="1"]/cards'):
                player = node.attrib.get('player')
                cards = parse_cards_text(node.text)
                if player and len(cards) == 2:
                    pocket_cards[player] = cards
            if not pocket_cards:
                continue

            aggressive_level = 0
            total_pot = 0.0

            preflop_actions = []
            for rnd in root.findall('.//round'):
                if rnd.attrib.get('no') == '1':
                    preflop_actions.extend(rnd.findall('action'))
            if not preflop_actions:
                continue

            for action in preflop_actions:
                player = action.attrib.get('player')
                if not player:
                    continue
                act_type = action.attrib.get('type')
                amount_text = action.attrib.get('sum') or action.attrib.get('bet') or '0'
                try:
                    amount = float(amount_text)
                except ValueError:
                    amount = 0.0

                if amount > 0:
                    total_pot += amount

                if act_type not in BET_TYPES.union(RAISE_TYPES):
                    continue
                if amount <= 0:
                    continue

                aggressive_level += 1
                if not _is_all_in_action(action):
                    continue

                category = _categorise_shove(aggressive_level)
                if category is None:
                    continue
                hero_cards = pocket_cards.get(player)
                if not hero_cards:
                    continue
                hole_cards = ' '.join(card for _, _, card in hero_cards)
                pot_before = total_pot - amount
                events.append({
                    'hand_number': row['HandNumber'],
                    'player': player,
                    'category': category,
                    'aggressive_level': aggressive_level,
                    'hole_cards': hole_cards,
                    'bet_amount': amount,
                    'bet_amount_bb': amount / big_blind if big_blind else None,
                    'pot_before': pot_before,
                    'big_blind': big_blind,
                })

    if cache_path:
        cache_path.parent.mkdir(parents=True, exist_ok=True)
        with cache_path.open('w', encoding='utf-8') as fh:
            json.dump(events, fh, ensure_ascii=False, indent=2)
    return events

# %%
events = load_preflop_shove_events(DB_PATH, cache_path=CACHE_PATH, force=FORCE_RELOAD)
events_df = pd.DataFrame(events)
print(f'Loaded {len(events_df)} preflop shove events with known hole cards.')
if not events_df.empty:
    display(events_df['category'].value_counts().reindex(CATEGORY_ORDER, fill_value=0))
# Out:
# Loaded 762 preflop shove events with known hole cards.
# category
# First to Bet Shove    161
# 3-Bet Shove           201
# 4-Bet Shove           207
# 5+ Bet Shove          193
# Name: count, dtype: int64

# %% [markdown]
# ### Starting Hand Grids
#
# For each shove category, the 13×13 matrix shows the percentage share of
# starting hands (pairs on the diagonal, suited combos upper-right).
# The adjacent summary table aggregates broader hand groups.

# %%
SUIT_SYMBOLS = {'S', 'H', 'D', 'C'}
SUIT_NORMALIZE = {
    'S': 'S', 'H': 'H', 'D': 'D', 'C': 'C',
    's': 'S', 'h': 'H', 'd': 'D', 'c': 'C',
}
RANK_SYMBOLS = set(RANK_INDEX.keys())
SUIT_TO_CHAR = {'S': 's', 'H': 'h', 'D': 'd', 'C': 'c'}


def _parse_card(part: str) -> tuple[str, str] | None:
    part = part.strip()
    if len(part) != 2:
        return None
    first, second = part[0], part[1]
    first_up, second_up = first.upper(), second.upper()
    if first_up in SUIT_SYMBOLS and second_up in RANK_SYMBOLS:
        suit = SUIT_NORMALIZE[first]
        rank = second_up
        return rank, suit
    if second_up in SUIT_SYMBOLS and first_up in RANK_SYMBOLS:
        suit = SUIT_NORMALIZE[second]
        rank = first_up
        return rank, suit
    return None


def _cards_to_grid_position(card_string: str) -> tuple[str, str] | None:
    parts = card_string.split()
    if len(parts) != 2:
        return None
    parsed = [_parse_card(part) for part in parts]
    if any(item is None for item in parsed):
        return None
    ranks, suits = zip(*parsed)
    if ranks[0] == ranks[1]:
        return ranks[0], ranks[0]
    sorted_ranks = sorted(ranks, key=lambda r: RANK_INDEX[r])
    high, low = sorted_ranks[0], sorted_ranks[1]
    suited = suits[0] == suits[1]
    if suited:
        return high, low
    return low, high


def _classify_hand_group(card_string: str) -> tuple[str, str] | None:
    parts = card_string.split()
    if len(parts) != 2:
        return None
    parsed = [_parse_card(part) for part in parts]
    if any(item is None for item in parsed):
        return None
    ranks, suits = zip(*parsed)
    if ranks[0] == ranks[1]:
        rank = ranks[0]
        if rank == 'A':
            return 'AA', 'KK - AA'
        if rank == 'K':
            return 'KK', 'KK - AA'
        if rank == 'Q':
            return 'QQ', 'TT - QQ'
        if rank == 'J':
            return 'JJ', 'TT - QQ'
        if rank == 'T':
            return 'TT', 'TT - QQ'
        if rank in {'9', '8', '7', '6', '5', '4', '3', '2'}:
            return 'Other Pair', '22 - 99'
        if rank in BROADWAY_RANKS:
            return 'Other Broadway Pair', 'All Others'
        return 'Other Pair', 'All Others'
    sorted_ranks = sorted(ranks, key=lambda r: RANK_INDEX[r])
    high, low = sorted_ranks[0], sorted_ranks[1]
    suited = suits[0] == suits[1]
    combo_set = frozenset({high, low})
    if combo_set == frozenset({'A', 'K'}):
        return 'AK', 'AK'
    if 'A' in combo_set:
        other = next(iter(combo_set - {'A'}))
        if suited:
            if other in {'T', 'J', 'Q'}:
                return 'ATs - AQs', 'Any Other Ace'
            if other in {'2', '3', '4', '5', '6', '7', '8', '9'}:
                return 'A2s - A9s', 'Any Other Ace'
        else:
            if other in {'T', 'J', 'Q'}:
                return 'ATo - AQo', 'Any Other Ace'
            if other in {'2', '3', '4', '5', '6', '7', '8', '9'}:
                return 'A2o - A9o', 'Any Other Ace'
    if combo_set in BROADWAY_COMBOS:
        return 'Other Broadway Pair', 'All Others'
    return 'Other', 'All Others'


def build_grid(df: pd.DataFrame) -> tuple[pd.DataFrame, float]:
    grid = pd.DataFrame(0.0, index=RANKS, columns=RANKS)
    total = 0.0
    for value in df.get('hole_cards', []):
        if not isinstance(value, str):
            continue
        position = _cards_to_grid_position(value)
        if position is None:
            continue
        row, col = position
        grid.loc[row, col] += 1
        total += 1
    return grid, total


def build_summary_tables(df: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame, float]:
    counts1 = {group: 0 for group in HAND_GROUPS_ORDER}
    counts2 = {group: 0 for group in SUMMARY2_GROUPS_ORDER}
    total = 0
    for value in df.get('hole_cards', []):
        if not isinstance(value, str):
            continue
        labels = _classify_hand_group(value)
        if labels is None:
            continue
        label1, label2 = labels
        counts1[label1] += 1
        counts2[label2] += 1
        total += 1
    summary1 = pd.DataFrame(
        {
            'Hand Group': HAND_GROUPS_ORDER,
            'Percent': [
                (counts1[group] / total * 100.0) if total else 0.0
                for group in HAND_GROUPS_ORDER
            ],
        }
    )
    summary2 = pd.DataFrame(
        {
            'Hand Group': SUMMARY2_GROUPS_ORDER,
            'Percent': [
                (counts2[group] / total * 100.0) if total else 0.0
                for group in SUMMARY2_GROUPS_ORDER
            ],
        }
    )
    return summary1, summary2, total


def style_grid(grid: pd.DataFrame, title: str, *, fmt: str = '{:.1f}'):
    if grid.values.sum() == 0:
        return None
    styled = (
        grid.style
        .format(fmt)
        .background_gradient(cmap=BLUE_CMAP, axis=None, vmin=0)
        .set_caption(title)
    )
    return styled


def style_summary(summary_df: pd.DataFrame, title: str):
    styled = (
        summary_df.style
        .format({'Percent': '{:.1f}%'})
        .set_caption(title)
        .hide(axis='index')
        .set_properties(subset=['Hand Group'], **{'text-align': 'left'})
        .set_properties(subset=['Percent'], **{'text-align': 'right'})
    )
    return styled


def display_shove_range(category: str, *, max_bb: float | None = None, min_bb: float | None = None, title_suffix: str = ''):
    subset = events_df[events_df['category'] == category]
    if max_bb is not None:
        subset = subset[subset['bet_amount_bb'].fillna(0) <= max_bb]
    if min_bb is not None:
        subset = subset[subset['bet_amount_bb'].fillna(0) > min_bb]
    if subset.empty:
        print(f'No events recorded for {category}{title_suffix}.')
        return
    grid, total = build_grid(subset)
    if total == 0:
        print(f'No hole cards recorded for {category}{title_suffix}.')
        return
    grid_pct = grid / total * 100.0
    grid_title = f"{category}{title_suffix} - {int(total)} events"
    grid_styled = style_grid(grid_pct, grid_title)
    summary1_df, summary2_df, summary_total = build_summary_tables(subset)
    summary1_styled = style_summary(summary1_df, 'Summary')
    summary2_styled = style_summary(summary2_df, 'Summary')
    if grid_styled is None or summary1_styled is None or summary2_styled is None:
        if grid_styled is not None:
            display(grid_styled)
        else:
            print(f'No displayable data for {category}{title_suffix}.')
        return
    grid_html = grid_styled.to_html()
    summary1_html = summary1_styled.to_html()
    summary2_html = summary2_styled.to_html()
    combined_html = (
        "<div style='display:flex; gap:24px; align-items:flex-start;'>"
        f"<div>{grid_html}</div>"
        f"<div>{summary1_html}</div>"
        f"<div>{summary2_html}</div>"
        "</div>"
    )
    display(HTML(combined_html))

# %%
for category in CATEGORY_ORDER:
    if category == 'First to Bet Shove':
        display_shove_range(category, max_bb=30.0, title_suffix=' (≤30 BB)')
        display_shove_range(category, min_bb=30.0, title_suffix=' (>30 BB)')
    else:
        display_shove_range(category)
# Out:
# <div style='display:flex; gap:24px; align-items:flex-start;'><div><style type="text/css">
# #T_ba641_row0_col0, #T_ba641_row0_col4, #T_ba641_row0_col9, #T_ba641_row0_col10, #T_ba641_row1_col0, #T_ba641_row1_col3, #T_ba641_row1_col7, #T_ba641_row2_col1, #T_ba641_row4_col0, #T_ba641_row4_col1, #T_ba641_row4_col4, #T_ba641_row6_col2, #T_ba641_row6_col6, #T_ba641_row8_col7, #T_ba641_row8_col8, #T_ba641_row9_col12, #T_ba641_row11_col0, #T_ba641_row12_col4 {
#   background-color: #a5b8ef;
#   color: #000000;
# }
# #T_ba641_row0_col1, #T_ba641_row0_col2, #T_ba641_row0_col5, #T_ba641_row0_col6, #T_ba641_row0_col7, #T_ba641_row0_col12, #T_ba641_row1_col2, #T_ba641_row1_col6, #T_ba641_row1_col10, #T_ba641_row2_col2, #T_ba641_row2_col3, #T_ba641_row2_col9, #T_ba641_row3_col1, #T_ba641_row3_col4, #T_ba641_row3_col6, #T_ba641_row4_col2, #T_ba641_row4_col3, #T_ba641_row4_col6, #T_ba641_row4_col11, #T_ba641_row5_col1, #T_ba641_row5_col2, #T_ba641_row6_col1, #T_ba641_row6_col5, #T_ba641_row7_col1, #T_ba641_row7_col11, #T_ba641_row8_col0, #T_ba641_row9_col5, #T_ba641_row9_col9, #T_ba641_row10_col0, #T_ba641_row10_col3, #T_ba641_row10_col5, #T_ba641_row10_col7, #T_ba641_row10_col10, #T_ba641_row11_col5, #T_ba641_row11_col6, #T_ba641_row11_col11, #T_ba641_row12_col12 {
#   background-color: #d2dcf7;
#   color: #000000;
# }
# #T_ba641_row0_col3, #T_ba641_row2_col0, #T_ba641_row7_col0, #T_ba641_row12_col0, #T_ba641_row12_col1 {
#   background-color: #7795e8;
#   color: #f1f1f1;
# }
# #T_ba641_row0_col8, #T_ba641_row0_col11, #T_ba641_row1_col1, #T_ba641_row1_col4, #T_ba641_row1_col5, #T_ba641_row1_col8, #T_ba641_row1_col9, #T_ba641_row1_col11, #T_ba641_row1_col12, #T_ba641_row2_col4, #T_ba641_row2_col5, #T_ba641_row2_col6, #T_ba641_row2_col7, #T_ba641_row2_col8, #T_ba641_row2_col10, #T_ba641_row2_col11, #T_ba641_row2_col12, #T_ba641_row3_col2, #T_ba641_row3_col5, #T_ba641_row3_col7, #T_ba641_row3_col8, #T_ba641_row3_col9, #T_ba641_row3_col10, #T_ba641_row3_col11, #T_ba641_row3_col12, #T_ba641_row4_col5, #T_ba641_row4_col7, #T_ba641_row4_col8, #T_ba641_row4_col9, #T_ba641_row4_col10, #T_ba641_row4_col12, #T_ba641_row5_col3, #T_ba641_row5_col4, #T_ba641_row5_col6, #T_ba641_row5_col7, #T_ba641_row5_col8, #T_ba641_row5_col9, #T_ba641_row5_col10, #T_ba641_row5_col11, #T_ba641_row5_col12, #T_ba641_row6_col0, #T_ba641_row6_col3, #T_ba641_row6_col4, #T_ba641_row6_col7, #T_ba641_row6_col8, #T_ba641_row6_col9, #T_ba641_row6_col10, #T_ba641_row6_col11, #T_ba641_row6_col12, #T_ba641_row7_col2, #T_ba641_row7_col3, #T_ba641_row7_col4, #T_ba641_row7_col5, #T_ba641_row7_col6, #T_ba641_row7_col7, #T_ba641_row7_col8, #T_ba641_row7_col9, #T_ba641_row7_col10, #T_ba641_row7_col12, #T_ba641_row8_col1, #T_ba641_row8_col2, #T_ba641_row8_col3, #T_ba641_row8_col4, #T_ba641_row8_col5, #T_ba641_row8_col6, #T_ba641_row8_col9, #T_ba641_row8_col10, #T_ba641_row8_col11, #T_ba641_row8_col12, #T_ba641_row9_col0, #T_ba641_row9_col1, #T_ba641_row9_col2, #T_ba641_row9_col3, #T_ba641_row9_col4, #T_ba641_row9_col6, #T_ba641_row9_col7, #T_ba641_row9_col8, #T_ba641_row9_col10, #T_ba641_row9_col11, #T_ba641_row10_col1, #T_ba641_row10_col2, #T_ba641_row10_col4, #T_ba641_row10_col6, #T_ba641_row10_col8, #T_ba641_row10_col9, #T_ba641_row10_col11, #T_ba641_row10_col12, #T_ba641_row11_col1, #T_ba641_row11_col2, #T_ba641_row11_col3, #T_ba641_row11_col4, #T_ba641_row11_col7, #T_ba641_row11_col8, #T_ba641_row11_col9, #T_ba641_row11_col10, #T_ba641_row11_col12, #T_ba641_row12_col2, #T_ba641_row12_col3, #T_ba641_row12_col5, #T_ba641_row12_col6, #T_ba641_row12_col7, #T_ba641_row12_col8, #T_ba641_row12_col9, #T_ba641_row12_col10, #T_ba641_row12_col11 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_ba641_row3_col0, #T_ba641_row5_col0 {
#   background-color: #1d4ed8;
#   color: #f1f1f1;
# }
# #T_ba641_row3_col3, #T_ba641_row5_col5 {
#   background-color: #4a71e0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ba641">
#   <caption>First to Bet Shove (≤30 BB) - 106 events</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba641_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ba641_level0_col1" class="col_heading level0 col1" >K</th>
#       <th id="T_ba641_level0_col2" class="col_heading level0 col2" >Q</th>
#       <th id="T_ba641_level0_col3" class="col_heading level0 col3" >J</th>
#       <th id="T_ba641_level0_col4" class="col_heading level0 col4" >T</th>
#       <th id="T_ba641_level0_col5" class="col_heading level0 col5" >9</th>
#       <th id="T_ba641_level0_col6" class="col_heading level0 col6" >8</th>
#       <th id="T_ba641_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_ba641_level0_col8" class="col_heading level0 col8" >6</th>
#       <th id="T_ba641_level0_col9" class="col_heading level0 col9" >5</th>
#       <th id="T_ba641_level0_col10" class="col_heading level0 col10" >4</th>
#       <th id="T_ba641_level0_col11" class="col_heading level0 col11" >3</th>
#       <th id="T_ba641_level0_col12" class="col_heading level0 col12" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba641_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_ba641_row0_col0" class="data row0 col0" >1.9</td>
#       <td id="T_ba641_row0_col1" class="data row0 col1" >0.9</td>
#       <td id="T_ba641_row0_col2" class="data row0 col2" >0.9</td>
#       <td id="T_ba641_row0_col3" class="data row0 col3" >2.8</td>
#       <td id="T_ba641_row0_col4" class="data row0 col4" >1.9</td>
#       <td id="T_ba641_row0_col5" class="data row0 col5" >0.9</td>
#       <td id="T_ba641_row0_col6" class="data row0 col6" >0.9</td>
#       <td id="T_ba641_row0_col7" class="data row0 col7" >0.9</td>
#       <td id="T_ba641_row0_col8" class="data row0 col8" >0.0</td>
#       <td id="T_ba641_row0_col9" class="data row0 col9" >1.9</td>
#       <td id="T_ba641_row0_col10" class="data row0 col10" >1.9</td>
#       <td id="T_ba641_row0_col11" class="data row0 col11" >0.0</td>
#       <td id="T_ba641_row0_col12" class="data row0 col12" >0.9</td>
#     </tr>
#     <tr>
#       <th id="T_ba641_level0_row1" class="row_heading level0 row1" >K</th>
#       <td id="T_ba641_row1_col0" class="data row1 col0" >1.9</td>
#       <td id="T_ba641_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_ba641_row1_col2" class="data row1 col2" >0.9</td>
#       <td id="T_ba641_row1_col3" class="data row1 col3" >1.9</td>
#       <td id="T_ba641_row1_col4" class="data row1 col4" >0.0</td>
#       <td id="T_ba641_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_ba641_row1_col6" class="data row1 col6" >0.9</td>
#       <td id="T_ba641_row1_col7" class="data row1 col7" >1.9</td>
#       <td id="T_ba641_row1_col8" class="data row1 col8" >0.0</td>
#       <td id="T_ba641_row1_col9" class="data row1 col9" >0.0</td>
#       <td id="T_ba641_row1_col10" class="data row1 col10" >0.9</td>
#       <td id="T_ba641_row1_col11" class="data row1 col11" >0.0</td>
#       <td id="T_ba641_row1_col12" class="data row1 col12" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_ba641_level0_row2" class="row_heading level0 row2" >Q</th>
#       <td id="T_ba641_row2_col0" class="data row2 col0" >2.8</td>
#       <td id="T_ba641_row2_col1" class="data row2 col1" >1.9</td>
#       <td id="T_ba641_row2_col2" class="data row2 col2" >0.9</td>
#       <td id="T_ba641_row2_col3" class="data row2 col3" >0.9</td>
#       <td id="T_ba641_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_ba641_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_ba641_row2_col6" class="data row2 col6" >0.0</td>
#       <td id="T_ba641_row2_col7" class="data row2 col7" >0.0</td>
#       <td id="T_ba641_row2_col8" class="data row2 col8" >0.0</td>
#       <td id="T_ba641_row2_col9" class="data row2 col9" >0.9</td>
#       <td id="T_ba641_row2_col10" class="data row2 col10" >0.0</td>
#       <td id="T_ba641_row2_col11" class="data row2 col11" >0.0</td>
#       <td id="T_ba641_row2_col12" class="data row2 col12" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_ba641_level0_row3" class="row_heading level0 row3" >J</th>
#       <td id="T_ba641_row3_
# <div style='display:flex; gap:24px; align-items:flex-start;'><div><style type="text/css">
# #T_f466a_row0_col0 {
#   background-color: #1d4ed8;
#   color: #f1f1f1;
# }
# #T_f466a_row0_col1, #T_f466a_row3_col0, #T_f466a_row3_col1, #T_f466a_row7_col0 {
#   background-color: #7795e8;
#   color: #f1f1f1;
# }
# #T_f466a_row0_col2, #T_f466a_row1_col1, #T_f466a_row1_col9, #T_f466a_row2_col1, #T_f466a_row2_col3, #T_f466a_row3_col3, #T_f466a_row3_col5, #T_f466a_row3_col10, #T_f466a_row4_col8, #T_f466a_row5_col0, #T_f466a_row5_col5, #T_f466a_row5_col9, #T_f466a_row6_col2, #T_f466a_row6_col4, #T_f466a_row7_col7, #T_f466a_row7_col9, #T_f466a_row7_col11, #T_f466a_row8_col0, #T_f466a_row8_col1, #T_f466a_row8_col5, #T_f466a_row8_col7, #T_f466a_row8_col8, #T_f466a_row9_col5, #T_f466a_row11_col4 {
#   background-color: #d2dcf7;
#   color: #000000;
# }
# #T_f466a_row0_col3, #T_f466a_row0_col10, #T_f466a_row2_col0, #T_f466a_row2_col11, #T_f466a_row4_col0, #T_f466a_row4_col2, #T_f466a_row4_col4 {
#   background-color: #a5b8ef;
#   color: #000000;
# }
# #T_f466a_row0_col4, #T_f466a_row0_col5, #T_f466a_row0_col6, #T_f466a_row0_col7, #T_f466a_row0_col8, #T_f466a_row0_col9, #T_f466a_row0_col11, #T_f466a_row0_col12, #T_f466a_row1_col0, #T_f466a_row1_col2, #T_f466a_row1_col3, #T_f466a_row1_col4, #T_f466a_row1_col5, #T_f466a_row1_col6, #T_f466a_row1_col7, #T_f466a_row1_col8, #T_f466a_row1_col10, #T_f466a_row1_col11, #T_f466a_row1_col12, #T_f466a_row2_col2, #T_f466a_row2_col4, #T_f466a_row2_col5, #T_f466a_row2_col6, #T_f466a_row2_col7, #T_f466a_row2_col8, #T_f466a_row2_col9, #T_f466a_row2_col10, #T_f466a_row2_col12, #T_f466a_row3_col2, #T_f466a_row3_col4, #T_f466a_row3_col6, #T_f466a_row3_col7, #T_f466a_row3_col8, #T_f466a_row3_col9, #T_f466a_row3_col11, #T_f466a_row3_col12, #T_f466a_row4_col1, #T_f466a_row4_col3, #T_f466a_row4_col5, #T_f466a_row4_col6, #T_f466a_row4_col7, #T_f466a_row4_col9, #T_f466a_row4_col10, #T_f466a_row4_col11, #T_f466a_row4_col12, #T_f466a_row5_col1, #T_f466a_row5_col2, #T_f466a_row5_col3, #T_f466a_row5_col4, #T_f466a_row5_col6, #T_f466a_row5_col7, #T_f466a_row5_col8, #T_f466a_row5_col10, #T_f466a_row5_col11, #T_f466a_row5_col12, #T_f466a_row6_col0, #T_f466a_row6_col1, #T_f466a_row6_col3, #T_f466a_row6_col5, #T_f466a_row6_col6, #T_f466a_row6_col7, #T_f466a_row6_col8, #T_f466a_row6_col9, #T_f466a_row6_col10, #T_f466a_row6_col11, #T_f466a_row6_col12, #T_f466a_row7_col1, #T_f466a_row7_col2, #T_f466a_row7_col3, #T_f466a_row7_col4, #T_f466a_row7_col5, #T_f466a_row7_col6, #T_f466a_row7_col8, #T_f466a_row7_col10, #T_f466a_row7_col12, #T_f466a_row8_col2, #T_f466a_row8_col3, #T_f466a_row8_col4, #T_f466a_row8_col6, #T_f466a_row8_col9, #T_f466a_row8_col10, #T_f466a_row8_col11, #T_f466a_row8_col12, #T_f466a_row9_col0, #T_f466a_row9_col1, #T_f466a_row9_col2, #T_f466a_row9_col3, #T_f466a_row9_col4, #T_f466a_row9_col6, #T_f466a_row9_col7, #T_f466a_row9_col8, #T_f466a_row9_col9, #T_f466a_row9_col10, #T_f466a_row9_col11, #T_f466a_row9_col12, #T_f466a_row10_col0, #T_f466a_row10_col1, #T_f466a_row10_col2, #T_f466a_row10_col3, #T_f466a_row10_col4, #T_f466a_row10_col5, #T_f466a_row10_col6, #T_f466a_row10_col7, #T_f466a_row10_col8, #T_f466a_row10_col9, #T_f466a_row10_col10, #T_f466a_row10_col11, #T_f466a_row10_col12, #T_f466a_row11_col0, #T_f466a_row11_col1, #T_f466a_row11_col2, #T_f466a_row11_col3, #T_f466a_row11_col5, #T_f466a_row11_col6, #T_f466a_row11_col7, #T_f466a_row11_col8, #T_f466a_row11_col9, #T_f466a_row11_col10, #T_f466a_row11_col11, #T_f466a_row11_col12, #T_f466a_row12_col0, #T_f466a_row12_col1, #T_f466a_row12_col2, #T_f466a_row12_col3, #T_f466a_row12_col4, #T_f466a_row12_col5, #T_f466a_row12_col6, #T_f466a_row12_col7, #T_f466a_row12_col8, #T_f466a_row12_col9, #T_f466a_row12_col10, #T_f466a_row12_col11, #T_f466a_row12_col12 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_f466a">
#   <caption>First to Bet Shove (>30 BB) - 55 events</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f466a_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f466a_level0_col1" class="col_heading level0 col1" >K</th>
#       <th id="T_f466a_level0_col2" class="col_heading level0 col2" >Q</th>
#       <th id="T_f466a_level0_col3" class="col_heading level0 col3" >J</th>
#       <th id="T_f466a_level0_col4" class="col_heading level0 col4" >T</th>
#       <th id="T_f466a_level0_col5" class="col_heading level0 col5" >9</th>
#       <th id="T_f466a_level0_col6" class="col_heading level0 col6" >8</th>
#       <th id="T_f466a_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_f466a_level0_col8" class="col_heading level0 col8" >6</th>
#       <th id="T_f466a_level0_col9" class="col_heading level0 col9" >5</th>
#       <th id="T_f466a_level0_col10" class="col_heading level0 col10" >4</th>
#       <th id="T_f466a_level0_col11" class="col_heading level0 col11" >3</th>
#       <th id="T_f466a_level0_col12" class="col_heading level0 col12" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f466a_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_f466a_row0_col0" class="data row0 col0" >9.1</td>
#       <td id="T_f466a_row0_col1" class="data row0 col1" >5.5</td>
#       <td id="T_f466a_row0_col2" class="data row0 col2" >1.8</td>
#       <td id="T_f466a_row0_col3" class="data row0 col3" >3.6</td>
#       <td id="T_f466a_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_f466a_row0_col5" class="data row0 col5" >0.0</td>
#       <td id="T_f466a_row0_col6" class="data row0 col6" >0.0</td>
#       <td id="T_f466a_row0_col7" class="data row0 col7" >0.0</td>
#       <td id="T_f466a_row0_col8" class="data row0 col8" >0.0</td>
#       <td id="T_f466a_row0_col9" class="data row0 col9" >0.0</td>
#       <td id="T_f466a_row0_col10" class="data row0 col10" >3.6</td>
#       <td id="T_f466a_row0_col11" class="data row0 col11" >0.0</td>
#       <td id="T_f466a_row0_col12" class="data row0 col12" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f466a_level0_row1" class="row_heading level0 row1" >K</th>
#       <td id="T_f466a_row1_col0" class="data row1 col0" >0.0</td>
#       <td id="T_f466a_row1_col1" class="data row1 col1" >1.8</td>
#       <td id="T_f466a_row1_col2" class="data row1 col2" >0.0</td>
#       <td id="T_f466a_row1_col3" class="data row1 col3" >0.0</td>
#       <td id="T_f466a_row1_col4" class="data row1 col4" >0.0</td>
#       <td id="T_f466a_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_f466a_row1_col6" class="data row1 col6" >0.0</td>
#       <td id="T_f466a_row1_col7" class="data row1 col7" >0.0</td>
#       <td id="T_f466a_row1_col8" class="data row1 col8" >0.0</td>
#       <td id="T_f466a_row1_col9" class="data row1 col9" >1.8</td>
#       <td id="T_f466a_row1_col10" class="data row1 col10" >0.0</td>
#       <td id="T_f466a_row1_col11" class="data row1 col11" >0.0</td>
#       <td id="T_f466a_row1_col12" class="data row1 col12" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f466a_level0_row2" class="row_heading level0 row2" >Q</th>
#       <td id="T_f466a_row2_col0" class="data row2 col0" >3.6</td>
#       <td id="T_f466a_row2_col1" class="data row2 col1" >1.8</td>
#       <td id="T_f466a_row2_col2" class="data row2 col2" >0.0</td>
#       <td id="T_f466a_row2_col3" class="data row2 col3" >1.8</td>
#       <td id="T_f466a_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_f466a_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_f466a_row2_col6" class="data row2 col6" >0.0</td>
#       <td id="T_f466a_row2_col7" class="data row2 col7" >0.0</td>
#       <td id="T_f466a_row2_col8" class="data row2 col8" >0.0</td>
#       <td id="T_f466a_row2_col9" class="data row2 col9" >0.0</td>
#       <td id="T_f466a_row2_col10" class="data row2 col10" >0.0</td>
#       <td id="T_f466a_row2_col11" class="data row2 col11" >3.6</td>
#       <td id="T_f466a_row2_col12" class="data row2 col12" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f466a_level0_row3" class="row_heading level0 row3" >J</th>
#       <td id="T_f466a_row3_col0" class="data row3 col0" >5.5</td>
#       <td id
# <div style='display:flex; gap:24px; align-items:flex-start;'><div><style type="text/css">
# #T_085f2_row0_col0, #T_085f2_row8_col8 {
#   background-color: #849fea;
#   color: #f1f1f1;
# }
# #T_085f2_row0_col1, #T_085f2_row0_col5, #T_085f2_row0_col12, #T_085f2_row1_col2, #T_085f2_row1_col3, #T_085f2_row2_col3, #T_085f2_row2_col4, #T_085f2_row3_col4, #T_085f2_row3_col5, #T_085f2_row7_col0, #T_085f2_row7_col4, #T_085f2_row7_col10, #T_085f2_row8_col0, #T_085f2_row9_col0, #T_085f2_row9_col6, #T_085f2_row10_col0 {
#   background-color: #d6dff8;
#   color: #000000;
# }
# #T_085f2_row0_col2, #T_085f2_row0_col4, #T_085f2_row0_col7, #T_085f2_row0_col8, #T_085f2_row0_col11, #T_085f2_row1_col5, #T_085f2_row1_col8, #T_085f2_row1_col9, #T_085f2_row1_col11, #T_085f2_row2_col6, #T_085f2_row2_col7, #T_085f2_row2_col11, #T_085f2_row3_col2, #T_085f2_row3_col6, #T_085f2_row3_col12, #T_085f2_row4_col1, #T_085f2_row4_col4, #T_085f2_row4_col12, #T_085f2_row5_col0, #T_085f2_row5_col11, #T_085f2_row6_col1, #T_085f2_row6_col5, #T_085f2_row6_col8, #T_085f2_row6_col10, #T_085f2_row7_col1, #T_085f2_row7_col2, #T_085f2_row7_col8, #T_085f2_row8_col5, #T_085f2_row8_col6, #T_085f2_row8_col10, #T_085f2_row9_col2, #T_085f2_row9_col4, #T_085f2_row10_col1, #T_085f2_row10_col4, #T_085f2_row10_col7, #T_085f2_row10_col9, #T_085f2_row10_col10, #T_085f2_row11_col9, #T_085f2_row11_col12, #T_085f2_row12_col0, #T_085f2_row12_col2, #T_085f2_row12_col6, #T_085f2_row12_col9 {
#   background-color: #ebeffb;
#   color: #000000;
# }
# #T_085f2_row0_col3, #T_085f2_row0_col6, #T_085f2_row0_col9, #T_085f2_row1_col4, #T_085f2_row1_col6, #T_085f2_row1_col7, #T_085f2_row1_col10, #T_085f2_row1_col12, #T_085f2_row2_col5, #T_085f2_row2_col8, #T_085f2_row2_col9, #T_085f2_row2_col10, #T_085f2_row2_col12, #T_085f2_row3_col7, #T_085f2_row3_col8, #T_085f2_row3_col9, #T_085f2_row3_col10, #T_085f2_row3_col11, #T_085f2_row4_col2, #T_085f2_row4_col3, #T_085f2_row4_col5, #T_085f2_row4_col6, #T_085f2_row4_col7, #T_085f2_row4_col8, #T_085f2_row4_col9, #T_085f2_row4_col10, #T_085f2_row4_col11, #T_085f2_row5_col1, #T_085f2_row5_col3, #T_085f2_row5_col4, #T_085f2_row5_col6, #T_085f2_row5_col7, #T_085f2_row5_col8, #T_085f2_row5_col9, #T_085f2_row5_col10, #T_085f2_row5_col12, #T_085f2_row6_col2, #T_085f2_row6_col3, #T_085f2_row6_col4, #T_085f2_row6_col7, #T_085f2_row6_col9, #T_085f2_row6_col11, #T_085f2_row6_col12, #T_085f2_row7_col3, #T_085f2_row7_col5, #T_085f2_row7_col6, #T_085f2_row7_col9, #T_085f2_row7_col11, #T_085f2_row7_col12, #T_085f2_row8_col1, #T_085f2_row8_col2, #T_085f2_row8_col3, #T_085f2_row8_col4, #T_085f2_row8_col7, #T_085f2_row8_col9, #T_085f2_row8_col11, #T_085f2_row8_col12, #T_085f2_row9_col1, #T_085f2_row9_col3, #T_085f2_row9_col5, #T_085f2_row9_col7, #T_085f2_row9_col8, #T_085f2_row9_col10, #T_085f2_row9_col11, #T_085f2_row9_col12, #T_085f2_row10_col2, #T_085f2_row10_col3, #T_085f2_row10_col5, #T_085f2_row10_col6, #T_085f2_row10_col8, #T_085f2_row10_col11, #T_085f2_row10_col12, #T_085f2_row11_col1, #T_085f2_row11_col2, #T_085f2_row11_col3, #T_085f2_row11_col4, #T_085f2_row11_col5, #T_085f2_row11_col6, #T_085f2_row11_col7, #T_085f2_row11_col8, #T_085f2_row11_col10, #T_085f2_row12_col1, #T_085f2_row12_col3, #T_085f2_row12_col4, #T_085f2_row12_col5, #T_085f2_row12_col7, #T_085f2_row12_col8, #T_085f2_row12_col10, #T_085f2_row12_col11 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_085f2_row0_col10, #T_085f2_row2_col2, #T_085f2_row3_col1, #T_085f2_row11_col11, #T_085f2_row12_col12 {
#   background-color: #98aeed;
#   color: #000000;
# }
# #T_085f2_row1_col0, #T_085f2_row3_col0 {
#   background-color: #1d4ed8;
#   color: #f1f1f1;
# }
# #T_085f2_row1_col1, #T_085f2_row4_col0 {
#   background-color: #466edf;
#   color: #f1f1f1;
# }
# #T_085f2_row2_col0 {
#   background-color: #315edc;
#   color: #f1f1f1;
# }
# #T_085f2_row2_col1, #T_085f2_row3_col3 {
#   background-color: #6f8fe6;
#   color: #f1f1f1;
# }
# #T_085f2_row5_col2, #T_085f2_row5_col5, #T_085f2_row6_col0 {
#   background-color: #c2cff4;
#   color: #000000;
# }
# #T_085f2_row6_col6, #T_085f2_row7_col7, #T_085f2_row9_col9, #T_085f2_row11_col0 {
#   background-color: #adbef1;
#   color: #000000;
# }
# </style>
# <table id="T_085f2">
#   <caption>3-Bet Shove - 201 events</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_085f2_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_085f2_level0_col1" class="col_heading level0 col1" >K</th>
#       <th id="T_085f2_level0_col2" class="col_heading level0 col2" >Q</th>
#       <th id="T_085f2_level0_col3" class="col_heading level0 col3" >J</th>
#       <th id="T_085f2_level0_col4" class="col_heading level0 col4" >T</th>
#       <th id="T_085f2_level0_col5" class="col_heading level0 col5" >9</th>
#       <th id="T_085f2_level0_col6" class="col_heading level0 col6" >8</th>
#       <th id="T_085f2_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_085f2_level0_col8" class="col_heading level0 col8" >6</th>
#       <th id="T_085f2_level0_col9" class="col_heading level0 col9" >5</th>
#       <th id="T_085f2_level0_col10" class="col_heading level0 col10" >4</th>
#       <th id="T_085f2_level0_col11" class="col_heading level0 col11" >3</th>
#       <th id="T_085f2_level0_col12" class="col_heading level0 col12" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_085f2_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_085f2_row0_col0" class="data row0 col0" >3.0</td>
#       <td id="T_085f2_row0_col1" class="data row0 col1" >1.0</td>
#       <td id="T_085f2_row0_col2" class="data row0 col2" >0.5</td>
#       <td id="T_085f2_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_085f2_row0_col4" class="data row0 col4" >0.5</td>
#       <td id="T_085f2_row0_col5" class="data row0 col5" >1.0</td>
#       <td id="T_085f2_row0_col6" class="data row0 col6" >0.0</td>
#       <td id="T_085f2_row0_col7" class="data row0 col7" >0.5</td>
#       <td id="T_085f2_row0_col8" class="data row0 col8" >0.5</td>
#       <td id="T_085f2_row0_col9" class="data row0 col9" >0.0</td>
#       <td id="T_085f2_row0_col10" class="data row0 col10" >2.5</td>
#       <td id="T_085f2_row0_col11" class="data row0 col11" >0.5</td>
#       <td id="T_085f2_row0_col12" class="data row0 col12" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_085f2_level0_row1" class="row_heading level0 row1" >K</th>
#       <td id="T_085f2_row1_col0" class="data row1 col0" >5.5</td>
#       <td id="T_085f2_row1_col1" class="data row1 col1" >4.5</td>
#       <td id="T_085f2_row1_col2" class="data row1 col2" >1.0</td>
#       <td id="T_085f2_row1_col3" class="data row1 col3" >1.0</td>
#       <td id="T_085f2_row1_col4" class="data row1 col4" >0.0</td>
#       <td id="T_085f2_row1_col5" class="data row1 col5" >0.5</td>
#       <td id="T_085f2_row1_col6" class="data row1 col6" >0.0</td>
#       <td id="T_085f2_row1_col7" class="data row1 col7" >0.0</td>
#       <td id="T_085f2_row1_col8" class="data row1 col8" >0.5</td>
#       <td id="T_085f2_row1_col9" class="data row1 col9" >0.5</td>
#       <td id="T_085f2_row1_col10" class="data row1 col10" >0.0</td>
#       <td id="T_085f2_row1_col11" class="data row1 col11" >0.5</td>
#       <td id="T_085f2_row1_col12" class="data row1 col12" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_085f2_level0_row2" class="row_heading level0 row2" >Q</th>
#       <td id="T_085f2_row2_col0" class="data row2 col0" >5.0</td>
#       <td id="T_085f2_row2_col1" class="data row2 col1" >3.5</td>
#       <td id="T_085f2_row2_col2" class="data row2 col2" >2.5</td>
#       <td id="T_085f2_row2_col3" class="data row2 col3" >1.0</td>
#       <td id="T_085f2_row2_col4" class="data row2 col4" >1.0</td>
#       <td id="T_085f2_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_085f2_row2_col6" class="data row2 col6" >0.5</td>
#       <td id="T_085f2_row2_col7" class="data row2 col7" >0.5</td>
#       <td id="T_085f2_row2_col8" class="data row2 col8" >0.0</td>
#       <td id="T_085f2_row2_col9" class="data row2 col9" >0.0</td>
#       <td id="T_085f2_row2_col10" class="data row2 col10" >0.0</td>
#       <td id="T_085f2_r
# <div style='display:flex; gap:24px; align-items:flex-start;'><div><style type="text/css">
# #T_da3a1_row0_col0, #T_da3a1_row0_col1, #T_da3a1_row3_col0 {
#   background-color: #d1dbf7;
#   color: #000000;
# }
# #T_da3a1_row0_col2, #T_da3a1_row2_col0 {
#   background-color: #cad5f6;
#   color: #000000;
# }
# #T_da3a1_row0_col3, #T_da3a1_row0_col12, #T_da3a1_row1_col10, #T_da3a1_row1_col12, #T_da3a1_row2_col3, #T_da3a1_row2_col4, #T_da3a1_row3_col2, #T_da3a1_row3_col8, #T_da3a1_row4_col1, #T_da3a1_row6_col0, #T_da3a1_row6_col2, #T_da3a1_row6_col5, #T_da3a1_row7_col0, #T_da3a1_row8_col2, #T_da3a1_row8_col9, #T_da3a1_row10_col0, #T_da3a1_row11_col4, #T_da3a1_row11_col9, #T_da3a1_row11_col11, #T_da3a1_row12_col3, #T_da3a1_row12_col11, #T_da3a1_row12_col12 {
#   background-color: #f9fafe;
#   color: #000000;
# }
# #T_da3a1_row0_col4, #T_da3a1_row0_col5, #T_da3a1_row1_col2, #T_da3a1_row1_col3, #T_da3a1_row1_col8, #T_da3a1_row3_col5, #T_da3a1_row7_col1, #T_da3a1_row8_col0, #T_da3a1_row9_col0, #T_da3a1_row11_col0, #T_da3a1_row12_col0 {
#   background-color: #f2f5fd;
#   color: #000000;
# }
# #T_da3a1_row0_col6, #T_da3a1_row0_col7, #T_da3a1_row0_col8, #T_da3a1_row0_col9, #T_da3a1_row0_col10, #T_da3a1_row1_col5, #T_da3a1_row1_col6, #T_da3a1_row1_col7, #T_da3a1_row1_col9, #T_da3a1_row1_col11, #T_da3a1_row2_col5, #T_da3a1_row2_col6, #T_da3a1_row2_col7, #T_da3a1_row2_col8, #T_da3a1_row2_col9, #T_da3a1_row2_col10, #T_da3a1_row2_col11, #T_da3a1_row2_col12, #T_da3a1_row3_col1, #T_da3a1_row3_col4, #T_da3a1_row3_col6, #T_da3a1_row3_col7, #T_da3a1_row3_col9, #T_da3a1_row3_col10, #T_da3a1_row3_col11, #T_da3a1_row3_col12, #T_da3a1_row4_col3, #T_da3a1_row4_col5, #T_da3a1_row4_col6, #T_da3a1_row4_col7, #T_da3a1_row4_col8, #T_da3a1_row4_col9, #T_da3a1_row4_col10, #T_da3a1_row4_col11, #T_da3a1_row4_col12, #T_da3a1_row5_col1, #T_da3a1_row5_col2, #T_da3a1_row5_col3, #T_da3a1_row5_col6, #T_da3a1_row5_col7, #T_da3a1_row5_col8, #T_da3a1_row5_col9, #T_da3a1_row5_col10, #T_da3a1_row5_col11, #T_da3a1_row5_col12, #T_da3a1_row6_col1, #T_da3a1_row6_col3, #T_da3a1_row6_col4, #T_da3a1_row6_col7, #T_da3a1_row6_col8, #T_da3a1_row6_col9, #T_da3a1_row6_col10, #T_da3a1_row6_col11, #T_da3a1_row6_col12, #T_da3a1_row7_col2, #T_da3a1_row7_col3, #T_da3a1_row7_col4, #T_da3a1_row7_col5, #T_da3a1_row7_col6, #T_da3a1_row7_col8, #T_da3a1_row7_col9, #T_da3a1_row7_col10, #T_da3a1_row7_col11, #T_da3a1_row7_col12, #T_da3a1_row8_col1, #T_da3a1_row8_col3, #T_da3a1_row8_col4, #T_da3a1_row8_col5, #T_da3a1_row8_col6, #T_da3a1_row8_col7, #T_da3a1_row8_col10, #T_da3a1_row8_col11, #T_da3a1_row8_col12, #T_da3a1_row9_col1, #T_da3a1_row9_col2, #T_da3a1_row9_col3, #T_da3a1_row9_col4, #T_da3a1_row9_col5, #T_da3a1_row9_col6, #T_da3a1_row9_col7, #T_da3a1_row9_col8, #T_da3a1_row9_col10, #T_da3a1_row9_col11, #T_da3a1_row9_col12, #T_da3a1_row10_col1, #T_da3a1_row10_col2, #T_da3a1_row10_col3, #T_da3a1_row10_col4, #T_da3a1_row10_col5, #T_da3a1_row10_col6, #T_da3a1_row10_col7, #T_da3a1_row10_col8, #T_da3a1_row10_col9, #T_da3a1_row10_col11, #T_da3a1_row10_col12, #T_da3a1_row11_col1, #T_da3a1_row11_col2, #T_da3a1_row11_col3, #T_da3a1_row11_col5, #T_da3a1_row11_col6, #T_da3a1_row11_col7, #T_da3a1_row11_col8, #T_da3a1_row11_col10, #T_da3a1_row11_col12, #T_da3a1_row12_col1, #T_da3a1_row12_col2, #T_da3a1_row12_col4, #T_da3a1_row12_col5, #T_da3a1_row12_col6, #T_da3a1_row12_col7, #T_da3a1_row12_col8, #T_da3a1_row12_col9, #T_da3a1_row12_col10 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_da3a1_row0_col11, #T_da3a1_row2_col1, #T_da3a1_row7_col7, #T_da3a1_row9_col9, #T_da3a1_row10_col10 {
#   background-color: #e4eafa;
#   color: #000000;
# }
# #T_da3a1_row1_col0 {
#   background-color: #1d4ed8;
#   color: #f1f1f1;
# }
# #T_da3a1_row1_col1, #T_da3a1_row5_col5 {
#   background-color: #bdcbf4;
#   color: #000000;
# }
# #T_da3a1_row1_col4, #T_da3a1_row4_col2, #T_da3a1_row5_col0, #T_da3a1_row5_col4, #T_da3a1_row6_col6 {
#   background-color: #ecf0fc;
#   color: #000000;
# }
# #T_da3a1_row2_col2 {
#   background-color: #afc1f1;
#   color: #000000;
# }
# #T_da3a1_row3_col3 {
#   background-color: #c4d0f5;
#   color: #000000;
# }
# #T_da3a1_row4_col0, #T_da3a1_row8_col8 {
#   background-color: #dee5f9;
#   color: #000000;
# }
# #T_da3a1_row4_col4 {
#   background-color: #d7e0f8;
#   color: #000000;
# }
# </style>
# <table id="T_da3a1">
#   <caption>4-Bet Shove - 207 events</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da3a1_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_da3a1_level0_col1" class="col_heading level0 col1" >K</th>
#       <th id="T_da3a1_level0_col2" class="col_heading level0 col2" >Q</th>
#       <th id="T_da3a1_level0_col3" class="col_heading level0 col3" >J</th>
#       <th id="T_da3a1_level0_col4" class="col_heading level0 col4" >T</th>
#       <th id="T_da3a1_level0_col5" class="col_heading level0 col5" >9</th>
#       <th id="T_da3a1_level0_col6" class="col_heading level0 col6" >8</th>
#       <th id="T_da3a1_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_da3a1_level0_col8" class="col_heading level0 col8" >6</th>
#       <th id="T_da3a1_level0_col9" class="col_heading level0 col9" >5</th>
#       <th id="T_da3a1_level0_col10" class="col_heading level0 col10" >4</th>
#       <th id="T_da3a1_level0_col11" class="col_heading level0 col11" >3</th>
#       <th id="T_da3a1_level0_col12" class="col_heading level0 col12" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da3a1_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_da3a1_row0_col0" class="data row0 col0" >3.4</td>
#       <td id="T_da3a1_row0_col1" class="data row0 col1" >3.4</td>
#       <td id="T_da3a1_row0_col2" class="data row0 col2" >3.9</td>
#       <td id="T_da3a1_row0_col3" class="data row0 col3" >0.5</td>
#       <td id="T_da3a1_row0_col4" class="data row0 col4" >1.0</td>
#       <td id="T_da3a1_row0_col5" class="data row0 col5" >1.0</td>
#       <td id="T_da3a1_row0_col6" class="data row0 col6" >0.0</td>
#       <td id="T_da3a1_row0_col7" class="data row0 col7" >0.0</td>
#       <td id="T_da3a1_row0_col8" class="data row0 col8" >0.0</td>
#       <td id="T_da3a1_row0_col9" class="data row0 col9" >0.0</td>
#       <td id="T_da3a1_row0_col10" class="data row0 col10" >0.0</td>
#       <td id="T_da3a1_row0_col11" class="data row0 col11" >1.9</td>
#       <td id="T_da3a1_row0_col12" class="data row0 col12" >0.5</td>
#     </tr>
#     <tr>
#       <th id="T_da3a1_level0_row1" class="row_heading level0 row1" >K</th>
#       <td id="T_da3a1_row1_col0" class="data row1 col0" >16.4</td>
#       <td id="T_da3a1_row1_col1" class="data row1 col1" >4.8</td>
#       <td id="T_da3a1_row1_col2" class="data row1 col2" >1.0</td>
#       <td id="T_da3a1_row1_col3" class="data row1 col3" >1.0</td>
#       <td id="T_da3a1_row1_col4" class="data row1 col4" >1.4</td>
#       <td id="T_da3a1_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_da3a1_row1_col6" class="data row1 col6" >0.0</td>
#       <td id="T_da3a1_row1_col7" class="data row1 col7" >0.0</td>
#       <td id="T_da3a1_row1_col8" class="data row1 col8" >1.0</td>
#       <td id="T_da3a1_row1_col9" class="data row1 col9" >0.0</td>
#       <td id="T_da3a1_row1_col10" class="data row1 col10" >0.5</td>
#       <td id="T_da3a1_row1_col11" class="data row1 col11" >0.0</td>
#       <td id="T_da3a1_row1_col12" class="data row1 col12" >0.5</td>
#     </tr>
#     <tr>
#       <th id="T_da3a1_level0_row2" class="row_heading level0 row2" >Q</th>
#       <td id="T_da3a1_row2_col0" class="data row2 col0" >3.9</td>
#       <td id="T_da3a1_row2_col1" class="data row2 col1" >1.9</td>
#       <td id="T_da3a1_row2_col2" class="data row2 col2" >5.8</td>
#       <td id="T_da3a1_row2_col3" class="data row2 col3" >0.5</td>
#       <td id="T_da3a1_row2_col4" class="data row2 col4" >0.5</td>
#       <td id="T_da3a1_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_da3a1_row2_col6" class="data row2 col6" >0.0</td>
#       <td id="T_da3a1_row2_col7" class="data row2 col7" >0.0</td>
#       <td id="T_da3a1_row2_col8" class="data row2 col8" >0.0</td>
#       <td id="T_da3a1_row2_col9" class="data row2 col9"
# <div style='display:flex; gap:24px; align-items:flex-start;'><div><style type="text/css">
# #T_08ad3_row0_col0 {
#   background-color: #7996e8;
#   color: #f1f1f1;
# }
# #T_08ad3_row0_col1 {
#   background-color: #819ce9;
#   color: #f1f1f1;
# }
# #T_08ad3_row0_col2 {
#   background-color: #cdd8f6;
#   color: #000000;
# }
# #T_08ad3_row0_col3, #T_08ad3_row0_col6, #T_08ad3_row0_col10, #T_08ad3_row0_col12, #T_08ad3_row1_col3, #T_08ad3_row1_col8, #T_08ad3_row2_col3, #T_08ad3_row2_col5, #T_08ad3_row3_col1, #T_08ad3_row3_col7, #T_08ad3_row4_col1, #T_08ad3_row4_col3, #T_08ad3_row4_col5, #T_08ad3_row5_col1, #T_08ad3_row5_col2, #T_08ad3_row5_col3, #T_08ad3_row6_col2, #T_08ad3_row6_col5, #T_08ad3_row6_col8, #T_08ad3_row7_col0, #T_08ad3_row7_col6, #T_08ad3_row8_col0, #T_08ad3_row8_col8, #T_08ad3_row9_col3, #T_08ad3_row9_col9, #T_08ad3_row9_col10, #T_08ad3_row10_col11, #T_08ad3_row11_col0, #T_08ad3_row11_col4, #T_08ad3_row11_col11, #T_08ad3_row12_col0, #T_08ad3_row12_col1, #T_08ad3_row12_col2 {
#   background-color: #f7f9fe;
#   color: #000000;
# }
# #T_08ad3_row0_col4, #T_08ad3_row2_col1 {
#   background-color: #dee5f9;
#   color: #000000;
# }
# #T_08ad3_row0_col5, #T_08ad3_row0_col7, #T_08ad3_row0_col8, #T_08ad3_row0_col11, #T_08ad3_row1_col2, #T_08ad3_row1_col4, #T_08ad3_row1_col5, #T_08ad3_row1_col6, #T_08ad3_row1_col7, #T_08ad3_row1_col9, #T_08ad3_row1_col10, #T_08ad3_row1_col11, #T_08ad3_row1_col12, #T_08ad3_row2_col4, #T_08ad3_row2_col6, #T_08ad3_row2_col7, #T_08ad3_row2_col8, #T_08ad3_row2_col9, #T_08ad3_row2_col10, #T_08ad3_row2_col11, #T_08ad3_row2_col12, #T_08ad3_row3_col2, #T_08ad3_row3_col4, #T_08ad3_row3_col5, #T_08ad3_row3_col6, #T_08ad3_row3_col8, #T_08ad3_row3_col9, #T_08ad3_row3_col10, #T_08ad3_row3_col11, #T_08ad3_row3_col12, #T_08ad3_row4_col6, #T_08ad3_row4_col7, #T_08ad3_row4_col8, #T_08ad3_row4_col9, #T_08ad3_row4_col10, #T_08ad3_row4_col11, #T_08ad3_row4_col12, #T_08ad3_row5_col0, #T_08ad3_row5_col4, #T_08ad3_row5_col7, #T_08ad3_row5_col8, #T_08ad3_row5_col9, #T_08ad3_row5_col10, #T_08ad3_row5_col11, #T_08ad3_row5_col12, #T_08ad3_row6_col1, #T_08ad3_row6_col3, #T_08ad3_row6_col4, #T_08ad3_row6_col7, #T_08ad3_row6_col9, #T_08ad3_row6_col10, #T_08ad3_row6_col11, #T_08ad3_row6_col12, #T_08ad3_row7_col1, #T_08ad3_row7_col2, #T_08ad3_row7_col3, #T_08ad3_row7_col4, #T_08ad3_row7_col5, #T_08ad3_row7_col8, #T_08ad3_row7_col9, #T_08ad3_row7_col10, #T_08ad3_row7_col11, #T_08ad3_row7_col12, #T_08ad3_row8_col1, #T_08ad3_row8_col2, #T_08ad3_row8_col3, #T_08ad3_row8_col4, #T_08ad3_row8_col5, #T_08ad3_row8_col7, #T_08ad3_row8_col9, #T_08ad3_row8_col10, #T_08ad3_row8_col11, #T_08ad3_row8_col12, #T_08ad3_row9_col0, #T_08ad3_row9_col1, #T_08ad3_row9_col2, #T_08ad3_row9_col4, #T_08ad3_row9_col5, #T_08ad3_row9_col6, #T_08ad3_row9_col7, #T_08ad3_row9_col8, #T_08ad3_row9_col11, #T_08ad3_row9_col12, #T_08ad3_row10_col0, #T_08ad3_row10_col1, #T_08ad3_row10_col2, #T_08ad3_row10_col3, #T_08ad3_row10_col4, #T_08ad3_row10_col5, #T_08ad3_row10_col6, #T_08ad3_row10_col7, #T_08ad3_row10_col8, #T_08ad3_row10_col9, #T_08ad3_row10_col10, #T_08ad3_row10_col12, #T_08ad3_row11_col1, #T_08ad3_row11_col2, #T_08ad3_row11_col3, #T_08ad3_row11_col5, #T_08ad3_row11_col6, #T_08ad3_row11_col7, #T_08ad3_row11_col8, #T_08ad3_row11_col9, #T_08ad3_row11_col10, #T_08ad3_row11_col12, #T_08ad3_row12_col3, #T_08ad3_row12_col4, #T_08ad3_row12_col5, #T_08ad3_row12_col6, #T_08ad3_row12_col7, #T_08ad3_row12_col8, #T_08ad3_row12_col9, #T_08ad3_row12_col10, #T_08ad3_row12_col11, #T_08ad3_row12_col12 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_08ad3_row0_col9, #T_08ad3_row2_col0, #T_08ad3_row3_col0, #T_08ad3_row4_col0, #T_08ad3_row6_col6, #T_08ad3_row7_col7 {
#   background-color: #e6ecfb;
#   color: #000000;
# }
# #T_08ad3_row1_col0 {
#   background-color: #1d4ed8;
#   color: #f1f1f1;
# }
# #T_08ad3_row1_col1 {
#   background-color: #476fdf;
#   color: #f1f1f1;
# }
# #T_08ad3_row2_col2 {
#   background-color: #708fe6;
#   color: #f1f1f1;
# }
# #T_08ad3_row3_col3 {
#   background-color: #c5d1f5;
#   color: #000000;
# }
# #T_08ad3_row4_col2, #T_08ad3_row5_col6, #T_08ad3_row6_col0, #T_08ad3_row8_col6 {
#   background-color: #eff3fc;
#   color: #000000;
# }
# #T_08ad3_row4_col4 {
#   background-color: #a3b7ef;
#   color: #000000;
# }
# #T_08ad3_row5_col5 {
#   background-color: #d5def8;
#   color: #000000;
# }
# </style>
# <table id="T_08ad3">
#   <caption>5+ Bet Shove - 193 events</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08ad3_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_08ad3_level0_col1" class="col_heading level0 col1" >K</th>
#       <th id="T_08ad3_level0_col2" class="col_heading level0 col2" >Q</th>
#       <th id="T_08ad3_level0_col3" class="col_heading level0 col3" >J</th>
#       <th id="T_08ad3_level0_col4" class="col_heading level0 col4" >T</th>
#       <th id="T_08ad3_level0_col5" class="col_heading level0 col5" >9</th>
#       <th id="T_08ad3_level0_col6" class="col_heading level0 col6" >8</th>
#       <th id="T_08ad3_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_08ad3_level0_col8" class="col_heading level0 col8" >6</th>
#       <th id="T_08ad3_level0_col9" class="col_heading level0 col9" >5</th>
#       <th id="T_08ad3_level0_col10" class="col_heading level0 col10" >4</th>
#       <th id="T_08ad3_level0_col11" class="col_heading level0 col11" >3</th>
#       <th id="T_08ad3_level0_col12" class="col_heading level0 col12" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08ad3_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_08ad3_row0_col0" class="data row0 col0" >8.3</td>
#       <td id="T_08ad3_row0_col1" class="data row0 col1" >7.8</td>
#       <td id="T_08ad3_row0_col2" class="data row0 col2" >3.1</td>
#       <td id="T_08ad3_row0_col3" class="data row0 col3" >0.5</td>
#       <td id="T_08ad3_row0_col4" class="data row0 col4" >2.1</td>
#       <td id="T_08ad3_row0_col5" class="data row0 col5" >0.0</td>
#       <td id="T_08ad3_row0_col6" class="data row0 col6" >0.5</td>
#       <td id="T_08ad3_row0_col7" class="data row0 col7" >0.0</td>
#       <td id="T_08ad3_row0_col8" class="data row0 col8" >0.0</td>
#       <td id="T_08ad3_row0_col9" class="data row0 col9" >1.6</td>
#       <td id="T_08ad3_row0_col10" class="data row0 col10" >0.5</td>
#       <td id="T_08ad3_row0_col11" class="data row0 col11" >0.0</td>
#       <td id="T_08ad3_row0_col12" class="data row0 col12" >0.5</td>
#     </tr>
#     <tr>
#       <th id="T_08ad3_level0_row1" class="row_heading level0 row1" >K</th>
#       <td id="T_08ad3_row1_col0" class="data row1 col0" >14.0</td>
#       <td id="T_08ad3_row1_col1" class="data row1 col1" >11.4</td>
#       <td id="T_08ad3_row1_col2" class="data row1 col2" >0.0</td>
#       <td id="T_08ad3_row1_col3" class="data row1 col3" >0.5</td>
#       <td id="T_08ad3_row1_col4" class="data row1 col4" >0.0</td>
#       <td id="T_08ad3_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_08ad3_row1_col6" class="data row1 col6" >0.0</td>
#       <td id="T_08ad3_row1_col7" class="data row1 col7" >0.0</td>
#       <td id="T_08ad3_row1_col8" class="data row1 col8" >0.5</td>
#       <td id="T_08ad3_row1_col9" class="data row1 col9" >0.0</td>
#       <td id="T_08ad3_row1_col10" class="data row1 col10" >0.0</td>
#       <td id="T_08ad3_row1_col11" class="data row1 col11" >0.0</td>
#       <td id="T_08ad3_row1_col12" class="data row1 col12" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_08ad3_level0_row2" class="row_heading level0 row2" >Q</th>
#       <td id="T_08ad3_row2_col0" class="data row2 col0" >1.6</td>
#       <td id="T_08ad3_row2_col1" class="data row2 col1" >2.1</td>
#       <td id="T_08ad3_row2_col2" class="data row2 col2" >8.8</td>
#       <td id="T_08ad3_row2_col3" class="data row2 col3" >0.5</td>
#       <td id="T_08ad3_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_08ad3_row2_col5" class="data row2 col5" >0.5</td>
#       <td id="T_08ad3_row2_col6" class="data row2 col6" >0.0</td>
#       <td id="T_08ad3_row2_col7" class="data row2 col7" >0.0</td>
#       <td id="T_08ad3_row2_col8" class="data row2 col8" >0.0</td>

# %% [markdown]
# ### Call Equity vs Shove Ranges
#
# Run `scripts/preflop_equity.py` to precompute equity tables, then load the cached results here.

# %%
EQUITY_RESULTS_PATH = PROJECT_ROOT / 'analysis' / 'cache' / 'preflop_equity.json'
if EQUITY_RESULTS_PATH.exists():
    with EQUITY_RESULTS_PATH.open('r', encoding='utf-8') as fh:
        equity_results = json.load(fh)
else:
    equity_results = None
    print('Equity cache not found. Run scripts/preflop_equity.py to generate results.')
EQUITY_SCENARIOS = [
    ('first_to_bet_leq30', 'First to Bet Shove (≤30 BB)'),
    ('first_to_bet_gt30', 'First to Bet Shove (>30 BB)'),
    ('three_bet_shove', '3-Bet Shove'),
    ('four_bet_shove', '4-Bet Shove'),
    ('five_plus_bet_shove', '5+ Bet Shove'),
]
EQUITY_CMAP = LinearSegmentedColormap.from_list('equity_cmap', ['#b91c1c', '#ffffff', '#15803d'])

# %%
def build_equity_grid(scenario_data: dict, key: str | None = None) -> pd.DataFrame:
    grid_dict = scenario_data.get(key or 'grid', {})
    df = pd.DataFrame(index=RANKS, columns=RANKS, dtype=float)
    for row in RANKS:
        for col in RANKS:
            df.loc[row, col] = grid_dict.get(row, {}).get(col, float('nan'))
    return df


def build_equity_summaries(combo_equities: dict[str, float]) -> tuple[pd.DataFrame, pd.DataFrame]:
    aggregates1 = {group: [] for group in HAND_GROUPS_ORDER}
    aggregates2 = {group: [] for group in SUMMARY2_GROUPS_ORDER}
    for combo_str, equity in combo_equities.items():
        labels = _classify_hand_group(combo_str)
        if labels is None:
            continue
        label1, label2 = labels
        aggregates1[label1].append(equity)
        aggregates2[label2].append(equity)
    summary1 = pd.DataFrame({
        'Hand Group': HAND_GROUPS_ORDER,
        'Equity (%)': [
            (sum(values) / len(values)) if values else float('nan')
            for values in aggregates1.values()
        ],
    })
    summary2 = pd.DataFrame({
        'Hand Group': SUMMARY2_GROUPS_ORDER,
        'Equity (%)': [
            (sum(values) / len(values)) if values else float('nan')
            for values in aggregates2.values()
        ],
    })
    return summary1, summary2


def _clip(val: float | None) -> float | None:
    if val is None:
        return None
    if isinstance(val, float) and math.isnan(val):
        return None
    return float(val)


def _equity_color(val: float | None, min_red: float, max_green: float) -> str:
    val = _clip(val)
    if val is None:
        return 'background-color: #f8fafc'
    if val == 50:
        return 'background-color: #ffffff'
    top_color = (21, 128, 61)
    bottom_color = (185, 28, 28)
    white = (255, 255, 255)
    if val > 50:
        alpha = 1.0 if max_green <= 50 else (val - 50) / (max_green - 50)
        red = int(white[0] + alpha * (top_color[0] - white[0]))
        green = int(white[1] + alpha * (top_color[1] - white[1]))
        blue = int(white[2] + alpha * (top_color[2] - white[2]))
        return f'background-color: rgb({red}, {green}, {blue})'
    alpha = 1.0 if min_red >= 50 else (50 - val) / (50 - min_red)
    red = int(white[0] + alpha * (bottom_color[0] - white[0]))
    green = int(white[1] + alpha * (bottom_color[1] - white[1]))
    blue = int(white[2] + alpha * (bottom_color[2] - white[2]))
    return f'background-color: rgb({red}, {green}, {blue})'


def _ev_color(val: float | None, min_red: float, max_green: float) -> str:
    val = _clip(val)
    if val is None:
        return 'background-color: #f8fafc'
    if abs(val) < 1e-9:
        return 'background-color: #ffffff'
    top_color = (21, 128, 61)
    bottom_color = (185, 28, 28)
    white = (255, 255, 255)
    if val > 0:
        alpha = 1.0 if max_green <= 0 else val / max_green
        red = int(white[0] + alpha * (top_color[0] - white[0]))
        green = int(white[1] + alpha * (top_color[1] - white[1]))
        blue = int(white[2] + alpha * (top_color[2] - white[2]))
        return f'background-color: rgb({red}, {green}, {blue})'
    alpha = 1.0 if min_red >= 0 else (0 - val) / (0 - min_red)
    red = int(white[0] + alpha * (bottom_color[0] - white[0]))
    green = int(white[1] + alpha * (bottom_color[1] - white[1]))
    blue = int(white[2] + alpha * (bottom_color[2] - white[2]))
    return f'background-color: rgb({red}, {green}, {blue})'


def compute_ev_frame(
    equity_df: pd.DataFrame,
    *,
    call_amount: float,
    villain_amount: float | None,
    pot_before: float,
    rake_percent: float,
    rake_cap: float,
) -> pd.DataFrame:
    villain_amt = call_amount if villain_amount is None else float(villain_amount)
    final_pot = float(pot_before) + float(call_amount) + float(villain_amt)
    rake = min(float(rake_percent) * final_pot, float(rake_cap))
    post_rake_pot = final_pot - rake

    def to_ev(value: float) -> float:
        if pd.isna(value):
            return float('nan')
        return (float(value) / 100.0) * post_rake_pot - float(call_amount)

    return equity_df.map(to_ev)


def derive_ev_inputs(scenario_data: dict) -> tuple[float, float | None, float, float, float]:
    effective_stack = float(scenario_data.get('assumed_effective_stack_bb') or 0.0)
    avg_bet_total = float(scenario_data.get('avg_bet_bb') or 0.0)
    avg_bet_added = float(scenario_data.get('avg_bet_added_bb') or 0.0)

    call_amount_raw = scenario_data.get('call_amount_bb')
    call_amount = float(call_amount_raw) if call_amount_raw is not None else 0.0
    if avg_bet_added > 0:
        if call_amount <= 0:
            call_amount = avg_bet_added
        else:
            call_amount = min(call_amount, avg_bet_added)
    elif avg_bet_total > 0:
        if call_amount <= 0:
            call_amount = avg_bet_total
        else:
            call_amount = min(call_amount, avg_bet_total)
    if effective_stack > 0 and call_amount > effective_stack:
        call_amount = effective_stack

    villain_amount_raw = scenario_data.get('villain_amount_bb')
    villain_amount = float(villain_amount_raw) if villain_amount_raw is not None else None
    if villain_amount is None or villain_amount <= 0:
        base_amount = call_amount if call_amount > 0 else (
            avg_bet_added if avg_bet_added > 0 else avg_bet_total
        )
        villain_amount = base_amount if base_amount and base_amount > 0 else None

    avg_pot_before = float(scenario_data.get('avg_pot_before_bb') or 0.0)
    pot_before = float(scenario_data.get('pot_before_bb') or 0.0)
    scale_denominator = avg_bet_added if avg_bet_added > 0 else (
        avg_bet_total if avg_bet_total > 0 else None
    )
    if call_amount > 0 and scale_denominator:
        scale_factor = call_amount / scale_denominator
        if pot_before <= 0 or abs(pot_before - avg_pot_before) < 1e-6:
            pot_before = avg_pot_before * scale_factor
    elif pot_before <= 0:
        pot_before = avg_pot_before

    rake_percent = float(scenario_data.get('rake_percent', 0.05))
    rake_cap = float(scenario_data.get('rake_cap_bb', 10.0))
    return call_amount, villain_amount, pot_before, rake_percent, rake_cap


def _apply_cell_sizes(styler: pd.io.formats.style.Styler) -> pd.io.formats.style.Styler:
    cell_props = {
        'width': '30px',
        'height': '30px',
        'min-width': '30px',
        'max-width': '30px',
        'min-height': '30px',
        'max-height': '30px',
        'padding': '0px',
        'line-height': '30px',
        'text-align': 'center',
        'font-size': '9px',
        'white-space': 'nowrap',
        'overflow': 'hidden',
    }
    styler = styler.set_properties(**cell_props)
    table_styles = [
        {
            'selector': 'table',
            'props': [
                ('border-collapse', 'collapse'),
                ('table-layout', 'fixed'),
                ('width', 'auto !important'),
                ('max-width', 'none !important'),
                ('display', 'inline-block !important'),
                ('margin', '0'),
                ('border-spacing', '0'),
            ],
        },
        {
            'selector': 'thead th',
            'props': [
                ('width', '30px !important'),
                ('height', '30px !important'),
                ('min-width', '30px !important'),
                ('max-width', '30px !important'),
                ('min-height', '30px !important'),
                ('max-height', '30px !important'),
                ('box-sizing', 'border-box'),
                ('padding', '0px !important'),
                ('line-height', '30px'),
                ('text-align', 'center'),
                ('font-size', '9px'),
                ('white-space', 'nowrap'),
                ('overflow', 'hidden'),
            ],
        },
        {
            'selector': 'tbody th',
            'props': [
                ('width', '30px !important'),
                ('height', '30px !important'),
                ('min-width', '30px !important'),
                ('max-width', '30px !important'),
                ('min-height', '30px !important'),
                ('max-height', '30px !important'),
                ('box-sizing', 'border-box'),
                ('padding', '0px !important'),
                ('line-height', '30px'),
                ('text-align', 'center'),
                ('font-size', '9px'),
                ('white-space', 'nowrap'),
                ('overflow', 'hidden'),
            ],
        },
        {
            'selector': 'td',
            'props': [
                ('width', '30px !important'),
                ('height', '30px !important'),
                ('min-width', '30px !important'),
                ('max-width', '30px !important'),
                ('min-height', '30px !important'),
                ('max-height', '30px !important'),
                ('box-sizing', 'border-box'),
                ('padding', '0px !important'),
                ('line-height', '30px'),
                ('text-align', 'center'),
                ('font-size', '9px'),
                ('white-space', 'nowrap'),
                ('overflow', 'hidden'),
            ],
        },
    ]
    styler = styler.set_table_styles(table_styles, overwrite=False)
    return styler.set_table_attributes('style="border-collapse:collapse;table-layout:fixed;width:auto;display:inline-block;"')


def style_equity_grid(df: pd.DataFrame, title: str):
    values = df.values.flatten()
    finite = values[~pd.isna(values)]
    if finite.size == 0:
        return None
    gt50 = finite[finite > 50]
    lt50 = finite[finite < 50]
    max_green = float(gt50.max()) if gt50.size else 50.0
    min_red = float(lt50.min()) if lt50.size else 50.0

    def apply_color(val: float):
        return _equity_color(val, min_red, max_green)

    styled = (
        df.style
        .format('{:.1f}')
        .map(apply_color)
        .set_caption(title)
    )
    return _apply_cell_sizes(styled)


def style_ev_grid(df: pd.DataFrame, title: str):
    values = df.values.flatten()
    finite = values[~pd.isna(values)]
    if finite.size == 0:
        return None
    positives = finite[finite > 0]
    negatives = finite[finite < 0]
    max_green = float(positives.max()) if positives.size else 0.0
    min_red = float(negatives.min()) if negatives.size else 0.0

    def apply_color(val: float):
        return _ev_color(val, min_red, max_green)

    styled = (
        df.style
        .format('{:.2f}')
        .map(apply_color)
        .set_caption(title)
    )
    return _apply_cell_sizes(styled)


def display_equity_tables(scenario_key: str, scenario_label: str):
    if equity_results is None:
        return
    scenario_data = equity_results.get(scenario_key)
    if not scenario_data:
        print(f'No equity data cached for {scenario_label}.')
        return

    sections = []

    equity_df = build_equity_grid(scenario_data)
    equity_title = f"{scenario_label} Equity"
    equity_styled = style_equity_grid(equity_df, equity_title)
    if equity_styled is not None:
        sections.append(equity_styled.to_html())

    call_amount, villain_amount, pot_before, rake_percent, rake_cap = derive_ev_inputs(scenario_data)
    include_ev = scenario_key not in {'three_bet_shove', 'four_bet_shove', 'five_plus_bet_shove'}
    if include_ev and call_amount > 0 and pot_before is not None:
        ev_df = compute_ev_frame(
            equity_df,
            call_amount=call_amount,
            villain_amount=villain_amount,
            pot_before=pot_before,
            rake_percent=rake_percent,
            rake_cap=rake_cap,
        )
        ev_title = f"{scenario_label} EV (bb)"
        ev_styled = style_ev_grid(ev_df, ev_title)
        if ev_styled is not None:
            sections.append(ev_styled.to_html())

    if sections:
        container = ("<div style='display:flex;flex-direction:row;flex-wrap:wrap;gap:12px;align-items:flex-start;'>"
            + ''.join(sections)
            + "</div>")
        display(HTML(container))
        display(HTML("<hr style='margin:28px 0;border:0;border-top:1px solid #cbd5f5;'>"))

# %%
if equity_results is not None:
    for key, label in EQUITY_SCENARIOS:
        display_equity_tables(key, label)
# Out:
# <div style='display:flex;flex-direction:row;flex-wrap:wrap;gap:12px;align-items:flex-start;'><style type="text/css">
# #T_7f3b2 table {
#   border-collapse: collapse;
#   table-layout: fixed;
#   width: auto !important;
#   max-width: none !important;
#   display: inline-block !important;
#   margin: 0;
#   border-spacing: 0;
# }
# #T_7f3b2 thead th {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2 tbody th {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2 td {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col0 {
#   background-color: rgb(21, 128, 61);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col1, #T_7f3b2_row4_col4 {
#   background-color: rgb(133, 189, 154);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col2 {
#   background-color: rgb(164, 205, 179);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col3 {
#   background-color: rgb(173, 210, 187);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col4 {
#   background-color: rgb(189, 219, 200);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col5 {
#   background-color: rgb(213, 232, 220);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col6 {
#   background-color: rgb(217, 234, 223);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col7, #T_7f3b2_row10_col10 {
#   background-color: rgb(235, 244, 238);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col8 {
#   background-color: rgb(242, 248, 244);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col9, #T_7f3b2_row1_col4 {
#   background-color: rgb(241, 247, 243);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col10 {
#   background-color: rgb(246, 250, 248);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col11 {
#   background-color: rgb(248, 251, 249);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row0_col12 {
#   background-color: rgb(252, 253, 252);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row1_col0 {
#   background-color: rgb(141, 193, 160);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row1_col1 {
#   background-color: rgb(65, 152, 98);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row1_col2 {
#   background-color: rgb(216, 233, 222);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row1_col3 {
#   background-color: rgb(225, 239, 230);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row1_col5 {
#   background-color: rgb(252, 245, 245);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row1_col6 {
#   background-color: rgb(246, 228, 228);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row1_col7 {
#   background-color: rgb(244, 220, 220);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row1_col8 {
#   background-color: rgb(239, 203, 203);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row1_col9, #T_7f3b2_row4_col6 {
#   background-color: rgb(235, 190, 190);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_7f3b2_row1_col10 {
#   background-color: rgb(231, 179, 179);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width:
# <hr style='margin:28px 0;border:0;border-top:1px solid #cbd5f5;'>
# <div style='display:flex;flex-direction:row;flex-wrap:wrap;gap:12px;align-items:flex-start;'><style type="text/css">
# #T_109cc table {
#   border-collapse: collapse;
#   table-layout: fixed;
#   width: auto !important;
#   max-width: none !important;
#   display: inline-block !important;
#   margin: 0;
#   border-spacing: 0;
# }
# #T_109cc thead th {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc tbody th {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc td {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col0 {
#   background-color: rgb(21, 128, 61);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col1 {
#   background-color: rgb(172, 210, 186);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col2 {
#   background-color: rgb(187, 218, 198);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col3 {
#   background-color: rgb(203, 227, 212);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col4, #T_109cc_row7_col7 {
#   background-color: rgb(237, 245, 240);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col5 {
#   background-color: rgb(253, 254, 254);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col6 {
#   background-color: rgb(251, 243, 243);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col7 {
#   background-color: rgb(245, 223, 223);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col8 {
#   background-color: rgb(243, 217, 217);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col9 {
#   background-color: rgb(242, 214, 214);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col10 {
#   background-color: rgb(241, 211, 211);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col11 {
#   background-color: rgb(236, 194, 194);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row0_col12, #T_109cc_row3_col1 {
#   background-color: rgb(239, 205, 205);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row1_col0 {
#   background-color: rgb(175, 211, 189);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row1_col1 {
#   background-color: rgb(99, 170, 126);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row1_col2 {
#   background-color: rgb(254, 254, 254);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row1_col3 {
#   background-color: rgb(247, 229, 229);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row1_col4 {
#   background-color: rgb(250, 239, 239);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row1_col5 {
#   background-color: rgb(239, 204, 204);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row1_col6, #T_109cc_row1_col7 {
#   background-color: rgb(234, 187, 187);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row1_col8 {
#   background-color: rgb(233, 184, 184);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row1_col9 {
#   background-color: rgb(229, 172, 172);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_109cc_row1_col10 {
#   background-color: rgb(227, 167, 167);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 3
# <hr style='margin:28px 0;border:0;border-top:1px solid #cbd5f5;'>
# <div style='display:flex;flex-direction:row;flex-wrap:wrap;gap:12px;align-items:flex-start;'><style type="text/css">
# #T_3c7a6 table {
#   border-collapse: collapse;
#   table-layout: fixed;
#   width: auto !important;
#   max-width: none !important;
#   display: inline-block !important;
#   margin: 0;
#   border-spacing: 0;
# }
# #T_3c7a6 thead th {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6 tbody th {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6 td {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row0_col0 {
#   background-color: rgb(21, 128, 61);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row0_col1 {
#   background-color: rgb(180, 214, 193);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row0_col2 {
#   background-color: rgb(205, 228, 214);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row0_col3 {
#   background-color: rgb(222, 237, 227);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row0_col4 {
#   background-color: rgb(235, 244, 238);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row0_col5 {
#   background-color: rgb(251, 243, 243);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row0_col6 {
#   background-color: rgb(250, 239, 239);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row0_col7 {
#   background-color: rgb(248, 232, 232);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row0_col8, #T_3c7a6_row0_col10 {
#   background-color: rgb(240, 207, 207);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row0_col9 {
#   background-color: rgb(246, 226, 226);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row0_col11 {
#   background-color: rgb(237, 196, 196);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row0_col12 {
#   background-color: rgb(230, 175, 175);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row1_col0 {
#   background-color: rgb(184, 216, 196);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row1_col1 {
#   background-color: rgb(83, 161, 112);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row1_col2 {
#   background-color: rgb(253, 250, 250);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row1_col3 {
#   background-color: rgb(245, 224, 224);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row1_col4 {
#   background-color: rgb(242, 215, 215);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row1_col5, #T_3c7a6_row11_col11 {
#   background-color: rgb(239, 203, 203);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row1_col6, #T_3c7a6_row9_col0 {
#   background-color: rgb(233, 185, 185);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row1_col7, #T_3c7a6_row2_col5 {
#   background-color: rgb(232, 182, 182);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row1_col8 {
#   background-color: rgb(229, 173, 173);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row1_col9 {
#   background-color: rgb(225, 157, 157);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_3c7a6_row1_col10 {
#   background-color: rgb(226, 161, 161);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width:
# <hr style='margin:28px 0;border:0;border-top:1px solid #cbd5f5;'>
# <div style='display:flex;flex-direction:row;flex-wrap:wrap;gap:12px;align-items:flex-start;'><style type="text/css">
# #T_bb862 table {
#   border-collapse: collapse;
#   table-layout: fixed;
#   width: auto !important;
#   max-width: none !important;
#   display: inline-block !important;
#   margin: 0;
#   border-spacing: 0;
# }
# #T_bb862 thead th {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862 tbody th {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862 td {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col0 {
#   background-color: rgb(21, 128, 61);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col1 {
#   background-color: rgb(210, 230, 218);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col2 {
#   background-color: rgb(253, 254, 254);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col3 {
#   background-color: rgb(248, 232, 232);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col4 {
#   background-color: rgb(243, 218, 218);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col5 {
#   background-color: rgb(231, 179, 179);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col6, #T_bb862_row1_col4 {
#   background-color: rgb(228, 169, 169);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col7, #T_bb862_row2_col1 {
#   background-color: rgb(228, 168, 168);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col8, #T_bb862_row12_col12 {
#   background-color: rgb(226, 161, 161);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col9, #T_bb862_row4_col5 {
#   background-color: rgb(224, 155, 155);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col10, #T_bb862_row5_col0 {
#   background-color: rgb(223, 153, 153);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col11, #T_bb862_row3_col2 {
#   background-color: rgb(221, 145, 145);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row0_col12 {
#   background-color: rgb(220, 144, 144);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row1_col0 {
#   background-color: rgb(214, 232, 221);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row1_col1 {
#   background-color: rgb(91, 166, 119);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row1_col2 {
#   background-color: rgb(237, 197, 197);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row1_col3 {
#   background-color: rgb(234, 187, 187);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row1_col5 {
#   background-color: rgb(224, 156, 156);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row1_col6 {
#   background-color: rgb(220, 141, 141);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row1_col7, #T_bb862_row2_col5 {
#   background-color: rgb(220, 142, 142);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row1_col8 {
#   background-color: rgb(215, 128, 128);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row1_col9, #T_bb862_row5_col6 {
#   background-color: rgb(217, 131, 131);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_bb862_row1_col10, #T_bb862_row4_col7, #T_
# <hr style='margin:28px 0;border:0;border-top:1px solid #cbd5f5;'>
# <div style='display:flex;flex-direction:row;flex-wrap:wrap;gap:12px;align-items:flex-start;'><style type="text/css">
# #T_e5425 table {
#   border-collapse: collapse;
#   table-layout: fixed;
#   width: auto !important;
#   max-width: none !important;
#   display: inline-block !important;
#   margin: 0;
#   border-spacing: 0;
# }
# #T_e5425 thead th {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425 tbody th {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425 td {
#   width: 30px !important;
#   height: 30px !important;
#   min-width: 30px !important;
#   max-width: 30px !important;
#   min-height: 30px !important;
#   max-height: 30px !important;
#   box-sizing: border-box;
#   padding: 0px !important;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row0_col0 {
#   background-color: rgb(21, 128, 61);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row0_col1 {
#   background-color: rgb(234, 244, 238);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row0_col2 {
#   background-color: rgb(244, 220, 220);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row0_col3 {
#   background-color: rgb(238, 201, 201);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row0_col4 {
#   background-color: rgb(231, 177, 177);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row0_col5, #T_e5425_row0_col6 {
#   background-color: rgb(223, 153, 153);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row0_col7 {
#   background-color: rgb(223, 154, 154);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row0_col8, #T_e5425_row12_col12 {
#   background-color: rgb(219, 138, 138);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row0_col9 {
#   background-color: rgb(222, 150, 150);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row0_col10 {
#   background-color: rgb(221, 144, 144);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row0_col11 {
#   background-color: rgb(220, 143, 143);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row0_col12 {
#   background-color: rgb(218, 137, 137);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row1_col0 {
#   background-color: rgb(250, 252, 251);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row1_col1 {
#   background-color: rgb(123, 183, 145);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row1_col2 {
#   background-color: rgb(228, 169, 169);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row1_col3 {
#   background-color: rgb(221, 146, 146);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row1_col4 {
#   background-color: rgb(220, 142, 142);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row1_col5 {
#   background-color: rgb(213, 119, 119);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row1_col6 {
#   background-color: rgb(211, 114, 114);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row1_col7 {
#   background-color: rgb(209, 108, 108);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row1_col8 {
#   background-color: rgb(213, 118, 118);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row1_col9 {
#   background-color: rgb(212, 116, 116);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height: 30px;
#   padding: 0px;
#   line-height: 30px;
#   text-align: center;
#   font-size: 9px;
#   white-space: nowrap;
#   overflow: hidden;
# }
# #T_e5425_row1_col10 {
#   background-color: rgb(208, 102, 102);
#   width: 30px;
#   height: 30px;
#   min-width: 30px;
#   max-width: 30px;
#   min-height: 30px;
#   max-height
# <hr style='margin:28px 0;border:0;border-top:1px solid #cbd5f5;'>
